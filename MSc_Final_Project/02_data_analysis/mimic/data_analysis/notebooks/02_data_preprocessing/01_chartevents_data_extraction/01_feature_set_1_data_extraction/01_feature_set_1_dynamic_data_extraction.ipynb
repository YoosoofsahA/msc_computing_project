# %% [markdown]
# # **Time series data extraction for feature set 1**
#
# Feature set 1 is defined as the features that are the most popular from literature and clinically available, with the WAVE study used as a proxy.
#
# For all patients in the derived set, time series data for each of these features will be extracted from the chart events table.
#
# The data will then be observed, cleaned and pre-processed as required to train an LSTM model.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
# Extract id, extubation starttime and annotation columns from patient data
patient_df = patient_df[['subject_id', 'extubation_starttime', 'extubation_failure']]
patient_df.head()
# Out:
#     subject_id extubation_starttime  extubation_failure
# 0     10001884  2131-01-12 17:40:00                   1
# 22    10002428  2156-04-22 17:10:00                   0
# 29    10004235  2196-02-27 16:28:00                   1
# 32    10004720  2186-11-17 14:00:00                   1
# 33    10004733  2174-12-07 16:20:00                   0

# %%
# Initialize a dictionary to hold the null counts
null_counts = {
    'subject_id': 0,
    'charttime': 0,
    'itemid': 0,
    'valuenum': 0
}

# %%
chartevents_path = '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/mimic-iv-2.2-raw-data/icu/chartevents.csv'

# %%
# Read in chartevents file into pandas and process in chunks and count null values
chartevents_path = '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/mimic-iv-2.2-raw-data/icu/chartevents.csv'

processed_rows = 0

for chunk in pd.read_csv(chartevents_path, chunksize=100000, parse_dates=['charttime']):
  # Filter the columns
    chunk = chunk[['subject_id', 'charttime', 'itemid', 'valuenum']].copy()

    # Convert subject_id to nullable integer type if necessary
    chunk.loc[:, 'subject_id'] = chunk['subject_id'].astype('Int64')

    # Count the null values in the current chunk
    chunk_null_counts = chunk.isnull().sum()

    # Aggregate the null counts
    for column in null_counts:
        null_counts[column] += chunk_null_counts[column]

    processed_rows += len(chunk)

    if processed_rows % 1000000 == 0:
        print(f"Processed {processed_rows} rows")

# Print the results
for column, count in null_counts.items():
    print(f"Column '{column}': {count} null values")
# Out:
# Processed 1000000 rows
# Processed 2000000 rows
# Processed 3000000 rows
# Processed 4000000 rows
# Processed 5000000 rows
# Processed 6000000 rows
# Processed 7000000 rows
# Processed 8000000 rows
# Processed 9000000 rows
# Processed 10000000 rows
# Processed 11000000 rows
# Processed 12000000 rows
# Processed 13000000 rows
# Processed 14000000 rows
# Processed 15000000 rows
# Processed 16000000 rows
# Processed 17000000 rows
# Processed 18000000 rows
# Processed 19000000 rows
# Processed 20000000 rows
# Processed 21000000 rows
# Processed 22000000 rows
# Processed 23000000 rows
# Processed 24000000 rows
# Processed 25000000 rows
# Processed 26000000 rows
# Processed 27000000 rows
# Processed 28000000 rows
# Processed 29000000 rows
# Processed 30000000 rows
# Processed 31000000 rows
# Processed 32000000 rows
# Processed 33000000 rows
# Processed 34000000 rows
# Processed 35000000 rows
# Processed 36000000 rows
# Processed 37000000 rows
# Processed 38000000 rows
# Processed 39000000 rows
# Processed 40000000 rows
# Processed 41000000 rows
# Processed 42000000 rows
# Processed 43000000 rows
# Processed 44000000 rows
# Processed 45000000 rows
# Processed 46000000 rows
# Processed 47000000 rows
# Processed 48000000 rows
# Processed 49000000 rows
# Processed 50000000 rows
# Processed 51000000 rows
# Processed 52000000 rows
# Processed 53000000 rows
# Processed 54000000 rows
# Processed 55000000 rows
# Processed 56000000 rows
# Processed 57000000 rows
# Processed 58000000 rows
# Processed 59000000 rows
# Processed 60000000 rows
# Processed 61000000 rows
# Processed 62000000 rows
# Processed 63000000 rows
# Processed 64000000 rows
# Processed 65000000 rows
# Processed 66000000 rows
# Processed 67000000 rows
# Processed 68000000 rows
# Processed 69000000 rows
# Processed 70000000 rows
# Processed 71000000 rows
# Processed 72000000 rows
# Processed 73000000 rows
# Processed 74000000 rows
# Processed 75000000 rows
# Processed 76000000 rows
# Processed 77000000 rows
# Processed 78000000 rows
# Processed 79000000 rows
# Processed 80000000 rows
# Processed 81000000 rows
# Processed 82000000 rows
# Processed 83000000 rows
# Processed 84000000 rows
# Processed 85000000 rows
# Processed 86000000 rows
# Processed 87000000 rows
# Processed 88000000 rows
# Processed 89000000 rows
# Processed 90000000 rows
# Processed 91000000 rows
# Processed 92000000 rows
# Processed 93000000 rows
# Processed 94000000 rows
# Processed 95000000 rows
# Processed 96000000 rows
# Processed 97000000 rows
# Processed 98000000 rows
# Processed 99000000 rows
# Processed 100000000 rows
# Processed 101000000 rows
# Processed 102000000 rows
# Processed 103000000 rows
# Processed 104000000 rows
# Processed 105000000 rows
# Processed 106000000 rows
# Processed 107000000 rows
# Processed 108000000 rows
# Processed 109000000 rows
# Processed 110000000 rows
# Processed 111000000 rows
# Processed 112000000 rows
# Processed 113000000 rows
# Processed 114000000 rows
# Processed 115000000 rows
# Processed 116000000 rows
# Processed 117000000 rows
# Processed 118000000 rows
# Processed 119000000 rows
# Processed 120000000 rows
# Processed 121000000 rows
# Processed 122000000 rows
# Processed 123000000 rows
# Processed 124000000 rows
# Processed 125000000 rows
# Processed 126000000 rows
# Processed 127000000 rows
# Processed 128000000 rows
# Processed 129000000 rows
# Processed 130000000 rows
# Processed 131000000 rows
# Processed 132000000 rows
# Processed 133000000 rows
# Processed 134000000 rows
# Processed 135000000 rows
# Processed 136000000 rows
# Processed 137000000 rows
# Processed 138000000 rows
# Processed 139000000 rows
# Processed 140000000 rows
# Processed 141000000 rows
# Processed 142000000 rows
# Processed 143000000 rows
# Processed 144000000 rows
# Processed 145000000 rows
# Processed 146000000 rows
# Processed 147000000 rows
# Processed 148000000 rows
# Processed 149000000 rows
# Processed 150000000 rows
# Processed 151000000 rows
# Processed 152000000 rows
# Processed 153000000 rows
# Processed 154000000 rows
# Processed 155000000 rows
# Processed 156000000 rows
# Processed 157000000 rows
# Processed 158000000 rows
# Processed 159000000 rows
# Processed 160000000 rows
# Processed 161000000 rows
# Processed 162000000 rows
# Processed 163000000 rows
# Processed 164000000 rows
# Processed 165000000 rows
# Processed 166000000 rows
# Processed 167000000 rows
# Processed 168000000 rows
# Processed 169000000 rows
# Processed 170000000 rows
# Processed 171000000 rows
# Processed 172000000 rows
# Processed 173000000 rows
# Processed 174000000 rows
# Processed 175000000 rows
# Processed 176000000 rows
# Processed 177000000 rows
# Processed 178000000 rows
# Processed 179000000 rows
# Processed 180000000 rows
# Processed 181000000 rows
# Processed 182000000 rows
# Processed 183000000 rows
# Processed 184000000 rows
# Processed 185000000 rows
# Processed 186000000 rows
# Processed 187000000 rows
# Processed 188000000 rows
# Processed 189000000 rows
# Processed 190000000 rows
# Processed 191000000 rows
# Processed 192000000 rows
# Processed 193000000 rows
# Processed 194000000 rows
# Processed 195000000 rows
# Processed 196000000 rows
# Processed 197000000 rows
# Processed 198000000 rows
# Processed 199000000 rows
# Processed 200000000 rows
# Processed 201000000 rows
# Processed 202000000 rows
# Processed 203000000 rows
# Processed 204000000 rows
# Processed 205000000 rows
# Processed 206000000 rows
# Processed 207000000 rows
# Processed 208000000 rows
# Processed 209000000 rows
# Processed 210000000 rows
# Processed 211000000 rows
# Processed 212000000 rows
# Processed 213000000 rows
# Processed 214000000 rows
# Processed 215000000 rows
# Processed 216000000 rows
# Processed 217000000 rows
# Processed 218000000 rows
# Processed 219000000 rows
# Processed 220000000 rows
# Processed 221000000 rows
# Processed 222000000 rows
# Processed 223000000 rows
# Processed 224000000 rows
# Processed 225000000 rows
# Processed 226000000 rows
# Processed 227000000 rows
# Processed 228000000 rows
# Processed 229000000 rows
# Processed 230000000 rows
# Processed 231000000 rows
# Processed 232000000 rows
# Processed 233000000 rows
# Processed 234000000 rows
# Processed 235000000 rows
# Processed 236000000 rows
# Processed 237000000 rows
# Processed 238000000 rows
# Processed 239000000 rows
# Processed 240000000 rows
# Processed 241000000 rows
# Processed 242000000 rows
# Processed 243000000 rows
# Processed 244000000 rows
# Processed 245000000 rows
# Processed 246000000 rows
# Processed 247000000 rows
# Processed 248000000 rows
# Column 'subject_id': 0 null values
# Column 'charttime': 0 null values
# Column 'itemid': 1 null values
# Column 'valuenum': 185521099 null values

# %%
# Print the results
for column, count in null_counts.items():
    print(f"Column '{column}': {count} null values")
# Out:
# Column 'subject_id': 0 null values
# Column 'charttime': 0 null values
# Column 'itemid': 1 null values
# Column 'valuenum': 185521099 null values

# %% [markdown]
# Now trying to execute task to extract data.

# %%
from datetime import timedelta

# %%
def extract_patient_data(patient_df, chartevents_file_path, features, time_window):
  results = []

  chunksize = 100000

  features_set = set(features)

  processed_rows = 0

  # Read and process file in chunks
  for chunk in pd.read_csv(chartevents_file_path, chunksize=chunksize, parse_dates=['charttime']):
    # Filter the columns
    chunk = chunk[['subject_id', 'charttime', 'itemid', 'valuenum']].copy()

    # Drop rows where itemid or valuenum is null
    chunk = chunk.dropna(subset=['itemid', 'valuenum'])

    # Convert subject_id to nullable integer type if necessary
    chunk.loc[:, 'subject_id'] = chunk['subject_id'].astype('Int64')

    # Filter by itemid
    chunk = chunk[chunk['itemid'].isin(features_set)]

    # Merge with patient_df to get the extubation_starttime and extubation_failure columns
    merged = pd.merge(chunk, patient_df, on='subject_id', how='inner')

    # Filter by time window
    merged = merged[(merged['charttime'] >= merged['extubation_starttime'] - time_window)
              & (merged['charttime'] <= merged['extubation_starttime'])]

    results.append(merged)

    processed_rows += len(chunk)

    if processed_rows % 10000 == 0:
        print(f"Processed {processed_rows} rows")


  results_df = pd.concat(results)

  # Extract the data and labels
  data = result_df[['subject_id', 'charttime', 'itemid', 'valuenum']]
  labels = result_df[['subject_id', 'extubation_starttime', 'extubation_failure']]

  return data, labels

# %%
# State the features to be extracted
feature_set_1_dynamic = [220210, 220277, 228640, 220235, 223830, 220224,
                         220228, 223835, 224685, 224686, 224695, 224687, 224696, 223849, 224419]

# %%
chartevents_path
# Out:
# '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/mimic-iv-2.2-raw-data/icu/chartevents.csv'

# %%
time_window_hours = timedelta(hours=6)

# %%
# Test out on patient file
data, labels = extract_patient_data(patient_df, chartevents_path, feature_set_1_dynamic, time_window_hours)

print(data.head())
print(labels.head())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-d8a6d4137467> in <cell line: 2>()
#       1 # Test out on patient file
# ----> 2 data, labels = extract_patient_data(patient_df, chartevents_path, feature_set_1_dynamic, time_window_hours)
#       3
#       4 print(data.head())
#       5 print(labels.head())
#
# <ipython-input-31-020738b96e6c> in extract_patient_data(patient_df, chartevents_file_path, features, time_window)
#       9
#      10   # Read and process file in chunks
# ---> 11   for chunk in pd.read_csv(chartevents_file_path, chunksize=chunksize, parse_dates=['charttime']):
#      12     # Filter the columns
#      13     chunk = chunk[['subject_id', 'charttime', 'itemid', 'valuenum']].copy()
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __next__(self)
#    1622     def __next__(self) -> DataFrame:
#    1623         try:
# -> 1624             return self.get_chunk()
#    1625         except StopIteration:
#    1626             self.close()
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in get_chunk(self, size)
#    1731                 raise StopIteration
#    1732             size = min(size, self.nrows - self._currow)
# -> 1733         return self.read(nrows=size)
#    1734
#    1735     def __enter__(self) -> TextFileReader:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1702                     columns,
#    1703                     col_dict,
# -> 1704                 ) = self._engine.read(  # type: ignore[attr-defined]
#    1705                     nrows
#    1706                 )
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     232         try:
#     233             if self.low_memory:
# --> 234                 chunks = self._reader.read_low_memory(nrows)
#     235                 # destructive to chunks
#     236                 data = _concatenate_chunks(chunks)
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/common.py in is_extension_array_dtype(arr_or_dtype)
#    1333
#    1334
# -> 1335 def is_extension_array_dtype(arr_or_dtype) -> bool:
#    1336     """
#    1337     Check if an object is a pandas extension array type.
#
# KeyboardInterrupt:

# %% [markdown]
# Merging is slow so will try without merging and filtering directly.

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.4)

# %%
from tqdm import tqdm

# %%
# Test on patient set
data, labels = extract_patient_data_2(patient_df, chartevents_path, feature_set_1_dynamic, time_window_hours)

print(data.head())
print(labels.head())
# Out:
# 1
# 3
# 4
# 5
# 6
# New chunk
# New chunk
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-62-8f8aa73212be> in <cell line: 2>()
#       1 # Test on patient set
# ----> 2 data, labels = extract_patient_data_2(patient_df, chartevents_path, feature_set_1_dynamic, time_window_hours)
#       3
#       4 print(data.head())
#       5 print(labels.head())
#
# <ipython-input-61-72d8c5305931> in extract_patient_data_2(patient_df, chartevents_file_path, itemids, time_window)
#      26
#      27     # Read and process the file in chunks
# ---> 28     for chunk in pd.read_csv(chartevents_file_path, parse_dates=['charttime'], chunksize=chunksize):
#      29
#      30       print('New chunk')
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __next__(self)
#    1622     def __next__(self) -> DataFrame:
#    1623         try:
# -> 1624             return self.get_chunk()
#    1625         except StopIteration:
#    1626             self.close()
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in get_chunk(self, size)
#    1731                 raise StopIteration
#    1732             size = min(size, self.nrows - self._currow)
# -> 1733         return self.read(nrows=size)
#    1734
#    1735     def __enter__(self) -> TextFileReader:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1702                     columns,
#    1703                     col_dict,
# -> 1704                 ) = self._engine.read(  # type: ignore[attr-defined]
#    1705                     nrows
#    1706                 )
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     232         try:
#     233             if self.low_memory:
# --> 234                 chunks = self._reader.read_low_memory(nrows)
#     235                 # destructive to chunks
#     236                 data = _concatenate_chunks(chunks)
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %%
print(data.head())
print(labels.head())
# Out:
#    subject_id           charttime  itemid  valuenum
# 0    10001884 2131-01-12 15:00:00  223835      40.0
# 1    10001884 2131-01-12 15:00:00  224685     284.0
# 2    10001884 2131-01-12 15:00:00  224686     284.0
# 3    10001884 2131-01-12 15:00:00  224687       6.1
# 4    10001884 2131-01-12 15:00:00  224695      17.0
#    subject_id  extubation_failure
# 0    10001884                   1
# 1    10001884                   1
# 2    10001884                   1
# 3    10001884                   1
# 4    10001884                   1

# %%
def process_chunk_2(chunk, patient_dict, itemid_set, time_window):
    # Filter the columns
    chunk = chunk[['subject_id', 'charttime', 'itemid', 'valuenum']].copy()

    # Drop rows where itemid or valuenum is null
    chunk = chunk.dropna(subset=['itemid', 'valuenum'])

    # Convert subject_id to nullable integer type if necessary
    chunk.loc[:, 'subject_id'] = chunk['subject_id'].astype('Int64')

    # Filter by subject_id
    chunk = chunk[chunk['subject_id'].isin(patient_dict.keys())]

    # Filter by itemid
    chunk = chunk[chunk['itemid'].isin(itemid_set)]

    # Apply the time window filter using the patient_dict
    filtered_rows = []
    for idx, row in chunk.iterrows():
        extubation_time = patient_dict[row['subject_id']]['extubation_starttime']
        if (row['charttime'] >= extubation_time - time_window) and (row['charttime'] <= extubation_time):
            filtered_rows.append(row)

    filtered_df = pd.DataFrame(filtered_rows)
    if not filtered_df.empty:
        filtered_df['extubation_starttime'] = filtered_df['subject_id'].map(lambda x: patient_dict[x]['extubation_starttime'])
        filtered_df['extubation_failure'] = filtered_df['subject_id'].map(lambda x: patient_dict[x]['extubation_failure'])

    return filtered_df

# %%
def extract_patient_data_2(patient_df, chartevents_file_path, itemids, time_window):
    # Initialize a list to hold the results
    results = []

    # Define the chunk size
    chunksize = 100000

    # Convert itemids to a set for faster lookup
    itemid_set = set(itemids)

    # Convert patient_df to a dictionary for fast lookups
    patient_dict = patient_df.set_index('subject_id').to_dict('index')

    # # Get the total number of rows in the file
    # total_rows = sum(1 for row in open(chartevents_file_path)) - 1  # Subtract 1 for the header row


    # Track the number of processed rows
    processed_rows = 0

    # Read and process the file in chunks
    for chunk in pd.read_csv(chartevents_file_path, parse_dates=['charttime'], chunksize=chunksize):

      # Process each chunk and filter the data
      filtered_df = process_chunk_2(chunk, patient_dict, itemid_set, time_window)

      # Append the filtered data to the results list
      results.append(filtered_df)

      # Update the processed rows count
      processed_rows += len(chunk)

      # Print the progress every 100,000 rows
      if processed_rows % 10000000 == 0:
          print(f"Processed {processed_rows} rows")


    # Concatenate all the results
    result_df = pd.concat(results, ignore_index=True)

    # Check if result_df is empty and handle it accordingly
    if result_df.empty:
        print("Warning: No data found for the given criteria.")
        return pd.DataFrame(), pd.DataFrame() # Return empty DataFrames


    # Extract the data and labels
    data = result_df[['subject_id', 'charttime', 'itemid', 'valuenum']]
    labels = result_df[['subject_id','extubation_failure']]

    return data, labels

# %%
# Now can run this for all patient files
patient_chunk_files = [f'/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/03_annotated_set/final_set_split_files/patient_chunk_{i}.parquet' for i in range(10)]

output_dir = '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/05_time_series_data_preprocessing/feature_set_1_results'

# %%
for i, patient_file in enumerate(patient_chunk_files):
  print(f'Processing patient file {patient_file}')

  patient_df = pd.read_parquet(patient_file)

  data, labels = extract_patient_data_2(patient_df, chartevents_path, feature_set_1_dynamic, time_window_hours)

  data_file_path = f'{output_dir}/data_chunk_{i}.parquet'
  labels_file_path = f'{output_dir}/labels_chunk_{i}.parquet'

  data.to_parquet(data_file_path, index=False)
  labels.to_parquet(labels_file_path, index=False)

  print(f"Saved data and labels for patient file {i} to {output_dir}")

print("All files processed and saved.")
# Out:
# Streaming output truncated to the last 5000 lines.
# Processed 244800000 rows
# Processed 244900000 rows
# Processed 245000000 rows
# Processed 245100000 rows
# Processed 245200000 rows
# Processed 245300000 rows
# Processed 245400000 rows
# Processed 245500000 rows
# Processed 245600000 rows
# Processed 245700000 rows
# Processed 245800000 rows
# Processed 245900000 rows
# Processed 246000000 rows
# Processed 246100000 rows
# Processed 246200000 rows
# Processed 246300000 rows
# Processed 246400000 rows
# Processed 246500000 rows
# Processed 246600000 rows
# Processed 246700000 rows
# Processed 246800000 rows
# Processed 246900000 rows
# Processed 247000000 rows
# Processed 247100000 rows
# Processed 247200000 rows
# Processed 247300000 rows
# Processed 247400000 rows
# Processed 247500000 rows
# Processed 247600000 rows
# Processed 247700000 rows
# Processed 247800000 rows
# Processed 247900000 rows
# Processed 248000000 rows
# Processed 248100000 rows
# Saved data and labels for patient file 6 to /content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/05_time_series_data_preprocessing/feature_set_1_results
# Processing patient file /content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/03_annotated_set/final_set_split_files/patient_chunk_7.parquet
# Processed 100000 rows
# Processed 200000 rows
# Processed 300000 rows
# Processed 400000 rows
# Processed 500000 rows
# Processed 600000 rows
# Processed 700000 rows
# Processed 800000 rows
# Processed 900000 rows
# Processed 1000000 rows
# Processed 1100000 rows
# Processed 1200000 rows
# Processed 1300000 rows
# Processed 1400000 rows
# Processed 1500000 rows
# Processed 1600000 rows
# Processed 1700000 rows
# Processed 1800000 rows
# Processed 1900000 rows
# Processed 2000000 rows
# Processed 2100000 rows
# Processed 2200000 rows
# Processed 2300000 rows
# Processed 2400000 rows
# Processed 2500000 rows
# Processed 2600000 rows
# Processed 2700000 rows
# Processed 2800000 rows
# Processed 2900000 rows
# Processed 3000000 rows
# Processed 3100000 rows
# Processed 3200000 rows
# Processed 3300000 rows
# Processed 3400000 rows
# Processed 3500000 rows
# Processed 3600000 rows
# Processed 3700000 rows
# Processed 3800000 rows
# Processed 3900000 rows
# Processed 4000000 rows
# Processed 4100000 rows
# Processed 4200000 rows
# Processed 4300000 rows
# Processed 4400000 rows
# Processed 4500000 rows
# Processed 4600000 rows
# Processed 4700000 rows
# Processed 4800000 rows
# Processed 4900000 rows
# Processed 5000000 rows
# Processed 5100000 rows
# Processed 5200000 rows
# Processed 5300000 rows
# Processed 5400000 rows
# Processed 5500000 rows
# Processed 5600000 rows
# Processed 5700000 rows
# Processed 5800000 rows
# Processed 5900000 rows
# Processed 6000000 rows
# Processed 6100000 rows
# Processed 6200000 rows
# Processed 6300000 rows
# Processed 6400000 rows
# Processed 6500000 rows
# Processed 6600000 rows
# Processed 6700000 rows
# Processed 6800000 rows
# Processed 6900000 rows
# Processed 7000000 rows
# Processed 7100000 rows
# Processed 7200000 rows
# Processed 7300000 rows
# Processed 7400000 rows
# Processed 7500000 rows
# Processed 7600000 rows
# Processed 7700000 rows
# Processed 7800000 rows
# Processed 7900000 rows
# Processed 8000000 rows
# Processed 8100000 rows
# Processed 8200000 rows
# Processed 8300000 rows
# Processed 8400000 rows
# Processed 8500000 rows
# Processed 8600000 rows
# Processed 8700000 rows
# Processed 8800000 rows
# Processed 8900000 rows
# Processed 9000000 rows
# Processed 9100000 rows
# Processed 9200000 rows
# Processed 9300000 rows
# Processed 9400000 rows
# Processed 9500000 rows
# Processed 9600000 rows
# Processed 9700000 rows
# Processed 9800000 rows
# Processed 9900000 rows
# Processed 10000000 rows
# Processed 10100000 rows
# Processed 10200000 rows
# Processed 10300000 rows
# Processed 10400000 rows
# Processed 10500000 rows
# Processed 10600000 rows
# Processed 10700000 rows
# Processed 10800000 rows
# Processed 10900000 rows
# Processed 11000000 rows
# Processed 11100000 rows
# Processed 11200000 rows
# Processed 11300000 rows
# Processed 11400000 rows
# Processed 11500000 rows
# Processed 11600000 rows
# Processed 11700000 rows
# Processed 11800000 rows
# Processed 11900000 rows
# Processed 12000000 rows
# Processed 12100000 rows
# Processed 12200000 rows
# Processed 12300000 rows
# Processed 12400000 rows
# Processed 12500000 rows
# Processed 12600000 rows
# Processed 12700000 rows
# Processed 12800000 rows
# Processed 12900000 rows
# Processed 13000000 rows
# Processed 13100000 rows
# Processed 13200000 rows
# Processed 13300000 rows
# Processed 13400000 rows
# Processed 13500000 rows
# Processed 13600000 rows
# Processed 13700000 rows
# Processed 13800000 rows
# Processed 13900000 rows
# Processed 14000000 rows
# Processed 14100000 rows
# Processed 14200000 rows
# Processed 14300000 rows
# Processed 14400000 rows
# Processed 14500000 rows
# Processed 14600000 rows
# Processed 14700000 rows
# Processed 14800000 rows
# Processed 14900000 rows
# Processed 15000000 rows
# Processed 15100000 rows
# Processed 15200000 rows
# Processed 15300000 rows
# Processed 15400000 rows
# Processed 15500000 rows
# Processed 15600000 rows
# Processed 15700000 rows
# Processed 15800000 rows
# Processed 15900000 rows
# Processed 16000000 rows
# Processed 16100000 rows
# Processed 16200000 rows
# Processed 16300000 rows
# Processed 16400000 rows
# Processed 16500000 rows
# Processed 16600000 rows
# Processed 16700000 rows
# Processed 16800000 rows
# Processed 16900000 rows
# Processed 17000000 rows
# Processed 17100000 rows
# Processed 17200000 rows
# Processed 17300000 rows
# Processed 17400000 rows
# Processed 17500000 rows
# Processed 17600000 rows
# Processed 17700000 rows
# Processed 17800000 rows
# Processed 17900000 rows
# Processed 18000000 rows
# Processed 18100000 rows
# Processed 18200000 rows
# Processed 18300000 rows
# Processed 18400000 rows
# Processed 18500000 rows
# Processed 18600000 rows
# Processed 18700000 rows
# Processed 18800000 rows
# Processed 18900000 rows
# Processed 19000000 rows
# Processed 19100000 rows
# Processed 19200000 rows
# Processed 19300000 rows
# Processed 19400000 rows
# Processed 19500000 rows
# Processed 19600000 rows
# Processed 19700000 rows
# Processed 19800000 rows
# Processed 19900000 rows
# Processed 20000000 rows
# Processed 20100000 rows
# Processed 20200000 rows
# Processed 20300000 rows
# Processed 20400000 rows
# Processed 20500000 rows
# Processed 20600000 rows
# Processed 20700000 rows
# Processed 20800000 rows
# Processed 20900000 rows
# Processed 21000000 rows
# Processed 21100000 rows
# Processed 21200000 rows
# Processed 21300000 rows
# Processed 21400000 rows
# Processed 21500000 rows
# Processed 21600000 rows
# Processed 21700000 rows
# Processed 21800000 rows
# Processed 21900000 rows
# Processed 22000000 rows
# Processed 22100000 rows
# Processed 22200000 rows
# Processed 22300000 rows
# Processed 22400000 rows
# Processed 22500000 rows
# Processed 22600000 rows
# Processed 22700000 rows
# Processed 22800000 rows
# Processed 22900000 rows
# Processed 23000000 rows
# Processed 23100000 rows
# Processed 23200000 rows
# Processed 23300000 rows
# Processed 23400000 rows
# Processed 23500000 rows
# Processed 23600000 rows
# Processed 23700000 rows
# Processed 23800000 rows
# Processed 23900000 rows
# Processed 24000000 rows
# Processed 24100000 rows
# Processed 24200000 rows
# Processed 24300000 rows
# Processed 24400000 rows
# Processed 24500000 rows
# Processed 24600000 rows
# Processed 24700000 rows
# Processed 24800000 rows
# Processed 24900000 rows
# Processed 25000000 rows
# Processed 25100000 rows
# Processed 25200000 rows
# Processed 25300000 rows
# Processed 25400000 rows
# Processed 25500000 rows
# Processed 25600000 rows
# Processed 25700000 rows
# Processed 25800000 rows
# Processed 25900000 rows
# Processed 26000000 rows
# Processed 26100000 rows
# Processed 26200000 rows
# Processed 26300000 rows
# Processed 26400000 rows
# Processed 26500000 rows
# Processed 26600000 rows
# Processed 26700000 rows
# Processed 26800000 rows
# Processed 26900000 rows
# Processed 27000000 rows
# Processed 27100000 rows
# Processed 27200000 rows
# Processed 27300000 rows
# Processed 27400000 rows
# Processed 27500000 rows
# Processed 27600000 rows
# Processed 27700000 rows
# Processed 27800000 rows
# Processed 27900000 rows
# Processed 28000000 rows
# Processed 28100000 rows
# Processed 28200000 rows
# Processed 28300000 rows
# Processed 28400000 rows
# Processed 28500000 rows
# Processed 28600000 rows
# Processed 28700000 rows
# Processed 28800000 rows
# Processed 28900000 rows
# Processed 29000000 rows
# Processed 29100000 rows
# Processed 29200000 rows
# Processed 29300000 rows
# Processed 29400000 rows
# Processed 29500000 rows
# Processed 29600000 rows
# Processed 29700000 rows
# Processed 29800000 rows
# Processed 29900000 rows
# Processed 30000000 rows
# Processed 30100000 rows
# Processed 30200000 rows
# Processed 30300000 rows
# Processed 30400000 rows
# Processed 30500000 rows
# Processed 30600000 rows
# Processed 30700000 rows
# Processed 30800000 rows
# Processed 30900000 rows
# Processed 31000000 rows
# Processed 31100000 rows
# Processed 31200000 rows
# Processed 31300000 rows
# Processed 31400000 rows
# Processed 31500000 rows
# Processed 31600000 rows
# Processed 31700000 rows
# Processed 31800000 rows
# Processed 31900000 rows
# Processed 32000000 rows
# Processed 32100000 rows
# Processed 32200000 rows
# Processed 32300000 rows
# Processed 32400000 rows
# Processed 32500000 rows
# Processed 32600000 rows
# Processed 32700000 rows
# Processed 32800000 rows
# Processed 32900000 rows
# Processed 33000000 rows
# Processed 33100000 rows
# Processed 33200000 rows
# Processed 33300000 rows
# Processed 33400000 rows
# Processed 33500000 rows
# Processed 33600000 rows
# Processed 33700000 rows
# Processed 33800000 rows
# Processed 33900000 rows
# Processed 34000000 rows
# Processed 34100000 rows
# Processed 34200000 rows
# Processed 34300000 rows
# Processed 34400000 rows
# Processed 34500000 rows
# Processed 34600000 rows
# Processed 34700000 rows
# Processed 34800000 rows
# Processed 34900000 rows
# Processed 35000000 rows
# Processed 35100000 rows
# Processed 35200000 rows
# Processed 35300000 rows
# Processed 35400000 rows
# Processed 35500000 rows
# Processed 35600000 rows
# Processed 35700000 rows
# Processed 35800000 rows
# Processed 35900000 rows
# Processed 36000000 rows
# Processed 36100000 rows
# Processed 36200000 rows
# Processed 36300000 rows
# Processed 36400000 rows
# Processed 36500000 rows
# Processed 36600000 rows
# Processed 36700000 rows
# Processed 36800000 rows
# Processed 36900000 rows
# Processed 37000000 rows
# Processed 37100000 rows
# Processed 37200000 rows
# Processed 37300000 rows
# Processed 37400000 rows
# Processed 37500000 rows
# Processed 37600000 rows
# Processed 37700000 rows
# Processed 37800000 rows
# Processed 37900000 rows
# Processed 38000000 rows
# Processed 38100000 rows
# Processed 38200000 rows
# Processed 38300000 rows
# Processed 38400000 rows
# Processed 38500000 rows
# Processed 38600000 rows
# Processed 38700000 rows
# Processed 38800000 rows
# Processed 38900000 rows
# Processed 39000000 rows
# Processed 39100000 rows
# Processed 39200000 rows
# Processed 39300000 rows
# Processed 39400000 rows
# Processed 39500000 rows
# Processed 39600000 rows
# Processed 39700000 rows
# Processed 39800000 rows
# Processed 39900000 rows
# Processed 40000000 rows
# Processed 40100000 rows
# Processed 40200000 rows
# Processed 40300000 rows
# Processed 40400000 rows
# Processed 40500000 rows
# Processed 40600000 rows
# Processed 40700000 rows
# Processed 40800000 rows
# Processed 40900000 rows
# Processed 41000000 rows
# Processed 41100000 rows
# Processed 41200000 rows
# Processed 41300000 rows
# Processed 41400000 rows
# Processed 41500000 rows
# Processed 41600000 rows
# Processed 41700000 rows
# Processed 41800000 rows
# Processed 41900000 rows
# Processed 42000000 rows
# Processed 42100000 rows
# Processed 42200000 rows
# Processed 42300000 rows
# Processed 42400000 rows
# Processed 42500000 rows
# Processed 42600000 rows
# Processed 42700000 rows
# Processed 42800000 rows
# Processed 42900000 rows
# Processed 43000000 rows
# Processed 43100000 rows
# Processed 43200000 rows
# Processed 43300000 rows
# Processed 43400000 rows
# Processed 43500000 rows
# Processed 43600000 rows
# Processed 43700000 rows
# Processed 43800000 rows
# Processed 43900000 rows
# Processed 44000000 rows
# Processed 44100000 rows
# Processed 44200000 rows
# Processed 44300000 rows
# Processed 44400000 rows
# Processed 44500000 rows
# Processed 44600000 rows
# Processed 44700000 rows
# Processed 44800000 rows
# Processed 44900000 rows
# Processed 45000000 rows
# Processed 45100000 rows
# Processed 45200000 rows
# Processed 45300000 rows
# Processed 45400000 rows
# Processed 45500000 rows
# Processed 45600000 rows
# Processed 45700000 rows
# Processed 45800000 rows
# Processed 45900000 rows
# Processed 46000000 rows
# Processed 46100000 rows
# Processed 46200000 rows
# Processed 46300000 rows
# Processed 46400000 rows
# Processed 46500000 rows
# Processed 46600000 rows
# Processed 46700000 rows
# Processed 46800000 rows
# Processed 46900000 rows
# Processed 47000000 rows
# Processed 47100000 rows
# Processed 47200000 rows
# Processed 47300000 rows
# Processed 47400000 rows
# Processed 47500000 rows
# Processed 47600000 rows
# Processed 47700000 rows
# Processed 47800000 rows
# Processed 47900000 rows
# Processed 48000000 rows
# Processed 48100000 rows
# Processed 48200000 rows
# Processed 48300000 rows
# Processed 48400000 rows
# Processed 48500000 rows
# Processed 48600000 rows
# Processed 48700000 rows
# Processed 48800000 rows
# Processed 48900000 rows
# Processed 49000000 rows
# Processed 49100000 rows
# Processed 49200000 rows
# Processed 49300000 rows
# Processed 49400000 rows
# Processed 49500000 rows
# Processed 49600000 rows
# Processed 49700000 rows
# Processed 49800000 rows
# Processed 49900000 rows
# Processed 50000000 rows
# Processed 50100000 rows
# Processed 50200000 rows
# Processed 50300000 rows
# Processed 50400000 rows
# Processed 50500000 rows
# Processed 50600000 rows
# Processed 50700000 rows
# Processed 50800000 rows
# Processed 50900000 rows
# Processed 51000000 rows
# Processed 51100000 rows
# Processed 51200000 rows
# Processed 51300000 rows
# Processed 51400000 rows
# Processed 51500000 rows
# Processed 51600000 rows
# Processed 51700000 rows
# Processed 51800000 rows
# Processed 51900000 rows
# Processed 52000000 rows
# Processed 52100000 rows
# Processed 52200000 rows
# Processed 52300000 rows
# Processed 52400000 rows
# Processed 52500000 rows
# Processed 52600000 rows
# Processed 52700000 rows
# Processed 52800000 rows
# Processed 52900000 rows
# Processed 53000000 rows
# Processed 53100000 rows
# Processed 53200000 rows
# Processed 53300000 rows
# Processed 53400000 rows
# Processed 53500000 rows
# Processed 53600000 rows
# Processed 53700000 rows
# Processed 53800000 rows
# Processed 53900000 rows
# Processed 54000000 rows
# Processed 54100000 rows
# Processed 54200000 rows
# Processed 54300000 rows
# Processed 54400000 rows
# Processed 54500000 rows
# Processed 54600000 rows
# Processed 54700000 rows
# Processed 54800000 rows
# Processed 54900000 rows
# Processed 55000000 rows
# Processed 55100000 rows
# Processed 55200000 rows
# Processed 55300000 rows
# Processed 55400000 rows
# Processed 55500000 rows
# Processed 55600000 rows
# Processed 55700000 rows
# Processed 55800000 rows
# Processed 55900000 rows
# Processed 56000000 rows
# Processed 56100000 rows
# Processed 56200000 rows
# Processed 56300000 rows
# Processed 56400000 rows
# Processed 56500000 rows
# Processed 56600000 rows
# Processed 56700000 rows
# Processed 56800000 rows
# Processed 56900000 rows
# Processed 57000000 rows
# Processed 57100000 rows
# Processed 57200000 rows
# Processed 57300000 rows
# Processed 57400000 rows
# Processed 57500000 rows
# Processed 57600000 rows
# Processed 57700000 rows
# Processed 57800000 rows
# Processed 57900000 rows
# Processed 58000000 rows
# Processed 58100000 rows
# Processed 58200000 rows
# Processed 58300000 rows
# Processed 58400000 rows
# Processed 58500000 rows
# Processed 58600000 rows
# Processed 58700000 rows
# Processed 58800000 rows
# Processed 58900000 rows
# Processed 59000000 rows
# Processed 59100000 rows
# Processed 59200000 rows
# Processed 59300000 rows
# Processed 59400000 rows
# Processed 59500000 rows
# Processed 59600000 rows
# Processed 59700000 rows
# Processed 59800000 rows
# Processed 59900000 rows
# Processed 60000000 rows
# Processed 60100000 rows
# Processed 60200000 rows
# Processed 60300000 rows
# Processed 60400000 rows
# Processed 60500000 rows
# Processed 60600000 rows
# Processed 60700000 rows
# Processed 60800000 rows
# Processed 60900000 rows
# Processed 61000000 rows
# Processed 61100000 rows
# Processed 61200000 rows
# Processed 61300000 rows
# Processed 61400000 rows
# Processed 61500000 rows
# Processed 61600000 rows
# Processed 61700000 rows
# Processed 61800000 rows
# Processed 61900000 rows
# Processed 62000000 rows
# Processed 62100000 rows
# Processed 62200000 rows
# Processed 62300000 rows
# Processed 62400000 rows
# Processed 62500000 rows
# Processed 62600000 rows
# Processed 62700000 rows
# Processed 62800000 rows
# Processed 62900000 rows
# Processed 63000000 rows
# Processed 63100000 rows
# Processed 63200000 rows
# Processed 63300000 rows
# Processed 63400000 rows
# Processed 63500000 rows
# Processed 63600000 rows
# Processed 63700000 rows
# Processed 63800000 rows
# Processed 63900000 rows
# Processed 64000000 rows
# Processed 64100000 rows
# Processed 64200000 rows
# Processed 64300000 rows
# Processed 64400000 rows
# Processed 64500000 rows
# Processed 64600000 rows
# Processed 64700000 rows
# Processed 64800000 rows
# Processed 64900000 rows
# Processed 65000000 rows
# Processed 65100000 rows
# Processed 65200000 rows
# Processed 65300000 rows
# Processed 65400000 rows
# Processed 65500000 rows
# Processed 65600000 rows
# Processed 65700000 rows
# Processed 65800000 rows
# Processed 65900000 rows
# Processed 66000000 rows
# Processed 66100000 rows
# Processed 66200000 rows
# Processed 66300000 rows
# Processed 66400000 rows
# Processed 66500000 rows
# Processed 66600000 rows
# Processed 66700000 rows
# Processed 66800000 rows
# Processed 66900000 rows
# Processed 67000000 rows
# Processed 67100000 rows
# Processed 67200000 rows
# Processed 67300000 rows
# Processed 67400000 rows
# Processed 67500000 rows
# Processed 67600000 rows
# Processed 67700000 rows
# Processed 67800000 rows
# Processed 67900000 rows
# Processed 68000000 rows
# Processed 68100000 rows
# Processed 68200000 rows
# Processed 68300000 rows
# Processed 68400000 rows
# Processed 68500000 rows
# Processed 68600000 rows
# Processed 68700000 rows
# Processed 68800000 rows
# Processed 68900000 rows
# Processed 69000000 rows
# Processed 69100000 rows
# Processed 69200000 rows
# Processed 69300000 rows
# Processed 69400000 rows
# Processed 69500000 rows
# Processed 69600000 rows
# Processed 69700000 rows
# Processed 69800000 rows
# Processed 69900000 rows
# Processed 70000000 rows
# Processed 70100000 rows
# Processed 70200000 rows
# Processed 70300000 rows
# Processed 70400000 rows
# Processed 70500000 rows
# Processed 70600000 rows
# Processed 70700000 rows
# Processed 70800000 rows
# Processed 70900000 rows
# Processed 71000000 rows
# Processed 71100000 rows
# Processed 71200000 rows
# Processed 71300000 rows
# Processed 71400000 rows
# Processed 71500000 rows
# Processed 71600000 rows
# Processed 71700000 rows
# Processed 71800000 rows
# Processed 71900000 rows
# Processed 72000000 rows
# Processed 72100000 rows
# Processed 72200000 rows
# Processed 72300000 rows
# Processed 72400000 rows
# Processed 72500000 rows
# Processed 72600000 rows
# Processed 72700000 rows
# Processed 72800000 rows
# Processed 72900000 rows
# Processed 73000000 rows
# Processed 73100000 rows
# Processed 73200000 rows
# Processed 73300000 rows
# Processed 73400000 rows
# Processed 73500000 rows
# Processed 73600000 rows
# Processed 73700000 rows
# Processed 73800000 rows
# Processed 73900000 rows
# Processed 74000000 rows
# Processed 74100000 rows
# Processed 74200000 rows
# Processed 74300000 rows
# Processed 74400000 rows
# Processed 74500000 rows
# Processed 74600000 rows
# Processed 74700000 rows
# Processed 74800000 rows
# Processed 74900000 rows
# Processed 75000000 rows
# Processed 75100000 rows
# Processed 75200000 rows
# Processed 75300000 rows
# Processed 75400000 rows
# Processed 75500000 rows
# Processed 75600000 rows
# Processed 75700000 rows
# Processed 75800000 rows
# Processed 75900000 rows
# Processed 76000000 rows
# Processed 76100000 rows
# Processed 76200000 rows
# Processed 76300000 rows
# Processed 76400000 rows
# Processed 76500000 rows
# Processed 76600000 rows
# Processed 76700000 rows
# Processed 76800000 rows
# Processed 76900000 rows
# Processed 77000000 rows
# Processed 77100000 rows
# Processed 77200000 rows
# Processed 77300000 rows
# Processed 77400000 rows
# Processed 77500000 rows
# Processed 77600000 rows
# Processed 77700000 rows
# Processed 77800000 rows
# Processed 77900000 rows
# Processed 78000000 rows
# Processed 78100000 rows
# Processed 78200000 rows
# Processed 78300000 rows
# Processed 78400000 rows
# Processed 78500000 rows
# Processed 78600000 rows
# Processed 78700000 rows
# Processed 78800000 rows
# Processed 78900000 rows
# Processed 79000000 rows
# Processed 79100000 rows
# Processed 79200000 rows
# Processed 79300000 rows
# Processed 79400000 rows
# Processed 79500000 rows
# Processed 79600000 rows
# Processed 79700000 rows
# Processed 79800000 rows
# Processed 79900000 rows
# Processed 80000000 rows
# Processed 80100000 rows
# Processed 80200000 rows
# Processed 80300000 rows
# Processed 80400000 rows
# Processed 80500000 rows
# Processed 80600000 rows
# Processed 80700000 rows
# Processed 80800000 rows
# Processed 80900000 rows
# Processed 81000000 rows
# Processed 81100000 rows
# Processed 81200000 rows
# Processed 81300000 rows
# Processed 81400000 rows
# Processed 81500000 rows
# Processed 81600000 rows
# Processed 81700000 rows
# Processed 81800000 rows
# Processed 81900000 rows
# Processed 82000000 rows
# Processed 82100000 rows
# Processed 82200000 rows
# Processed 82300000 rows
# Processed 82400000 rows
# Processed 82500000 rows
# Processed 82600000 rows
# Processed 82700000 rows
# Processed 82800000 rows
# Processed 82900000 rows
# Processed 83000000 rows
# Processed 83100000 rows
# Processed 83200000 rows
# Processed 83300000 rows
# Processed 83400000 rows
# Processed 83500000 rows
# Processed 83600000 rows
# Processed 83700000 rows
# Processed 83800000 rows
# Processed 83900000 rows
# Processed 84000000 rows
# Processed 84100000 rows
# Processed 84200000 rows
# Processed 84300000 rows
# Processed 84400000 rows
# Processed 84500000 rows
# Processed 84600000 rows
# Processed 84700000 rows
# Processed 84800000 rows
# Processed 84900000 rows
# Processed 85000000 rows
# Processed 85100000 rows
# Processed 85200000 rows
# Processed 85300000 rows
# Processed 85400000 rows
# Processed 85500000 rows
# Processed 85600000 rows
# Processed 85700000 rows
# Processed 85800000 rows
# Processed 85900000 rows
# Processed 86000000 rows
# Processed 86100000 rows
# Processed 86200000 rows
# Processed 86300000 rows
# Processed 86400000 rows
# Processed 86500000 rows
# Processed 86600000 rows
# Processed 86700000 rows
# Processed 86800000 rows
# Processed 86900000 rows
# Processed 87000000 rows
# Processed 87100000 rows
# Processed 87200000 rows
# Processed 87300000 rows
# Processed 87400000 rows
# Processed 87500000 rows
# Processed 87600000 rows
# Processed 87700000 rows
# Processed 87800000 rows
# Processed 87900000 rows
# Processed 88000000 rows
# Processed 88100000 rows
# Processed 88200000 rows
# Processed 88300000 rows
# Processed 88400000 rows
# Processed 88500000 rows
# Processed 88600000 rows
# Processed 88700000 rows
# Processed 88800000 rows
# Processed 88900000 rows
# Processed 89000000 rows
# Processed 89100000 rows
# Processed 89200000 rows
# Processed 89300000 rows
# Processed 89400000 rows
# Processed 89500000 rows
# Processed 89600000 rows
# Processed 89700000 rows
# Processed 89800000 rows
# Processed 89900000 rows
# Processed 90000000 rows
# Processed 90100000 rows
# Processed 90200000 rows
# Processed 90300000 rows
# Processed 90400000 rows
# Processed 90500000 rows
# Processed 90600000 rows
# Processed 90700000 rows
# Processed 90800000 rows
# Processed 90900000 rows
# Processed 91000000 rows
# Processed 91100000 rows
# Processed 91200000 rows
# Processed 91300000 rows
# Processed 91400000 rows
# Processed 91500000 rows
# Processed 91600000 rows
# Processed 91700000 rows
# Processed 91800000 rows
# Processed 91900000 rows
# Processed 92000000 rows
# Processed 92100000 rows
# Processed 92200000 rows
# Processed 92300000 rows
# Processed 92400000 rows
# Processed 92500000 rows
# Processed 92600000 rows
# Processed 92700000 rows
# Processed 92800000 rows
# Processed 92900000 rows
# Processed 93000000 rows
# Processed 93100000 rows
# Processed 93200000 rows
# Processed 93300000 rows
# Processed 93400000 rows
# Processed 93500000 rows
# Processed 93600000 rows
# Processed 93700000 rows
# Processed 93800000 rows
# Processed 93900000 rows
# Processed 94000000 rows
# Processed 94100000 rows
# Processed 94200000 rows
# Processed 94300000 rows
# Processed 94400000 rows
# Processed 94500000 rows
# Processed 94600000 rows
# Processed 94700000 rows
# Processed 94800000 rows
# Processed 94900000 rows
# Processed 95000000 rows
# Processed 95100000 rows
# Processed 95200000 rows
# Processed 95300000 rows
# Processed 95400000 rows
# Processed 95500000 rows
# Processed 95600000 rows
# Processed 95700000 rows
# Processed 95800000 rows
# Processed 95900000 rows
# Processed 96000000 rows
# Processed 96100000 rows
# Processed 96200000 rows
# Processed 96300000 rows
# Processed 96400000 rows
# Processed 96500000 rows
# Processed 96600000 rows
# Processed 96700000 rows
# Processed 96800000 rows
# Processed 96900000 rows
# Processed 97000000 rows
# Processed 97100000 rows
# Processed 97200000 rows
# Processed 97300000 rows
# Processed 97400000 rows
# Processed 97500000 rows
# Processed 97600000 rows
# Processed 97700000 rows
# Processed 97800000 rows
# Processed 97900000 rows
# Processed 98000000 rows
# Processed 98100000 rows
# Processed 98200000 rows
# Processed 98300000 rows
# Processed 98400000 rows
# Processed 98500000 rows
# Processed 98600000 rows
# Processed 98700000 rows
# Processed 98800000 rows
# Processed 98900000 rows
# Processed 99000000 rows
# Processed 99100000 rows
# Processed 99200000 rows
# Processed 99300000 rows
# Processed 99400000 rows
# Processed 99500000 rows
# Processed 99600000 rows
# Processed 99700000 rows
# Processed 99800000 rows
# Processed 99900000 rows
# Processed 100000000 rows
# Processed 100100000 rows
# Processed 100200000 rows
# Processed 100300000 rows
# Processed 100400000 rows
# Processed 100500000 rows
# Processed 100600000 rows
# Processed 100700000 rows
# Processed 100800000 rows
# Processed 100900000 rows
# Processed 101000000 rows
# Processed 101100000 rows
# Processed 101200000 rows
# Processed 101300000 rows
# Processed 101400000 rows
# Processed 101500000 rows
# Processed 101600000 rows
# Processed 101700000 rows
# Processed 101800000 rows
# Processed 101900000 rows
# Processed 102000000 rows
# Processed 102100000 rows
# Processed 102200000 rows
# Processed 102300000 rows
# Processed 102400000 rows
# Processed 102500000 rows
# Processed 102600000 rows
# Processed 102700000 rows
# Processed 102800000 rows
# Processed 102900000 rows
# Processed 103000000 rows
# Processed 103100000 rows
# Processed 103200000 rows
# Processed 103300000 rows
# Processed 103400000 rows
# Processed 103500000 rows
# Processed 103600000 rows
# Processed 103700000 rows
# Processed 103800000 rows
# Processed 103900000 rows
# Processed 104000000 rows
# Processed 104100000 rows
# Processed 104200000 rows
# Processed 104300000 rows
# Processed 104400000 rows
# Processed 104500000 rows
# Processed 104600000 rows
# Processed 104700000 rows
# Processed 104800000 rows
# Processed 104900000 rows
# Processed 105000000 rows
# Processed 105100000 rows
# Processed 105200000 rows
# Processed 105300000 rows
# Processed 105400000 rows
# Processed 105500000 rows
# Processed 105600000 rows
# Processed 105700000 rows
# Processed 105800000 rows
# Processed 105900000 rows
# Processed 106000000 rows
# Processed 106100000 rows
# Processed 106200000 rows
# Processed 106300000 rows
# Processed 106400000 rows
# Processed 106500000 rows
# Processed 106600000 rows
# Processed 106700000 rows
# Processed 106800000 rows
# Processed 106900000 rows
# Processed 107000000 rows
# Processed 107100000 rows
# Processed 107200000 rows
# Processed 107300000 rows
# Processed 107400000 rows
# Processed 107500000 rows
# Processed 107600000 rows
# Processed 107700000 rows
# Processed 107800000 rows
# Processed 107900000 rows
# Processed 108000000 rows
# Processed 108100000 rows
# Processed 108200000 rows
# Processed 108300000 rows
# Processed 108400000 rows
# Processed 108500000 rows
# Processed 108600000 rows
# Processed 108700000 rows
# Processed 108800000 rows
# Processed 108900000 rows
# Processed 109000000 rows
# Processed 109100000 rows
# Processed 109200000 rows
# Processed 109300000 rows
# Processed 109400000 rows
# Processed 109500000 rows
# Processed 109600000 rows
# Processed 109700000 rows
# Processed 109800000 rows
# Processed 109900000 rows
# Processed 110000000 rows
# Processed 110100000 rows
# Processed 110200000 rows
# Processed 110300000 rows
# Processed 110400000 rows
# Processed 110500000 rows
# Processed 110600000 rows
# Processed 110700000 rows
# Processed 110800000 rows
# Processed 110900000 rows
# Processed 111000000 rows
# Processed 111100000 rows
# Processed 111200000 rows
# Processed 111300000 rows
# Processed 111400000 rows
# Processed 111500000 rows
# Processed 111600000 rows
# Processed 111700000 rows
# Processed 111800000 rows
# Processed 111900000 rows
# Processed 112000000 rows
# Processed 112100000 rows
# Processed 112200000 rows
# Processed 112300000 rows
# Processed 112400000 rows
# Processed 112500000 rows
# Processed 112600000 rows
# Processed 112700000 rows
# Processed 112800000 rows
# Processed 112900000 rows
# Processed 113000000 rows
# Processed 113100000 rows
# Processed 113200000 rows
# Processed 113300000 rows
# Processed 113400000 rows
# Processed 113500000 rows
# Processed 113600000 rows
# Processed 113700000 rows
# Processed 113800000 rows
# Processed 113900000 rows
# Processed 114000000 rows
# Processed 114100000 rows
# Processed 114200000 rows
# Processed 114300000 rows
# Processed 114400000 rows
# Processed 114500000 rows
# Processed 114600000 rows
# Processed 114700000 rows
# Processed 114800000 rows
# Processed 114900000 rows
# Processed 115000000 rows
# Processed 115100000 rows
# Processed 115200000 rows
# Processed 115300000 rows
# Processed 115400000 rows
# Processed 115500000 rows
# Processed 115600000 rows
# Processed 115700000 rows
# Processed 115800000 rows
# Processed 115900000 rows
# Processed 116000000 rows
# Processed 116100000 rows
# Processed 116200000 rows
# Processed 116300000 rows
# Processed 116400000 rows
# Processed 116500000 rows
# Processed 116600000 rows
# Processed 116700000 rows
# Processed 116800000 rows
# Processed 116900000 rows
# Processed 117000000 rows
# Processed 117100000 rows
# Processed 117200000 rows
# Processed 117300000 rows
# Processed 117400000 rows
# Processed 117500000 rows
# Processed 117600000 rows
# Processed 117700000 rows
# Processed 117800000 rows
# Processed 117900000 rows
# Processed 118000000 rows
# Processed 118100000 rows
# Processed 118200000 rows
# Processed 118300000 rows
# Processed 118400000 rows
# Processed 118500000 rows
# Processed 118600000 rows
# Processed 118700000 rows
# Processed 118800000 rows
# Processed 118900000 rows
# Processed 119000000 rows
# Processed 119100000 rows
# Processed 119200000 rows
# Processed 119300000 rows
# Processed 119400000 rows
# Processed 119500000 rows
# Processed 119600000 rows
# Processed 119700000 rows
# Processed 119800000 rows
# Processed 119900000 rows
# Processed 120000000 rows
# Processed 120100000 rows
# Processed 120200000 rows
# Processed 120300000 rows
# Processed 120400000 rows
# Processed 120500000 rows
# Processed 120600000 rows
# Processed 120700000 rows
# Processed 120800000 rows
# Processed 120900000 rows
# Processed 121000000 rows
# Processed 121100000 rows
# Processed 121200000 rows
# Processed 121300000 rows
# Processed 121400000 rows
# Processed 121500000 rows
# Processed 121600000 rows
# Processed 121700000 rows
# Processed 121800000 rows
# Processed 121900000 rows
# Processed 122000000 rows
# Processed 122100000 rows
# Processed 122200000 rows
# Processed 122300000 rows
# Processed 122400000 rows
# Processed 122500000 rows
# Processed 122600000 rows
# Processed 122700000 rows
# Processed 122800000 rows
# Processed 122900000 rows
# Processed 123000000 rows
# Processed 123100000 rows
# Processed 123200000 rows
# Processed 123300000 rows
# Processed 123400000 rows
# Processed 123500000 rows
# Processed 123600000 rows
# Processed 123700000 rows
# Processed 123800000 rows
# Processed 123900000 rows
# Processed 124000000 rows
# Processed 124100000 rows
# Processed 124200000 rows
# Processed 124300000 rows
# Processed 124400000 rows
# Processed 124500000 rows
# Processed 124600000 rows
# Processed 124700000 rows
# Processed 124800000 rows
# Processed 124900000 rows
# Processed 125000000 rows
# Processed 125100000 rows
# Processed 125200000 rows
# Processed 125300000 rows
# Processed 125400000 rows
# Processed 125500000 rows
# Processed 125600000 rows
# Processed 125700000 rows
# Processed 125800000 rows
# Processed 125900000 rows
# Processed 126000000 rows
# Processed 126100000 rows
# Processed 126200000 rows
# Processed 126300000 rows
# Processed 126400000 rows
# Processed 126500000 rows
# Processed 126600000 rows
# Processed 126700000 rows
# Processed 126800000 rows
# Processed 126900000 rows
# Processed 127000000 rows
# Processed 127100000 rows
# Processed 127200000 rows
# Processed 127300000 rows
# Processed 127400000 rows
# Processed 127500000 rows
# Processed 127600000 rows
# Processed 127700000 rows
# Processed 127800000 rows
# Processed 127900000 rows
# Processed 128000000 rows
# Processed 128100000 rows
# Processed 128200000 rows
# Processed 128300000 rows
# Processed 128400000 rows
# Processed 128500000 rows
# Processed 128600000 rows
# Processed 128700000 rows
# Processed 128800000 rows
# Processed 128900000 rows
# Processed 129000000 rows
# Processed 129100000 rows
# Processed 129200000 rows
# Processed 129300000 rows
# Processed 129400000 rows
# Processed 129500000 rows
# Processed 129600000 rows
# Processed 129700000 rows
# Processed 129800000 rows
# Processed 129900000 rows
# Processed 130000000 rows
# Processed 130100000 rows
# Processed 130200000 rows
# Processed 130300000 rows
# Processed 130400000 rows
# Processed 130500000 rows
# Processed 130600000 rows
# Processed 130700000 rows
# Processed 130800000 rows
# Processed 130900000 rows
# Processed 131000000 rows
# Processed 131100000 rows
# Processed 131200000 rows
# Processed 131300000 rows
# Processed 131400000 rows
# Processed 131500000 rows
# Processed 131600000 rows
# Processed 131700000 rows
# Processed 131800000 rows
# Processed 131900000 rows
# Processed 132000000 rows
# Processed 132100000 rows
# Processed 132200000 rows
# Processed 132300000 rows
# Processed 132400000 rows
# Processed 132500000 rows
# Processed 132600000 rows
# Processed 132700000 rows
# Processed 132800000 rows
# Processed 132900000 rows
# Processed 133000000 rows
# Processed 133100000 rows
# Processed 133200000 rows
# Processed 133300000 rows
# Processed 133400000 rows
# Processed 133500000 rows
# Processed 133600000 rows
# Processed 133700000 rows
# Processed 133800000 rows
# Processed 133900000 rows
# Processed 134000000 rows
# Processed 134100000 rows
# Processed 134200000 rows
# Processed 134300000 rows
# Processed 134400000 rows
# Processed 134500000 rows
# Processed 134600000 rows
# Processed 134700000 rows
# Processed 134800000 rows
# Processed 134900000 rows
# Processed 135000000 rows
# Processed 135100000 rows
# Processed 135200000 rows
# Processed 135300000 rows
# Processed 135400000 rows
# Processed 135500000 rows
# Processed 135600000 rows
# Processed 135700000 rows
# Processed 135800000 rows
# Processed 135900000 rows
# Processed 136000000 rows
# Processed 136100000 rows
# Processed 136200000 rows
# Processed 136300000 rows
# Processed 136400000 rows
# Processed 136500000 rows
# Processed 136600000 rows
# Processed 136700000 rows
# Processed 136800000 rows
# Processed 136900000 rows
# Processed 137000000 rows
# Processed 137100000 rows
# Processed 137200000 rows
# Processed 137300000 rows
# Processed 137400000 rows
# Processed 137500000 rows
# Processed 137600000 rows
# Processed 137700000 rows
# Processed 137800000 rows
# Processed 137900000 rows
# Processed 138000000 rows
# Processed 138100000 rows
# Processed 138200000 rows
# Processed 138300000 rows
# Processed 138400000 rows
# Processed 138500000 rows
# Processed 138600000 rows
# Processed 138700000 rows
# Processed 138800000 rows
# Processed 138900000 rows
# Processed 139000000 rows
# Processed 139100000 rows
# Processed 139200000 rows
# Processed 139300000 rows
# Processed 139400000 rows
# Processed 139500000 rows
# Processed 139600000 rows
# Processed 139700000 rows
# Processed 139800000 rows
# Processed 139900000 rows
# Processed 140000000 rows
# Processed 140100000 rows
# Processed 140200000 rows
# Processed 140300000 rows
# Processed 140400000 rows
# Processed 140500000 rows
# Processed 140600000 rows
# Processed 140700000 rows
# Processed 140800000 rows
# Processed 140900000 rows
# Processed 141000000 rows
# Processed 141100000 rows
# Processed 141200000 rows
# Processed 141300000 rows
# Processed 141400000 rows
# Processed 141500000 rows
# Processed 141600000 rows
# Processed 141700000 rows
# Processed 141800000 rows
# Processed 141900000 rows
# Processed 142000000 rows
# Processed 142100000 rows
# Processed 142200000 rows
# Processed 142300000 rows
# Processed 142400000 rows
# Processed 142500000 rows
# Processed 142600000 rows
# Processed 142700000 rows
# Processed 142800000 rows
# Processed 142900000 rows
# Processed 143000000 rows
# Processed 143100000 rows
# Processed 143200000 rows
# Processed 143300000 rows
# Processed 143400000 rows
# Processed 143500000 rows
# Processed 143600000 rows
# Processed 143700000 rows
# Processed 143800000 rows
# Processed 143900000 rows
# Processed 144000000 rows
# Processed 144100000 rows
# Processed 144200000 rows
# Processed 144300000 rows
# Processed 144400000 rows
# Processed 144500000 rows
# Processed 144600000 rows
# Processed 144700000 rows
# Processed 144800000 rows
# Processed 144900000 rows
# Processed 145000000 rows
# Processed 145100000 rows
# Processed 145200000 rows
# Processed 145300000 rows
# Processed 145400000 rows
# Processed 145500000 rows
# Processed 145600000 rows
# Processed 145700000 rows
# Processed 145800000 rows
# Processed 145900000 rows
# Processed 146000000 rows
# Processed 146100000 rows
# Processed 146200000 rows
# Processed 146300000 rows
# Processed 146400000 rows
# Processed 146500000 rows
# Processed 146600000 rows
# Processed 146700000 rows
# Processed 146800000 rows
# Processed 146900000 rows
# Processed 147000000 rows
# Processed 147100000 rows
# Processed 147200000 rows
# Processed 147300000 rows
# Processed 147400000 rows
# Processed 147500000 rows
# Processed 147600000 rows
# Processed 147700000 rows
# Processed 147800000 rows
# Processed 147900000 rows
# Processed 148000000 rows
# Processed 148100000 rows
# Processed 148200000 rows
# Processed 148300000 rows
# Processed 148400000 rows
# Processed 148500000 rows
# Processed 148600000 rows
# Processed 148700000 rows
# Processed 148800000 rows
# Processed 148900000 rows
# Processed 149000000 rows
# Processed 149100000 rows
# Processed 149200000 rows
# Processed 149300000 rows
# Processed 149400000 rows
# Processed 149500000 rows
# Processed 149600000 rows
# Processed 149700000 rows
# Processed 149800000 rows
# Processed 149900000 rows
# Processed 150000000 rows
# Processed 150100000 rows
# Processed 150200000 rows
# Processed 150300000 rows
# Processed 150400000 rows
# Processed 150500000 rows
# Processed 150600000 rows
# Processed 150700000 rows
# Processed 150800000 rows
# Processed 150900000 rows
# Processed 151000000 rows
# Processed 151100000 rows
# Processed 151200000 rows
# Processed 151300000 rows
# Processed 151400000 rows
# Processed 151500000 rows
# Processed 151600000 rows
# Processed 151700000 rows
# Processed 151800000 rows
# Processed 151900000 rows
# Processed 152000000 rows
# Processed 152100000 rows
# Processed 152200000 rows
# Processed 152300000 rows
# Processed 152400000 rows
# Processed 152500000 rows
# Processed 152600000 rows
# Processed 152700000 rows
# Processed 152800000 rows
# Processed 152900000 rows
# Processed 153000000 rows
# Processed 153100000 rows
# Processed 153200000 rows
# Processed 153300000 rows
# Processed 153400000 rows
# Processed 153500000 rows
# Processed 153600000 rows
# Processed 153700000 rows
# Processed 153800000 rows
# Processed 153900000 rows
# Processed 154000000 rows
# Processed 154100000 rows
# Processed 154200000 rows
# Processed 154300000 rows
# Processed 154400000 rows
# Processed 154500000 rows
# Processed 154600000 rows
# Processed 154700000 rows
# Processed 154800000 rows
# Processed 154900000 rows
# Processed 155000000 rows
# Processed 155100000 rows
# Processed 155200000 rows
# Processed 155300000 rows
# Processed 155400000 rows
# Processed 155500000 rows
# Processed 155600000 rows
# Processed 155700000 rows
# Processed 155800000 rows
# Processed 155900000 rows
# Processed 156000000 rows
# Processed 156100000 rows
# Processed 156200000 rows
# Processed 156300000 rows
# Processed 156400000 rows
# Processed 156500000 rows
# Processed 156600000 rows
# Processed 156700000 rows
# Processed 156800000 rows
# Processed 156900000 rows
# Processed 157000000 rows
# Processed 157100000 rows
# Processed 157200000 rows
# Processed 157300000 rows
# Processed 157400000 rows
# Processed 157500000 rows
# Processed 157600000 rows
# Processed 157700000 rows
# Processed 157800000 rows
# Processed 157900000 rows
# Processed 158000000 rows
# Processed 158100000 rows
# Processed 158200000 rows
# Processed 158300000 rows
# Processed 158400000 rows
# Processed 158500000 rows
# Processed 158600000 rows
# Processed 158700000 rows
# Processed 158800000 rows
# Processed 158900000 rows
# Processed 159000000 rows
# Processed 159100000 rows
# Processed 159200000 rows
# Processed 159300000 rows
# Processed 159400000 rows
# Processed 159500000 rows
# Processed 159600000 rows
# Processed 159700000 rows
# Processed 159800000 rows
# Processed 159900000 rows
# Processed 160000000 rows
# Processed 160100000 rows
# Processed 160200000 rows
# Processed 160300000 rows
# Processed 160400000 rows
# Processed 160500000 rows
# Processed 160600000 rows
# Processed 160700000 rows
# Processed 160800000 rows
# Processed 160900000 rows
# Processed 161000000 rows
# Processed 161100000 rows
# Processed 161200000 rows
# Processed 161300000 rows
# Processed 161400000 rows
# Processed 161500000 rows
# Processed 161600000 rows
# Processed 161700000 rows
# Processed 161800000 rows
# Processed 161900000 rows
# Processed 162000000 rows
# Processed 162100000 rows
# Processed 162200000 rows
# Processed 162300000 rows
# Processed 162400000 rows
# Processed 162500000 rows
# Processed 162600000 rows
# Processed 162700000 rows
# Processed 162800000 rows
# Processed 162900000 rows
# Processed 163000000 rows
# Processed 163100000 rows
# Processed 163200000 rows
# Processed 163300000 rows
# Processed 163400000 rows
# Processed 163500000 rows
# Processed 163600000 rows
# Processed 163700000 rows
# Processed 163800000 rows
# Processed 163900000 rows
# Processed 164000000 rows
# Processed 164100000 rows
# Processed 164200000 rows
# Processed 164300000 rows
# Processed 164400000 rows
# Processed 164500000 rows
# Processed 164600000 rows
# Processed 164700000 rows
# Processed 164800000 rows
# Processed 164900000 rows
# Processed 165000000 rows
# Processed 165100000 rows
# Processed 165200000 rows
# Processed 165300000 rows
# Processed 165400000 rows
# Processed 165500000 rows
# Processed 165600000 rows
# Processed 165700000 rows
# Processed 165800000 rows
# Processed 165900000 rows
# Processed 166000000 rows
# Processed 166100000 rows
# Processed 166200000 rows
# Processed 166300000 rows
# Processed 166400000 rows
# Processed 166500000 rows
# Processed 166600000 rows
# Processed 166700000 rows
# Processed 166800000 rows
# Processed 166900000 rows
# Processed 167000000 rows
# Processed 167100000 rows
# Processed 167200000 rows
# Processed 167300000 rows
# Processed 167400000 rows
# Processed 167500000 rows
# Processed 167600000 rows
# Processed 167700000 rows
# Processed 167800000 rows
# Processed 167900000 rows
# Processed 168000000 rows
# Processed 168100000 rows
# Processed 168200000 rows
# Processed 168300000 rows
# Processed 168400000 rows
# Processed 168500000 rows
# Processed 168600000 rows
# Processed 168700000 rows
# Processed 168800000 rows
# Processed 168900000 rows
# Processed 169000000 rows
# Processed 169100000 rows
# Processed 169200000 rows
# Processed 169300000 rows
# Processed 169400000 rows
# Processed 169500000 rows
# Processed 169600000 rows
# Processed 169700000 rows
# Processed 169800000 rows
# Processed 169900000 rows
# Processed 170000000 rows
# Processed 170100000 rows
# Processed 170200000 rows
# Processed 170300000 rows
# Processed 170400000 rows
# Processed 170500000 rows
# Processed 170600000 rows
# Processed 170700000 rows
# Processed 170800000 rows
# Processed 170900000 rows
# Processed 171000000 rows
# Processed 171100000 rows
# Processed 171200000 rows
# Processed 171300000 rows
# Processed 171400000 rows
# Processed 171500000 rows
# Processed 171600000 rows
# Processed 171700000 rows
# Processed 171800000 rows
# Processed 171900000 rows
# Processed 172000000 rows
# Processed 172100000 rows
# Processed 172200000 rows
# Processed 172300000 rows
# Processed 172400000 rows
# Processed 172500000 rows
# Processed 172600000 rows
# Processed 172700000 rows
# Processed 172800000 rows
# Processed 172900000 rows
# Processed 173000000 rows
# Processed 173100000 rows
# Processed 173200000 rows
# Processed 173300000 rows
# Processed 173400000 rows
# Processed 173500000 rows
# Processed 173600000 rows
# Processed 173700000 rows
# Processed 173800000 rows
# Processed 173900000 rows
# Processed 174000000 rows
# Processed 174100000 rows
# Processed 174200000 rows
# Processed 174300000 rows
# Processed 174400000 rows
# Processed 174500000 rows
# Processed 174600000 rows
# Processed 174700000 rows
# Processed 174800000 rows
# Processed 174900000 rows
# Processed 175000000 rows
# Processed 175100000 rows
# Processed 175200000 rows
# Processed 175300000 rows
# Processed 175400000 rows
# Processed 175500000 rows
# Processed 175600000 rows
# Processed 175700000 rows
# Processed 175800000 rows
# Processed 175900000 rows
# Processed 176000000 rows
# Processed 176100000 rows
# Processed 176200000 rows
# Processed 176300000 rows
# Processed 176400000 rows
# Processed 176500000 rows
# Processed 176600000 rows
# Processed 176700000 rows
# Processed 176800000 rows
# Processed 176900000 rows
# Processed 177000000 rows
# Processed 177100000 rows
# Processed 177200000 rows
# Processed 177300000 rows
# Processed 177400000 rows
# Processed 177500000 rows
# Processed 177600000 rows
# Processed 177700000 rows
# Processed 177800000 rows
# Processed 177900000 rows
# Processed 178000000 rows
# Processed 178100000 rows
# Processed 178200000 rows
# Processed 178300000 rows
# Processed 178400000 rows
# Processed 178500000 rows
# Processed 178600000 rows
# Processed 178700000 rows
# Processed 178800000 rows
# Processed 178900000 rows
# Processed 179000000 rows
# Processed 179100000 rows
# Processed 179200000 rows
# Processed 179300000 rows
# Processed 179400000 rows
# Processed 179500000 rows
# Processed 179600000 rows
# Processed 179700000 rows
# Processed 179800000 rows
# Processed 179900000 rows
# Processed 180000000 rows
# Processed 180100000 rows
# Processed 180200000 rows
# Processed 180300000 rows
# Processed 180400000 rows
# Processed 180500000 rows
# Processed 180600000 rows
# Processed 180700000 rows
# Processed 180800000 rows
# Processed 180900000 rows
# Processed 181000000 rows
# Processed 181100000 rows
# Processed 181200000 rows
# Processed 181300000 rows
# Processed 181400000 rows
# Processed 181500000 rows
# Processed 181600000 rows
# Processed 181700000 rows
# Processed 181800000 rows
# Processed 181900000 rows
# Processed 182000000 rows
# Processed 182100000 rows
# Processed 182200000 rows
# Processed 182300000 rows
# Processed 182400000 rows
# Processed 182500000 rows
# Processed 182600000 rows
# Processed 182700000 rows
# Processed 182800000 rows
# Processed 182900000 rows
# Processed 183000000 rows
# Processed 183100000 rows
# Processed 183200000 rows
# Processed 183300000 rows
# Processed 183400000 rows
# Processed 183500000 rows
# Processed 183600000 rows
# Processed 183700000 rows
# Processed 183800000 rows
# Processed 183900000 rows
# Processed 184000000 rows
# Processed 184100000 rows
# Processed 184200000 rows
# Processed 184300000 rows
# Processed 184400000 rows
# Processed 184500000 rows
# Processed 184600000 rows
# Processed 184700000 rows
# Processed 184800000 rows
# Processed 184900000 rows
# Processed 185000000 rows
# Processed 185100000 rows
# Processed 185200000 rows
# Processed 185300000 rows
# Processed 185400000 rows
# Processed 185500000 rows
# Processed 185600000 rows
# Processed 185700000 rows
# Processed 185800000 rows
# Processed 185900000 rows
# Processed 186000000 rows
# Processed 186100000 rows
# Processed 186200000 rows
# Processed 186300000 rows
# Processed 186400000 rows
# Processed 186500000 rows
# Processed 186600000 rows
# Processed 186700000 rows
# Processed 186800000 rows
# Processed 186900000 rows
# Processed 187000000 rows
# Processed 187100000 rows
# Processed 187200000 rows
# Processed 187300000 rows
# Processed 187400000 rows
# Processed 187500000 rows
# Processed 187600000 rows
# Processed 187700000 rows
# Processed 187800000 rows
# Processed 187900000 rows
# Processed 188000000 rows
# Processed 188100000 rows
# Processed 188200000 rows
# Processed 188300000 rows
# Processed 188400000 rows
# Processed 188500000 rows
# Processed 188600000 rows
# Processed 188700000 rows
# Processed 188800000 rows
# Processed 188900000 rows
# Processed 189000000 rows
# Processed 189100000 rows
# Processed 189200000 rows
# Processed 189300000 rows
# Processed 189400000 rows
# Processed 189500000 rows
# Processed 189600000 rows
# Processed 189700000 rows
# Processed 189800000 rows
# Processed 189900000 rows
# Processed 190000000 rows
# Processed 190100000 rows
# Processed 190200000 rows
# Processed 190300000 rows
# Processed 190400000 rows
# Processed 190500000 rows
# Processed 190600000 rows
# Processed 190700000 rows
# Processed 190800000 rows
# Processed 190900000 rows
# Processed 191000000 rows
# Processed 191100000 rows
# Processed 191200000 rows
# Processed 191300000 rows
# ...
# Processed 192000000 rows
# Processed 192100000 rows
# Processed 192200000 rows
# Processed 192300000 rows
# Processed 192400000 rows
# Processed 192500000 rows
# Processed 192600000 rows
# Processed 192700000 rows
# Processed 192800000 rows
# Processed 192900000 rows
# Processed 193000000 rows
# Processed 193100000 rows
# Processed 193200000 rows
# Processed 193300000 rows
# Processed 193400000 rows
# Processed 193500000 rows
# Processed 193600000 rows
# Processed 193700000 rows
# Processed 193800000 rows
# Processed 193900000 rows
# Processed 194000000 rows
# Processed 194100000 rows
# Processed 194200000 rows
# Processed 194300000 rows
# Processed 194400000 rows
# Processed 194500000 rows
# Processed 194600000 rows
# Processed 194700000 rows
# Processed 194800000 rows
# Processed 194900000 rows
# Processed 195000000 rows
# Processed 195100000 rows
# Processed 195200000 rows
# Processed 195300000 rows
# Processed 195400000 rows
# Processed 195500000 rows
# Processed 195600000 rows
# Processed 195700000 rows
# Processed 195800000 rows
# Processed 195900000 rows
# Processed 196000000 rows
# Processed 196100000 rows
# Processed 196200000 rows
# Processed 196300000 rows
# Processed 196400000 rows
# Processed 196500000 rows
# Processed 196600000 rows
# Processed 196700000 rows
# Processed 196800000 rows
# Processed 196900000 rows
# Processed 197000000 rows
# Processed 197100000 rows
# Processed 197200000 rows
# Processed 197300000 rows
# Processed 197400000 rows
# Processed 197500000 rows
# Processed 197600000 rows
# Processed 197700000 rows
# Processed 197800000 rows
# Processed 197900000 rows
# Processed 198000000 rows
# Processed 198100000 rows
# Processed 198200000 rows
# Processed 198300000 rows
# Processed 198400000 rows
# Processed 198500000 rows
# Processed 198600000 rows
# Processed 198700000 rows
# Processed 198800000 rows
# Processed 198900000 rows
# Processed 199000000 rows
# Processed 199100000 rows
# Processed 199200000 rows
# Processed 199300000 rows
# Processed 199400000 rows
# Processed 199500000 rows
# Processed 199600000 rows
# Processed 199700000 rows
# Processed 199800000 rows
# Processed 199900000 rows
# Processed 200000000 rows
# Processed 200100000 rows
# Processed 200200000 rows
# Processed 200300000 rows
# Processed 200400000 rows
# Processed 200500000 rows
# Processed 200600000 rows
# Processed 200700000 rows
# Processed 200800000 rows
# Processed 200900000 rows
# Processed 201000000 rows
# Processed 201100000 rows
# Processed 201200000 rows
# Processed 201300000 rows
# Processed 201400000 rows
# Processed 201500000 rows
# Processed 201600000 rows
# Processed 201700000 rows
# Processed 201800000 rows
# Processed 201900000 rows
# Processed 202000000 rows
# Processed 202100000 rows
# Processed 202200000 rows
# Processed 202300000 rows
# Processed 202400000 rows
# Processed 202500000 rows
# Processed 202600000 rows
# Processed 202700000 rows
# Processed 202800000 rows
# Processed 202900000 rows
# Processed 203000000 rows
# Processed 203100000 rows
# Processed 203200000 rows
# Processed 203300000 rows
# Processed 203400000 rows
# Processed 203500000 rows
# Processed 203600000 rows
# Processed 203700000 rows
# Processed 203800000 rows
# Processed 203900000 rows
# Processed 204000000 rows
# Processed 204100000 rows
# Processed 204200000 rows
# Processed 204300000 rows
# Processed 204400000 rows
# Processed 204500000 rows
# Processed 204600000 rows
# Processed 204700000 rows
# Processed 204800000 rows
# Processed 204900000 rows
# Processed 205000000 rows
# Processed 205100000 rows
# Processed 205200000 rows
# Processed 205300000 rows
# Processed 205400000 rows
# Processed 205500000 rows
# Processed 205600000 rows
# Processed 205700000 rows
# Processed 205800000 rows
# Processed 205900000 rows
# Processed 206000000 rows
# Processed 206100000 rows
# Processed 206200000 rows
# Processed 206300000 rows
# Processed 206400000 rows
# Processed 206500000 rows
# Processed 206600000 rows
# Processed 206700000 rows
# Processed 206800000 rows
# Processed 206900000 rows
# Processed 207000000 rows
# Processed 207100000 rows
# Processed 207200000 rows
# Processed 207300000 rows
# Processed 207400000 rows
# Processed 207500000 rows
# Processed 207600000 rows
# Processed 207700000 rows
# Processed 207800000 rows
# Processed 207900000 rows
# Processed 208000000 rows
# Processed 208100000 rows
# Processed 208200000 rows
# Processed 208300000 rows
# Processed 208400000 rows
# Processed 208500000 rows
# Processed 208600000 rows
# Processed 208700000 rows
# Processed 208800000 rows
# Processed 208900000 rows
# Processed 209000000 rows
# Processed 209100000 rows
# Processed 209200000 rows
# Processed 209300000 rows
# Processed 209400000 rows
# Processed 209500000 rows
# Processed 209600000 rows
# Processed 209700000 rows
# Processed 209800000 rows
# Processed 209900000 rows
# Processed 210000000 rows
# Processed 210100000 rows
# Processed 210200000 rows
# Processed 210300000 rows
# Processed 210400000 rows
# Processed 210500000 rows
# Processed 210600000 rows
# Processed 210700000 rows
# Processed 210800000 rows
# Processed 210900000 rows
# Processed 211000000 rows
# Processed 211100000 rows
# Processed 211200000 rows
# Processed 211300000 rows
# Processed 211400000 rows
# Processed 211500000 rows
# Processed 211600000 rows
# Processed 211700000 rows
# Processed 211800000 rows
# Processed 211900000 rows
# Processed 212000000 rows
# Processed 212100000 rows
# Processed 212200000 rows
# Processed 212300000 rows
# Processed 212400000 rows
# Processed 212500000 rows
# Processed 212600000 rows
# Processed 212700000 rows
# Processed 212800000 rows
# Processed 212900000 rows
# Processed 213000000 rows
# Processed 213100000 rows
# Processed 213200000 rows
# Processed 213300000 rows
# Processed 213400000 rows
# Processed 213500000 rows
# Processed 213600000 rows
# Processed 213700000 rows
# Processed 213800000 rows
# Processed 213900000 rows
# Processed 214000000 rows
# Processed 214100000 rows
# Processed 214200000 rows
# Processed 214300000 rows
# Processed 214400000 rows
# Processed 214500000 rows
# Processed 214600000 rows
# Processed 214700000 rows
# Processed 214800000 rows
# Processed 214900000 rows
# Processed 215000000 rows
# Processed 215100000 rows
# Processed 215200000 rows
# Processed 215300000 rows
# Processed 215400000 rows
# Processed 215500000 rows
# Processed 215600000 rows
# Processed 215700000 rows
# Processed 215800000 rows
# Processed 215900000 rows
# Processed 216000000 rows
# Processed 216100000 rows
# Processed 216200000 rows
# Processed 216300000 rows
# Processed 216400000 rows
# Processed 216500000 rows
# Processed 216600000 rows
# Processed 216700000 rows
# Processed 216800000 rows
# Processed 216900000 rows
# Processed 217000000 rows
# Processed 217100000 rows
# Processed 217200000 rows
# Processed 217300000 rows
# Processed 217400000 rows
# Processed 217500000 rows
# Processed 217600000 rows
# Processed 217700000 rows
# Processed 217800000 rows
# Processed 217900000 rows
# Processed 218000000 rows
# Processed 218100000 rows
# Processed 218200000 rows
# Processed 218300000 rows
# Processed 218400000 rows
# Processed 218500000 rows
# Processed 218600000 rows
# Processed 218700000 rows
# Processed 218800000 rows
# Processed 218900000 rows
# Processed 219000000 rows
# Processed 219100000 rows
# Processed 219200000 rows
# Processed 219300000 rows
# Processed 219400000 rows
# Processed 219500000 rows
# Processed 219600000 rows
# Processed 219700000 rows
# Processed 219800000 rows
# Processed 219900000 rows
# Processed 220000000 rows
# Processed 220100000 rows
# Processed 220200000 rows
# Processed 220300000 rows
# Processed 220400000 rows
# Processed 220500000 rows
# Processed 220600000 rows
# Processed 220700000 rows
# Processed 220800000 rows
# Processed 220900000 rows
# Processed 221000000 rows
# Processed 221100000 rows
# Processed 221200000 rows
# Processed 221300000 rows
# Processed 221400000 rows
# Processed 221500000 rows
# Processed 221600000 rows
# Processed 221700000 rows
# Processed 221800000 rows
# Processed 221900000 rows
# Processed 222000000 rows
# Processed 222100000 rows
# Processed 222200000 rows
# Processed 222300000 rows
# Processed 222400000 rows
# Processed 222500000 rows
# Processed 222600000 rows
# Processed 222700000 rows
# Processed 222800000 rows
# Processed 222900000 rows
# Processed 223000000 rows
# Processed 223100000 rows
# Processed 223200000 rows
# Processed 223300000 rows
# Processed 223400000 rows
# Processed 223500000 rows
# Processed 223600000 rows
# Processed 223700000 rows
# Processed 223800000 rows
# Processed 223900000 rows
# Processed 224000000 rows
# Processed 224100000 rows
# Processed 224200000 rows
# Processed 224300000 rows
# Processed 224400000 rows
# Processed 224500000 rows
# Processed 224600000 rows
# Processed 224700000 rows
# Processed 224800000 rows
# Processed 224900000 rows
# Processed 225000000 rows
# Processed 225100000 rows
# Processed 225200000 rows
# Processed 225300000 rows
# Processed 225400000 rows
# Processed 225500000 rows
# Processed 225600000 rows
# Processed 225700000 rows
# Processed 225800000 rows
# Processed 225900000 rows
# Processed 226000000 rows
# Processed 226100000 rows
# Processed 226200000 rows
# Processed 226300000 rows
# Processed 226400000 rows
# Processed 226500000 rows
# Processed 226600000 rows
# Processed 226700000 rows
# Processed 226800000 rows
# Processed 226900000 rows
# Processed 227000000 rows
# Processed 227100000 rows
# Processed 227200000 rows
# Processed 227300000 rows
# Processed 227400000 rows
# Processed 227500000 rows
# Processed 227600000 rows
# Processed 227700000 rows
# Processed 227800000 rows
# Processed 227900000 rows
# Processed 228000000 rows
# Processed 228100000 rows
# Processed 228200000 rows
# Processed 228300000 rows
# Processed 228400000 rows
# Processed 228500000 rows
# Processed 228600000 rows
# Processed 228700000 rows
# Processed 228800000 rows
# Processed 228900000 rows
# Processed 229000000 rows
# Processed 229100000 rows
# Processed 229200000 rows
# Processed 229300000 rows
# Processed 229400000 rows
# Processed 229500000 rows
# Processed 229600000 rows
# Processed 229700000 rows
# Processed 229800000 rows
# Processed 229900000 rows
# Processed 230000000 rows
# Processed 230100000 rows
# Processed 230200000 rows
# Processed 230300000 rows
# Processed 230400000 rows
# Processed 230500000 rows
# Processed 230600000 rows
# Processed 230700000 rows
# Processed 230800000 rows
# Processed 230900000 rows
# Processed 231000000 rows
# Processed 231100000 rows
# Processed 231200000 rows
# Processed 231300000 rows
# Processed 231400000 rows
# Processed 231500000 rows
# Processed 231600000 rows
# Processed 231700000 rows
# Processed 231800000 rows
# Processed 231900000 rows
# Processed 232000000 rows
# Processed 232100000 rows
# Processed 232200000 rows
# Processed 232300000 rows
# Processed 232400000 rows
# Processed 232500000 rows
# Processed 232600000 rows
# Processed 232700000 rows
# Processed 232800000 rows
# Processed 232900000 rows
# Processed 233000000 rows
# Processed 233100000 rows
# Processed 233200000 rows
# Processed 233300000 rows
# Processed 233400000 rows
# Processed 233500000 rows
# Processed 233600000 rows
# Processed 233700000 rows
# Processed 233800000 rows
# Processed 233900000 rows
# Processed 234000000 rows
# Processed 234100000 rows
# Processed 234200000 rows
# Processed 234300000 rows
# Processed 234400000 rows
# Processed 234500000 rows
# Processed 234600000 rows
# Processed 234700000 rows
# Processed 234800000 rows
# Processed 234900000 rows
# Processed 235000000 rows
# Processed 235100000 rows
# Processed 235200000 rows
# Processed 235300000 rows
# Processed 235400000 rows
# Processed 235500000 rows
# Processed 235600000 rows
# Processed 235700000 rows
# Processed 235800000 rows
# Processed 235900000 rows
# Processed 236000000 rows
# Processed 236100000 rows
# Processed 236200000 rows
# Processed 236300000 rows
# Processed 236400000 rows
# Processed 236500000 rows
# Processed 236600000 rows
# Processed 236700000 rows
# Processed 236800000 rows
# Processed 236900000 rows
# Processed 237000000 rows
# Processed 237100000 rows
# Processed 237200000 rows
# Processed 237300000 rows
# Processed 237400000 rows
# Processed 237500000 rows
# Processed 237600000 rows
# Processed 237700000 rows
# Processed 237800000 rows
# Processed 237900000 rows
# Processed 238000000 rows
# Processed 238100000 rows
# Processed 238200000 rows
# Processed 238300000 rows
# Processed 238400000 rows
# Processed 238500000 rows
# Processed 238600000 rows
# Processed 238700000 rows
# Processed 238800000 rows
# Processed 238900000 rows
# Processed 239000000 rows
# Processed 239100000 rows
# Processed 239200000 rows
# Processed 239300000 rows
# Processed 239400000 rows
# Processed 239500000 rows
# Processed 239600000 rows
# Processed 239700000 rows
# Processed 239800000 rows
# Processed 239900000 rows
# Processed 240000000 rows
# Processed 240100000 rows
# Processed 240200000 rows
# Processed 240300000 rows
# Processed 240400000 rows
# Processed 240500000 rows
# Processed 240600000 rows
# Processed 240700000 rows
# Processed 240800000 rows
# Processed 240900000 rows
# Processed 241000000 rows
# Processed 241100000 rows
# Processed 241200000 rows
# Processed 241300000 rows
# Processed 241400000 rows
# Processed 241500000 rows
# Processed 241600000 rows
# Processed 241700000 rows
# Processed 241800000 rows
# Processed 241900000 rows
# Processed 242000000 rows
# Processed 242100000 rows
# Processed 242200000 rows
# Processed 242300000 rows
# Processed 242400000 rows
# Processed 242500000 rows
# Processed 242600000 rows
# Processed 242700000 rows
# Processed 242800000 rows
# Processed 242900000 rows
# Processed 243000000 rows
# Processed 243100000 rows
# Processed 243200000 rows
# Processed 243300000 rows
# Processed 243400000 rows
# Processed 243500000 rows
# Processed 243600000 rows
# Processed 243700000 rows
# Processed 243800000 rows
# Processed 243900000 rows
# Processed 244000000 rows
# Processed 244100000 rows
# Processed 244200000 rows
# Processed 244300000 rows
# Processed 244400000 rows
# Processed 244500000 rows
# Processed 244600000 rows
# Processed 244700000 rows
# Processed 244800000 rows
# Processed 244900000 rows
# Processed 245000000 rows
# Processed 245100000 rows
# Processed 245200000 rows
# Processed 245300000 rows
# Processed 245400000 rows
# Processed 245500000 rows
# Processed 245600000 rows
# Processed 245700000 rows
# Processed 245800000 rows
# Processed 245900000 rows
# Processed 246000000 rows
# Processed 246100000 rows
# Processed 246200000 rows
# Processed 246300000 rows
# Processed 246400000 rows
# Processed 246500000 rows
# Processed 246600000 rows
# Processed 246700000 rows
# Processed 246800000 rows
# Processed 246900000 rows
# Processed 247000000 rows
# Processed 247100000 rows
# Processed 247200000 rows
# Processed 247300000 rows
# Processed 247400000 rows
# Processed 247500000 rows
# Processed 247600000 rows
# Processed 247700000 rows
# Processed 247800000 rows
# Processed 247900000 rows
# Processed 248000000 rows
# Processed 248100000 rows
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-75-fc7820a05197> in <cell line: 1>()
#       4   patient_df = pd.read_parquet(patient_file)
#       5
# ----> 6   data, labels = extract_patient_data_2(patient_df, chartevents_path, feature_set_1_dynamic, time_window_hours)
#       7
#       8   data_file_path = f'{output_dir}/data_chunk_{i}.parquet'
#
# <ipython-input-74-e1a88ef848a0> in extract_patient_data_2(patient_df, chartevents_file_path, itemids, time_window)
#      40
#      41     # Extract the data and labels
# ---> 42     data = result_df[['subject_id', 'charttime', 'itemid', 'valuenum']]
#      43     labels = result_df[['subject_id','extubation_failure']]
#      44
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3765             if is_iterator(key):
#    3766                 key = list(key)
# -> 3767             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3768
#    3769         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5875             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5876
# -> 5877         self._raise_if_missing(keyarr, indexer, axis_name)
#    5878
#    5879         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    5936                 if use_interval_msg:
#    5937                     key = list(key)
# -> 5938                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5939
#    5940             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['subject_id', 'charttime', 'itemid', 'valuenum'], dtype='object')] are in the [columns]"

# %% [markdown]
# This worked for the first 7 patient chunks so will reattempt on 8 and 9

# %%
# Load patient files 8 and 9
patient_chunk_8 = pd.read_parquet('/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/03_annotated_set/final_set_split_files/patient_chunk_8.parquet')
patient_chunk_9 = pd.read_parquet('/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/03_annotated_set/final_set_split_files/patient_chunk_9.parquet')

patient_chunks_2 = [patient_chunk_8, patient_chunk_9]

# %%
for i, patient_file in enumerate(patient_chunks_2):
  print(f'Processing patient file {patient_file}')

  patient_df = pd.read_parquet(patient_file)

  data, labels = extract_patient_data_2(patient_df, chartevents_path, feature_set_1_dynamic, time_window_hours)

  data_file_path = f'{output_dir}/data_chunk_{i}.parquet'
  labels_file_path = f'{output_dir}/labels_chunk_{i}.parquet'

  data.to_parquet(data_file_path, index=False)
  labels.to_parquet(labels_file_path, index=False)

  print(f"Saved data and labels for patient file {i} to {output_dir}")
# Out:
# Processing patient file        subject_id   hadm_id   stay_id ventilation_starttime  \
# 20810    18043820  25736266  37330264   2187-03-20 14:05:00
# 20812    18044289  23747254  32716668   2153-06-26 11:40:00
# 20813    18044722  23096487  33401395   2133-04-22 05:00:00
# 20822    18046344  22674038  30198295   2118-12-30 23:41:00
# 20824    18049351  28941140  37164191   2170-05-16 17:00:00
# ...           ...       ...       ...                   ...
# 23553    19034482  28077278  31136798   2140-04-28 18:06:00
# 23556    19034841  25036939  37384421   2177-11-01 08:00:00
# 23557    19036639  23424336  30354179   2152-08-03 19:23:00
# 23560    19039155  28887061  33701331   2169-12-03 00:00:00
# 23562    19040738  26585450  35842035   2143-08-13 04:00:00
#
#       ventilation_endtime  ventilation_itemid ventilation_ordercategoryname  \
# 20810 2187-03-21 15:32:00              225792                   Ventilation
# 20812 2153-06-27 16:45:00              225792                   Ventilation
# 20813 2133-04-23 14:31:00              225792                   Ventilation
# 20822 2119-01-02 09:20:00              225792                   Ventilation
# 20824 2170-05-19 09:15:00              225792                   Ventilation
# ...                   ...                 ...                           ...
# 23553 2140-05-03 08:46:00              225792                   Ventilation
# 23556 2177-11-06 06:56:00              225792                   Ventilation
# 23557 2152-08-08 07:44:00              225792                   Ventilation
# 23560 2169-12-07 12:20:00              225792                   Ventilation
# 23562 2143-08-14 12:46:00              225792                   Ventilation
#
#       extubation_starttime  extubation_endtime  extubation_itemid  \
# 20810  2187-03-21 15:33:00 2187-03-21 15:34:00             227194
# 20812  2153-06-27 16:45:00 2153-06-27 16:46:00             227194
# 20813  2133-04-23 14:36:00 2133-04-23 14:37:00             227194
# 20822  2119-01-02 09:20:00 2119-01-02 09:21:00             227194
# 20824  2170-05-19 09:15:00 2170-05-19 09:16:00             227194
# ...                    ...                 ...                ...
# 23553  2140-05-03 08:49:00 2140-05-03 08:50:00             227194
# 23556  2177-11-06 06:57:00 2177-11-06 06:58:00             227194
# 23557  2152-08-08 07:44:00 2152-08-08 07:45:00             227194
# 23560  2169-12-07 12:20:00 2169-12-07 12:21:00             227194
# 23562  2143-08-14 12:46:00 2143-08-14 12:47:00             227194
#
#       extubation_ordercategoryname  ventilation_duration  anchor_age  \
# 20810        Intubation/Extubation                1527.0          79
# 20812        Intubation/Extubation                1745.0          26
# 20813        Intubation/Extubation                2011.0          41
# 20822        Intubation/Extubation                3459.0          33
# 20824        Intubation/Extubation                3855.0          66
# ...                            ...                   ...         ...
# 23553        Intubation/Extubation                6640.0          79
# 23556        Intubation/Extubation                7136.0          87
# 23557        Intubation/Extubation                6501.0          21
# 23560        Intubation/Extubation                6500.0          51
# 23562        Intubation/Extubation                1966.0          67
#
#        extubation_failure
# 20810                   0
# 20812                   0
# 20813                   0
# 20822                   0
# 20824                   0
# ...                   ...
# 23553                   1
# 23556                   0
# 23557                   0
# 23560                   0
# 23562                   0
#
# [597 rows x 14 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-9449835914b6> in <cell line: 1>()
#       2   print(f'Processing patient file {patient_file}')
#       3
# ----> 4   patient_df = pd.read_parquet(patient_file)
#       5
#       6   data, labels = extract_patient_data_2(patient_df, chartevents_path, feature_set_1_dynamic, time_window_hours)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parquet.py in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, **kwargs)
#     507     check_dtype_backend(dtype_backend)
#     508
# --> 509     return impl.read(
#     510         path,
#     511         columns=columns,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parquet.py in read(self, path, columns, use_nullable_dtypes, dtype_backend, storage_options, **kwargs)
#     225         )
#     226         try:
# --> 227             pa_table = self.api.parquet.read_table(
#     228                 path_or_handle, columns=columns, **kwargs
#     229             )
#
# /usr/local/lib/python3.10/dist-packages/pyarrow/parquet/core.py in read_table(source, columns, use_threads, metadata, schema, use_pandas_metadata, read_dictionary, memory_map, buffer_size, partitioning, filesystem, filters, use_legacy_dataset, ignore_prefixes, pre_buffer, coerce_int96_timestamp_unit, decryption_properties, thrift_string_size_limit, thrift_container_size_limit)
#    2954             )
#    2955         try:
# -> 2956             dataset = _ParquetDatasetV2(
#    2957                 source,
#    2958                 schema=schema,
#
# /usr/local/lib/python3.10/dist-packages/pyarrow/parquet/core.py in __init__(self, path_or_paths, filesystem, filters, partitioning, read_dictionary, buffer_size, memory_map, ignore_prefixes, pre_buffer, coerce_int96_timestamp_unit, schema, decryption_properties, thrift_string_size_limit, thrift_container_size_limit, **kwargs)
#    2491
#    2492         if single_file is not None:
# -> 2493             fragment = parquet_format.make_fragment(single_file, filesystem)
#    2494
#    2495             self._dataset = ds.FileSystemDataset(
#
# /usr/local/lib/python3.10/dist-packages/pyarrow/_dataset_parquet.pyx in pyarrow._dataset_parquet.ParquetFileFormat.make_fragment()
#
# /usr/local/lib/python3.10/dist-packages/pyarrow/_dataset.pyx in pyarrow._dataset.FileFormat.make_fragment()
#
# /usr/local/lib/python3.10/dist-packages/pyarrow/_dataset.pyx in pyarrow._dataset._make_file_source()
#
# TypeError: cannot construct a FileSource from        subject_id   hadm_id   stay_id ventilation_starttime  \
# 20810    18043820  25736266  37330264   2187-03-20 14:05:00
# 20812    18044289  23747254  32716668   2153-06-26 11:40:00
# 20813    18044722  23096487  33401395   2133-04-22 05:00:00
# 20822    18046344  22674038  30198295   2118-12-30 23:41:00
# 20824    18049351  28941140  37164191   2170-05-16 17:00:00
# ...           ...       ...       ...                   ...
# 23553    19034482  28077278  31136798   2140-04-28 18:06:00
# 23556    19034841  25036939  37384421   2177-11-01 08:00:00
# 23557    19036639  23424336  30354179   2152-08-03 19:23:00
# 23560    19039155  28887061  33701331   2169-12-03 00:00:00
# 23562    19040738  26585450  35842035   2143-08-13 04:00:00
#
#       ventilation_endtime  ventilation_itemid ventilation_ordercategoryname  \
# 20810 2187-03-21 15:32:00              225792                   Ventilation
# 20812 2153-06-27 16:45:00              225792                   Ventilation
# 20813 2133-04-23 14:31:00              225792                   Ventilation
# 20822 2119-01-02 09:20:00              225792                   Ventilation
# 20824 2170-05-19 09:15:00              225792                   Ventilation
# ...                   ...                 ...                           ...
# 23553 2140-05-03 08:46:00              225792                   Ventilation
# 23556 2177-11-06 06:56:00              225792                   Ventilation
# 23557 2152-08-08 07:44:00              225792                   Ventilation
# 23560 2169-12-07 12:20:00              225792                   Ventilation
# 23562 2143-08-14 12:46:00              225792                   Ventilation
#
#       extubation_starttime  extubation_endtime  extubation_itemid  \
# 20810  2187-03-21 15:33:00 2187-03-21 15:34:00             227194
# 20812  2153-06-27 16:45:00 2153-06-27 16:46:00             227194
# 20813  2133-04-23 14:36:00 2133-04-23 14:37:00             227194
# 20822  2119-01-02 09:20:00 2119-01-02 09:21:00             227194
# 20824  2170-05-19 09:15:00 2170-05-19 09:16:00             227194
# ...                    ...                 ...                ...
# 23553  2140-05-03 08:49:00 2140-05-03 08:50:00             227194
# 23556  2177-11-06 06:57:00 2177-11-06 06:58:00             227194
# 23557  2152-08-08 07:44:00 2152-08-08 07:45:00             227194
# 23560  2169-12-07 12:20:00 2169-12-07 12:21:00             227194
# 23562  2143-08-14 12:46:00 2143-08-14 12:47:00             227194
#
#       extubation_ordercategoryname  ventilation_duration  anchor_age  \
# 20810        Intubation/Extubation                1527.0          79
# 20812        Intubation/Extubation                1745.0          26
# 20813        Intubation/Extubation                2011.0          41
# 20822        Intubation/Extubation                3459.0          33
# 20824        Intubation/Extubation                3855.0          66
# ...                            ...                   ...         ...
# 23553        Intubation/Extubation                6640.0          79
# 23556        Intubation/Extubation                7136.0          87
# 23557        Intubation/Extubation                6501.0          21
# 23560        Intubation/Extubation                6500.0          51
# 23562        Intubation/Extubation                1966.0          67
#
#        extubation_failure
# 20810                   0
# 20812                   0
# 20813                   0
# 20822                   0
# 20824                   0
# ...                   ...
# 23553                   1
# 23556                   0
# 23557                   0
# 23560                   0
# 23562                   0
#
# [597 rows x 14 columns]

# %% [markdown]
# There seems to be an issue with files 8 and 9 so further investigation will be carried out

# %%
# Load set 8
chunk_8 = '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/03_annotated_set/final_set_split_files/patient_chunk_8.parquet'
patient_chunk_8 = pd.read_parquet(chunk_8)
patient_chunk_8.head()
# Out:
#        subject_id   hadm_id   stay_id ventilation_starttime  \
# 20810    18043820  25736266  37330264   2187-03-20 14:05:00
# 20812    18044289  23747254  32716668   2153-06-26 11:40:00
# 20813    18044722  23096487  33401395   2133-04-22 05:00:00
# 20822    18046344  22674038  30198295   2118-12-30 23:41:00
# 20824    18049351  28941140  37164191   2170-05-16 17:00:00
#
#       ventilation_endtime  ventilation_itemid ventilation_ordercategoryname  \
# 20810 2187-03-21 15:32:00              225792                   Ventilation
# 20812 2153-06-27 16:45:00              225792                   Ventilation
# 20813 2133-04-23 14:31:00              225792                   Ventilation
# 20822 2119-01-02 09:20:00              225792                   Ventilation
# 20824 2170-05-19 09:15:00              225792                   Ventilation
#
#       extubation_starttime  extubation_endtime  extubation_itemid  \
# 20810  2187-03-21 15:33:00 2187-03-21 15:34:00             227194
# 20812  2153-06-27 16:45:00 2153-06-27 16:46:00             227194
# 20813  2133-04-23 14:36:00 2133-04-23 14:37:00             227194
# 20822  2119-01-02 09:20:00 2119-01-02 09:21:00             227194
# 20824  2170-05-19 09:15:00 2170-05-19 09:16:00             227194
#
#       extubation_ordercategoryname  ventilation_duration  anchor_age  \
# 20810        Intubation/Extubation                1527.0          79
# 20812        Intubation/Extubation                1745.0          26
# 20813        Intubation/Extubation                2011.0          41
# 20822        Intubation/Extubation                3459.0          33
# 20824        Intubation/Extubation                3855.0          66
#
#        extubation_failure
# 20810                   0
# 20812                   0
# 20813                   0
# 20822                   0
# 20824                   0

# %%
# Run extraction on chunk 8
data_8, labels_8 = extract_patient_data_2(patient_chunk_8, chartevents_path, feature_set_1_dynamic, time_window_hours)

data_8_file_path = f'{output_dir}/data_chunk_{8}.parquet'
labels_8_file_path = f'{output_dir}/labels_chunk_{8}.parquet'

data_8.to_parquet(data_8_file_path, index=False)
labels_8.to_parquet(labels_8_file_path, index=False)

print(f"Saved data and labels for patient file to {output_dir}")
# Out:
# Processed 100000 rows
# Processed 200000 rows
# Processed 300000 rows
# Processed 400000 rows
# Processed 500000 rows
# Processed 600000 rows
# Processed 700000 rows
# Processed 800000 rows
# Processed 900000 rows
# Processed 1000000 rows
# Processed 1100000 rows
# Processed 1200000 rows
# Processed 1300000 rows
# Processed 1400000 rows
# Processed 1500000 rows
# Processed 1600000 rows
# Processed 1700000 rows
# Processed 1800000 rows
# Processed 1900000 rows
# Processed 2000000 rows
# Processed 2100000 rows
# Processed 2200000 rows
# Processed 2300000 rows
# Processed 2400000 rows
# Processed 2500000 rows
# Processed 2600000 rows
# Processed 2700000 rows
# Processed 2800000 rows
# Processed 2900000 rows
# Processed 3000000 rows
# Processed 3100000 rows
# Processed 3200000 rows
# Processed 3300000 rows
# Processed 3400000 rows
# Processed 3500000 rows
# Processed 3600000 rows
# Processed 3700000 rows
# Processed 3800000 rows
# Processed 3900000 rows
# Processed 4000000 rows
# Processed 4100000 rows
# Processed 4200000 rows
# Processed 4300000 rows
# Processed 4400000 rows
# Processed 4500000 rows
# Processed 4600000 rows
# Processed 4700000 rows
# Processed 4800000 rows
# Processed 4900000 rows
# Processed 5000000 rows
# Processed 5100000 rows
# Processed 5200000 rows
# Processed 5300000 rows
# Processed 5400000 rows
# Processed 5500000 rows
# Processed 5600000 rows
# Processed 5700000 rows
# Processed 5800000 rows
# Processed 5900000 rows
# Processed 6000000 rows
# Processed 6100000 rows
# Processed 6200000 rows
# Processed 6300000 rows
# Processed 6400000 rows
# Processed 6500000 rows
# Processed 6600000 rows
# Processed 6700000 rows
# Processed 6800000 rows
# Processed 6900000 rows
# Processed 7000000 rows
# Processed 7100000 rows
# Processed 7200000 rows
# Processed 7300000 rows
# Processed 7400000 rows
# Processed 7500000 rows
# Processed 7600000 rows
# Processed 7700000 rows
# Processed 7800000 rows
# Processed 7900000 rows
# Processed 8000000 rows
# Processed 8100000 rows
# Processed 8200000 rows
# Processed 8300000 rows
# Processed 8400000 rows
# Processed 8500000 rows
# Processed 8600000 rows
# Processed 8700000 rows
# Processed 8800000 rows
# Processed 8900000 rows
# Processed 9000000 rows
# Processed 9100000 rows
# Processed 9200000 rows
# Processed 9300000 rows
# Processed 9400000 rows
# Processed 9500000 rows
# Processed 9600000 rows
# Processed 9700000 rows
# Processed 9800000 rows
# Processed 9900000 rows
# Processed 10000000 rows
# Processed 10100000 rows
# Processed 10200000 rows
# Processed 10300000 rows
# Processed 10400000 rows
# Processed 10500000 rows
# Processed 10600000 rows
# Processed 10700000 rows
# Processed 10800000 rows
# Processed 10900000 rows
# Processed 11000000 rows
# Processed 11100000 rows
# Processed 11200000 rows
# Processed 11300000 rows
# Processed 11400000 rows
# Processed 11500000 rows
# Processed 11600000 rows
# Processed 11700000 rows
# Processed 11800000 rows
# Processed 11900000 rows
# Processed 12000000 rows
# Processed 12100000 rows
# Processed 12200000 rows
# Processed 12300000 rows
# Processed 12400000 rows
# Processed 12500000 rows
# Processed 12600000 rows
# Processed 12700000 rows
# Processed 12800000 rows
# Processed 12900000 rows
# Processed 13000000 rows
# Processed 13100000 rows
# Processed 13200000 rows
# Processed 13300000 rows
# Processed 13400000 rows
# Processed 13500000 rows
# Processed 13600000 rows
# Processed 13700000 rows
# Processed 13800000 rows
# Processed 13900000 rows
# Processed 14000000 rows
# Processed 14100000 rows
# Processed 14200000 rows
# Processed 14300000 rows
# Processed 14400000 rows
# Processed 14500000 rows
# Processed 14600000 rows
# Processed 14700000 rows
# Processed 14800000 rows
# Processed 14900000 rows
# Processed 15000000 rows
# Processed 15100000 rows
# Processed 15200000 rows
# Processed 15300000 rows
# Processed 15400000 rows
# Processed 15500000 rows
# Processed 15600000 rows
# Processed 15700000 rows
# Processed 15800000 rows
# Processed 15900000 rows
# Processed 16000000 rows
# Processed 16100000 rows
# Processed 16200000 rows
# Processed 16300000 rows
# Processed 16400000 rows
# Processed 16500000 rows
# Processed 16600000 rows
# Processed 16700000 rows
# Processed 16800000 rows
# Processed 16900000 rows
# Processed 17000000 rows
# Processed 17100000 rows
# Processed 17200000 rows
# Processed 17300000 rows
# Processed 17400000 rows
# Processed 17500000 rows
# Processed 17600000 rows
# Processed 17700000 rows
# Processed 17800000 rows
# Processed 17900000 rows
# Processed 18000000 rows
# Processed 18100000 rows
# Processed 18200000 rows
# Processed 18300000 rows
# Processed 18400000 rows
# Processed 18500000 rows
# Processed 18600000 rows
# Processed 18700000 rows
# Processed 18800000 rows
# Processed 18900000 rows
# Processed 19000000 rows
# Processed 19100000 rows
# Processed 19200000 rows
# Processed 19300000 rows
# Processed 19400000 rows
# Processed 19500000 rows
# Processed 19600000 rows
# Processed 19700000 rows
# Processed 19800000 rows
# Processed 19900000 rows
# Processed 20000000 rows
# Processed 20100000 rows
# Processed 20200000 rows
# Processed 20300000 rows
# Processed 20400000 rows
# Processed 20500000 rows
# Processed 20600000 rows
# Processed 20700000 rows
# Processed 20800000 rows
# Processed 20900000 rows
# Processed 21000000 rows
# Processed 21100000 rows
# Processed 21200000 rows
# Processed 21300000 rows
# Processed 21400000 rows
# Processed 21500000 rows
# Processed 21600000 rows
# Processed 21700000 rows
# Processed 21800000 rows
# Processed 21900000 rows
# Processed 22000000 rows
# Processed 22100000 rows
# Processed 22200000 rows
# Processed 22300000 rows
# Processed 22400000 rows
# Processed 22500000 rows
# Processed 22600000 rows
# Processed 22700000 rows
# Processed 22800000 rows
# Processed 22900000 rows
# Processed 23000000 rows
# Processed 23100000 rows
# Processed 23200000 rows
# Processed 23300000 rows
# Processed 23400000 rows
# Processed 23500000 rows
# Processed 23600000 rows
# Processed 23700000 rows
# Processed 23800000 rows
# Processed 23900000 rows
# Processed 24000000 rows
# Processed 24100000 rows
# Processed 24200000 rows
# Processed 24300000 rows
# Processed 24400000 rows
# Processed 24500000 rows
# Processed 24600000 rows
# Processed 24700000 rows
# Processed 24800000 rows
# Processed 24900000 rows
# Processed 25000000 rows
# Processed 25100000 rows
# Processed 25200000 rows
# Processed 25300000 rows
# Processed 25400000 rows
# Processed 25500000 rows
# Processed 25600000 rows
# Processed 25700000 rows
# Processed 25800000 rows
# Processed 25900000 rows
# Processed 26000000 rows
# Processed 26100000 rows
# Processed 26200000 rows
# Processed 26300000 rows
# Processed 26400000 rows
# Processed 26500000 rows
# Processed 26600000 rows
# Processed 26700000 rows
# Processed 26800000 rows
# Processed 26900000 rows
# Processed 27000000 rows
# Processed 27100000 rows
# Processed 27200000 rows
# Processed 27300000 rows
# Processed 27400000 rows
# Processed 27500000 rows
# Processed 27600000 rows
# Processed 27700000 rows
# Processed 27800000 rows
# Processed 27900000 rows
# Processed 28000000 rows
# Processed 28100000 rows
# Processed 28200000 rows
# Processed 28300000 rows
# Processed 28400000 rows
# Processed 28500000 rows
# Processed 28600000 rows
# Processed 28700000 rows
# Processed 28800000 rows
# Processed 28900000 rows
# Processed 29000000 rows
# Processed 29100000 rows
# Processed 29200000 rows
# Processed 29300000 rows
# Processed 29400000 rows
# Processed 29500000 rows
# Processed 29600000 rows
# Processed 29700000 rows
# Processed 29800000 rows
# Processed 29900000 rows
# Processed 30000000 rows
# Processed 30100000 rows
# Processed 30200000 rows
# Processed 30300000 rows
# Processed 30400000 rows
# Processed 30500000 rows
# Processed 30600000 rows
# Processed 30700000 rows
# Processed 30800000 rows
# Processed 30900000 rows
# Processed 31000000 rows
# Processed 31100000 rows
# Processed 31200000 rows
# Processed 31300000 rows
# Processed 31400000 rows
# Processed 31500000 rows
# Processed 31600000 rows
# Processed 31700000 rows
# Processed 31800000 rows
# Processed 31900000 rows
# Processed 32000000 rows
# Processed 32100000 rows
# Processed 32200000 rows
# Processed 32300000 rows
# Processed 32400000 rows
# Processed 32500000 rows
# Processed 32600000 rows
# Processed 32700000 rows
# Processed 32800000 rows
# Processed 32900000 rows
# Processed 33000000 rows
# Processed 33100000 rows
# Processed 33200000 rows
# Processed 33300000 rows
# Processed 33400000 rows
# Processed 33500000 rows
# Processed 33600000 rows
# Processed 33700000 rows
# Processed 33800000 rows
# Processed 33900000 rows
# Processed 34000000 rows
# Processed 34100000 rows
# Processed 34200000 rows
# Processed 34300000 rows
# Processed 34400000 rows
# Processed 34500000 rows
# Processed 34600000 rows
# Processed 34700000 rows
# Processed 34800000 rows
# Processed 34900000 rows
# Processed 35000000 rows
# Processed 35100000 rows
# Processed 35200000 rows
# Processed 35300000 rows
# Processed 35400000 rows
# Processed 35500000 rows
# Processed 35600000 rows
# Processed 35700000 rows
# Processed 35800000 rows
# Processed 35900000 rows
# Processed 36000000 rows
# Processed 36100000 rows
# Processed 36200000 rows
# Processed 36300000 rows
# Processed 36400000 rows
# Processed 36500000 rows
# Processed 36600000 rows
# Processed 36700000 rows
# Processed 36800000 rows
# Processed 36900000 rows
# Processed 37000000 rows
# Processed 37100000 rows
# Processed 37200000 rows
# Processed 37300000 rows
# Processed 37400000 rows
# Processed 37500000 rows
# Processed 37600000 rows
# Processed 37700000 rows
# Processed 37800000 rows
# Processed 37900000 rows
# Processed 38000000 rows
# Processed 38100000 rows
# Processed 38200000 rows
# Processed 38300000 rows
# Processed 38400000 rows
# Processed 38500000 rows
# Processed 38600000 rows
# Processed 38700000 rows
# Processed 38800000 rows
# Processed 38900000 rows
# Processed 39000000 rows
# Processed 39100000 rows
# Processed 39200000 rows
# Processed 39300000 rows
# Processed 39400000 rows
# Processed 39500000 rows
# Processed 39600000 rows
# Processed 39700000 rows
# Processed 39800000 rows
# Processed 39900000 rows
# Processed 40000000 rows
# Processed 40100000 rows
# Processed 40200000 rows
# Processed 40300000 rows
# Processed 40400000 rows
# Processed 40500000 rows
# Processed 40600000 rows
# Processed 40700000 rows
# Processed 40800000 rows
# Processed 40900000 rows
# Processed 41000000 rows
# Processed 41100000 rows
# Processed 41200000 rows
# Processed 41300000 rows
# Processed 41400000 rows
# Processed 41500000 rows
# Processed 41600000 rows
# Processed 41700000 rows
# Processed 41800000 rows
# Processed 41900000 rows
# Processed 42000000 rows
# Processed 42100000 rows
# Processed 42200000 rows
# Processed 42300000 rows
# Processed 42400000 rows
# Processed 42500000 rows
# Processed 42600000 rows
# Processed 42700000 rows
# Processed 42800000 rows
# Processed 42900000 rows
# Processed 43000000 rows
# Processed 43100000 rows
# Processed 43200000 rows
# Processed 43300000 rows
# Processed 43400000 rows
# Processed 43500000 rows
# Processed 43600000 rows
# Processed 43700000 rows
# Processed 43800000 rows
# Processed 43900000 rows
# Processed 44000000 rows
# Processed 44100000 rows
# Processed 44200000 rows
# Processed 44300000 rows
# Processed 44400000 rows
# Processed 44500000 rows
# Processed 44600000 rows
# Processed 44700000 rows
# Processed 44800000 rows
# Processed 44900000 rows
# Processed 45000000 rows
# Processed 45100000 rows
# Processed 45200000 rows
# Processed 45300000 rows
# Processed 45400000 rows
# Processed 45500000 rows
# Processed 45600000 rows
# Processed 45700000 rows
# Processed 45800000 rows
# Processed 45900000 rows
# Processed 46000000 rows
# Processed 46100000 rows
# Processed 46200000 rows
# Processed 46300000 rows
# Processed 46400000 rows
# Processed 46500000 rows
# Processed 46600000 rows
# Processed 46700000 rows
# Processed 46800000 rows
# Processed 46900000 rows
# Processed 47000000 rows
# Processed 47100000 rows
# Processed 47200000 rows
# Processed 47300000 rows
# Processed 47400000 rows
# Processed 47500000 rows
# Processed 47600000 rows
# Processed 47700000 rows
# Processed 47800000 rows
# Processed 47900000 rows
# Processed 48000000 rows
# Processed 48100000 rows
# Processed 48200000 rows
# Processed 48300000 rows
# Processed 48400000 rows
# Processed 48500000 rows
# Processed 48600000 rows
# Processed 48700000 rows
# Processed 48800000 rows
# Processed 48900000 rows
# Processed 49000000 rows
# Processed 49100000 rows
# Processed 49200000 rows
# Processed 49300000 rows
# Processed 49400000 rows
# Processed 49500000 rows
# Processed 49600000 rows
# Processed 49700000 rows
# Processed 49800000 rows
# Processed 49900000 rows
# Processed 50000000 rows
# Processed 50100000 rows
# Processed 50200000 rows
# Processed 50300000 rows
# Processed 50400000 rows
# Processed 50500000 rows
# Processed 50600000 rows
# Processed 50700000 rows
# Processed 50800000 rows
# Processed 50900000 rows
# Processed 51000000 rows
# Processed 51100000 rows
# Processed 51200000 rows
# Processed 51300000 rows
# Processed 51400000 rows
# Processed 51500000 rows
# Processed 51600000 rows
# Processed 51700000 rows
# Processed 51800000 rows
# Processed 51900000 rows
# Processed 52000000 rows
# Processed 52100000 rows
# Processed 52200000 rows
# Processed 52300000 rows
# Processed 52400000 rows
# Processed 52500000 rows
# Processed 52600000 rows
# Processed 52700000 rows
# Processed 52800000 rows
# Processed 52900000 rows
# Processed 53000000 rows
# Processed 53100000 rows
# Processed 53200000 rows
# Processed 53300000 rows
# Processed 53400000 rows
# Processed 53500000 rows
# Processed 53600000 rows
# Processed 53700000 rows
# Processed 53800000 rows
# Processed 53900000 rows
# Processed 54000000 rows
# Processed 54100000 rows
# Processed 54200000 rows
# Processed 54300000 rows
# Processed 54400000 rows
# Processed 54500000 rows
# Processed 54600000 rows
# Processed 54700000 rows
# Processed 54800000 rows
# Processed 54900000 rows
# Processed 55000000 rows
# Processed 55100000 rows
# Processed 55200000 rows
# Processed 55300000 rows
# Processed 55400000 rows
# Processed 55500000 rows
# Processed 55600000 rows
# Processed 55700000 rows
# Processed 55800000 rows
# Processed 55900000 rows
# Processed 56000000 rows
# Processed 56100000 rows
# Processed 56200000 rows
# Processed 56300000 rows
# Processed 56400000 rows
# Processed 56500000 rows
# Processed 56600000 rows
# Processed 56700000 rows
# Processed 56800000 rows
# Processed 56900000 rows
# Processed 57000000 rows
# Processed 57100000 rows
# Processed 57200000 rows
# Processed 57300000 rows
# Processed 57400000 rows
# Processed 57500000 rows
# Processed 57600000 rows
# Processed 57700000 rows
# Processed 57800000 rows
# Processed 57900000 rows
# Processed 58000000 rows
# Processed 58100000 rows
# Processed 58200000 rows
# Processed 58300000 rows
# Processed 58400000 rows
# Processed 58500000 rows
# Processed 58600000 rows
# Processed 58700000 rows
# Processed 58800000 rows
# Processed 58900000 rows
# Processed 59000000 rows
# Processed 59100000 rows
# Processed 59200000 rows
# Processed 59300000 rows
# Processed 59400000 rows
# Processed 59500000 rows
# Processed 59600000 rows
# Processed 59700000 rows
# Processed 59800000 rows
# Processed 59900000 rows
# Processed 60000000 rows
# Processed 60100000 rows
# Processed 60200000 rows
# Processed 60300000 rows
# Processed 60400000 rows
# Processed 60500000 rows
# Processed 60600000 rows
# Processed 60700000 rows
# Processed 60800000 rows
# Processed 60900000 rows
# Processed 61000000 rows
# Processed 61100000 rows
# Processed 61200000 rows
# Processed 61300000 rows
# Processed 61400000 rows
# Processed 61500000 rows
# Processed 61600000 rows
# Processed 61700000 rows
# Processed 61800000 rows
# Processed 61900000 rows
# Processed 62000000 rows
# Processed 62100000 rows
# Processed 62200000 rows
# Processed 62300000 rows
# Processed 62400000 rows
# Processed 62500000 rows
# Processed 62600000 rows
# Processed 62700000 rows
# Processed 62800000 rows
# Processed 62900000 rows
# Processed 63000000 rows
# Processed 63100000 rows
# Processed 63200000 rows
# Processed 63300000 rows
# Processed 63400000 rows
# Processed 63500000 rows
# Processed 63600000 rows
# Processed 63700000 rows
# Processed 63800000 rows
# Processed 63900000 rows
# Processed 64000000 rows
# Processed 64100000 rows
# Processed 64200000 rows
# Processed 64300000 rows
# Processed 64400000 rows
# Processed 64500000 rows
# Processed 64600000 rows
# Processed 64700000 rows
# Processed 64800000 rows
# Processed 64900000 rows
# Processed 65000000 rows
# Processed 65100000 rows
# Processed 65200000 rows
# Processed 65300000 rows
# Processed 65400000 rows
# Processed 65500000 rows
# Processed 65600000 rows
# Processed 65700000 rows
# Processed 65800000 rows
# Processed 65900000 rows
# Processed 66000000 rows
# Processed 66100000 rows
# Processed 66200000 rows
# Processed 66300000 rows
# Processed 66400000 rows
# Processed 66500000 rows
# Processed 66600000 rows
# Processed 66700000 rows
# Processed 66800000 rows
# Processed 66900000 rows
# Processed 67000000 rows
# Processed 67100000 rows
# Processed 67200000 rows
# Processed 67300000 rows
# Processed 67400000 rows
# Processed 67500000 rows
# Processed 67600000 rows
# Processed 67700000 rows
# Processed 67800000 rows
# Processed 67900000 rows
# Processed 68000000 rows
# Processed 68100000 rows
# Processed 68200000 rows
# Processed 68300000 rows
# Processed 68400000 rows
# Processed 68500000 rows
# Processed 68600000 rows
# Processed 68700000 rows
# Processed 68800000 rows
# Processed 68900000 rows
# Processed 69000000 rows
# Processed 69100000 rows
# Processed 69200000 rows
# Processed 69300000 rows
# Processed 69400000 rows
# Processed 69500000 rows
# Processed 69600000 rows
# Processed 69700000 rows
# Processed 69800000 rows
# Processed 69900000 rows
# Processed 70000000 rows
# Processed 70100000 rows
# Processed 70200000 rows
# Processed 70300000 rows
# Processed 70400000 rows
# Processed 70500000 rows
# Processed 70600000 rows
# Processed 70700000 rows
# Processed 70800000 rows
# Processed 70900000 rows
# Processed 71000000 rows
# Processed 71100000 rows
# Processed 71200000 rows
# Processed 71300000 rows
# Processed 71400000 rows
# Processed 71500000 rows
# Processed 71600000 rows
# Processed 71700000 rows
# Processed 71800000 rows
# Processed 71900000 rows
# Processed 72000000 rows
# Processed 72100000 rows
# Processed 72200000 rows
# Processed 72300000 rows
# Processed 72400000 rows
# Processed 72500000 rows
# Processed 72600000 rows
# Processed 72700000 rows
# Processed 72800000 rows
# Processed 72900000 rows
# Processed 73000000 rows
# Processed 73100000 rows
# Processed 73200000 rows
# Processed 73300000 rows
# Processed 73400000 rows
# Processed 73500000 rows
# Processed 73600000 rows
# Processed 73700000 rows
# Processed 73800000 rows
# Processed 73900000 rows
# Processed 74000000 rows
# Processed 74100000 rows
# Processed 74200000 rows
# Processed 74300000 rows
# Processed 74400000 rows
# Processed 74500000 rows
# Processed 74600000 rows
# Processed 74700000 rows
# Processed 74800000 rows
# Processed 74900000 rows
# Processed 75000000 rows
# Processed 75100000 rows
# Processed 75200000 rows
# Processed 75300000 rows
# Processed 75400000 rows
# Processed 75500000 rows
# Processed 75600000 rows
# Processed 75700000 rows
# Processed 75800000 rows
# Processed 75900000 rows
# Processed 76000000 rows
# Processed 76100000 rows
# Processed 76200000 rows
# Processed 76300000 rows
# Processed 76400000 rows
# Processed 76500000 rows
# Processed 76600000 rows
# Processed 76700000 rows
# Processed 76800000 rows
# Processed 76900000 rows
# Processed 77000000 rows
# Processed 77100000 rows
# Processed 77200000 rows
# Processed 77300000 rows
# Processed 77400000 rows
# Processed 77500000 rows
# Processed 77600000 rows
# Processed 77700000 rows
# Processed 77800000 rows
# Processed 77900000 rows
# Processed 78000000 rows
# Processed 78100000 rows
# Processed 78200000 rows
# Processed 78300000 rows
# Processed 78400000 rows
# Processed 78500000 rows
# Processed 78600000 rows
# Processed 78700000 rows
# Processed 78800000 rows
# Processed 78900000 rows
# Processed 79000000 rows
# Processed 79100000 rows
# Processed 79200000 rows
# Processed 79300000 rows
# Processed 79400000 rows
# Processed 79500000 rows
# Processed 79600000 rows
# Processed 79700000 rows
# Processed 79800000 rows
# Processed 79900000 rows
# Processed 80000000 rows
# Processed 80100000 rows
# Processed 80200000 rows
# Processed 80300000 rows
# Processed 80400000 rows
# Processed 80500000 rows
# Processed 80600000 rows
# Processed 80700000 rows
# Processed 80800000 rows
# Processed 80900000 rows
# Processed 81000000 rows
# Processed 81100000 rows
# Processed 81200000 rows
# Processed 81300000 rows
# Processed 81400000 rows
# Processed 81500000 rows
# Processed 81600000 rows
# Processed 81700000 rows
# Processed 81800000 rows
# Processed 81900000 rows
# Processed 82000000 rows
# Processed 82100000 rows
# Processed 82200000 rows
# Processed 82300000 rows
# Processed 82400000 rows
# Processed 82500000 rows
# Processed 82600000 rows
# Processed 82700000 rows
# Processed 82800000 rows
# Processed 82900000 rows
# Processed 83000000 rows
# Processed 83100000 rows
# Processed 83200000 rows
# Processed 83300000 rows
# Processed 83400000 rows
# Processed 83500000 rows
# Processed 83600000 rows
# Processed 83700000 rows
# Processed 83800000 rows
# Processed 83900000 rows
# Processed 84000000 rows
# Processed 84100000 rows
# Processed 84200000 rows
# Processed 84300000 rows
# Processed 84400000 rows
# Processed 84500000 rows
# Processed 84600000 rows
# Processed 84700000 rows
# Processed 84800000 rows
# Processed 84900000 rows
# Processed 85000000 rows
# Processed 85100000 rows
# Processed 85200000 rows
# Processed 85300000 rows
# Processed 85400000 rows
# Processed 85500000 rows
# Processed 85600000 rows
# Processed 85700000 rows
# Processed 85800000 rows
# Processed 85900000 rows
# Processed 86000000 rows
# Processed 86100000 rows
# Processed 86200000 rows
# Processed 86300000 rows
# Processed 86400000 rows
# Processed 86500000 rows
# Processed 86600000 rows
# Processed 86700000 rows
# Processed 86800000 rows
# Processed 86900000 rows
# Processed 87000000 rows
# Processed 87100000 rows
# Processed 87200000 rows
# Processed 87300000 rows
# Processed 87400000 rows
# Processed 87500000 rows
# Processed 87600000 rows
# Processed 87700000 rows
# Processed 87800000 rows
# Processed 87900000 rows
# Processed 88000000 rows
# Processed 88100000 rows
# Processed 88200000 rows
# Processed 88300000 rows
# Processed 88400000 rows
# Processed 88500000 rows
# Processed 88600000 rows
# Processed 88700000 rows
# Processed 88800000 rows
# Processed 88900000 rows
# Processed 89000000 rows
# Processed 89100000 rows
# Processed 89200000 rows
# Processed 89300000 rows
# Processed 89400000 rows
# Processed 89500000 rows
# Processed 89600000 rows
# Processed 89700000 rows
# Processed 89800000 rows
# Processed 89900000 rows
# Processed 90000000 rows
# Processed 90100000 rows
# Processed 90200000 rows
# Processed 90300000 rows
# Processed 90400000 rows
# Processed 90500000 rows
# Processed 90600000 rows
# Processed 90700000 rows
# Processed 90800000 rows
# Processed 90900000 rows
# Processed 91000000 rows
# Processed 91100000 rows
# Processed 91200000 rows
# Processed 91300000 rows
# Processed 91400000 rows
# Processed 91500000 rows
# Processed 91600000 rows
# Processed 91700000 rows
# Processed 91800000 rows
# Processed 91900000 rows
# Processed 92000000 rows
# Processed 92100000 rows
# Processed 92200000 rows
# Processed 92300000 rows
# Processed 92400000 rows
# Processed 92500000 rows
# Processed 92600000 rows
# Processed 92700000 rows
# Processed 92800000 rows
# Processed 92900000 rows
# Processed 93000000 rows
# Processed 93100000 rows
# Processed 93200000 rows
# Processed 93300000 rows
# Processed 93400000 rows
# Processed 93500000 rows
# Processed 93600000 rows
# Processed 93700000 rows
# Processed 93800000 rows
# Processed 93900000 rows
# Processed 94000000 rows
# Processed 94100000 rows
# Processed 94200000 rows
# Processed 94300000 rows
# Processed 94400000 rows
# Processed 94500000 rows
# Processed 94600000 rows
# Processed 94700000 rows
# Processed 94800000 rows
# Processed 94900000 rows
# Processed 95000000 rows
# Processed 95100000 rows
# Processed 95200000 rows
# Processed 95300000 rows
# Processed 95400000 rows
# Processed 95500000 rows
# Processed 95600000 rows
# Processed 95700000 rows
# Processed 95800000 rows
# Processed 95900000 rows
# Processed 96000000 rows
# Processed 96100000 rows
# Processed 96200000 rows
# Processed 96300000 rows
# Processed 96400000 rows
# Processed 96500000 rows
# Processed 96600000 rows
# Processed 96700000 rows
# Processed 96800000 rows
# Processed 96900000 rows
# Processed 97000000 rows
# Processed 97100000 rows
# Processed 97200000 rows
# Processed 97300000 rows
# Processed 97400000 rows
# Processed 97500000 rows
# Processed 97600000 rows
# Processed 97700000 rows
# Processed 97800000 rows
# Processed 97900000 rows
# Processed 98000000 rows
# Processed 98100000 rows
# Processed 98200000 rows
# Processed 98300000 rows
# Processed 98400000 rows
# Processed 98500000 rows
# Processed 98600000 rows
# Processed 98700000 rows
# Processed 98800000 rows
# Processed 98900000 rows
# Processed 99000000 rows
# Processed 99100000 rows
# Processed 99200000 rows
# Processed 99300000 rows
# Processed 99400000 rows
# Processed 99500000 rows
# Processed 99600000 rows
# Processed 99700000 rows
# Processed 99800000 rows
# Processed 99900000 rows
# Processed 100000000 rows
# Processed 100100000 rows
# Processed 100200000 rows
# Processed 100300000 rows
# Processed 100400000 rows
# Processed 100500000 rows
# Processed 100600000 rows
# Processed 100700000 rows
# Processed 100800000 rows
# Processed 100900000 rows
# Processed 101000000 rows
# Processed 101100000 rows
# Processed 101200000 rows
# Processed 101300000 rows
# Processed 101400000 rows
# Processed 101500000 rows
# Processed 101600000 rows
# Processed 101700000 rows
# Processed 101800000 rows
# Processed 101900000 rows
# Processed 102000000 rows
# Processed 102100000 rows
# Processed 102200000 rows
# Processed 102300000 rows
# Processed 102400000 rows
# Processed 102500000 rows
# Processed 102600000 rows
# Processed 102700000 rows
# Processed 102800000 rows
# Processed 102900000 rows
# Processed 103000000 rows
# Processed 103100000 rows
# Processed 103200000 rows
# Processed 103300000 rows
# Processed 103400000 rows
# Processed 103500000 rows
# Processed 103600000 rows
# Processed 103700000 rows
# Processed 103800000 rows
# Processed 103900000 rows
# Processed 104000000 rows
# Processed 104100000 rows
# Processed 104200000 rows
# Processed 104300000 rows
# Processed 104400000 rows
# Processed 104500000 rows
# Processed 104600000 rows
# Processed 104700000 rows
# Processed 104800000 rows
# Processed 104900000 rows
# Processed 105000000 rows
# Processed 105100000 rows
# Processed 105200000 rows
# Processed 105300000 rows
# Processed 105400000 rows
# Processed 105500000 rows
# Processed 105600000 rows
# Processed 105700000 rows
# Processed 105800000 rows
# Processed 105900000 rows
# Processed 106000000 rows
# Processed 106100000 rows
# Processed 106200000 rows
# Processed 106300000 rows
# Processed 106400000 rows
# Processed 106500000 rows
# Processed 106600000 rows
# Processed 106700000 rows
# Processed 106800000 rows
# Processed 106900000 rows
# Processed 107000000 rows
# Processed 107100000 rows
# Processed 107200000 rows
# Processed 107300000 rows
# Processed 107400000 rows
# Processed 107500000 rows
# Processed 107600000 rows
# Processed 107700000 rows
# Processed 107800000 rows
# Processed 107900000 rows
# Processed 108000000 rows
# Processed 108100000 rows
# Processed 108200000 rows
# Processed 108300000 rows
# Processed 108400000 rows
# Processed 108500000 rows
# Processed 108600000 rows
# Processed 108700000 rows
# Processed 108800000 rows
# Processed 108900000 rows
# Processed 109000000 rows
# Processed 109100000 rows
# Processed 109200000 rows
# Processed 109300000 rows
# Processed 109400000 rows
# Processed 109500000 rows
# Processed 109600000 rows
# Processed 109700000 rows
# Processed 109800000 rows
# Processed 109900000 rows
# Processed 110000000 rows
# Processed 110100000 rows
# Processed 110200000 rows
# Processed 110300000 rows
# Processed 110400000 rows
# Processed 110500000 rows
# Processed 110600000 rows
# Processed 110700000 rows
# Processed 110800000 rows
# Processed 110900000 rows
# Processed 111000000 rows
# Processed 111100000 rows
# Processed 111200000 rows
# Processed 111300000 rows
# Processed 111400000 rows
# Processed 111500000 rows
# Processed 111600000 rows
# Processed 111700000 rows
# Processed 111800000 rows
# Processed 111900000 rows
# Processed 112000000 rows
# Processed 112100000 rows
# Processed 112200000 rows
# Processed 112300000 rows
# Processed 112400000 rows
# Processed 112500000 rows
# Processed 112600000 rows
# Processed 112700000 rows
# Processed 112800000 rows
# Processed 112900000 rows
# Processed 113000000 rows
# Processed 113100000 rows
# Processed 113200000 rows
# Processed 113300000 rows
# Processed 113400000 rows
# Processed 113500000 rows
# Processed 113600000 rows
# Processed 113700000 rows
# Processed 113800000 rows
# Processed 113900000 rows
# Processed 114000000 rows
# Processed 114100000 rows
# Processed 114200000 rows
# Processed 114300000 rows
# Processed 114400000 rows
# Processed 114500000 rows
# Processed 114600000 rows
# Processed 114700000 rows
# Processed 114800000 rows
# Processed 114900000 rows
# Processed 115000000 rows
# Processed 115100000 rows
# Processed 115200000 rows
# Processed 115300000 rows
# Processed 115400000 rows
# Processed 115500000 rows
# Processed 115600000 rows
# Processed 115700000 rows
# Processed 115800000 rows
# Processed 115900000 rows
# Processed 116000000 rows
# Processed 116100000 rows
# Processed 116200000 rows
# Processed 116300000 rows
# Processed 116400000 rows
# Processed 116500000 rows
# Processed 116600000 rows
# Processed 116700000 rows
# Processed 116800000 rows
# Processed 116900000 rows
# Processed 117000000 rows
# Processed 117100000 rows
# Processed 117200000 rows
# Processed 117300000 rows
# Processed 117400000 rows
# Processed 117500000 rows
# Processed 117600000 rows
# Processed 117700000 rows
# Processed 117800000 rows
# Processed 117900000 rows
# Processed 118000000 rows
# Processed 118100000 rows
# Processed 118200000 rows
# Processed 118300000 rows
# Processed 118400000 rows
# Processed 118500000 rows
# Processed 118600000 rows
# Processed 118700000 rows
# Processed 118800000 rows
# Processed 118900000 rows
# Processed 119000000 rows
# Processed 119100000 rows
# Processed 119200000 rows
# Processed 119300000 rows
# Processed 119400000 rows
# Processed 119500000 rows
# Processed 119600000 rows
# Processed 119700000 rows
# Processed 119800000 rows
# Processed 119900000 rows
# Processed 120000000 rows
# Processed 120100000 rows
# Processed 120200000 rows
# Processed 120300000 rows
# Processed 120400000 rows
# Processed 120500000 rows
# Processed 120600000 rows
# Processed 120700000 rows
# Processed 120800000 rows
# Processed 120900000 rows
# Processed 121000000 rows
# Processed 121100000 rows
# Processed 121200000 rows
# Processed 121300000 rows
# Processed 121400000 rows
# Processed 121500000 rows
# Processed 121600000 rows
# Processed 121700000 rows
# Processed 121800000 rows
# Processed 121900000 rows
# Processed 122000000 rows
# Processed 122100000 rows
# Processed 122200000 rows
# Processed 122300000 rows
# Processed 122400000 rows
# Processed 122500000 rows
# Processed 122600000 rows
# Processed 122700000 rows
# Processed 122800000 rows
# Processed 122900000 rows
# Processed 123000000 rows
# Processed 123100000 rows
# Processed 123200000 rows
# Processed 123300000 rows
# Processed 123400000 rows
# Processed 123500000 rows
# Processed 123600000 rows
# Processed 123700000 rows
# Processed 123800000 rows
# Processed 123900000 rows
# Processed 124000000 rows
# Processed 124100000 rows
# Processed 124200000 rows
# Processed 124300000 rows
# Processed 124400000 rows
# Processed 124500000 rows
# Processed 124600000 rows
# Processed 124700000 rows
# Processed 124800000 rows
# Processed 124900000 rows
# Processed 125000000 rows
# Processed 125100000 rows
# Processed 125200000 rows
# Processed 125300000 rows
# Processed 125400000 rows
# Processed 125500000 rows
# Processed 125600000 rows
# Processed 125700000 rows
# Processed 125800000 rows
# Processed 125900000 rows
# Processed 126000000 rows
# Processed 126100000 rows
# Processed 126200000 rows
# Processed 126300000 rows
# Processed 126400000 rows
# Processed 126500000 rows
# Processed 126600000 rows
# Processed 126700000 rows
# Processed 126800000 rows
# Processed 126900000 rows
# Processed 127000000 rows
# Processed 127100000 rows
# Processed 127200000 rows
# Processed 127300000 rows
# Processed 127400000 rows
# Processed 127500000 rows
# Processed 127600000 rows
# Processed 127700000 rows
# Processed 127800000 rows
# Processed 127900000 rows
# Processed 128000000 rows
# Processed 128100000 rows
# Processed 128200000 rows
# Processed 128300000 rows
# Processed 128400000 rows
# Processed 128500000 rows
# Processed 128600000 rows
# Processed 128700000 rows
# Processed 128800000 rows
# Processed 128900000 rows
# Processed 129000000 rows
# Processed 129100000 rows
# Processed 129200000 rows
# Processed 129300000 rows
# Processed 129400000 rows
# Processed 129500000 rows
# Processed 129600000 rows
# Processed 129700000 rows
# Processed 129800000 rows
# Processed 129900000 rows
# Processed 130000000 rows
# Processed 130100000 rows
# Processed 130200000 rows
# Processed 130300000 rows
# Processed 130400000 rows
# Processed 130500000 rows
# Processed 130600000 rows
# Processed 130700000 rows
# Processed 130800000 rows
# Processed 130900000 rows
# Processed 131000000 rows
# Processed 131100000 rows
# Processed 131200000 rows
# Processed 131300000 rows
# Processed 131400000 rows
# Processed 131500000 rows
# Processed 131600000 rows
# Processed 131700000 rows
# Processed 131800000 rows
# Processed 131900000 rows
# Processed 132000000 rows
# Processed 132100000 rows
# Processed 132200000 rows
# Processed 132300000 rows
# Processed 132400000 rows
# Processed 132500000 rows
# Processed 132600000 rows
# Processed 132700000 rows
# Processed 132800000 rows
# Processed 132900000 rows
# Processed 133000000 rows
# Processed 133100000 rows
# Processed 133200000 rows
# Processed 133300000 rows
# Processed 133400000 rows
# Processed 133500000 rows
# Processed 133600000 rows
# Processed 133700000 rows
# Processed 133800000 rows
# Processed 133900000 rows
# Processed 134000000 rows
# Processed 134100000 rows
# Processed 134200000 rows
# Processed 134300000 rows
# Processed 134400000 rows
# Processed 134500000 rows
# Processed 134600000 rows
# Processed 134700000 rows
# Processed 134800000 rows
# Processed 134900000 rows
# Processed 135000000 rows
# Processed 135100000 rows
# Processed 135200000 rows
# Processed 135300000 rows
# Processed 135400000 rows
# Processed 135500000 rows
# Processed 135600000 rows
# Processed 135700000 rows
# Processed 135800000 rows
# Processed 135900000 rows
# Processed 136000000 rows
# Processed 136100000 rows
# Processed 136200000 rows
# Processed 136300000 rows
# Processed 136400000 rows
# Processed 136500000 rows
# Processed 136600000 rows
# Processed 136700000 rows
# Processed 136800000 rows
# Processed 136900000 rows
# Processed 137000000 rows
# Processed 137100000 rows
# Processed 137200000 rows
# Processed 137300000 rows
# Processed 137400000 rows
# Processed 137500000 rows
# Processed 137600000 rows
# Processed 137700000 rows
# Processed 137800000 rows
# Processed 137900000 rows
# Processed 138000000 rows
# Processed 138100000 rows
# Processed 138200000 rows
# Processed 138300000 rows
# Processed 138400000 rows
# Processed 138500000 rows
# Processed 138600000 rows
# Processed 138700000 rows
# Processed 138800000 rows
# Processed 138900000 rows
# Processed 139000000 rows
# Processed 139100000 rows
# Processed 139200000 rows
# Processed 139300000 rows
# Processed 139400000 rows
# Processed 139500000 rows
# Processed 139600000 rows
# Processed 139700000 rows
# Processed 139800000 rows
# Processed 139900000 rows
# Processed 140000000 rows
# Processed 140100000 rows
# Processed 140200000 rows
# Processed 140300000 rows
# Processed 140400000 rows
# Processed 140500000 rows
# Processed 140600000 rows
# Processed 140700000 rows
# Processed 140800000 rows
# Processed 140900000 rows
# Processed 141000000 rows
# Processed 141100000 rows
# Processed 141200000 rows
# Processed 141300000 rows
# Processed 141400000 rows
# Processed 141500000 rows
# Processed 141600000 rows
# Processed 141700000 rows
# Processed 141800000 rows
# Processed 141900000 rows
# Processed 142000000 rows
# Processed 142100000 rows
# Processed 142200000 rows
# Processed 142300000 rows
# Processed 142400000 rows
# Processed 142500000 rows
# Processed 142600000 rows
# Processed 142700000 rows
# Processed 142800000 rows
# Processed 142900000 rows
# Processed 143000000 rows
# Processed 143100000 rows
# Processed 143200000 rows
# Processed 143300000 rows
# Processed 143400000 rows
# Processed 143500000 rows
# Processed 143600000 rows
# Processed 143700000 rows
# Processed 143800000 rows
# Processed 143900000 rows
# Processed 144000000 rows
# Processed 144100000 rows
# Processed 144200000 rows
# Processed 144300000 rows
# Processed 144400000 rows
# Processed 144500000 rows
# Processed 144600000 rows
# Processed 144700000 rows
# Processed 144800000 rows
# Processed 144900000 rows
# Processed 145000000 rows
# Processed 145100000 rows
# Processed 145200000 rows
# Processed 145300000 rows
# Processed 145400000 rows
# Processed 145500000 rows
# Processed 145600000 rows
# Processed 145700000 rows
# Processed 145800000 rows
# Processed 145900000 rows
# Processed 146000000 rows
# Processed 146100000 rows
# Processed 146200000 rows
# Processed 146300000 rows
# Processed 146400000 rows
# Processed 146500000 rows
# Processed 146600000 rows
# Processed 146700000 rows
# Processed 146800000 rows
# Processed 146900000 rows
# Processed 147000000 rows
# Processed 147100000 rows
# Processed 147200000 rows
# Processed 147300000 rows
# Processed 147400000 rows
# Processed 147500000 rows
# Processed 147600000 rows
# Processed 147700000 rows
# Processed 147800000 rows
# Processed 147900000 rows
# Processed 148000000 rows
# Processed 148100000 rows
# Processed 148200000 rows
# Processed 148300000 rows
# Processed 148400000 rows
# Processed 148500000 rows
# Processed 148600000 rows
# Processed 148700000 rows
# Processed 148800000 rows
# Processed 148900000 rows
# Processed 149000000 rows
# Processed 149100000 rows
# Processed 149200000 rows
# Processed 149300000 rows
# Processed 149400000 rows
# Processed 149500000 rows
# Processed 149600000 rows
# Processed 149700000 rows
# Processed 149800000 rows
# Processed 149900000 rows
# Processed 150000000 rows
# Processed 150100000 rows
# Processed 150200000 rows
# Processed 150300000 rows
# Processed 150400000 rows
# Processed 150500000 rows
# Processed 150600000 rows
# Processed 150700000 rows
# Processed 150800000 rows
# Processed 150900000 rows
# Processed 151000000 rows
# Processed 151100000 rows
# Processed 151200000 rows
# Processed 151300000 rows
# Processed 151400000 rows
# Processed 151500000 rows
# Processed 151600000 rows
# Processed 151700000 rows
# Processed 151800000 rows
# Processed 151900000 rows
# Processed 152000000 rows
# Processed 152100000 rows
# Processed 152200000 rows
# Processed 152300000 rows
# Processed 152400000 rows
# Processed 152500000 rows
# Processed 152600000 rows
# Processed 152700000 rows
# Processed 152800000 rows
# Processed 152900000 rows
# Processed 153000000 rows
# Processed 153100000 rows
# Processed 153200000 rows
# Processed 153300000 rows
# Processed 153400000 rows
# Processed 153500000 rows
# Processed 153600000 rows
# Processed 153700000 rows
# Processed 153800000 rows
# Processed 153900000 rows
# Processed 154000000 rows
# Processed 154100000 rows
# Processed 154200000 rows
# Processed 154300000 rows
# Processed 154400000 rows
# Processed 154500000 rows
# Processed 154600000 rows
# Processed 154700000 rows
# Processed 154800000 rows
# Processed 154900000 rows
# Processed 155000000 rows
# Processed 155100000 rows
# Processed 155200000 rows
# Processed 155300000 rows
# Processed 155400000 rows
# Processed 155500000 rows
# Processed 155600000 rows
# Processed 155700000 rows
# Processed 155800000 rows
# Processed 155900000 rows
# Processed 156000000 rows
# Processed 156100000 rows
# Processed 156200000 rows
# Processed 156300000 rows
# Processed 156400000 rows
# Processed 156500000 rows
# Processed 156600000 rows
# Processed 156700000 rows
# Processed 156800000 rows
# Processed 156900000 rows
# Processed 157000000 rows
# Processed 157100000 rows
# Processed 157200000 rows
# Processed 157300000 rows
# Processed 157400000 rows
# Processed 157500000 rows
# Processed 157600000 rows
# Processed 157700000 rows
# Processed 157800000 rows
# Processed 157900000 rows
# Processed 158000000 rows
# Processed 158100000 rows
# Processed 158200000 rows
# Processed 158300000 rows
# Processed 158400000 rows
# Processed 158500000 rows
# Processed 158600000 rows
# Processed 158700000 rows
# Processed 158800000 rows
# Processed 158900000 rows
# Processed 159000000 rows
# Processed 159100000 rows
# Processed 159200000 rows
# Processed 159300000 rows
# Processed 159400000 rows
# Processed 159500000 rows
# Processed 159600000 rows
# Processed 159700000 rows
# Processed 159800000 rows
# Processed 159900000 rows
# Processed 160000000 rows
# Processed 160100000 rows
# Processed 160200000 rows
# Processed 160300000 rows
# Processed 160400000 rows
# Processed 160500000 rows
# Processed 160600000 rows
# Processed 160700000 rows
# Processed 160800000 rows
# Processed 160900000 rows
# Processed 161000000 rows
# Processed 161100000 rows
# Processed 161200000 rows
# Processed 161300000 rows
# Processed 161400000 rows
# Processed 161500000 rows
# Processed 161600000 rows
# Processed 161700000 rows
# Processed 161800000 rows
# Processed 161900000 rows
# Processed 162000000 rows
# Processed 162100000 rows
# Processed 162200000 rows
# Processed 162300000 rows
# Processed 162400000 rows
# Processed 162500000 rows
# Processed 162600000 rows
# Processed 162700000 rows
# Processed 162800000 rows
# Processed 162900000 rows
# Processed 163000000 rows
# Processed 163100000 rows
# Processed 163200000 rows
# Processed 163300000 rows
# Processed 163400000 rows
# Processed 163500000 rows
# Processed 163600000 rows
# Processed 163700000 rows
# Processed 163800000 rows
# Processed 163900000 rows
# Processed 164000000 rows
# Processed 164100000 rows
# Processed 164200000 rows
# Processed 164300000 rows
# Processed 164400000 rows
# Processed 164500000 rows
# Processed 164600000 rows
# Processed 164700000 rows
# Processed 164800000 rows
# Processed 164900000 rows
# Processed 165000000 rows
# Processed 165100000 rows
# Processed 165200000 rows
# Processed 165300000 rows
# Processed 165400000 rows
# Processed 165500000 rows
# Processed 165600000 rows
# Processed 165700000 rows
# Processed 165800000 rows
# Processed 165900000 rows
# Processed 166000000 rows
# Processed 166100000 rows
# Processed 166200000 rows
# Processed 166300000 rows
# Processed 166400000 rows
# Processed 166500000 rows
# Processed 166600000 rows
# Processed 166700000 rows
# Processed 166800000 rows
# Processed 166900000 rows
# Processed 167000000 rows
# Processed 167100000 rows
# Processed 167200000 rows
# Processed 167300000 rows
# Processed 167400000 rows
# Processed 167500000 rows
# Processed 167600000 rows
# Processed 167700000 rows
# Processed 167800000 rows
# Processed 167900000 rows
# Processed 168000000 rows
# Processed 168100000 rows
# Processed 168200000 rows
# Processed 168300000 rows
# Processed 168400000 rows
# Processed 168500000 rows
# Processed 168600000 rows
# Processed 168700000 rows
# Processed 168800000 rows
# Processed 168900000 rows
# Processed 169000000 rows
# Processed 169100000 rows
# Processed 169200000 rows
# Processed 169300000 rows
# Processed 169400000 rows
# Processed 169500000 rows
# Processed 169600000 rows
# Processed 169700000 rows
# Processed 169800000 rows
# Processed 169900000 rows
# Processed 170000000 rows
# Processed 170100000 rows
# Processed 170200000 rows
# Processed 170300000 rows
# Processed 170400000 rows
# Processed 170500000 rows
# Processed 170600000 rows
# Processed 170700000 rows
# Processed 170800000 rows
# Processed 170900000 rows
# Processed 171000000 rows
# Processed 171100000 rows
# Processed 171200000 rows
# Processed 171300000 rows
# Processed 171400000 rows
# Processed 171500000 rows
# Processed 171600000 rows
# Processed 171700000 rows
# Processed 171800000 rows
# Processed 171900000 rows
# Processed 172000000 rows
# Processed 172100000 rows
# Processed 172200000 rows
# Processed 172300000 rows
# Processed 172400000 rows
# Processed 172500000 rows
# Processed 172600000 rows
# Processed 172700000 rows
# Processed 172800000 rows
# Processed 172900000 rows
# Processed 173000000 rows
# Processed 173100000 rows
# Processed 173200000 rows
# Processed 173300000 rows
# Processed 173400000 rows
# Processed 173500000 rows
# Processed 173600000 rows
# Processed 173700000 rows
# Processed 173800000 rows
# Processed 173900000 rows
# Processed 174000000 rows
# Processed 174100000 rows
# Processed 174200000 rows
# Processed 174300000 rows
# Processed 174400000 rows
# Processed 174500000 rows
# Processed 174600000 rows
# Processed 174700000 rows
# Processed 174800000 rows
# Processed 174900000 rows
# Processed 175000000 rows
# Processed 175100000 rows
# Processed 175200000 rows
# Processed 175300000 rows
# Processed 175400000 rows
# Processed 175500000 rows
# Processed 175600000 rows
# Processed 175700000 rows
# Processed 175800000 rows
# Processed 175900000 rows
# Processed 176000000 rows
# Processed 176100000 rows
# Processed 176200000 rows
# Processed 176300000 rows
# Processed 176400000 rows
# Processed 176500000 rows
# Processed 176600000 rows
# Processed 176700000 rows
# Processed 176800000 rows
# Processed 176900000 rows
# Processed 177000000 rows
# Processed 177100000 rows
# Processed 177200000 rows
# Processed 177300000 rows
# Processed 177400000 rows
# Processed 177500000 rows
# Processed 177600000 rows
# Processed 177700000 rows
# Processed 177800000 rows
# Processed 177900000 rows
# Processed 178000000 rows
# Processed 178100000 rows
# Processed 178200000 rows
# Processed 178300000 rows
# Processed 178400000 rows
# Processed 178500000 rows
# Processed 178600000 rows
# Processed 178700000 rows
# Processed 178800000 rows
# Processed 178900000 rows
# Processed 179000000 rows
# Processed 179100000 rows
# Processed 179200000 rows
# Processed 179300000 rows
# Processed 179400000 rows
# Processed 179500000 rows
# Processed 179600000 rows
# Processed 179700000 rows
# Processed 179800000 rows
# Processed 179900000 rows
# Processed 180000000 rows
# Processed 180100000 rows
# Processed 180200000 rows
# Processed 180300000 rows
# Processed 180400000 rows
# Processed 180500000 rows
# Processed 180600000 rows
# Processed 180700000 rows
# Processed 180800000 rows
# Processed 180900000 rows
# Processed 181000000 rows
# Processed 181100000 rows
# Processed 181200000 rows
# Processed 181300000 rows
# Processed 181400000 rows
# Processed 181500000 rows
# Processed 181600000 rows
# Processed 181700000 rows
# Processed 181800000 rows
# Processed 181900000 rows
# Processed 182000000 rows
# Processed 182100000 rows
# Processed 182200000 rows
# Processed 182300000 rows
# Processed 182400000 rows
# Processed 182500000 rows
# Processed 182600000 rows
# Processed 182700000 rows
# Processed 182800000 rows
# Processed 182900000 rows
# Processed 183000000 rows
# Processed 183100000 rows
# Processed 183200000 rows
# Processed 183300000 rows
# Processed 183400000 rows
# Processed 183500000 rows
# Processed 183600000 rows
# Processed 183700000 rows
# Processed 183800000 rows
# Processed 183900000 rows
# Processed 184000000 rows
# Processed 184100000 rows
# Processed 184200000 rows
# Processed 184300000 rows
# Processed 184400000 rows
# Processed 184500000 rows
# Processed 184600000 rows
# Processed 184700000 rows
# Processed 184800000 rows
# Processed 184900000 rows
# Processed 185000000 rows
# Processed 185100000 rows
# Processed 185200000 rows
# Processed 185300000 rows
# Processed 185400000 rows
# Processed 185500000 rows
# Processed 185600000 rows
# Processed 185700000 rows
# Processed 185800000 rows
# Processed 185900000 rows
# Processed 186000000 rows
# Processed 186100000 rows
# Processed 186200000 rows
# Processed 186300000 rows
# Processed 186400000 rows
# Processed 186500000 rows
# Processed 186600000 rows
# Processed 186700000 rows
# Processed 186800000 rows
# Processed 186900000 rows
# Processed 187000000 rows
# Processed 187100000 rows
# Processed 187200000 rows
# Processed 187300000 rows
# Processed 187400000 rows
# Processed 187500000 rows
# Processed 187600000 rows
# Processed 187700000 rows
# Processed 187800000 rows
# Processed 187900000 rows
# Processed 188000000 rows
# Processed 188100000 rows
# Processed 188200000 rows
# Processed 188300000 rows
# Processed 188400000 rows
# Processed 188500000 rows
# Processed 188600000 rows
# Processed 188700000 rows
# Processed 188800000 rows
# Processed 188900000 rows
# Processed 189000000 rows
# Processed 189100000 rows
# Processed 189200000 rows
# Processed 189300000 rows
# Processed 189400000 rows
# Processed 189500000 rows
# Processed 189600000 rows
# Processed 189700000 rows
# Processed 189800000 rows
# Processed 189900000 rows
# Processed 190000000 rows
# Processed 190100000 rows
# Processed 190200000 rows
# Processed 190300000 rows
# Processed 190400000 rows
# Processed 190500000 rows
# Processed 190600000 rows
# Processed 190700000 rows
# Processed 190800000 rows
# Processed 190900000 rows
# Processed 191000000 rows
# Processed 191100000 rows
# Processed 191200000 rows
# Processed 191300000 rows
# Processed 191400000 rows
# Processed 191500000 rows
# Processed 191600000 rows
# Processed 191700000 rows
# Processed 191800000 rows
# Processed 191900000 rows
# Processed 192000000 rows
# Processed 192100000 rows
# Processed 192200000 rows
# Processed 192300000 rows
# Processed 192400000 rows
# Processed 192500000 rows
# Processed 192600000 rows
# Processed 192700000 rows
# Processed 192800000 rows
# Processed 192900000 rows
# Processed 193000000 rows
# Processed 193100000 rows
# Processed 193200000 rows
# Processed 193300000 rows
# Processed 193400000 rows
# Processed 193500000 rows
# Processed 193600000 rows
# Processed 193700000 rows
# Processed 193800000 rows
# Processed 193900000 rows
# Processed 194000000 rows
# Processed 194100000 rows
# Processed 194200000 rows
# Processed 194300000 rows
# Processed 194400000 rows
# Processed 194500000 rows
# Processed 194600000 rows
# Processed 194700000 rows
# Processed 194800000 rows
# Processed 194900000 rows
# Processed 195000000 rows
# Processed 195100000 rows
# Processed 195200000 rows
# Processed 195300000 rows
# Processed 195400000 rows
# Processed 195500000 rows
# Processed 195600000 rows
# Processed 195700000 rows
# Processed 195800000 rows
# Processed 195900000 rows
# Processed 196000000 rows
# Processed 196100000 rows
# Processed 196200000 rows
# Processed 196300000 rows
# Processed 196400000 rows
# Processed 196500000 rows
# Processed 196600000 rows
# Processed 196700000 rows
# Processed 196800000 rows
# Processed 196900000 rows
# Processed 197000000 rows
# Processed 197100000 rows
# Processed 197200000 rows
# Processed 197300000 rows
# Processed 197400000 rows
# Processed 197500000 rows
# Processed 197600000 rows
# Processed 197700000 rows
# Processed 197800000 rows
# Processed 197900000 rows
# Processed 198000000 rows
# Processed 198100000 rows
# Processed 198200000 rows
# Processed 198300000 rows
# Processed 198400000 rows
# Processed 198500000 rows
# Processed 198600000 rows
# Processed 198700000 rows
# Processed 198800000 rows
# Processed 198900000 rows
# Processed 199000000 rows
# Processed 199100000 rows
# Processed 199200000 rows
# Processed 199300000 rows
# Processed 199400000 rows
# Processed 199500000 rows
# Processed 199600000 rows
# Processed 199700000 rows
# Processed 199800000 rows
# Processed 199900000 rows
# Processed 200000000 rows
# Processed 200100000 rows
# Processed 200200000 rows
# Processed 200300000 rows
# Processed 200400000 rows
# Processed 200500000 rows
# Processed 200600000 rows
# Processed 200700000 rows
# Processed 200800000 rows
# Processed 200900000 rows
# Processed 201000000 rows
# Processed 201100000 rows
# Processed 201200000 rows
# Processed 201300000 rows
# Processed 201400000 rows
# Processed 201500000 rows
# Processed 201600000 rows
# Processed 201700000 rows
# Processed 201800000 rows
# Processed 201900000 rows
# Processed 202000000 rows
# Processed 202100000 rows
# Processed 202200000 rows
# Processed 202300000 rows
# Processed 202400000 rows
# Processed 202500000 rows
# Processed 202600000 rows
# Processed 202700000 rows
# Processed 202800000 rows
# Processed 202900000 rows
# Processed 203000000 rows
# Processed 203100000 rows
# Processed 203200000 rows
# Processed 203300000 rows
# Processed 203400000 rows
# Processed 203500000 rows
# Processed 203600000 rows
# Processed 203700000 rows
# Processed 203800000 rows
# Processed 203900000 rows
# Processed 204000000 rows
# Processed 204100000 rows
# Processed 204200000 rows
# Processed 204300000 rows
# Processed 204400000 rows
# Processed 204500000 rows
# Processed 204600000 rows
# Processed 204700000 rows
# Processed 204800000 rows
# Processed 204900000 rows
# Processed 205000000 rows
# Processed 205100000 rows
# Processed 205200000 rows
# Processed 205300000 rows
# Processed 205400000 rows
# Processed 205500000 rows
# Processed 205600000 rows
# Processed 205700000 rows
# Processed 205800000 rows
# Processed 205900000 rows
# Processed 206000000 rows
# Processed 206100000 rows
# Processed 206200000 rows
# Processed 206300000 rows
# Processed 206400000 rows
# Processed 206500000 rows
# Processed 206600000 rows
# Processed 206700000 rows
# Processed 206800000 rows
# Processed 206900000 rows
# Processed 207000000 rows
# Processed 207100000 rows
# Processed 207200000 rows
# Processed 207300000 rows
# Processed 207400000 rows
# Processed 207500000 rows
# Processed 207600000 rows
# Processed 207700000 rows
# Processed 207800000 rows
# Processed 207900000 rows
# Processed 208000000 rows
# Processed 208100000 rows
# Processed 208200000 rows
# Processed 208300000 rows
# Processed 208400000 rows
# Processed 208500000 rows
# Processed 208600000 rows
# Processed 208700000 rows
# Processed 208800000 rows
# Processed 208900000 rows
# Processed 209000000 rows
# Processed 209100000 rows
# Processed 209200000 rows
# Processed 209300000 rows
# Processed 209400000 rows
# Processed 209500000 rows
# Processed 209600000 rows
# Processed 209700000 rows
# Processed 209800000 rows
# Processed 209900000 rows
# Processed 210000000 rows
# Processed 210100000 rows
# Processed 210200000 rows
# Processed 210300000 rows
# Processed 210400000 rows
# Processed 210500000 rows
# Processed 210600000 rows
# Processed 210700000 rows
# Processed 210800000 rows
# Processed 210900000 rows
# Processed 211000000 rows
# Processed 211100000 rows
# Processed 211200000 rows
# Processed 211300000 rows
# Processed 211400000 rows
# Processed 211500000 rows
# Processed 211600000 rows
# Processed 211700000 rows
# Processed 211800000 rows
# Processed 211900000 rows
# Processed 212000000 rows
# Processed 212100000 rows
# Processed 212200000 rows
# Processed 212300000 rows
# Processed 212400000 rows
# Processed 212500000 rows
# Processed 212600000 rows
# Processed 212700000 rows
# Processed 212800000 rows
# Processed 212900000 rows
# Processed 213000000 rows
# Processed 213100000 rows
# Processed 213200000 rows
# Processed 213300000 rows
# Processed 213400000 rows
# Processed 213500000 rows
# Processed 213600000 rows
# Processed 213700000 rows
# Processed 213800000 rows
# Processed 213900000 rows
# Processed 214000000 rows
# Processed 214100000 rows
# Processed 214200000 rows
# Processed 214300000 rows
# Processed 214400000 rows
# Processed 214500000 rows
# Processed 214600000 rows
# Processed 214700000 rows
# Processed 214800000 rows
# Processed 214900000 rows
# Processed 215000000 rows
# Processed 215100000 rows
# Processed 215200000 rows
# Processed 215300000 rows
# Processed 215400000 rows
# Processed 215500000 rows
# Processed 215600000 rows
# Processed 215700000 rows
# Processed 215800000 rows
# Processed 215900000 rows
# Processed 216000000 rows
# Processed 216100000 rows
# Processed 216200000 rows
# Processed 216300000 rows
# Processed 216400000 rows
# Processed 216500000 rows
# Processed 216600000 rows
# Processed 216700000 rows
# Processed 216800000 rows
# Processed 216900000 rows
# Processed 217000000 rows
# Processed 217100000 rows
# Processed 217200000 rows
# Processed 217300000 rows
# Processed 217400000 rows
# Processed 217500000 rows
# Processed 217600000 rows
# Processed 217700000 rows
# Processed 217800000 rows
# Processed 217900000 rows
# Processed 218000000 rows
# Processed 218100000 rows
# Processed 218200000 rows
# Processed 218300000 rows
# Processed 218400000 rows
# Processed 218500000 rows
# Processed 218600000 rows
# Processed 218700000 rows
# Processed 218800000 rows
# Processed 218900000 rows
# Processed 219000000 rows
# Processed 219100000 rows
# Processed 219200000 rows
# Processed 219300000 rows
# Processed 219400000 rows
# Processed 219500000 rows
# Processed 219600000 rows
# Processed 219700000 rows
# Processed 219800000 rows
# Processed 219900000 rows
# Processed 220000000 rows
# Processed 220100000 rows
# Processed 220200000 rows
# Processed 220300000 rows
# Processed 220400000 rows
# Processed 220500000 rows
# Processed 220600000 rows
# Processed 220700000 rows
# Processed 220800000 rows
# Processed 220900000 rows
# Processed 221000000 rows
# Processed 221100000 rows
# Processed 221200000 rows
# Processed 221300000 rows
# Processed 221400000 rows
# Processed 221500000 rows
# Processed 221600000 rows
# Processed 221700000 rows
# Processed 221800000 rows
# Processed 221900000 rows
# Processed 222000000 rows
# Processed 222100000 rows
# Processed 222200000 rows
# Processed 222300000 rows
# Processed 222400000 rows
# Processed 222500000 rows
# Processed 222600000 rows
# Processed 222700000 rows
# Processed 222800000 rows
# Processed 222900000 rows
# Processed 223000000 rows
# Processed 223100000 rows
# Processed 223200000 rows
# Processed 223300000 rows
# Processed 223400000 rows
# Processed 223500000 rows
# Processed 223600000 rows
# Processed 223700000 rows
# Processed 223800000 rows
# Processed 223900000 rows
# Processed 224000000 rows
# Processed 224100000 rows
# Processed 224200000 rows
# Processed 224300000 rows
# Processed 224400000 rows
# Processed 224500000 rows
# Processed 224600000 rows
# Processed 224700000 rows
# Processed 224800000 rows
# Processed 224900000 rows
# Processed 225000000 rows
# Processed 225100000 rows
# Processed 225200000 rows
# Processed 225300000 rows
# Processed 225400000 rows
# Processed 225500000 rows
# Processed 225600000 rows
# Processed 225700000 rows
# Processed 225800000 rows
# Processed 225900000 rows
# Processed 226000000 rows
# Processed 226100000 rows
# Processed 226200000 rows
# Processed 226300000 rows
# Processed 226400000 rows
# Processed 226500000 rows
# Processed 226600000 rows
# Processed 226700000 rows
# Processed 226800000 rows
# Processed 226900000 rows
# Processed 227000000 rows
# Processed 227100000 rows
# Processed 227200000 rows
# Processed 227300000 rows
# Processed 227400000 rows
# Processed 227500000 rows
# Processed 227600000 rows
# Processed 227700000 rows
# Processed 227800000 rows
# Processed 227900000 rows
# Processed 228000000 rows
# Processed 228100000 rows
# Processed 228200000 rows
# Processed 228300000 rows
# Processed 228400000 rows
# Processed 228500000 rows
# Processed 228600000 rows
# Processed 228700000 rows
# Processed 228800000 rows
# Processed 228900000 rows
# Processed 229000000 rows
# Processed 229100000 rows
# Processed 229200000 rows
# Processed 229300000 rows
# Processed 229400000 rows
# Processed 229500000 rows
# Processed 229600000 rows
# Processed 229700000 rows
# Processed 229800000 rows
# Processed 229900000 rows
# Processed 230000000 rows
# Processed 230100000 rows
# Processed 230200000 rows
# Processed 230300000 rows
# Processed 230400000 rows
# Processed 230500000 rows
# Processed 230600000 rows
# Processed 230700000 rows
# Processed 230800000 rows
# Processed 230900000 rows
# Processed 231000000 rows
# Processed 231100000 rows
# Processed 231200000 rows
# Processed 231300000 rows
# Processed 231400000 rows
# Processed 231500000 rows
# Processed 231600000 rows
# Processed 231700000 rows
# Processed 231800000 rows
# Processed 231900000 rows
# Processed 232000000 rows
# Processed 232100000 rows
# Processed 232200000 rows
# Processed 232300000 rows
# Processed 232400000 rows
# Processed 232500000 rows
# Processed 232600000 rows
# Processed 232700000 rows
# Processed 232800000 rows
# Processed 232900000 rows
# Processed 233000000 rows
# Processed 233100000 rows
# Processed 233200000 rows
# Processed 233300000 rows
# Processed 233400000 rows
# Processed 233500000 rows
# Processed 233600000 rows
# Processed 233700000 rows
# Processed 233800000 rows
# Processed 233900000 rows
# Processed 234000000 rows
# Processed 234100000 rows
# Processed 234200000 rows
# Processed 234300000 rows
# Processed 234400000 rows
# Processed 234500000 rows
# Processed 234600000 rows
# Processed 234700000 rows
# Processed 234800000 rows
# Processed 234900000 rows
# Processed 235000000 rows
# Processed 235100000 rows
# Processed 235200000 rows
# Processed 235300000 rows
# Processed 235400000 rows
# Processed 235500000 rows
# Processed 235600000 rows
# Processed 235700000 rows
# Processed 235800000 rows
# Processed 235900000 rows
# Processed 236000000 rows
# Processed 236100000 rows
# Processed 236200000 rows
# Processed 236300000 rows
# Processed 236400000 rows
# Processed 236500000 rows
# Processed 236600000 rows
# Processed 236700000 rows
# Processed 236800000 rows
# Processed 236900000 rows
# Processed 237000000 rows
# Processed 237100000 rows
# Processed 237200000 rows
# Processed 237300000 rows
# Processed 237400000 rows
# Processed 237500000 rows
# Processed 237600000 rows
# Processed 237700000 rows
# Processed 237800000 rows
# Processed 237900000 rows
# Processed 238000000 rows
# Processed 238100000 rows
# Processed 238200000 rows
# Processed 238300000 rows
# Processed 238400000 rows
# Processed 238500000 rows
# Processed 238600000 rows
# Processed 238700000 rows
# Processed 238800000 rows
# Processed 238900000 rows
# Processed 239000000 rows
# Processed 239100000 rows
# Processed 239200000 rows
# Processed 239300000 rows
# Processed 239400000 rows
# Processed 239500000 rows
# Processed 239600000 rows
# Processed 239700000 rows
# Processed 239800000 rows
# Processed 239900000 rows
# Processed 240000000 rows
# Processed 240100000 rows
# Processed 240200000 rows
# Processed 240300000 rows
# Processed 240400000 rows
# Processed 240500000 rows
# Processed 240600000 rows
# Processed 240700000 rows
# Processed 240800000 rows
# Processed 240900000 rows
# Processed 241000000 rows
# Processed 241100000 rows
# Processed 241200000 rows
# Processed 241300000 rows
# Processed 241400000 rows
# Processed 241500000 rows
# Processed 241600000 rows
# Processed 241700000 rows
# Processed 241800000 rows
# Processed 241900000 rows
# Processed 242000000 rows
# Processed 242100000 rows
# Processed 242200000 rows
# Processed 242300000 rows
# Processed 242400000 rows
# Processed 242500000 rows
# Processed 242600000 rows
# Processed 242700000 rows
# Processed 242800000 rows
# Processed 242900000 rows
# Processed 243000000 rows
# Processed 243100000 rows
# Processed 243200000 rows
# Processed 243300000 rows
# Processed 243400000 rows
# Processed 243500000 rows
# Processed 243600000 rows
# Processed 243700000 rows
# Processed 243800000 rows
# Processed 243900000 rows
# Processed 244000000 rows
# Processed 244100000 rows
# Processed 244200000 rows
# Processed 244300000 rows
# Processed 244400000 rows
# Processed 244500000 rows
# Processed 244600000 rows
# Processed 244700000 rows
# Processed 244800000 rows
# Processed 244900000 rows
# Processed 245000000 rows
# Processed 245100000 rows
# Processed 245200000 rows
# Processed 245300000 rows
# Processed 245400000 rows
# Processed 245500000 rows
# Processed 245600000 rows
# Processed 245700000 rows
# Processed 245800000 rows
# Processed 245900000 rows
# Processed 246000000 rows
# Processed 246100000 rows
# Processed 246200000 rows
# Processed 246300000 rows
# Processed 246400000 rows
# Processed 246500000 rows
# Processed 246600000 rows
# Processed 246700000 rows
# Processed 246800000 rows
# Processed 246900000 rows
# Processed 247000000 rows
# Processed 247100000 rows
# Processed 247200000 rows
# Processed 247300000 rows
# Processed 247400000 rows
# Processed 247500000 rows
# Processed 247600000 rows
# Processed 247700000 rows
# Processed 247800000 rows
# Processed 247900000 rows
# Processed 248000000 rows
# Processed 248100000 rows
# Warning: No data found for the given criteria.
# Saved data and labels for patient file to /content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/05_time_series_data_preprocessing/feature_set_1_results

# %%
# Repeat the same for chunk 9
chunk_9 = ('/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/03_annotated_set/final_set_split_files/patient_chunk_9.parquet')
patient_chunk_9 = pd.read_parquet(chunk_9)
patient_chunk_9.head()
# Out:
#        subject_id   hadm_id   stay_id ventilation_starttime  \
# 23568    19041108  24980238  32226561   2123-03-05 23:55:00
# 23569    19042662  28440124  37249777   2184-04-04 19:37:00
# 23571    19045496  22343752  37979029   2148-08-09 11:40:00
# 23576    19046076  27649252  33240155   2116-04-05 00:00:00
# 23577    19046107  21398294  32733363   2138-04-14 12:08:00
#
#       ventilation_endtime  ventilation_itemid ventilation_ordercategoryname  \
# 23568 2123-03-11 11:15:00              225792                   Ventilation
# 23569 2184-04-13 09:40:00              225792                   Ventilation
# 23571 2148-08-13 15:40:00              225792                   Ventilation
# 23576 2116-04-06 08:58:00              225792                   Ventilation
# 23577 2138-04-16 12:39:00              225792                   Ventilation
#
#       extubation_starttime  extubation_endtime  extubation_itemid  \
# 23568  2123-03-11 11:15:00 2123-03-11 11:16:00             227194
# 23569  2184-04-13 09:40:00 2184-04-13 09:41:00             227194
# 23571  2148-08-13 15:40:00 2148-08-13 15:41:00             227194
# 23576  2116-04-06 09:02:00 2116-04-06 09:03:00             227194
# 23577  2138-04-16 12:40:00 2138-04-16 12:41:00             227194
#
#       extubation_ordercategoryname  ventilation_duration  anchor_age  \
# 23568        Intubation/Extubation                7880.0          54
# 23569        Intubation/Extubation               12363.0          62
# 23571        Intubation/Extubation                6000.0          80
# 23576        Intubation/Extubation                1978.0          74
# 23577        Intubation/Extubation                2911.0          62
#
#        extubation_failure
# 23568                   0
# 23569                   0
# 23571                   0
# 23576                   0
# 23577                   0

# %%
# Run extraction on chunk 9
data_9, labels_9 = extract_patient_data_2(patient_chunk_9, chartevents_path, feature_set_1_dynamic, time_window_hours)
data_9_file_path = f'{output_dir}/data_chunk_{9}.parquet'
labels_9_file_path = f'{output_dir}/labels_chunk_{9}.parquet'

data_9.to_parquet(data_9_file_path, index=False)
labels_9.to_parquet(labels_9_file_path, index=False)

print(f"Saved data and labels for patient file to {output_dir}")
# Out:
# Processed 100000 rows
# Processed 200000 rows
# Processed 300000 rows
# Processed 400000 rows
# Processed 500000 rows
# Processed 600000 rows
# Processed 700000 rows
# Processed 800000 rows
# Processed 900000 rows
# Processed 1000000 rows
# Processed 1100000 rows
# Processed 1200000 rows
# Processed 1300000 rows
# Processed 1400000 rows
# Processed 1500000 rows
# Processed 1600000 rows
# Processed 1700000 rows
# Processed 1800000 rows
# Processed 1900000 rows
# Processed 2000000 rows
# Processed 2100000 rows
# Processed 2200000 rows
# Processed 2300000 rows
# Processed 2400000 rows
# Processed 2500000 rows
# Processed 2600000 rows
# Processed 2700000 rows
# Processed 2800000 rows
# Processed 2900000 rows
# Processed 3000000 rows
# Processed 3100000 rows
# Processed 3200000 rows
# Processed 3300000 rows
# Processed 3400000 rows
# Processed 3500000 rows
# Processed 3600000 rows
# Processed 3700000 rows
# Processed 3800000 rows
# Processed 3900000 rows
# Processed 4000000 rows
# Processed 4100000 rows
# Processed 4200000 rows
# Processed 4300000 rows
# Processed 4400000 rows
# Processed 4500000 rows
# Processed 4600000 rows
# Processed 4700000 rows
# Processed 4800000 rows
# Processed 4900000 rows
# Processed 5000000 rows
# Processed 5100000 rows
# Processed 5200000 rows
# Processed 5300000 rows
# Processed 5400000 rows
# Processed 5500000 rows
# Processed 5600000 rows
# Processed 5700000 rows
# Processed 5800000 rows
# Processed 5900000 rows
# Processed 6000000 rows
# Processed 6100000 rows
# Processed 6200000 rows
# Processed 6300000 rows
# Processed 6400000 rows
# Processed 6500000 rows
# Processed 6600000 rows
# Processed 6700000 rows
# Processed 6800000 rows
# Processed 6900000 rows
# Processed 7000000 rows
# Processed 7100000 rows
# Processed 7200000 rows
# Processed 7300000 rows
# Processed 7400000 rows
# Processed 7500000 rows
# Processed 7600000 rows
# Processed 7700000 rows
# Processed 7800000 rows
# Processed 7900000 rows
# Processed 8000000 rows
# Processed 8100000 rows
# Processed 8200000 rows
# Processed 8300000 rows
# Processed 8400000 rows
# Processed 8500000 rows
# Processed 8600000 rows
# Processed 8700000 rows
# Processed 8800000 rows
# Processed 8900000 rows
# Processed 9000000 rows
# Processed 9100000 rows
# Processed 9200000 rows
# Processed 9300000 rows
# Processed 9400000 rows
# Processed 9500000 rows
# Processed 9600000 rows
# Processed 9700000 rows
# Processed 9800000 rows
# Processed 9900000 rows
# Processed 10000000 rows
# Processed 10100000 rows
# Processed 10200000 rows
# Processed 10300000 rows
# Processed 10400000 rows
# Processed 10500000 rows
# Processed 10600000 rows
# Processed 10700000 rows
# Processed 10800000 rows
# Processed 10900000 rows
# Processed 11000000 rows
# Processed 11100000 rows
# Processed 11200000 rows
# Processed 11300000 rows
# Processed 11400000 rows
# Processed 11500000 rows
# Processed 11600000 rows
# Processed 11700000 rows
# Processed 11800000 rows
# Processed 11900000 rows
# Processed 12000000 rows
# Processed 12100000 rows
# Processed 12200000 rows
# Processed 12300000 rows
# Processed 12400000 rows
# Processed 12500000 rows
# Processed 12600000 rows
# Processed 12700000 rows
# Processed 12800000 rows
# Processed 12900000 rows
# Processed 13000000 rows
# Processed 13100000 rows
# Processed 13200000 rows
# Processed 13300000 rows
# Processed 13400000 rows
# Processed 13500000 rows
# Processed 13600000 rows
# Processed 13700000 rows
# Processed 13800000 rows
# Processed 13900000 rows
# Processed 14000000 rows
# Processed 14100000 rows
# Processed 14200000 rows
# Processed 14300000 rows
# Processed 14400000 rows
# Processed 14500000 rows
# Processed 14600000 rows
# Processed 14700000 rows
# Processed 14800000 rows
# Processed 14900000 rows
# Processed 15000000 rows
# Processed 15100000 rows
# Processed 15200000 rows
# Processed 15300000 rows
# Processed 15400000 rows
# Processed 15500000 rows
# Processed 15600000 rows
# Processed 15700000 rows
# Processed 15800000 rows
# Processed 15900000 rows
# Processed 16000000 rows
# Processed 16100000 rows
# Processed 16200000 rows
# Processed 16300000 rows
# Processed 16400000 rows
# Processed 16500000 rows
# Processed 16600000 rows
# Processed 16700000 rows
# Processed 16800000 rows
# Processed 16900000 rows
# Processed 17000000 rows
# Processed 17100000 rows
# Processed 17200000 rows
# Processed 17300000 rows
# Processed 17400000 rows
# Processed 17500000 rows
# Processed 17600000 rows
# Processed 17700000 rows
# Processed 17800000 rows
# Processed 17900000 rows
# Processed 18000000 rows
# Processed 18100000 rows
# Processed 18200000 rows
# Processed 18300000 rows
# Processed 18400000 rows
# Processed 18500000 rows
# Processed 18600000 rows
# Processed 18700000 rows
# Processed 18800000 rows
# Processed 18900000 rows
# Processed 19000000 rows
# Processed 19100000 rows
# Processed 19200000 rows
# Processed 19300000 rows
# Processed 19400000 rows
# Processed 19500000 rows
# Processed 19600000 rows
# Processed 19700000 rows
# Processed 19800000 rows
# Processed 19900000 rows
# Processed 20000000 rows
# Processed 20100000 rows
# Processed 20200000 rows
# Processed 20300000 rows
# Processed 20400000 rows
# Processed 20500000 rows
# Processed 20600000 rows
# Processed 20700000 rows
# Processed 20800000 rows
# Processed 20900000 rows
# Processed 21000000 rows
# Processed 21100000 rows
# Processed 21200000 rows
# Processed 21300000 rows
# Processed 21400000 rows
# Processed 21500000 rows
# Processed 21600000 rows
# Processed 21700000 rows
# Processed 21800000 rows
# Processed 21900000 rows
# Processed 22000000 rows
# Processed 22100000 rows
# Processed 22200000 rows
# Processed 22300000 rows
# Processed 22400000 rows
# Processed 22500000 rows
# Processed 22600000 rows
# Processed 22700000 rows
# Processed 22800000 rows
# Processed 22900000 rows
# Processed 23000000 rows
# Processed 23100000 rows
# Processed 23200000 rows
# Processed 23300000 rows
# Processed 23400000 rows
# Processed 23500000 rows
# Processed 23600000 rows
# Processed 23700000 rows
# Processed 23800000 rows
# Processed 23900000 rows
# Processed 24000000 rows
# Processed 24100000 rows
# Processed 24200000 rows
# Processed 24300000 rows
# Processed 24400000 rows
# Processed 24500000 rows
# Processed 24600000 rows
# Processed 24700000 rows
# Processed 24800000 rows
# Processed 24900000 rows
# Processed 25000000 rows
# Processed 25100000 rows
# Processed 25200000 rows
# Processed 25300000 rows
# Processed 25400000 rows
# Processed 25500000 rows
# Processed 25600000 rows
# Processed 25700000 rows
# Processed 25800000 rows
# Processed 25900000 rows
# Processed 26000000 rows
# Processed 26100000 rows
# Processed 26200000 rows
# Processed 26300000 rows
# Processed 26400000 rows
# Processed 26500000 rows
# Processed 26600000 rows
# Processed 26700000 rows
# Processed 26800000 rows
# Processed 26900000 rows
# Processed 27000000 rows
# Processed 27100000 rows
# Processed 27200000 rows
# Processed 27300000 rows
# Processed 27400000 rows
# Processed 27500000 rows
# Processed 27600000 rows
# Processed 27700000 rows
# Processed 27800000 rows
# Processed 27900000 rows
# Processed 28000000 rows
# Processed 28100000 rows
# Processed 28200000 rows
# Processed 28300000 rows
# Processed 28400000 rows
# Processed 28500000 rows
# Processed 28600000 rows
# Processed 28700000 rows
# Processed 28800000 rows
# Processed 28900000 rows
# Processed 29000000 rows
# Processed 29100000 rows
# Processed 29200000 rows
# Processed 29300000 rows
# Processed 29400000 rows
# Processed 29500000 rows
# Processed 29600000 rows
# Processed 29700000 rows
# Processed 29800000 rows
# Processed 29900000 rows
# Processed 30000000 rows
# Processed 30100000 rows
# Processed 30200000 rows
# Processed 30300000 rows
# Processed 30400000 rows
# Processed 30500000 rows
# Processed 30600000 rows
# Processed 30700000 rows
# Processed 30800000 rows
# Processed 30900000 rows
# Processed 31000000 rows
# Processed 31100000 rows
# Processed 31200000 rows
# Processed 31300000 rows
# Processed 31400000 rows
# Processed 31500000 rows
# Processed 31600000 rows
# Processed 31700000 rows
# Processed 31800000 rows
# Processed 31900000 rows
# Processed 32000000 rows
# Processed 32100000 rows
# Processed 32200000 rows
# Processed 32300000 rows
# Processed 32400000 rows
# Processed 32500000 rows
# Processed 32600000 rows
# Processed 32700000 rows
# Processed 32800000 rows
# Processed 32900000 rows
# Processed 33000000 rows
# Processed 33100000 rows
# Processed 33200000 rows
# Processed 33300000 rows
# Processed 33400000 rows
# Processed 33500000 rows
# Processed 33600000 rows
# Processed 33700000 rows
# Processed 33800000 rows
# Processed 33900000 rows
# Processed 34000000 rows
# Processed 34100000 rows
# Processed 34200000 rows
# Processed 34300000 rows
# Processed 34400000 rows
# Processed 34500000 rows
# Processed 34600000 rows
# Processed 34700000 rows
# Processed 34800000 rows
# Processed 34900000 rows
# Processed 35000000 rows
# Processed 35100000 rows
# Processed 35200000 rows
# Processed 35300000 rows
# Processed 35400000 rows
# Processed 35500000 rows
# Processed 35600000 rows
# Processed 35700000 rows
# Processed 35800000 rows
# Processed 35900000 rows
# Processed 36000000 rows
# Processed 36100000 rows
# Processed 36200000 rows
# Processed 36300000 rows
# Processed 36400000 rows
# Processed 36500000 rows
# Processed 36600000 rows
# Processed 36700000 rows
# Processed 36800000 rows
# Processed 36900000 rows
# Processed 37000000 rows
# Processed 37100000 rows
# Processed 37200000 rows
# Processed 37300000 rows
# Processed 37400000 rows
# Processed 37500000 rows
# Processed 37600000 rows
# Processed 37700000 rows
# Processed 37800000 rows
# Processed 37900000 rows
# Processed 38000000 rows
# Processed 38100000 rows
# Processed 38200000 rows
# Processed 38300000 rows
# Processed 38400000 rows
# Processed 38500000 rows
# Processed 38600000 rows
# Processed 38700000 rows
# Processed 38800000 rows
# Processed 38900000 rows
# Processed 39000000 rows
# Processed 39100000 rows
# Processed 39200000 rows
# Processed 39300000 rows
# Processed 39400000 rows
# Processed 39500000 rows
# Processed 39600000 rows
# Processed 39700000 rows
# Processed 39800000 rows
# Processed 39900000 rows
# Processed 40000000 rows
# Processed 40100000 rows
# Processed 40200000 rows
# Processed 40300000 rows
# Processed 40400000 rows
# Processed 40500000 rows
# Processed 40600000 rows
# Processed 40700000 rows
# Processed 40800000 rows
# Processed 40900000 rows
# Processed 41000000 rows
# Processed 41100000 rows
# Processed 41200000 rows
# Processed 41300000 rows
# Processed 41400000 rows
# Processed 41500000 rows
# Processed 41600000 rows
# Processed 41700000 rows
# Processed 41800000 rows
# Processed 41900000 rows
# Processed 42000000 rows
# Processed 42100000 rows
# Processed 42200000 rows
# Processed 42300000 rows
# Processed 42400000 rows
# Processed 42500000 rows
# Processed 42600000 rows
# Processed 42700000 rows
# Processed 42800000 rows
# Processed 42900000 rows
# Processed 43000000 rows
# Processed 43100000 rows
# Processed 43200000 rows
# Processed 43300000 rows
# Processed 43400000 rows
# Processed 43500000 rows
# Processed 43600000 rows
# Processed 43700000 rows
# Processed 43800000 rows
# Processed 43900000 rows
# Processed 44000000 rows
# Processed 44100000 rows
# Processed 44200000 rows
# Processed 44300000 rows
# Processed 44400000 rows
# Processed 44500000 rows
# Processed 44600000 rows
# Processed 44700000 rows
# Processed 44800000 rows
# Processed 44900000 rows
# Processed 45000000 rows
# Processed 45100000 rows
# Processed 45200000 rows
# Processed 45300000 rows
# Processed 45400000 rows
# Processed 45500000 rows
# Processed 45600000 rows
# Processed 45700000 rows
# Processed 45800000 rows
# Processed 45900000 rows
# Processed 46000000 rows
# Processed 46100000 rows
# Processed 46200000 rows
# Processed 46300000 rows
# Processed 46400000 rows
# Processed 46500000 rows
# Processed 46600000 rows
# Processed 46700000 rows
# Processed 46800000 rows
# Processed 46900000 rows
# Processed 47000000 rows
# Processed 47100000 rows
# Processed 47200000 rows
# Processed 47300000 rows
# Processed 47400000 rows
# Processed 47500000 rows
# Processed 47600000 rows
# Processed 47700000 rows
# Processed 47800000 rows
# Processed 47900000 rows
# Processed 48000000 rows
# Processed 48100000 rows
# Processed 48200000 rows
# Processed 48300000 rows
# Processed 48400000 rows
# Processed 48500000 rows
# Processed 48600000 rows
# Processed 48700000 rows
# Processed 48800000 rows
# Processed 48900000 rows
# Processed 49000000 rows
# Processed 49100000 rows
# Processed 49200000 rows
# Processed 49300000 rows
# Processed 49400000 rows
# Processed 49500000 rows
# Processed 49600000 rows
# Processed 49700000 rows
# Processed 49800000 rows
# Processed 49900000 rows
# Processed 50000000 rows
# Processed 50100000 rows
# Processed 50200000 rows
# Processed 50300000 rows
# Processed 50400000 rows
# Processed 50500000 rows
# Processed 50600000 rows
# Processed 50700000 rows
# Processed 50800000 rows
# Processed 50900000 rows
# Processed 51000000 rows
# Processed 51100000 rows
# Processed 51200000 rows
# Processed 51300000 rows
# Processed 51400000 rows
# Processed 51500000 rows
# Processed 51600000 rows
# Processed 51700000 rows
# Processed 51800000 rows
# Processed 51900000 rows
# Processed 52000000 rows
# Processed 52100000 rows
# Processed 52200000 rows
# Processed 52300000 rows
# Processed 52400000 rows
# Processed 52500000 rows
# Processed 52600000 rows
# Processed 52700000 rows
# Processed 52800000 rows
# Processed 52900000 rows
# Processed 53000000 rows
# Processed 53100000 rows
# Processed 53200000 rows
# Processed 53300000 rows
# Processed 53400000 rows
# Processed 53500000 rows
# Processed 53600000 rows
# Processed 53700000 rows
# Processed 53800000 rows
# Processed 53900000 rows
# Processed 54000000 rows
# Processed 54100000 rows
# Processed 54200000 rows
# Processed 54300000 rows
# Processed 54400000 rows
# Processed 54500000 rows
# Processed 54600000 rows
# Processed 54700000 rows
# Processed 54800000 rows
# Processed 54900000 rows
# Processed 55000000 rows
# Processed 55100000 rows
# Processed 55200000 rows
# Processed 55300000 rows
# Processed 55400000 rows
# Processed 55500000 rows
# Processed 55600000 rows
# Processed 55700000 rows
# Processed 55800000 rows
# Processed 55900000 rows
# Processed 56000000 rows
# Processed 56100000 rows
# Processed 56200000 rows
# Processed 56300000 rows
# Processed 56400000 rows
# Processed 56500000 rows
# Processed 56600000 rows
# Processed 56700000 rows
# Processed 56800000 rows
# Processed 56900000 rows
# Processed 57000000 rows
# Processed 57100000 rows
# Processed 57200000 rows
# Processed 57300000 rows
# Processed 57400000 rows
# Processed 57500000 rows
# Processed 57600000 rows
# Processed 57700000 rows
# Processed 57800000 rows
# Processed 57900000 rows
# Processed 58000000 rows
# Processed 58100000 rows
# Processed 58200000 rows
# Processed 58300000 rows
# Processed 58400000 rows
# Processed 58500000 rows
# Processed 58600000 rows
# Processed 58700000 rows
# Processed 58800000 rows
# Processed 58900000 rows
# Processed 59000000 rows
# Processed 59100000 rows
# Processed 59200000 rows
# Processed 59300000 rows
# Processed 59400000 rows
# Processed 59500000 rows
# Processed 59600000 rows
# Processed 59700000 rows
# Processed 59800000 rows
# Processed 59900000 rows
# Processed 60000000 rows
# Processed 60100000 rows
# Processed 60200000 rows
# Processed 60300000 rows
# Processed 60400000 rows
# Processed 60500000 rows
# Processed 60600000 rows
# Processed 60700000 rows
# Processed 60800000 rows
# Processed 60900000 rows
# Processed 61000000 rows
# Processed 61100000 rows
# Processed 61200000 rows
# Processed 61300000 rows
# Processed 61400000 rows
# Processed 61500000 rows
# Processed 61600000 rows
# Processed 61700000 rows
# Processed 61800000 rows
# Processed 61900000 rows
# Processed 62000000 rows
# Processed 62100000 rows
# Processed 62200000 rows
# Processed 62300000 rows
# Processed 62400000 rows
# Processed 62500000 rows
# Processed 62600000 rows
# Processed 62700000 rows
# Processed 62800000 rows
# Processed 62900000 rows
# Processed 63000000 rows
# Processed 63100000 rows
# Processed 63200000 rows
# Processed 63300000 rows
# Processed 63400000 rows
# Processed 63500000 rows
# Processed 63600000 rows
# Processed 63700000 rows
# Processed 63800000 rows
# Processed 63900000 rows
# Processed 64000000 rows
# Processed 64100000 rows
# Processed 64200000 rows
# Processed 64300000 rows
# Processed 64400000 rows
# Processed 64500000 rows
# Processed 64600000 rows
# Processed 64700000 rows
# Processed 64800000 rows
# Processed 64900000 rows
# Processed 65000000 rows
# Processed 65100000 rows
# Processed 65200000 rows
# Processed 65300000 rows
# Processed 65400000 rows
# Processed 65500000 rows
# Processed 65600000 rows
# Processed 65700000 rows
# Processed 65800000 rows
# Processed 65900000 rows
# Processed 66000000 rows
# Processed 66100000 rows
# Processed 66200000 rows
# Processed 66300000 rows
# Processed 66400000 rows
# Processed 66500000 rows
# Processed 66600000 rows
# Processed 66700000 rows
# Processed 66800000 rows
# Processed 66900000 rows
# Processed 67000000 rows
# Processed 67100000 rows
# Processed 67200000 rows
# Processed 67300000 rows
# Processed 67400000 rows
# Processed 67500000 rows
# Processed 67600000 rows
# Processed 67700000 rows
# Processed 67800000 rows
# Processed 67900000 rows
# Processed 68000000 rows
# Processed 68100000 rows
# Processed 68200000 rows
# Processed 68300000 rows
# Processed 68400000 rows
# Processed 68500000 rows
# Processed 68600000 rows
# Processed 68700000 rows
# Processed 68800000 rows
# Processed 68900000 rows
# Processed 69000000 rows
# Processed 69100000 rows
# Processed 69200000 rows
# Processed 69300000 rows
# Processed 69400000 rows
# Processed 69500000 rows
# Processed 69600000 rows
# Processed 69700000 rows
# Processed 69800000 rows
# Processed 69900000 rows
# Processed 70000000 rows
# Processed 70100000 rows
# Processed 70200000 rows
# Processed 70300000 rows
# Processed 70400000 rows
# Processed 70500000 rows
# Processed 70600000 rows
# Processed 70700000 rows
# Processed 70800000 rows
# Processed 70900000 rows
# Processed 71000000 rows
# Processed 71100000 rows
# Processed 71200000 rows
# Processed 71300000 rows
# Processed 71400000 rows
# Processed 71500000 rows
# Processed 71600000 rows
# Processed 71700000 rows
# Processed 71800000 rows
# Processed 71900000 rows
# Processed 72000000 rows
# Processed 72100000 rows
# Processed 72200000 rows
# Processed 72300000 rows
# Processed 72400000 rows
# Processed 72500000 rows
# Processed 72600000 rows
# Processed 72700000 rows
# Processed 72800000 rows
# Processed 72900000 rows
# Processed 73000000 rows
# Processed 73100000 rows
# Processed 73200000 rows
# Processed 73300000 rows
# Processed 73400000 rows
# Processed 73500000 rows
# Processed 73600000 rows
# Processed 73700000 rows
# Processed 73800000 rows
# Processed 73900000 rows
# Processed 74000000 rows
# Processed 74100000 rows
# Processed 74200000 rows
# Processed 74300000 rows
# Processed 74400000 rows
# Processed 74500000 rows
# Processed 74600000 rows
# Processed 74700000 rows
# Processed 74800000 rows
# Processed 74900000 rows
# Processed 75000000 rows
# Processed 75100000 rows
# Processed 75200000 rows
# Processed 75300000 rows
# Processed 75400000 rows
# Processed 75500000 rows
# Processed 75600000 rows
# Processed 75700000 rows
# Processed 75800000 rows
# Processed 75900000 rows
# Processed 76000000 rows
# Processed 76100000 rows
# Processed 76200000 rows
# Processed 76300000 rows
# Processed 76400000 rows
# Processed 76500000 rows
# Processed 76600000 rows
# Processed 76700000 rows
# Processed 76800000 rows
# Processed 76900000 rows
# Processed 77000000 rows
# Processed 77100000 rows
# Processed 77200000 rows
# Processed 77300000 rows
# Processed 77400000 rows
# Processed 77500000 rows
# Processed 77600000 rows
# Processed 77700000 rows
# Processed 77800000 rows
# Processed 77900000 rows
# Processed 78000000 rows
# Processed 78100000 rows
# Processed 78200000 rows
# Processed 78300000 rows
# Processed 78400000 rows
# Processed 78500000 rows
# Processed 78600000 rows
# Processed 78700000 rows
# Processed 78800000 rows
# Processed 78900000 rows
# Processed 79000000 rows
# Processed 79100000 rows
# Processed 79200000 rows
# Processed 79300000 rows
# Processed 79400000 rows
# Processed 79500000 rows
# Processed 79600000 rows
# Processed 79700000 rows
# Processed 79800000 rows
# Processed 79900000 rows
# Processed 80000000 rows
# Processed 80100000 rows
# Processed 80200000 rows
# Processed 80300000 rows
# Processed 80400000 rows
# Processed 80500000 rows
# Processed 80600000 rows
# Processed 80700000 rows
# Processed 80800000 rows
# Processed 80900000 rows
# Processed 81000000 rows
# Processed 81100000 rows
# Processed 81200000 rows
# Processed 81300000 rows
# Processed 81400000 rows
# Processed 81500000 rows
# Processed 81600000 rows
# Processed 81700000 rows
# Processed 81800000 rows
# Processed 81900000 rows
# Processed 82000000 rows
# Processed 82100000 rows
# Processed 82200000 rows
# Processed 82300000 rows
# Processed 82400000 rows
# Processed 82500000 rows
# Processed 82600000 rows
# Processed 82700000 rows
# Processed 82800000 rows
# Processed 82900000 rows
# Processed 83000000 rows
# Processed 83100000 rows
# Processed 83200000 rows
# Processed 83300000 rows
# Processed 83400000 rows
# Processed 83500000 rows
# Processed 83600000 rows
# Processed 83700000 rows
# Processed 83800000 rows
# Processed 83900000 rows
# Processed 84000000 rows
# Processed 84100000 rows
# Processed 84200000 rows
# Processed 84300000 rows
# Processed 84400000 rows
# Processed 84500000 rows
# Processed 84600000 rows
# Processed 84700000 rows
# Processed 84800000 rows
# Processed 84900000 rows
# Processed 85000000 rows
# Processed 85100000 rows
# Processed 85200000 rows
# Processed 85300000 rows
# Processed 85400000 rows
# Processed 85500000 rows
# Processed 85600000 rows
# Processed 85700000 rows
# Processed 85800000 rows
# Processed 85900000 rows
# Processed 86000000 rows
# Processed 86100000 rows
# Processed 86200000 rows
# Processed 86300000 rows
# Processed 86400000 rows
# Processed 86500000 rows
# Processed 86600000 rows
# Processed 86700000 rows
# Processed 86800000 rows
# Processed 86900000 rows
# Processed 87000000 rows
# Processed 87100000 rows
# Processed 87200000 rows
# Processed 87300000 rows
# Processed 87400000 rows
# Processed 87500000 rows
# Processed 87600000 rows
# Processed 87700000 rows
# Processed 87800000 rows
# Processed 87900000 rows
# Processed 88000000 rows
# Processed 88100000 rows
# Processed 88200000 rows
# Processed 88300000 rows
# Processed 88400000 rows
# Processed 88500000 rows
# Processed 88600000 rows
# Processed 88700000 rows
# Processed 88800000 rows
# Processed 88900000 rows
# Processed 89000000 rows
# Processed 89100000 rows
# Processed 89200000 rows
# Processed 89300000 rows
# Processed 89400000 rows
# Processed 89500000 rows
# Processed 89600000 rows
# Processed 89700000 rows
# Processed 89800000 rows
# Processed 89900000 rows
# Processed 90000000 rows
# Processed 90100000 rows
# Processed 90200000 rows
# Processed 90300000 rows
# Processed 90400000 rows
# Processed 90500000 rows
# Processed 90600000 rows
# Processed 90700000 rows
# Processed 90800000 rows
# Processed 90900000 rows
# Processed 91000000 rows
# Processed 91100000 rows
# Processed 91200000 rows
# Processed 91300000 rows
# Processed 91400000 rows
# Processed 91500000 rows
# Processed 91600000 rows
# Processed 91700000 rows
# Processed 91800000 rows
# Processed 91900000 rows
# Processed 92000000 rows
# Processed 92100000 rows
# Processed 92200000 rows
# Processed 92300000 rows
# Processed 92400000 rows
# Processed 92500000 rows
# Processed 92600000 rows
# Processed 92700000 rows
# Processed 92800000 rows
# Processed 92900000 rows
# Processed 93000000 rows
# Processed 93100000 rows
# Processed 93200000 rows
# Processed 93300000 rows
# Processed 93400000 rows
# Processed 93500000 rows
# Processed 93600000 rows
# Processed 93700000 rows
# Processed 93800000 rows
# Processed 93900000 rows
# Processed 94000000 rows
# Processed 94100000 rows
# Processed 94200000 rows
# Processed 94300000 rows
# Processed 94400000 rows
# Processed 94500000 rows
# Processed 94600000 rows
# Processed 94700000 rows
# Processed 94800000 rows
# Processed 94900000 rows
# Processed 95000000 rows
# Processed 95100000 rows
# Processed 95200000 rows
# Processed 95300000 rows
# Processed 95400000 rows
# Processed 95500000 rows
# Processed 95600000 rows
# Processed 95700000 rows
# Processed 95800000 rows
# Processed 95900000 rows
# Processed 96000000 rows
# Processed 96100000 rows
# Processed 96200000 rows
# Processed 96300000 rows
# Processed 96400000 rows
# Processed 96500000 rows
# Processed 96600000 rows
# Processed 96700000 rows
# Processed 96800000 rows
# Processed 96900000 rows
# Processed 97000000 rows
# Processed 97100000 rows
# Processed 97200000 rows
# Processed 97300000 rows
# Processed 97400000 rows
# Processed 97500000 rows
# Processed 97600000 rows
# Processed 97700000 rows
# Processed 97800000 rows
# Processed 97900000 rows
# Processed 98000000 rows
# Processed 98100000 rows
# Processed 98200000 rows
# Processed 98300000 rows
# Processed 98400000 rows
# Processed 98500000 rows
# Processed 98600000 rows
# Processed 98700000 rows
# Processed 98800000 rows
# Processed 98900000 rows
# Processed 99000000 rows
# Processed 99100000 rows
# Processed 99200000 rows
# Processed 99300000 rows
# Processed 99400000 rows
# Processed 99500000 rows
# Processed 99600000 rows
# Processed 99700000 rows
# Processed 99800000 rows
# Processed 99900000 rows
# Processed 100000000 rows
# Processed 100100000 rows
# Processed 100200000 rows
# Processed 100300000 rows
# Processed 100400000 rows
# Processed 100500000 rows
# Processed 100600000 rows
# Processed 100700000 rows
# Processed 100800000 rows
# Processed 100900000 rows
# Processed 101000000 rows
# Processed 101100000 rows
# Processed 101200000 rows
# Processed 101300000 rows
# Processed 101400000 rows
# Processed 101500000 rows
# Processed 101600000 rows
# Processed 101700000 rows
# Processed 101800000 rows
# Processed 101900000 rows
# Processed 102000000 rows
# Processed 102100000 rows
# Processed 102200000 rows
# Processed 102300000 rows
# Processed 102400000 rows
# Processed 102500000 rows
# Processed 102600000 rows
# Processed 102700000 rows
# Processed 102800000 rows
# Processed 102900000 rows
# Processed 103000000 rows
# Processed 103100000 rows
# Processed 103200000 rows
# Processed 103300000 rows
# Processed 103400000 rows
# Processed 103500000 rows
# Processed 103600000 rows
# Processed 103700000 rows
# Processed 103800000 rows
# Processed 103900000 rows
# Processed 104000000 rows
# Processed 104100000 rows
# Processed 104200000 rows
# Processed 104300000 rows
# Processed 104400000 rows
# Processed 104500000 rows
# Processed 104600000 rows
# Processed 104700000 rows
# Processed 104800000 rows
# Processed 104900000 rows
# Processed 105000000 rows
# Processed 105100000 rows
# Processed 105200000 rows
# Processed 105300000 rows
# Processed 105400000 rows
# Processed 105500000 rows
# Processed 105600000 rows
# Processed 105700000 rows
# Processed 105800000 rows
# Processed 105900000 rows
# Processed 106000000 rows
# Processed 106100000 rows
# Processed 106200000 rows
# Processed 106300000 rows
# Processed 106400000 rows
# Processed 106500000 rows
# Processed 106600000 rows
# Processed 106700000 rows
# Processed 106800000 rows
# Processed 106900000 rows
# Processed 107000000 rows
# Processed 107100000 rows
# Processed 107200000 rows
# Processed 107300000 rows
# Processed 107400000 rows
# Processed 107500000 rows
# Processed 107600000 rows
# Processed 107700000 rows
# Processed 107800000 rows
# Processed 107900000 rows
# Processed 108000000 rows
# Processed 108100000 rows
# Processed 108200000 rows
# Processed 108300000 rows
# Processed 108400000 rows
# Processed 108500000 rows
# Processed 108600000 rows
# Processed 108700000 rows
# Processed 108800000 rows
# Processed 108900000 rows
# Processed 109000000 rows
# Processed 109100000 rows
# Processed 109200000 rows
# Processed 109300000 rows
# Processed 109400000 rows
# Processed 109500000 rows
# Processed 109600000 rows
# Processed 109700000 rows
# Processed 109800000 rows
# Processed 109900000 rows
# Processed 110000000 rows
# Processed 110100000 rows
# Processed 110200000 rows
# Processed 110300000 rows
# Processed 110400000 rows
# Processed 110500000 rows
# Processed 110600000 rows
# Processed 110700000 rows
# Processed 110800000 rows
# Processed 110900000 rows
# Processed 111000000 rows
# Processed 111100000 rows
# Processed 111200000 rows
# Processed 111300000 rows
# Processed 111400000 rows
# Processed 111500000 rows
# Processed 111600000 rows
# Processed 111700000 rows
# Processed 111800000 rows
# Processed 111900000 rows
# Processed 112000000 rows
# Processed 112100000 rows
# Processed 112200000 rows
# Processed 112300000 rows
# Processed 112400000 rows
# Processed 112500000 rows
# Processed 112600000 rows
# Processed 112700000 rows
# Processed 112800000 rows
# Processed 112900000 rows
# Processed 113000000 rows
# Processed 113100000 rows
# Processed 113200000 rows
# Processed 113300000 rows
# Processed 113400000 rows
# Processed 113500000 rows
# Processed 113600000 rows
# Processed 113700000 rows
# Processed 113800000 rows
# Processed 113900000 rows
# Processed 114000000 rows
# Processed 114100000 rows
# Processed 114200000 rows
# Processed 114300000 rows
# Processed 114400000 rows
# Processed 114500000 rows
# Processed 114600000 rows
# Processed 114700000 rows
# Processed 114800000 rows
# Processed 114900000 rows
# Processed 115000000 rows
# Processed 115100000 rows
# Processed 115200000 rows
# Processed 115300000 rows
# Processed 115400000 rows
# Processed 115500000 rows
# Processed 115600000 rows
# Processed 115700000 rows
# Processed 115800000 rows
# Processed 115900000 rows
# Processed 116000000 rows
# Processed 116100000 rows
# Processed 116200000 rows
# Processed 116300000 rows
# Processed 116400000 rows
# Processed 116500000 rows
# Processed 116600000 rows
# Processed 116700000 rows
# Processed 116800000 rows
# Processed 116900000 rows
# Processed 117000000 rows
# Processed 117100000 rows
# Processed 117200000 rows
# Processed 117300000 rows
# Processed 117400000 rows
# Processed 117500000 rows
# Processed 117600000 rows
# Processed 117700000 rows
# Processed 117800000 rows
# Processed 117900000 rows
# Processed 118000000 rows
# Processed 118100000 rows
# Processed 118200000 rows
# Processed 118300000 rows
# Processed 118400000 rows
# Processed 118500000 rows
# Processed 118600000 rows
# Processed 118700000 rows
# Processed 118800000 rows
# Processed 118900000 rows
# Processed 119000000 rows
# Processed 119100000 rows
# Processed 119200000 rows
# Processed 119300000 rows
# Processed 119400000 rows
# Processed 119500000 rows
# Processed 119600000 rows
# Processed 119700000 rows
# Processed 119800000 rows
# Processed 119900000 rows
# Processed 120000000 rows
# Processed 120100000 rows
# Processed 120200000 rows
# Processed 120300000 rows
# Processed 120400000 rows
# Processed 120500000 rows
# Processed 120600000 rows
# Processed 120700000 rows
# Processed 120800000 rows
# Processed 120900000 rows
# Processed 121000000 rows
# Processed 121100000 rows
# Processed 121200000 rows
# Processed 121300000 rows
# Processed 121400000 rows
# Processed 121500000 rows
# Processed 121600000 rows
# Processed 121700000 rows
# Processed 121800000 rows
# Processed 121900000 rows
# Processed 122000000 rows
# Processed 122100000 rows
# Processed 122200000 rows
# Processed 122300000 rows
# Processed 122400000 rows
# Processed 122500000 rows
# Processed 122600000 rows
# Processed 122700000 rows
# Processed 122800000 rows
# Processed 122900000 rows
# Processed 123000000 rows
# Processed 123100000 rows
# Processed 123200000 rows
# Processed 123300000 rows
# Processed 123400000 rows
# Processed 123500000 rows
# Processed 123600000 rows
# Processed 123700000 rows
# Processed 123800000 rows
# Processed 123900000 rows
# Processed 124000000 rows
# Processed 124100000 rows
# Processed 124200000 rows
# Processed 124300000 rows
# Processed 124400000 rows
# Processed 124500000 rows
# Processed 124600000 rows
# Processed 124700000 rows
# Processed 124800000 rows
# Processed 124900000 rows
# Processed 125000000 rows
# Processed 125100000 rows
# Processed 125200000 rows
# Processed 125300000 rows
# Processed 125400000 rows
# Processed 125500000 rows
# Processed 125600000 rows
# Processed 125700000 rows
# Processed 125800000 rows
# Processed 125900000 rows
# Processed 126000000 rows
# Processed 126100000 rows
# Processed 126200000 rows
# Processed 126300000 rows
# Processed 126400000 rows
# Processed 126500000 rows
# Processed 126600000 rows
# Processed 126700000 rows
# Processed 126800000 rows
# Processed 126900000 rows
# Processed 127000000 rows
# Processed 127100000 rows
# Processed 127200000 rows
# Processed 127300000 rows
# Processed 127400000 rows
# Processed 127500000 rows
# Processed 127600000 rows
# Processed 127700000 rows
# Processed 127800000 rows
# Processed 127900000 rows
# Processed 128000000 rows
# Processed 128100000 rows
# Processed 128200000 rows
# Processed 128300000 rows
# Processed 128400000 rows
# Processed 128500000 rows
# Processed 128600000 rows
# Processed 128700000 rows
# Processed 128800000 rows
# Processed 128900000 rows
# Processed 129000000 rows
# Processed 129100000 rows
# Processed 129200000 rows
# Processed 129300000 rows
# Processed 129400000 rows
# Processed 129500000 rows
# Processed 129600000 rows
# Processed 129700000 rows
# Processed 129800000 rows
# Processed 129900000 rows
# Processed 130000000 rows
# Processed 130100000 rows
# Processed 130200000 rows
# Processed 130300000 rows
# Processed 130400000 rows
# Processed 130500000 rows
# Processed 130600000 rows
# Processed 130700000 rows
# Processed 130800000 rows
# Processed 130900000 rows
# Processed 131000000 rows
# Processed 131100000 rows
# Processed 131200000 rows
# Processed 131300000 rows
# Processed 131400000 rows
# Processed 131500000 rows
# Processed 131600000 rows
# Processed 131700000 rows
# Processed 131800000 rows
# Processed 131900000 rows
# Processed 132000000 rows
# Processed 132100000 rows
# Processed 132200000 rows
# Processed 132300000 rows
# Processed 132400000 rows
# Processed 132500000 rows
# Processed 132600000 rows
# Processed 132700000 rows
# Processed 132800000 rows
# Processed 132900000 rows
# Processed 133000000 rows
# Processed 133100000 rows
# Processed 133200000 rows
# Processed 133300000 rows
# Processed 133400000 rows
# Processed 133500000 rows
# Processed 133600000 rows
# Processed 133700000 rows
# Processed 133800000 rows
# Processed 133900000 rows
# Processed 134000000 rows
# Processed 134100000 rows
# Processed 134200000 rows
# Processed 134300000 rows
# Processed 134400000 rows
# Processed 134500000 rows
# Processed 134600000 rows
# Processed 134700000 rows
# Processed 134800000 rows
# Processed 134900000 rows
# Processed 135000000 rows
# Processed 135100000 rows
# Processed 135200000 rows
# Processed 135300000 rows
# Processed 135400000 rows
# Processed 135500000 rows
# Processed 135600000 rows
# Processed 135700000 rows
# Processed 135800000 rows
# Processed 135900000 rows
# Processed 136000000 rows
# Processed 136100000 rows
# Processed 136200000 rows
# Processed 136300000 rows
# Processed 136400000 rows
# Processed 136500000 rows
# Processed 136600000 rows
# Processed 136700000 rows
# Processed 136800000 rows
# Processed 136900000 rows
# Processed 137000000 rows
# Processed 137100000 rows
# Processed 137200000 rows
# Processed 137300000 rows
# Processed 137400000 rows
# Processed 137500000 rows
# Processed 137600000 rows
# Processed 137700000 rows
# Processed 137800000 rows
# Processed 137900000 rows
# Processed 138000000 rows
# Processed 138100000 rows
# Processed 138200000 rows
# Processed 138300000 rows
# Processed 138400000 rows
# Processed 138500000 rows
# Processed 138600000 rows
# Processed 138700000 rows
# Processed 138800000 rows
# Processed 138900000 rows
# Processed 139000000 rows
# Processed 139100000 rows
# Processed 139200000 rows
# Processed 139300000 rows
# Processed 139400000 rows
# Processed 139500000 rows
# Processed 139600000 rows
# Processed 139700000 rows
# Processed 139800000 rows
# Processed 139900000 rows
# Processed 140000000 rows
# Processed 140100000 rows
# Processed 140200000 rows
# Processed 140300000 rows
# Processed 140400000 rows
# Processed 140500000 rows
# Processed 140600000 rows
# Processed 140700000 rows
# Processed 140800000 rows
# Processed 140900000 rows
# Processed 141000000 rows
# Processed 141100000 rows
# Processed 141200000 rows
# Processed 141300000 rows
# Processed 141400000 rows
# Processed 141500000 rows
# Processed 141600000 rows
# Processed 141700000 rows
# Processed 141800000 rows
# Processed 141900000 rows
# Processed 142000000 rows
# Processed 142100000 rows
# Processed 142200000 rows
# Processed 142300000 rows
# Processed 142400000 rows
# Processed 142500000 rows
# Processed 142600000 rows
# Processed 142700000 rows
# Processed 142800000 rows
# Processed 142900000 rows
# Processed 143000000 rows
# Processed 143100000 rows
# Processed 143200000 rows
# Processed 143300000 rows
# Processed 143400000 rows
# Processed 143500000 rows
# Processed 143600000 rows
# Processed 143700000 rows
# Processed 143800000 rows
# Processed 143900000 rows
# Processed 144000000 rows
# Processed 144100000 rows
# Processed 144200000 rows
# Processed 144300000 rows
# Processed 144400000 rows
# Processed 144500000 rows
# Processed 144600000 rows
# Processed 144700000 rows
# Processed 144800000 rows
# Processed 144900000 rows
# Processed 145000000 rows
# Processed 145100000 rows
# Processed 145200000 rows
# Processed 145300000 rows
# Processed 145400000 rows
# Processed 145500000 rows
# Processed 145600000 rows
# Processed 145700000 rows
# Processed 145800000 rows
# Processed 145900000 rows
# Processed 146000000 rows
# Processed 146100000 rows
# Processed 146200000 rows
# Processed 146300000 rows
# Processed 146400000 rows
# Processed 146500000 rows
# Processed 146600000 rows
# Processed 146700000 rows
# Processed 146800000 rows
# Processed 146900000 rows
# Processed 147000000 rows
# Processed 147100000 rows
# Processed 147200000 rows
# Processed 147300000 rows
# Processed 147400000 rows
# Processed 147500000 rows
# Processed 147600000 rows
# Processed 147700000 rows
# Processed 147800000 rows
# Processed 147900000 rows
# Processed 148000000 rows
# Processed 148100000 rows
# Processed 148200000 rows
# Processed 148300000 rows
# Processed 148400000 rows
# Processed 148500000 rows
# Processed 148600000 rows
# Processed 148700000 rows
# Processed 148800000 rows
# Processed 148900000 rows
# Processed 149000000 rows
# Processed 149100000 rows
# Processed 149200000 rows
# Processed 149300000 rows
# Processed 149400000 rows
# Processed 149500000 rows
# Processed 149600000 rows
# Processed 149700000 rows
# Processed 149800000 rows
# Processed 149900000 rows
# Processed 150000000 rows
# Processed 150100000 rows
# Processed 150200000 rows
# Processed 150300000 rows
# Processed 150400000 rows
# Processed 150500000 rows
# Processed 150600000 rows
# Processed 150700000 rows
# Processed 150800000 rows
# Processed 150900000 rows
# Processed 151000000 rows
# Processed 151100000 rows
# Processed 151200000 rows
# Processed 151300000 rows
# Processed 151400000 rows
# Processed 151500000 rows
# Processed 151600000 rows
# Processed 151700000 rows
# Processed 151800000 rows
# Processed 151900000 rows
# Processed 152000000 rows
# Processed 152100000 rows
# Processed 152200000 rows
# Processed 152300000 rows
# Processed 152400000 rows
# Processed 152500000 rows
# Processed 152600000 rows
# Processed 152700000 rows
# Processed 152800000 rows
# Processed 152900000 rows
# Processed 153000000 rows
# Processed 153100000 rows
# Processed 153200000 rows
# Processed 153300000 rows
# Processed 153400000 rows
# Processed 153500000 rows
# Processed 153600000 rows
# Processed 153700000 rows
# Processed 153800000 rows
# Processed 153900000 rows
# Processed 154000000 rows
# Processed 154100000 rows
# Processed 154200000 rows
# Processed 154300000 rows
# Processed 154400000 rows
# Processed 154500000 rows
# Processed 154600000 rows
# Processed 154700000 rows
# Processed 154800000 rows
# Processed 154900000 rows
# Processed 155000000 rows
# Processed 155100000 rows
# Processed 155200000 rows
# Processed 155300000 rows
# Processed 155400000 rows
# Processed 155500000 rows
# Processed 155600000 rows
# Processed 155700000 rows
# Processed 155800000 rows
# Processed 155900000 rows
# Processed 156000000 rows
# Processed 156100000 rows
# Processed 156200000 rows
# Processed 156300000 rows
# Processed 156400000 rows
# Processed 156500000 rows
# Processed 156600000 rows
# Processed 156700000 rows
# Processed 156800000 rows
# Processed 156900000 rows
# Processed 157000000 rows
# Processed 157100000 rows
# Processed 157200000 rows
# Processed 157300000 rows
# Processed 157400000 rows
# Processed 157500000 rows
# Processed 157600000 rows
# Processed 157700000 rows
# Processed 157800000 rows
# Processed 157900000 rows
# Processed 158000000 rows
# Processed 158100000 rows
# Processed 158200000 rows
# Processed 158300000 rows
# Processed 158400000 rows
# Processed 158500000 rows
# Processed 158600000 rows
# Processed 158700000 rows
# Processed 158800000 rows
# Processed 158900000 rows
# Processed 159000000 rows
# Processed 159100000 rows
# Processed 159200000 rows
# Processed 159300000 rows
# Processed 159400000 rows
# Processed 159500000 rows
# Processed 159600000 rows
# Processed 159700000 rows
# Processed 159800000 rows
# Processed 159900000 rows
# Processed 160000000 rows
# Processed 160100000 rows
# Processed 160200000 rows
# Processed 160300000 rows
# Processed 160400000 rows
# Processed 160500000 rows
# Processed 160600000 rows
# Processed 160700000 rows
# Processed 160800000 rows
# Processed 160900000 rows
# Processed 161000000 rows
# Processed 161100000 rows
# Processed 161200000 rows
# Processed 161300000 rows
# Processed 161400000 rows
# Processed 161500000 rows
# Processed 161600000 rows
# Processed 161700000 rows
# Processed 161800000 rows
# Processed 161900000 rows
# Processed 162000000 rows
# Processed 162100000 rows
# Processed 162200000 rows
# Processed 162300000 rows
# Processed 162400000 rows
# Processed 162500000 rows
# Processed 162600000 rows
# Processed 162700000 rows
# Processed 162800000 rows
# Processed 162900000 rows
# Processed 163000000 rows
# Processed 163100000 rows
# Processed 163200000 rows
# Processed 163300000 rows
# Processed 163400000 rows
# Processed 163500000 rows
# Processed 163600000 rows
# Processed 163700000 rows
# Processed 163800000 rows
# Processed 163900000 rows
# Processed 164000000 rows
# Processed 164100000 rows
# Processed 164200000 rows
# Processed 164300000 rows
# Processed 164400000 rows
# Processed 164500000 rows
# Processed 164600000 rows
# Processed 164700000 rows
# Processed 164800000 rows
# Processed 164900000 rows
# Processed 165000000 rows
# Processed 165100000 rows
# Processed 165200000 rows
# Processed 165300000 rows
# Processed 165400000 rows
# Processed 165500000 rows
# Processed 165600000 rows
# Processed 165700000 rows
# Processed 165800000 rows
# Processed 165900000 rows
# Processed 166000000 rows
# Processed 166100000 rows
# Processed 166200000 rows
# Processed 166300000 rows
# Processed 166400000 rows
# Processed 166500000 rows
# Processed 166600000 rows
# Processed 166700000 rows
# Processed 166800000 rows
# Processed 166900000 rows
# Processed 167000000 rows
# Processed 167100000 rows
# Processed 167200000 rows
# Processed 167300000 rows
# Processed 167400000 rows
# Processed 167500000 rows
# Processed 167600000 rows
# Processed 167700000 rows
# Processed 167800000 rows
# Processed 167900000 rows
# Processed 168000000 rows
# Processed 168100000 rows
# Processed 168200000 rows
# Processed 168300000 rows
# Processed 168400000 rows
# Processed 168500000 rows
# Processed 168600000 rows
# Processed 168700000 rows
# Processed 168800000 rows
# Processed 168900000 rows
# Processed 169000000 rows
# Processed 169100000 rows
# Processed 169200000 rows
# Processed 169300000 rows
# Processed 169400000 rows
# Processed 169500000 rows
# Processed 169600000 rows
# Processed 169700000 rows
# Processed 169800000 rows
# Processed 169900000 rows
# Processed 170000000 rows
# Processed 170100000 rows
# Processed 170200000 rows
# Processed 170300000 rows
# Processed 170400000 rows
# Processed 170500000 rows
# Processed 170600000 rows
# Processed 170700000 rows
# Processed 170800000 rows
# Processed 170900000 rows
# Processed 171000000 rows
# Processed 171100000 rows
# Processed 171200000 rows
# Processed 171300000 rows
# Processed 171400000 rows
# Processed 171500000 rows
# Processed 171600000 rows
# Processed 171700000 rows
# Processed 171800000 rows
# Processed 171900000 rows
# Processed 172000000 rows
# Processed 172100000 rows
# Processed 172200000 rows
# Processed 172300000 rows
# Processed 172400000 rows
# Processed 172500000 rows
# Processed 172600000 rows
# Processed 172700000 rows
# Processed 172800000 rows
# Processed 172900000 rows
# Processed 173000000 rows
# Processed 173100000 rows
# Processed 173200000 rows
# Processed 173300000 rows
# Processed 173400000 rows
# Processed 173500000 rows
# Processed 173600000 rows
# Processed 173700000 rows
# Processed 173800000 rows
# Processed 173900000 rows
# Processed 174000000 rows
# Processed 174100000 rows
# Processed 174200000 rows
# Processed 174300000 rows
# Processed 174400000 rows
# Processed 174500000 rows
# Processed 174600000 rows
# Processed 174700000 rows
# Processed 174800000 rows
# Processed 174900000 rows
# Processed 175000000 rows
# Processed 175100000 rows
# Processed 175200000 rows
# Processed 175300000 rows
# Processed 175400000 rows
# Processed 175500000 rows
# Processed 175600000 rows
# Processed 175700000 rows
# Processed 175800000 rows
# Processed 175900000 rows
# Processed 176000000 rows
# Processed 176100000 rows
# Processed 176200000 rows
# Processed 176300000 rows
# Processed 176400000 rows
# Processed 176500000 rows
# Processed 176600000 rows
# Processed 176700000 rows
# Processed 176800000 rows
# Processed 176900000 rows
# Processed 177000000 rows
# Processed 177100000 rows
# Processed 177200000 rows
# Processed 177300000 rows
# Processed 177400000 rows
# Processed 177500000 rows
# Processed 177600000 rows
# Processed 177700000 rows
# Processed 177800000 rows
# Processed 177900000 rows
# Processed 178000000 rows
# Processed 178100000 rows
# Processed 178200000 rows
# Processed 178300000 rows
# Processed 178400000 rows
# Processed 178500000 rows
# Processed 178600000 rows
# Processed 178700000 rows
# Processed 178800000 rows
# Processed 178900000 rows
# Processed 179000000 rows
# Processed 179100000 rows
# Processed 179200000 rows
# Processed 179300000 rows
# Processed 179400000 rows
# Processed 179500000 rows
# Processed 179600000 rows
# Processed 179700000 rows
# Processed 179800000 rows
# Processed 179900000 rows
# Processed 180000000 rows
# Processed 180100000 rows
# Processed 180200000 rows
# Processed 180300000 rows
# Processed 180400000 rows
# Processed 180500000 rows
# Processed 180600000 rows
# Processed 180700000 rows
# Processed 180800000 rows
# Processed 180900000 rows
# Processed 181000000 rows
# Processed 181100000 rows
# Processed 181200000 rows
# Processed 181300000 rows
# Processed 181400000 rows
# Processed 181500000 rows
# Processed 181600000 rows
# Processed 181700000 rows
# Processed 181800000 rows
# Processed 181900000 rows
# Processed 182000000 rows
# Processed 182100000 rows
# Processed 182200000 rows
# Processed 182300000 rows
# Processed 182400000 rows
# Processed 182500000 rows
# Processed 182600000 rows
# Processed 182700000 rows
# Processed 182800000 rows
# Processed 182900000 rows
# Processed 183000000 rows
# Processed 183100000 rows
# Processed 183200000 rows
# Processed 183300000 rows
# Processed 183400000 rows
# Processed 183500000 rows
# Processed 183600000 rows
# Processed 183700000 rows
# Processed 183800000 rows
# Processed 183900000 rows
# Processed 184000000 rows
# Processed 184100000 rows
# Processed 184200000 rows
# Processed 184300000 rows
# Processed 184400000 rows
# Processed 184500000 rows
# Processed 184600000 rows
# Processed 184700000 rows
# Processed 184800000 rows
# Processed 184900000 rows
# Processed 185000000 rows
# Processed 185100000 rows
# Processed 185200000 rows
# Processed 185300000 rows
# Processed 185400000 rows
# Processed 185500000 rows
# Processed 185600000 rows
# Processed 185700000 rows
# Processed 185800000 rows
# Processed 185900000 rows
# Processed 186000000 rows
# Processed 186100000 rows
# Processed 186200000 rows
# Processed 186300000 rows
# Processed 186400000 rows
# Processed 186500000 rows
# Processed 186600000 rows
# Processed 186700000 rows
# Processed 186800000 rows
# Processed 186900000 rows
# Processed 187000000 rows
# Processed 187100000 rows
# Processed 187200000 rows
# Processed 187300000 rows
# Processed 187400000 rows
# Processed 187500000 rows
# Processed 187600000 rows
# Processed 187700000 rows
# Processed 187800000 rows
# Processed 187900000 rows
# Processed 188000000 rows
# Processed 188100000 rows
# Processed 188200000 rows
# Processed 188300000 rows
# Processed 188400000 rows
# Processed 188500000 rows
# Processed 188600000 rows
# Processed 188700000 rows
# Processed 188800000 rows
# Processed 188900000 rows
# Processed 189000000 rows
# Processed 189100000 rows
# Processed 189200000 rows
# Processed 189300000 rows
# Processed 189400000 rows
# Processed 189500000 rows
# Processed 189600000 rows
# Processed 189700000 rows
# Processed 189800000 rows
# Processed 189900000 rows
# Processed 190000000 rows
# Processed 190100000 rows
# Processed 190200000 rows
# Processed 190300000 rows
# Processed 190400000 rows
# Processed 190500000 rows
# Processed 190600000 rows
# Processed 190700000 rows
# Processed 190800000 rows
# Processed 190900000 rows
# Processed 191000000 rows
# Processed 191100000 rows
# Processed 191200000 rows
# Processed 191300000 rows
# Processed 191400000 rows
# Processed 191500000 rows
# Processed 191600000 rows
# Processed 191700000 rows
# Processed 191800000 rows
# Processed 191900000 rows
# Processed 192000000 rows
# Processed 192100000 rows
# Processed 192200000 rows
# Processed 192300000 rows
# Processed 192400000 rows
# Processed 192500000 rows
# Processed 192600000 rows
# Processed 192700000 rows
# Processed 192800000 rows
# Processed 192900000 rows
# Processed 193000000 rows
# Processed 193100000 rows
# Processed 193200000 rows
# Processed 193300000 rows
# Processed 193400000 rows
# Processed 193500000 rows
# Processed 193600000 rows
# Processed 193700000 rows
# Processed 193800000 rows
# Processed 193900000 rows
# Processed 194000000 rows
# Processed 194100000 rows
# Processed 194200000 rows
# Processed 194300000 rows
# Processed 194400000 rows
# Processed 194500000 rows
# Processed 194600000 rows
# Processed 194700000 rows
# Processed 194800000 rows
# Processed 194900000 rows
# Processed 195000000 rows
# Processed 195100000 rows
# Processed 195200000 rows
# Processed 195300000 rows
# Processed 195400000 rows
# Processed 195500000 rows
# Processed 195600000 rows
# Processed 195700000 rows
# Processed 195800000 rows
# Processed 195900000 rows
# Processed 196000000 rows
# Processed 196100000 rows
# Processed 196200000 rows
# Processed 196300000 rows
# Processed 196400000 rows
# Processed 196500000 rows
# Processed 196600000 rows
# Processed 196700000 rows
# Processed 196800000 rows
# Processed 196900000 rows
# Processed 197000000 rows
# Processed 197100000 rows
# Processed 197200000 rows
# Processed 197300000 rows
# Processed 197400000 rows
# Processed 197500000 rows
# Processed 197600000 rows
# Processed 197700000 rows
# Processed 197800000 rows
# Processed 197900000 rows
# Processed 198000000 rows
# Processed 198100000 rows
# Processed 198200000 rows
# Processed 198300000 rows
# Processed 198400000 rows
# Processed 198500000 rows
# Processed 198600000 rows
# Processed 198700000 rows
# Processed 198800000 rows
# Processed 198900000 rows
# Processed 199000000 rows
# Processed 199100000 rows
# Processed 199200000 rows
# Processed 199300000 rows
# Processed 199400000 rows
# Processed 199500000 rows
# Processed 199600000 rows
# Processed 199700000 rows
# Processed 199800000 rows
# Processed 199900000 rows
# Processed 200000000 rows
# Processed 200100000 rows
# Processed 200200000 rows
# Processed 200300000 rows
# Processed 200400000 rows
# Processed 200500000 rows
# Processed 200600000 rows
# Processed 200700000 rows
# Processed 200800000 rows
# Processed 200900000 rows
# Processed 201000000 rows
# Processed 201100000 rows
# Processed 201200000 rows
# Processed 201300000 rows
# Processed 201400000 rows
# Processed 201500000 rows
# Processed 201600000 rows
# Processed 201700000 rows
# Processed 201800000 rows
# Processed 201900000 rows
# Processed 202000000 rows
# Processed 202100000 rows
# Processed 202200000 rows
# Processed 202300000 rows
# Processed 202400000 rows
# Processed 202500000 rows
# Processed 202600000 rows
# Processed 202700000 rows
# Processed 202800000 rows
# Processed 202900000 rows
# Processed 203000000 rows
# Processed 203100000 rows
# Processed 203200000 rows
# Processed 203300000 rows
# Processed 203400000 rows
# Processed 203500000 rows
# Processed 203600000 rows
# Processed 203700000 rows
# Processed 203800000 rows
# Processed 203900000 rows
# Processed 204000000 rows
# Processed 204100000 rows
# Processed 204200000 rows
# Processed 204300000 rows
# Processed 204400000 rows
# Processed 204500000 rows
# Processed 204600000 rows
# Processed 204700000 rows
# Processed 204800000 rows
# Processed 204900000 rows
# Processed 205000000 rows
# Processed 205100000 rows
# Processed 205200000 rows
# Processed 205300000 rows
# Processed 205400000 rows
# Processed 205500000 rows
# Processed 205600000 rows
# Processed 205700000 rows
# Processed 205800000 rows
# Processed 205900000 rows
# Processed 206000000 rows
# Processed 206100000 rows
# Processed 206200000 rows
# Processed 206300000 rows
# Processed 206400000 rows
# Processed 206500000 rows
# Processed 206600000 rows
# Processed 206700000 rows
# Processed 206800000 rows
# Processed 206900000 rows
# Processed 207000000 rows
# Processed 207100000 rows
# Processed 207200000 rows
# Processed 207300000 rows
# Processed 207400000 rows
# Processed 207500000 rows
# Processed 207600000 rows
# Processed 207700000 rows
# Processed 207800000 rows
# Processed 207900000 rows
# Processed 208000000 rows
# Processed 208100000 rows
# Processed 208200000 rows
# Processed 208300000 rows
# Processed 208400000 rows
# Processed 208500000 rows
# Processed 208600000 rows
# Processed 208700000 rows
# Processed 208800000 rows
# Processed 208900000 rows
# Processed 209000000 rows
# Processed 209100000 rows
# Processed 209200000 rows
# Processed 209300000 rows
# Processed 209400000 rows
# Processed 209500000 rows
# Processed 209600000 rows
# Processed 209700000 rows
# Processed 209800000 rows
# Processed 209900000 rows
# Processed 210000000 rows
# Processed 210100000 rows
# Processed 210200000 rows
# Processed 210300000 rows
# Processed 210400000 rows
# Processed 210500000 rows
# Processed 210600000 rows
# Processed 210700000 rows
# Processed 210800000 rows
# Processed 210900000 rows
# Processed 211000000 rows
# Processed 211100000 rows
# Processed 211200000 rows
# Processed 211300000 rows
# Processed 211400000 rows
# Processed 211500000 rows
# Processed 211600000 rows
# Processed 211700000 rows
# Processed 211800000 rows
# Processed 211900000 rows
# Processed 212000000 rows
# Processed 212100000 rows
# Processed 212200000 rows
# Processed 212300000 rows
# Processed 212400000 rows
# Processed 212500000 rows
# Processed 212600000 rows
# Processed 212700000 rows
# Processed 212800000 rows
# Processed 212900000 rows
# Processed 213000000 rows
# Processed 213100000 rows
# Processed 213200000 rows
# Processed 213300000 rows
# Processed 213400000 rows
# Processed 213500000 rows
# Processed 213600000 rows
# Processed 213700000 rows
# Processed 213800000 rows
# Processed 213900000 rows
# Processed 214000000 rows
# Processed 214100000 rows
# Processed 214200000 rows
# Processed 214300000 rows
# Processed 214400000 rows
# Processed 214500000 rows
# Processed 214600000 rows
# Processed 214700000 rows
# Processed 214800000 rows
# Processed 214900000 rows
# Processed 215000000 rows
# Processed 215100000 rows
# Processed 215200000 rows
# Processed 215300000 rows
# Processed 215400000 rows
# Processed 215500000 rows
# Processed 215600000 rows
# Processed 215700000 rows
# Processed 215800000 rows
# Processed 215900000 rows
# Processed 216000000 rows
# Processed 216100000 rows
# Processed 216200000 rows
# Processed 216300000 rows
# Processed 216400000 rows
# Processed 216500000 rows
# Processed 216600000 rows
# Processed 216700000 rows
# Processed 216800000 rows
# Processed 216900000 rows
# Processed 217000000 rows
# Processed 217100000 rows
# Processed 217200000 rows
# Processed 217300000 rows
# Processed 217400000 rows
# Processed 217500000 rows
# Processed 217600000 rows
# Processed 217700000 rows
# Processed 217800000 rows
# Processed 217900000 rows
# Processed 218000000 rows
# Processed 218100000 rows
# Processed 218200000 rows
# Processed 218300000 rows
# Processed 218400000 rows
# Processed 218500000 rows
# Processed 218600000 rows
# Processed 218700000 rows
# Processed 218800000 rows
# Processed 218900000 rows
# Processed 219000000 rows
# Processed 219100000 rows
# Processed 219200000 rows
# Processed 219300000 rows
# Processed 219400000 rows
# Processed 219500000 rows
# Processed 219600000 rows
# Processed 219700000 rows
# Processed 219800000 rows
# Processed 219900000 rows
# Processed 220000000 rows
# Processed 220100000 rows
# Processed 220200000 rows
# Processed 220300000 rows
# Processed 220400000 rows
# Processed 220500000 rows
# Processed 220600000 rows
# Processed 220700000 rows
# Processed 220800000 rows
# Processed 220900000 rows
# Processed 221000000 rows
# Processed 221100000 rows
# Processed 221200000 rows
# Processed 221300000 rows
# Processed 221400000 rows
# Processed 221500000 rows
# Processed 221600000 rows
# Processed 221700000 rows
# Processed 221800000 rows
# Processed 221900000 rows
# Processed 222000000 rows
# Processed 222100000 rows
# Processed 222200000 rows
# Processed 222300000 rows
# Processed 222400000 rows
# Processed 222500000 rows
# Processed 222600000 rows
# Processed 222700000 rows
# Processed 222800000 rows
# Processed 222900000 rows
# Processed 223000000 rows
# Processed 223100000 rows
# Processed 223200000 rows
# Processed 223300000 rows
# Processed 223400000 rows
# Processed 223500000 rows
# Processed 223600000 rows
# Processed 223700000 rows
# Processed 223800000 rows
# Processed 223900000 rows
# Processed 224000000 rows
# Processed 224100000 rows
# Processed 224200000 rows
# Processed 224300000 rows
# Processed 224400000 rows
# Processed 224500000 rows
# Processed 224600000 rows
# Processed 224700000 rows
# Processed 224800000 rows
# Processed 224900000 rows
# Processed 225000000 rows
# Processed 225100000 rows
# Processed 225200000 rows
# Processed 225300000 rows
# Processed 225400000 rows
# Processed 225500000 rows
# Processed 225600000 rows
# Processed 225700000 rows
# Processed 225800000 rows
# Processed 225900000 rows
# Processed 226000000 rows
# Processed 226100000 rows
# Processed 226200000 rows
# Processed 226300000 rows
# Processed 226400000 rows
# Processed 226500000 rows
# Processed 226600000 rows
# Processed 226700000 rows
# Processed 226800000 rows
# Processed 226900000 rows
# Processed 227000000 rows
# Processed 227100000 rows
# Processed 227200000 rows
# Processed 227300000 rows
# Processed 227400000 rows
# Processed 227500000 rows
# Processed 227600000 rows
# Processed 227700000 rows
# Processed 227800000 rows
# Processed 227900000 rows
# Processed 228000000 rows
# Processed 228100000 rows
# Processed 228200000 rows
# Processed 228300000 rows
# Processed 228400000 rows
# Processed 228500000 rows
# Processed 228600000 rows
# Processed 228700000 rows
# Processed 228800000 rows
# Processed 228900000 rows
# Processed 229000000 rows
# Processed 229100000 rows
# Processed 229200000 rows
# Processed 229300000 rows
# Processed 229400000 rows
# Processed 229500000 rows
# Processed 229600000 rows
# Processed 229700000 rows
# Processed 229800000 rows
# Processed 229900000 rows
# Processed 230000000 rows
# Processed 230100000 rows
# Processed 230200000 rows
# Processed 230300000 rows
# Processed 230400000 rows
# Processed 230500000 rows
# Processed 230600000 rows
# Processed 230700000 rows
# Processed 230800000 rows
# Processed 230900000 rows
# Processed 231000000 rows
# Processed 231100000 rows
# Processed 231200000 rows
# Processed 231300000 rows
# Processed 231400000 rows
# Processed 231500000 rows
# Processed 231600000 rows
# Processed 231700000 rows
# Processed 231800000 rows
# Processed 231900000 rows
# Processed 232000000 rows
# Processed 232100000 rows
# Processed 232200000 rows
# Processed 232300000 rows
# Processed 232400000 rows
# Processed 232500000 rows
# Processed 232600000 rows
# Processed 232700000 rows
# Processed 232800000 rows
# Processed 232900000 rows
# Processed 233000000 rows
# Processed 233100000 rows
# Processed 233200000 rows
# Processed 233300000 rows
# Processed 233400000 rows
# Processed 233500000 rows
# Processed 233600000 rows
# Processed 233700000 rows
# Processed 233800000 rows
# Processed 233900000 rows
# Processed 234000000 rows
# Processed 234100000 rows
# Processed 234200000 rows
# Processed 234300000 rows
# Processed 234400000 rows
# Processed 234500000 rows
# Processed 234600000 rows
# Processed 234700000 rows
# Processed 234800000 rows
# Processed 234900000 rows
# Processed 235000000 rows
# Processed 235100000 rows
# Processed 235200000 rows
# Processed 235300000 rows
# Processed 235400000 rows
# Processed 235500000 rows
# Processed 235600000 rows
# Processed 235700000 rows
# Processed 235800000 rows
# Processed 235900000 rows
# Processed 236000000 rows
# Processed 236100000 rows
# Processed 236200000 rows
# Processed 236300000 rows
# Processed 236400000 rows
# Processed 236500000 rows
# Processed 236600000 rows
# Processed 236700000 rows
# Processed 236800000 rows
# Processed 236900000 rows
# Processed 237000000 rows
# Processed 237100000 rows
# Processed 237200000 rows
# Processed 237300000 rows
# Processed 237400000 rows
# Processed 237500000 rows
# Processed 237600000 rows
# Processed 237700000 rows
# Processed 237800000 rows
# Processed 237900000 rows
# Processed 238000000 rows
# Processed 238100000 rows
# Processed 238200000 rows
# Processed 238300000 rows
# Processed 238400000 rows
# Processed 238500000 rows
# Processed 238600000 rows
# Processed 238700000 rows
# Processed 238800000 rows
# Processed 238900000 rows
# Processed 239000000 rows
# Processed 239100000 rows
# Processed 239200000 rows
# Processed 239300000 rows
# Processed 239400000 rows
# Processed 239500000 rows
# Processed 239600000 rows
# Processed 239700000 rows
# Processed 239800000 rows
# Processed 239900000 rows
# Processed 240000000 rows
# Processed 240100000 rows
# Processed 240200000 rows
# Processed 240300000 rows
# Processed 240400000 rows
# Processed 240500000 rows
# Processed 240600000 rows
# Processed 240700000 rows
# Processed 240800000 rows
# Processed 240900000 rows
# Processed 241000000 rows
# Processed 241100000 rows
# Processed 241200000 rows
# Processed 241300000 rows
# Processed 241400000 rows
# Processed 241500000 rows
# Processed 241600000 rows
# Processed 241700000 rows
# Processed 241800000 rows
# Processed 241900000 rows
# Processed 242000000 rows
# Processed 242100000 rows
# Processed 242200000 rows
# Processed 242300000 rows
# Processed 242400000 rows
# Processed 242500000 rows
# Processed 242600000 rows
# Processed 242700000 rows
# Processed 242800000 rows
# Processed 242900000 rows
# Processed 243000000 rows
# Processed 243100000 rows
# Processed 243200000 rows
# Processed 243300000 rows
# Processed 243400000 rows
# Processed 243500000 rows
# Processed 243600000 rows
# Processed 243700000 rows
# Processed 243800000 rows
# Processed 243900000 rows
# Processed 244000000 rows
# Processed 244100000 rows
# Processed 244200000 rows
# Processed 244300000 rows
# Processed 244400000 rows
# Processed 244500000 rows
# Processed 244600000 rows
# Processed 244700000 rows
# Processed 244800000 rows
# Processed 244900000 rows
# Processed 245000000 rows
# Processed 245100000 rows
# Processed 245200000 rows
# Processed 245300000 rows
# Processed 245400000 rows
# Processed 245500000 rows
# Processed 245600000 rows
# Processed 245700000 rows
# Processed 245800000 rows
# Processed 245900000 rows
# Processed 246000000 rows
# Processed 246100000 rows
# Processed 246200000 rows
# Processed 246300000 rows
# Processed 246400000 rows
# Processed 246500000 rows
# Processed 246600000 rows
# Processed 246700000 rows
# Processed 246800000 rows
# Processed 246900000 rows
# Processed 247000000 rows
# Processed 247100000 rows
# Processed 247200000 rows
# Processed 247300000 rows
# Processed 247400000 rows
# Processed 247500000 rows
# Processed 247600000 rows
# Processed 247700000 rows
# Processed 247800000 rows
# Processed 247900000 rows
# Processed 248000000 rows
# Processed 248100000 rows
# Warning: No data found for the given criteria.
# Saved data and labels for patient file to /content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/05_time_series_data_preprocessing/feature_set_1_results

# %%
# Analyse chunk 8 and 9 results
chunk_8_results = '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/05_time_series_data_preprocessing/feature_set_1_results/data_chunk_8.parquet'

chunk_8_results_df = pd.read_parquet(chunk_8_results)
chunk_8_results_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
chunk_9_results = '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/05_time_series_data_preprocessing/feature_set_1_results/data_chunk_9.parquet'

chunk_9_results_df = pd.read_parquet(chunk_9_results)
chunk_9_results_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# It seems the results for both chunk 8 and chunk 9 are empty.
#
# Analyse if the patients in these chunks have any entries in the last 6 hours before extubation.
#
# Either: These patients have no entries for these specific itemids, or they have no entries at all.

# %%
# Analyse if patients have any entries at all and then within those check for the specific itemids
def process_all_chunk(chunk, patient_dict, time_window):
    # Filter the columns
    chunk = chunk[['subject_id', 'charttime', 'itemid', 'valuenum']].copy()

    # Drop rows where valuenum is null
    chunk = chunk.dropna(subset=['valuenum'])

    # Convert subject_id to nullable integer type if necessary
    chunk.loc[:, 'subject_id'] = chunk['subject_id'].astype('Int64')

    # Filter by subject_id
    chunk = chunk[chunk['subject_id'].isin(patient_dict.keys())]

    # Apply the time window filter using the patient_dict
    filtered_rows = []
    for idx, row in chunk.iterrows():
        extubation_time = patient_dict[row['subject_id']]['extubation_starttime']
        if (row['charttime'] >= extubation_time - time_window) and (row['charttime'] <= extubation_time):
            filtered_rows.append(row)

    filtered_df = pd.DataFrame(filtered_rows)
    if not filtered_df.empty:
        filtered_df.loc[:, 'extubation_starttime'] = filtered_df['subject_id'].map(lambda x: patient_dict[x]['extubation_starttime'])
        filtered_df.loc[:, 'extubation_failure'] = filtered_df['subject_id'].map(lambda x: patient_dict[x]['extubation_failure'])

    return filtered_df

# %%
# Extract all possible data from patients in each chunk
def extract_all_patient_data(patient_df, chartevents_file_path, time_window):
    # Initialize a list to hold the results
    results = []

    # Define the chunk size
    chunksize = 100000

    # Convert patient_df to a dictionary for fast lookups
    patient_dict = patient_df.set_index('subject_id').to_dict('index')

    # Track the number of processed rows
    processed_rows = 0

    # Read and process the file in chunks
    for chunk in pd.read_csv(chartevents_file_path, parse_dates=['charttime'], chunksize=chunksize):
        # Process each chunk and filter the data
        filtered_df = process_all_chunk(chunk, patient_dict, time_window)

        # Append the filtered data to the results list
        results.append(filtered_df)

        # Update the number of processed rows
        processed_rows += len(chunk)

        # Print the progress every 100,000 rows
        if processed_rows % 1000000 == 0:
          print(f"Processed {processed_rows} rows")

    # Concatenate all the results
    result_df = pd.concat(results, ignore_index=True)

    # Extract the data and labels
    data = result_df[['subject_id', 'charttime', 'itemid', 'valuenum']]
    labels = result_df[['subject_id', 'extubation_failure']]

    return data, labels

# %%
time_window_hours = timedelta(hours=6)

# %%
chartevents_path
# Out:
# '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/mimic-iv-2.2-raw-data/icu/chartevents.csv'

# %%
output_dir
# Out:
# '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/05_time_series_data_preprocessing/feature_set_1_results'

# %%
empty_patient_files = [chunk_8, chunk_9]

for i, patient_file in enumerate(empty_patient_files, start=8):
    print(f"Processing patient chunk file: {patient_file}")

    # Read the patient chunk file
    patient_df = pd.read_parquet(patient_file)

    # Extract all data and labels
    data, labels = extract_all_patient_data(patient_df, chartevents_path, time_window_hours)

    # Save the results to Google Drive
    data_file_path = f'{output_dir}all_data_chunk_{i}.parquet'
    labels_file_path = f'{output_dir}all_labels_chunk_{i}.parquet'

    data.to_parquet(data_file_path)
    labels.to_parquet(labels_file_path)

    print(f"Saved all data and labels for chunk {i} to {output_dir}")
# Out:
# Processing patient chunk file: /content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/03_annotated_set/final_set_split_files/patient_chunk_8.parquet
# Processed 1000000 rows
# Processed 2000000 rows
# Processed 3000000 rows
# Processed 4000000 rows
# Processed 5000000 rows
# Processed 6000000 rows
# Processed 7000000 rows
# Processed 8000000 rows
# Processed 9000000 rows
# Processed 10000000 rows
# Processed 11000000 rows
# Processed 12000000 rows
# Processed 13000000 rows
# Processed 14000000 rows
# Processed 15000000 rows
# Processed 16000000 rows
# Processed 17000000 rows
# Processed 18000000 rows
# Processed 19000000 rows
# Processed 20000000 rows
# Processed 21000000 rows
# Processed 22000000 rows
# Processed 23000000 rows
# Processed 24000000 rows
# Processed 25000000 rows
# Processed 26000000 rows
# Processed 27000000 rows
# Processed 28000000 rows
# Processed 29000000 rows
# Processed 30000000 rows
# Processed 31000000 rows
# Processed 32000000 rows
# Processed 33000000 rows
# Processed 34000000 rows
# Processed 35000000 rows
# Processed 36000000 rows
# Processed 37000000 rows
# Processed 38000000 rows
# Processed 39000000 rows
# Processed 40000000 rows
# Processed 41000000 rows
# Processed 42000000 rows
# Processed 43000000 rows
# Processed 44000000 rows
# Processed 45000000 rows
# Processed 46000000 rows
# Processed 47000000 rows
# Processed 48000000 rows
# Processed 49000000 rows
# Processed 50000000 rows
# Processed 51000000 rows
# Processed 52000000 rows
# Processed 53000000 rows
# Processed 54000000 rows
# Processed 55000000 rows
# Processed 56000000 rows
# Processed 57000000 rows
# Processed 58000000 rows
# Processed 59000000 rows
# Processed 60000000 rows
# Processed 61000000 rows
# Processed 62000000 rows
# Processed 63000000 rows
# Processed 64000000 rows
# Processed 65000000 rows
# Processed 66000000 rows
# Processed 67000000 rows
# Processed 68000000 rows
# Processed 69000000 rows
# Processed 70000000 rows
# Processed 71000000 rows
# Processed 72000000 rows
# Processed 73000000 rows
# Processed 74000000 rows
# Processed 75000000 rows
# Processed 76000000 rows
# Processed 77000000 rows
# Processed 78000000 rows
# Processed 79000000 rows
# Processed 80000000 rows
# Processed 81000000 rows
# Processed 82000000 rows
# Processed 83000000 rows
# Processed 84000000 rows
# Processed 85000000 rows
# Processed 86000000 rows
# Processed 87000000 rows
# Processed 88000000 rows
# Processed 89000000 rows
# Processed 90000000 rows
# Processed 91000000 rows
# Processed 92000000 rows
# Processed 93000000 rows
# Processed 94000000 rows
# Processed 95000000 rows
# Processed 96000000 rows
# Processed 97000000 rows
# Processed 98000000 rows
# Processed 99000000 rows
# Processed 100000000 rows
# Processed 101000000 rows
# Processed 102000000 rows
# Processed 103000000 rows
# Processed 104000000 rows
# Processed 105000000 rows
# Processed 106000000 rows
# Processed 107000000 rows
# Processed 108000000 rows
# Processed 109000000 rows
# Processed 110000000 rows
# Processed 111000000 rows
# Processed 112000000 rows
# Processed 113000000 rows
# Processed 114000000 rows
# Processed 115000000 rows
# Processed 116000000 rows
# Processed 117000000 rows
# Processed 118000000 rows
# Processed 119000000 rows
# Processed 120000000 rows
# Processed 121000000 rows
# Processed 122000000 rows
# Processed 123000000 rows
# Processed 124000000 rows
# Processed 125000000 rows
# Processed 126000000 rows
# Processed 127000000 rows
# Processed 128000000 rows
# Processed 129000000 rows
# Processed 130000000 rows
# Processed 131000000 rows
# Processed 132000000 rows
# Processed 133000000 rows
# Processed 134000000 rows
# Processed 135000000 rows
# Processed 136000000 rows
# Processed 137000000 rows
# Processed 138000000 rows
# Processed 139000000 rows
# Processed 140000000 rows
# Processed 141000000 rows
# Processed 142000000 rows
# Processed 143000000 rows
# Processed 144000000 rows
# Processed 145000000 rows
# Processed 146000000 rows
# Processed 147000000 rows
# Processed 148000000 rows
# Processed 149000000 rows
# Processed 150000000 rows
# Processed 151000000 rows
# Processed 152000000 rows
# Processed 153000000 rows
# Processed 154000000 rows
# Processed 155000000 rows
# Processed 156000000 rows
# Processed 157000000 rows
# Processed 158000000 rows
# Processed 159000000 rows
# Processed 160000000 rows
# Processed 161000000 rows
# Processed 162000000 rows
# Processed 163000000 rows
# Processed 164000000 rows
# Processed 165000000 rows
# Processed 166000000 rows
# Processed 167000000 rows
# Processed 168000000 rows
# Processed 169000000 rows
# Processed 170000000 rows
# Processed 171000000 rows
# Processed 172000000 rows
# Processed 173000000 rows
# Processed 174000000 rows
# Processed 175000000 rows
# Processed 176000000 rows
# Processed 177000000 rows
# Processed 178000000 rows
# Processed 179000000 rows
# Processed 180000000 rows
# Processed 181000000 rows
# Processed 182000000 rows
# Processed 183000000 rows
# Processed 184000000 rows
# Processed 185000000 rows
# Processed 186000000 rows
# Processed 187000000 rows
# Processed 188000000 rows
# Processed 189000000 rows
# Processed 190000000 rows
# Processed 191000000 rows
# Processed 192000000 rows
# Processed 193000000 rows
# Processed 194000000 rows
# Processed 195000000 rows
# Processed 196000000 rows
# Processed 197000000 rows
# Processed 198000000 rows
# Processed 199000000 rows
# Processed 200000000 rows
# Processed 201000000 rows
# Processed 202000000 rows
# Processed 203000000 rows
# Processed 204000000 rows
# Processed 205000000 rows
# Processed 206000000 rows
# Processed 207000000 rows
# Processed 208000000 rows
# Processed 209000000 rows
# Processed 210000000 rows
# Processed 211000000 rows
# Processed 212000000 rows
# Processed 213000000 rows
# Processed 214000000 rows
# Processed 215000000 rows
# Processed 216000000 rows
# Processed 217000000 rows
# Processed 218000000 rows
# Processed 219000000 rows
# Processed 220000000 rows
# Processed 221000000 rows
# Processed 222000000 rows
# Processed 223000000 rows
# Processed 224000000 rows
# Processed 225000000 rows
# Processed 226000000 rows
# Processed 227000000 rows
# Processed 228000000 rows
# Processed 229000000 rows
# Processed 230000000 rows
# Processed 231000000 rows
# Processed 232000000 rows
# Processed 233000000 rows
# Processed 234000000 rows
# Processed 235000000 rows
# Processed 236000000 rows
# Processed 237000000 rows
# Processed 238000000 rows
# Processed 239000000 rows
# Processed 240000000 rows
# Processed 241000000 rows
# Processed 242000000 rows
# Processed 243000000 rows
# Processed 244000000 rows
# Processed 245000000 rows
# Processed 246000000 rows
# Processed 247000000 rows
# Processed 248000000 rows
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-1d0398e055be> in <cell line: 3>()
#       8
#       9     # Extract all data and labels
# ---> 10     data, labels = extract_all_patient_data(patient_df, chartevents_path, time_window_hours)
#      11
#      12     # Save the results to Google Drive
#
# <ipython-input-22-e54241567f80> in extract_all_patient_data(patient_df, chartevents_file_path, time_window)
#      32
#      33     # Extract the data and labels
# ---> 34     data = result_df[['subject_id', 'charttime', 'itemid', 'valuenum']]
#      35     labels = result_df[['subject_id', 'extubation_failure']]
#      36
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3765             if is_iterator(key):
#    3766                 key = list(key)
# -> 3767             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3768
#    3769         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5875             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5876
# -> 5877         self._raise_if_missing(keyarr, indexer, axis_name)
#    5878
#    5879         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    5936                 if use_interval_msg:
#    5937                     key = list(key)
# -> 5938                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5939
#    5940             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['subject_id', 'charttime', 'itemid', 'valuenum'], dtype='object')] are in the [columns]"

# %% [markdown]
# There seems to be an error that the specified columns are not present in the chunk dataframe from chartevents.
#
# We will debug this issue by first printing the column names in the chunk.

# %%
def process_all_chunk_2(chunk, patient_dict, time_window):

    # Filter the columns
    chunk = chunk[['subject_id', 'charttime', 'itemid', 'valuenum']].copy()

    # # Print columns to debug
    # print("Columns in chunk:", chunk.columns)

    # Drop rows where valuenum is null
    chunk = chunk.dropna(subset=['valuenum'])

    # Convert subject_id to nullable integer type if necessary
    chunk.loc[:, 'subject_id'] = chunk['subject_id'].astype('Int64')

    # Filter by subject_id
    chunk = chunk[chunk['subject_id'].isin(patient_dict.keys())]

    # Apply the time window filter using the patient_dict
    filtered_rows = []
    for idx, row in chunk.iterrows():
        extubation_time = patient_dict[row['subject_id']]['extubation_starttime']
        if (row['charttime'] >= extubation_time - time_window) and (row['charttime'] <= extubation_time):
            filtered_rows.append(row)

    filtered_df = pd.DataFrame(filtered_rows)
    if not filtered_df.empty:
        filtered_df.loc[:, 'extubation_starttime'] = filtered_df['subject_id'].map(lambda x: patient_dict[x]['extubation_starttime'])
        filtered_df.loc[:, 'extubation_failure'] = filtered_df['subject_id'].map(lambda x: patient_dict[x]['extubation_failure'])

    return filtered_df

def extract_all_patient_data_2(patient_df, chartevents_file_path, time_window):
    # Initialize a list to hold the results
    results = []

    # Define the chunk size
    chunksize = 100000

    # Convert patient_df to a dictionary for fast lookups
    patient_dict = patient_df.set_index('subject_id').to_dict('index')

    # Track the number of processed rows
    processed_rows = 0

    # Read and process the file in chunks
    for chunk in pd.read_csv(chartevents_file_path, parse_dates=['charttime'], chunksize=chunksize):

        # print(chunk.head())

        # Process each chunk and filter the data
        filtered_df = process_all_chunk_2(chunk, patient_dict, time_window)

        # Append the filtered data to the results list
        results.append(filtered_df)

        # # Check if the filtered DataFrame is empty and has the expected columns
        # if filtered_df.empty:
        #     print("Warning: Filtered DataFrame is empty for this chunk.")
        # elif not all(col in filtered_df.columns for col in ['subject_id', 'charttime', 'itemid', 'valuenum']):
        #     print("Warning: Filtered DataFrame is missing expected columns.")
        #     return
        # else:
        #     # Append the filtered data to the results list
        #     results.append(filtered_df)

        # Update the number of processed rows
        processed_rows += len(chunk)

        # Print progress
        print(f"Processed {processed_rows} rows.")

    # Concatenate all the results
    result_df = pd.concat(results, ignore_index=True)

    # Extract the data and labels
    data = result_df[['subject_id', 'charttime', 'itemid', 'valuenum']]
    labels = result_df[['subject_id', 'extubation_starttime', 'extubation_failure']]

    return data, labels

# %%
empty_patient_files = [chunk_8, chunk_9]

for i, patient_file in enumerate(empty_patient_files, start=8):
    print(f"Processing patient chunk file: {patient_file}")

    # Read the patient chunk file
    patient_df = pd.read_parquet(patient_file)

    # Extract all data and labels
    data, labels = extract_all_patient_data_2(patient_df, chartevents_path, time_window_hours)

    # Save the results to Google Drive
    data_file_path = f'{output_dir}all_data_chunk_{i}.parquet'
    labels_file_path = f'{output_dir}all_labels_chunk_{i}.parquet'

    data.to_parquet(data_file_path)
    labels.to_parquet(labels_file_path)

    print(f"Saved all data and labels for chunk {i} to {output_dir}")
# Out:
# Processing patient chunk file: /content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/03_annotated_set/final_set_split_files/patient_chunk_8.parquet
#    subject_id   hadm_id   stay_id  caregiver_id           charttime  \
# 0    10000032  29079034  39553978       47007.0 2180-07-23 21:01:00
# 1    10000032  29079034  39553978       47007.0 2180-07-23 21:01:00
# 2    10000032  29079034  39553978       47007.0 2180-07-23 21:01:00
# 3    10000032  29079034  39553978       47007.0 2180-07-23 22:00:00
# 4    10000032  29079034  39553978       47007.0 2180-07-23 22:00:00
#
#              storetime  itemid value  valuenum valueuom  warning
# 0  2180-07-23 22:15:00  220179    82      82.0     mmHg      0.0
# 1  2180-07-23 22:15:00  220180    59      59.0     mmHg      0.0
# 2  2180-07-23 22:15:00  220181    63      63.0     mmHg      0.0
# 3  2180-07-23 22:15:00  220045    94      94.0      bpm      0.0
# 4  2180-07-23 22:15:00  220179    85      85.0     mmHg      0.0
# Columns in chunk: Index(['subject_id', 'charttime', 'itemid', 'valuenum'], dtype='object')
# Warning: Filtered DataFrame is empty for this chunk.
# Processed 100000 rows.
#         subject_id   hadm_id   stay_id  caregiver_id           charttime  \
# 100000    10003400  20214994  32128372       68979.0 2137-03-02 21:39:00
# 100001    10003400  20214994  32128372       68979.0 2137-03-02 21:39:00
# 100002    10003400  20214994  32128372       68979.0 2137-03-02 21:39:00
# 100003    10003400  20214994  32128372       68979.0 2137-03-02 21:39:00
# 100004    10003400  20214994  32128372       68979.0 2137-03-02 21:39:00
#
#                   storetime  itemid  \
# 100000  2137-03-02 21:39:00  228898
# 100001  2137-03-02 21:39:00  228898
# 100002  2137-03-02 21:39:00  228898
# 100003  2137-03-02 21:39:00  228902
# 100004  2137-03-02 21:39:00  228902
#
#                                                     value  valuenum valueuom  \
# 100000           Monitoring electrolytes / renal function       NaN      NaN
# 100001      Monitor vital signs and hemodynamic pressures       NaN      NaN
# 100002                       Strict / accurate I&O hourly       NaN      NaN
# 100003  Patient will avoid intubation by maintaining p...       NaN      NaN
# 100004  Patient will be able to maintain clear and pat...       NaN      NaN
#
#         warning
# 100000      0.0
# 100001      0.0
# 100002      0.0
# 100003      0.0
# 100004      0.0
# Columns in chunk: Index(['subject_id', 'charttime', 'itemid', 'valuenum'], dtype='object')
# Warning: Filtered DataFrame is empty for this chunk.
# Processed 200000 rows.
#         subject_id   hadm_id   stay_id  caregiver_id           charttime  \
# 200000    10004401  28128182  37919158       57011.0 2144-02-14 18:00:00
# 200001    10004401  28128182  37919158       57011.0 2144-02-14 18:00:00
# 200002    10004401  28128182  37919158       57011.0 2144-02-14 18:00:00
# 200003    10004401  28128182  37919158       57011.0 2144-02-14 18:00:00
# 200004    10004401  28128182  37919158       57011.0 2144-02-14 18:00:00
#
#                   storetime  itemid      value  valuenum valueuom  warning
# 200000  2144-02-14 18:01:00  224369      Thick       NaN      NaN      0.0
# 200001  2144-02-14 18:01:00  224370     Yellow       NaN      NaN      0.0
# 200002  2144-02-14 18:01:00  224372  Suctioned       NaN      NaN      0.0
# 200003  2144-02-14 18:01:00  224373      Small       NaN      NaN      0.0
# 200004  2144-02-14 18:12:00  220045         70      70.0      bpm      0.0
# Columns in chunk: Index(['subject_id', 'charttime', 'itemid', 'valuenum'], dtype='object')
# Warning: Filtered DataFrame is empty for this chunk.
# Processed 300000 rows.
#         subject_id   hadm_id   stay_id  caregiver_id           charttime  \
# 300000    10005866  20364112  34170353        2036.0 2149-10-02 13:14:00
# 300001    10005866  20364112  34170353        2036.0 2149-10-02 13:15:00
# 300002    10005866  20364112  34170353        2036.0 2149-10-02 13:15:00
# 300003    10005866  20364112  34170353        2036.0 2149-10-02 13:15:00
# 300004    10005866  20364112  34170353        2036.0 2149-10-02 14:00:00
#
#                   storetime  itemid      value  valuenum valueuom  warning
# 300000  2149-10-02 13:15:00  228099          0       0.0      NaN      0.0
# 300001  2149-10-02 13:15:00  223758  Full code       NaN      NaN      0.0
# 300002  2149-10-02 13:15:00  224640     T-SICU       NaN      NaN      0.0
# 300003  2149-10-02 13:15:00  226531      137.3     137.3      NaN      0.0
# 300004  2149-10-02 13:59:00  223761       98.2      98.2       °F      0.0
# Columns in chunk: Index(['subject_id', 'charttime', 'itemid', 'valuenum'], dtype='object')
# Warning: Filtered DataFrame is empty for this chunk.
# Processed 400000 rows.
#         subject_id   hadm_id   stay_id  caregiver_id  charttime  \
# 400000    10010867  22429197  39880770       87154.0 2148-01-07
# 400001    10010867  22429197  39880770       87154.0 2148-01-07
# 400002    10010867  22429197  39880770       87154.0 2148-01-07
# 400003    10010867  22429197  39880770       87154.0 2148-01-07
# 400004    10010867  22429197  39880770       87154.0 2148-01-07
#
#                   storetime  itemid value  valuenum valueuom  warning
# 400000  2148-01-07 00:37:00  220245   237     237.0   ml/min      0.0
# 400001  2148-01-07 00:37:00  220292     3       3.0    L/min      0.0
# 400002  2148-01-07 00:37:00  220293    14      14.0    L/min      0.0
# 400003  2148-01-07 00:37:00  220339     8       8.0    cmH2O      0.0
# 400004  2148-01-07 00:37:00  223835    40      40.0      NaN      0.0
# Columns in chunk: Index(['subject_id', 'charttime', 'itemid', 'valuenum'], dtype='object')
# Warning: Filtered DataFrame is empty for this chunk.
# Processed 500000 rows.
#         subject_id   hadm_id   stay_id  caregiver_id           charttime  \
# 500000    10014354  27487226  34600477       98270.0 2148-06-30 03:38:00
# 500001    10014354  27487226  34600477       98270.0 2148-06-30 03:38:00
# 500002    10014354  27487226  34600477       98270.0 2148-06-30 03:38:00
# 500003    10014354  27487226  34600477       98270.0 2148-06-30 03:38:00
# 500004    10014354  27487226  34600477       98270.0 2148-06-30 04:00:00
#
#                   storetime  itemid            value  valuenum valueuom  \
# 500000  2148-06-30 04:40:00  226113                0       0.0      NaN
# 500001  2148-06-30 04:40:00  227756     On admission       NaN      NaN
# 500002  2148-06-30 04:40:00  229475                1       1.0      NaN
# 500003  2148-06-30 04:40:00  229535  Indwelling Port       NaN      NaN
# 500004  2148-06-30 04:41:00  220045               89      89.0      bpm
#
#         warning
# 500000      0.0
# 500001      0.0
# 500002      0.0
# 500003      0.0
# 500004      0.0
# Columns in chunk: Index(['subject_id', 'charttime', 'itemid', 'valuenum'], dtype='object')
# Warning: Filtered DataFrame is empty for this chunk.
# Processed 600000 rows.
#         subject_id   hadm_id   stay_id  caregiver_id  charttime  \
# 600000    10017531  21095812  32136798       74197.0 2160-01-04
# 600001    10017531  21095812  32136798       74197.0 2160-01-04
# 600002    10017531  21095812  32136798       74197.0 2160-01-04
# 600003    10017531  21095812  32136798       74197.0 2160-01-04
# 600004    10017531  21095812  32136798       74197.0 2160-01-04
#
#                   storetime  itemid                  value  valuenum valueuom  \
# 600000  2160-01-03 23:27:00  223999                 Thrush       NaN      NaN
# 600001  2160-01-03 23:27:00  224785       Feeding/Peditube       NaN      NaN
# 600002  2160-01-03 23:27:00  226104  Arouse to Stimulation       NaN      NaN
# 600003  2160-01-03 23:28:00  224007             Right Nare       NaN      NaN
# 600004  2160-01-03 23:28:00  224012          Flexiseal FMS       NaN      NaN
#
#         warning
# 600000      0.0
# 600001      0.0
# 600002      0.0
# 600003      0.0
# 600004      0.0
# Columns in chunk: Index(['subject_id', 'charttime', 'itemid', 'valuenum'], dtype='object')
# Warning: Filtered DataFrame is empty for this chunk.
# Processed 700000 rows.
#         subject_id   hadm_id   stay_id  caregiver_id           charttime  \
# 700000    10018328  23786647  31269608       29573.0 2154-04-25 06:00:00
# 700001    10018328  23786647  31269608       29573.0 2154-04-25 06:00:00
# 700002    10018328  23786647  31269608       29573.0 2154-04-25 06:00:00
# 700003    10018328  23786647  31269608       29573.0 2154-04-25 06:00:00
# 700004    10018328  23786647  31269608       29573.0 2154-04-25 06:00:00
#
#                   storetime  itemid            value  valuenum valueuom  \
# 700000  2154-04-25 06:14:00  228411  Some resistance       4.0      NaN
# 700001  2154-04-25 06:14:00  228412  Full resistance       5.0      NaN
# 700002  2154-04-25 06:14:00  228414          Aphasic       NaN      NaN
# 700003  2154-04-25 06:14:00  229381             City       1.0      NaN
# 700004  2154-04-25 06:14:00  229381            Month       1.0      NaN
#
#         warning
# 700000      0.0
# 700001      0.0
# 700002      0.0
# 700003      0.0
# 700004      0.0
# Columns in chunk: Index(['subject_id', 'charttime', 'itemid', 'valuenum'], dtype='object')
# Warning: Filtered DataFrame is empty for this chunk.
# Processed 800000 rows.
#         subject_id   hadm_id   stay_id  caregiver_id           charttime  \
# 800000    10020944  29974575  30757476       65154.0 2131-03-03 17:00:00
# 800001    10020944  29974575  30757476       65154.0 2131-03-03 17:00:00
# 800002    10020944  29974575  30757476       65154.0 2131-03-03 17:00:00
# 800003    10020944  29974575  30757476       65154.0 2131-03-03 17:00:00
# 800004    10020944  29974575  30757476       65154.0 2131-03-03 17:22:00
#
#                   storetime  itemid       value  valuenum  valueuom  warning
# 800000  2131-03-03 17:20:00  220052          74      74.0      mmHg      0.0
# 800001  2131-03-03 17:20:00  220210          24      24.0  insp/min      0.0
# 800002  2131-03-03 17:20:00  220277         100     100.0         %      0.0
# 800003  2131-03-03 17:20:00  224650         NaN       NaN       NaN      0.0
# 800004  2131-03-03 17:22:00  224080  45 Degrees       NaN       NaN      0.0
# Columns in chunk: Index(['subject_id', 'charttime', 'itemid', 'valuenum'], dtype='object')
# Warning: Filtered DataFrame is empty for this chunk.
# Processed 900000 rows.
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-44-716e49951009> in <cell line: 3>()
#       8
#       9     # Extract all data and labels
# ---> 10     data, labels = extract_all_patient_data_2(patient_df, chartevents_path, time_window_hours)
#      11
#      12     # Save the results to Google Drive
#
# <ipython-input-43-e31976c25d1a> in extract_all_patient_data_2(patient_df, chartevents_file_path, time_window)
#      44
#      45     # Read and process the file in chunks
# ---> 46     for chunk in pd.read_csv(chartevents_file_path, parse_dates=['charttime'], chunksize=chunksize):
#      47
#      48         print(chunk.head())
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __next__(self)
#    1622     def __next__(self) -> DataFrame:
#    1623         try:
# -> 1624             return self.get_chunk()
#    1625         except StopIteration:
#    1626             self.close()
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in get_chunk(self, size)
#    1731                 raise StopIteration
#    1732             size = min(size, self.nrows - self._currow)
# -> 1733         return self.read(nrows=size)
#    1734
#    1735     def __enter__(self) -> TextFileReader:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1702                     columns,
#    1703                     col_dict,
# -> 1704                 ) = self._engine.read(  # type: ignore[attr-defined]
#    1705                     nrows
#    1706                 )
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     232         try:
#     233             if self.low_memory:
# --> 234                 chunks = self._reader.read_low_memory(nrows)
#     235                 # destructive to chunks
#     236                 data = _concatenate_chunks(chunks)
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %% [markdown]
# Similar issue is cropping up.
#
# We know the other patient files worked so will try the same function with those.

# %%
# Load chunk 7 results
chunk_7_results = '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/05_time_series_data_preprocessing/feature_set_1_results/data_chunk_7.parquet'

chunk_7_results_df = pd.read_parquet(chunk_7_results)
chunk_7_results_df.head()
# Out:
#    subject_id           charttime    itemid  valuenum
# 0    17062372 2143-02-25 04:00:00  223835.0      40.0
# 1    17062372 2143-02-25 04:00:00  223849.0      11.0
# 2    17062372 2143-02-25 04:00:00  224685.0     757.0
# 3    17062372 2143-02-25 04:00:00  224686.0     750.0
# 4    17062372 2143-02-25 04:00:00  224687.0       9.6

# %%
chunk_7 = '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/03_annotated_set/final_set_split_files/patient_chunk_7.parquet'

# Run chunk 7 through function
example_result, example_labels = extract_all_patient_data_2(pd.read_parquet(chunk_7), chartevents_path, time_window_hours)
# Out:
# Processed 100000 rows.
# Processed 200000 rows.
# Processed 300000 rows.
# Processed 400000 rows.
# Processed 500000 rows.
# Processed 600000 rows.
# Processed 700000 rows.
# Processed 800000 rows.
# Processed 900000 rows.
# Processed 1000000 rows.
# Processed 1100000 rows.
# Processed 1200000 rows.
# Processed 1300000 rows.
# Processed 1400000 rows.
# Processed 1500000 rows.
# Processed 1600000 rows.
# Processed 1700000 rows.
# Processed 1800000 rows.
# Processed 1900000 rows.
# Processed 2000000 rows.
# Processed 2100000 rows.
# Processed 2200000 rows.
# Processed 2300000 rows.
# Processed 2400000 rows.
# Processed 2500000 rows.
# Processed 2600000 rows.
# Processed 2700000 rows.
# Processed 2800000 rows.
# Processed 2900000 rows.
# Processed 3000000 rows.
# Processed 3100000 rows.
# Processed 3200000 rows.
# Processed 3300000 rows.
# Processed 3400000 rows.
# Processed 3500000 rows.
# Processed 3600000 rows.
# Processed 3700000 rows.
# Processed 3800000 rows.
# Processed 3900000 rows.
# Processed 4000000 rows.
# Processed 4100000 rows.
# Processed 4200000 rows.
# Processed 4300000 rows.
# Processed 4400000 rows.
# Processed 4500000 rows.
# Processed 4600000 rows.
# Processed 4700000 rows.
# Processed 4800000 rows.
# Processed 4900000 rows.
# Processed 5000000 rows.
# Processed 5100000 rows.
# Processed 5200000 rows.
# Processed 5300000 rows.
# Processed 5400000 rows.
# Processed 5500000 rows.
# Processed 5600000 rows.
# Processed 5700000 rows.
# Processed 5800000 rows.
# Processed 5900000 rows.
# Processed 6000000 rows.
# Processed 6100000 rows.
# Processed 6200000 rows.
# Processed 6300000 rows.
# Processed 6400000 rows.
# Processed 6500000 rows.
# Processed 6600000 rows.
# Processed 6700000 rows.
# Processed 6800000 rows.
# Processed 6900000 rows.
# Processed 7000000 rows.
# Processed 7100000 rows.
# Processed 7200000 rows.
# Processed 7300000 rows.
# Processed 7400000 rows.
# Processed 7500000 rows.
# Processed 7600000 rows.
# Processed 7700000 rows.
# Processed 7800000 rows.
# Processed 7900000 rows.
# Processed 8000000 rows.
# Processed 8100000 rows.
# Processed 8200000 rows.
# Processed 8300000 rows.
# Processed 8400000 rows.
# Processed 8500000 rows.
# Processed 8600000 rows.
# Processed 8700000 rows.
# Processed 8800000 rows.
# Processed 8900000 rows.
# Processed 9000000 rows.
# Processed 9100000 rows.
# Processed 9200000 rows.
# Processed 9300000 rows.
# Processed 9400000 rows.
# Processed 9500000 rows.
# Processed 9600000 rows.
# Processed 9700000 rows.
# Processed 9800000 rows.
# Processed 9900000 rows.
# Processed 10000000 rows.
# Processed 10100000 rows.
# Processed 10200000 rows.
# Processed 10300000 rows.
# Processed 10400000 rows.
# Processed 10500000 rows.
# Processed 10600000 rows.
# Processed 10700000 rows.
# Processed 10800000 rows.
# Processed 10900000 rows.
# Processed 11000000 rows.
# Processed 11100000 rows.
# Processed 11200000 rows.
# Processed 11300000 rows.
# Processed 11400000 rows.
# Processed 11500000 rows.
# Processed 11600000 rows.
# Processed 11700000 rows.
# Processed 11800000 rows.
# Processed 11900000 rows.
# Processed 12000000 rows.
# Processed 12100000 rows.
# Processed 12200000 rows.
# Processed 12300000 rows.
# Processed 12400000 rows.
# Processed 12500000 rows.
# Processed 12600000 rows.
# Processed 12700000 rows.
# Processed 12800000 rows.
# Processed 12900000 rows.
# Processed 13000000 rows.
# Processed 13100000 rows.
# Processed 13200000 rows.
# Processed 13300000 rows.
# Processed 13400000 rows.
# Processed 13500000 rows.
# Processed 13600000 rows.
# Processed 13700000 rows.
# Processed 13800000 rows.
# Processed 13900000 rows.
# Processed 14000000 rows.
# Processed 14100000 rows.
# Processed 14200000 rows.
# Processed 14300000 rows.
# Processed 14400000 rows.
# Processed 14500000 rows.
# Processed 14600000 rows.
# Processed 14700000 rows.
# Processed 14800000 rows.
# Processed 14900000 rows.
# Processed 15000000 rows.
# Processed 15100000 rows.
# Processed 15200000 rows.
# Processed 15300000 rows.
# Processed 15400000 rows.
# Processed 15500000 rows.
# Processed 15600000 rows.
# Processed 15700000 rows.
# Processed 15800000 rows.
# Processed 15900000 rows.
# Processed 16000000 rows.
# Processed 16100000 rows.
# Processed 16200000 rows.
# Processed 16300000 rows.
# Processed 16400000 rows.
# Processed 16500000 rows.
# Processed 16600000 rows.
# Processed 16700000 rows.
# Processed 16800000 rows.
# Processed 16900000 rows.
# Processed 17000000 rows.
# Processed 17100000 rows.
# Processed 17200000 rows.
# Processed 17300000 rows.
# Processed 17400000 rows.
# Processed 17500000 rows.
# Processed 17600000 rows.
# Processed 17700000 rows.
# Processed 17800000 rows.
# Processed 17900000 rows.
# Processed 18000000 rows.
# Processed 18100000 rows.
# Processed 18200000 rows.
# Processed 18300000 rows.
# Processed 18400000 rows.
# Processed 18500000 rows.
# Processed 18600000 rows.
# Processed 18700000 rows.
# Processed 18800000 rows.
# Processed 18900000 rows.
# Processed 19000000 rows.
# Processed 19100000 rows.
# Processed 19200000 rows.
# Processed 19300000 rows.
# Processed 19400000 rows.
# Processed 19500000 rows.
# Processed 19600000 rows.
# Processed 19700000 rows.
# Processed 19800000 rows.
# Processed 19900000 rows.
# Processed 20000000 rows.
# Processed 20100000 rows.
# Processed 20200000 rows.
# Processed 20300000 rows.
# Processed 20400000 rows.
# Processed 20500000 rows.
# Processed 20600000 rows.
# Processed 20700000 rows.
# Processed 20800000 rows.
# Processed 20900000 rows.
# Processed 21000000 rows.
# Processed 21100000 rows.
# Processed 21200000 rows.
# Processed 21300000 rows.
# Processed 21400000 rows.
# Processed 21500000 rows.
# Processed 21600000 rows.
# Processed 21700000 rows.
# Processed 21800000 rows.
# Processed 21900000 rows.
# Processed 22000000 rows.
# Processed 22100000 rows.
# Processed 22200000 rows.
# Processed 22300000 rows.
# Processed 22400000 rows.
# Processed 22500000 rows.
# Processed 22600000 rows.
# Processed 22700000 rows.
# Processed 22800000 rows.
# Processed 22900000 rows.
# Processed 23000000 rows.
# Processed 23100000 rows.
# Processed 23200000 rows.
# Processed 23300000 rows.
# Processed 23400000 rows.
# Processed 23500000 rows.
# Processed 23600000 rows.
# Processed 23700000 rows.
# Processed 23800000 rows.
# Processed 23900000 rows.
# Processed 24000000 rows.
# Processed 24100000 rows.
# Processed 24200000 rows.
# Processed 24300000 rows.
# Processed 24400000 rows.
# Processed 24500000 rows.
# Processed 24600000 rows.
# Processed 24700000 rows.
# Processed 24800000 rows.
# Processed 24900000 rows.
# Processed 25000000 rows.
# Processed 25100000 rows.
# Processed 25200000 rows.
# Processed 25300000 rows.
# Processed 25400000 rows.
# Processed 25500000 rows.
# Processed 25600000 rows.
# Processed 25700000 rows.
# Processed 25800000 rows.
# Processed 25900000 rows.
# Processed 26000000 rows.
# Processed 26100000 rows.
# Processed 26200000 rows.
# Processed 26300000 rows.
# Processed 26400000 rows.
# Processed 26500000 rows.
# Processed 26600000 rows.
# Processed 26700000 rows.
# Processed 26800000 rows.
# Processed 26900000 rows.
# Processed 27000000 rows.
# Processed 27100000 rows.
# Processed 27200000 rows.
# Processed 27300000 rows.
# Processed 27400000 rows.
# Processed 27500000 rows.
# Processed 27600000 rows.
# Processed 27700000 rows.
# Processed 27800000 rows.
# Processed 27900000 rows.
# Processed 28000000 rows.
# Processed 28100000 rows.
# Processed 28200000 rows.
# Processed 28300000 rows.
# Processed 28400000 rows.
# Processed 28500000 rows.
# Processed 28600000 rows.
# Processed 28700000 rows.
# Processed 28800000 rows.
# Processed 28900000 rows.
# Processed 29000000 rows.
# Processed 29100000 rows.
# Processed 29200000 rows.
# Processed 29300000 rows.
# Processed 29400000 rows.
# Processed 29500000 rows.
# Processed 29600000 rows.
# Processed 29700000 rows.
# Processed 29800000 rows.
# Processed 29900000 rows.
# Processed 30000000 rows.
# Processed 30100000 rows.
# Processed 30200000 rows.
# Processed 30300000 rows.
# Processed 30400000 rows.
# Processed 30500000 rows.
# Processed 30600000 rows.
# Processed 30700000 rows.
# Processed 30800000 rows.
# Processed 30900000 rows.
# Processed 31000000 rows.
# Processed 31100000 rows.
# Processed 31200000 rows.
# Processed 31300000 rows.
# Processed 31400000 rows.
# Processed 31500000 rows.
# Processed 31600000 rows.
# Processed 31700000 rows.
# Processed 31800000 rows.
# Processed 31900000 rows.
# Processed 32000000 rows.
# Processed 32100000 rows.
# Processed 32200000 rows.
# Processed 32300000 rows.
# Processed 32400000 rows.
# Processed 32500000 rows.
# Processed 32600000 rows.
# Processed 32700000 rows.
# Processed 32800000 rows.
# Processed 32900000 rows.
# Processed 33000000 rows.
# Processed 33100000 rows.
# Processed 33200000 rows.
# Processed 33300000 rows.
# Processed 33400000 rows.
# Processed 33500000 rows.
# Processed 33600000 rows.
# Processed 33700000 rows.
# Processed 33800000 rows.
# Processed 33900000 rows.
# Processed 34000000 rows.
# Processed 34100000 rows.
# Processed 34200000 rows.
# Processed 34300000 rows.
# Processed 34400000 rows.
# Processed 34500000 rows.
# Processed 34600000 rows.
# Processed 34700000 rows.
# Processed 34800000 rows.
# Processed 34900000 rows.
# Processed 35000000 rows.
# Processed 35100000 rows.
# Processed 35200000 rows.
# Processed 35300000 rows.
# Processed 35400000 rows.
# Processed 35500000 rows.
# Processed 35600000 rows.
# Processed 35700000 rows.
# Processed 35800000 rows.
# Processed 35900000 rows.
# Processed 36000000 rows.
# Processed 36100000 rows.
# Processed 36200000 rows.
# Processed 36300000 rows.
# Processed 36400000 rows.
# Processed 36500000 rows.
# Processed 36600000 rows.
# Processed 36700000 rows.
# Processed 36800000 rows.
# Processed 36900000 rows.
# Processed 37000000 rows.
# Processed 37100000 rows.
# Processed 37200000 rows.
# Processed 37300000 rows.
# Processed 37400000 rows.
# Processed 37500000 rows.
# Processed 37600000 rows.
# Processed 37700000 rows.
# Processed 37800000 rows.
# Processed 37900000 rows.
# Processed 38000000 rows.
# Processed 38100000 rows.
# Processed 38200000 rows.
# Processed 38300000 rows.
# Processed 38400000 rows.
# Processed 38500000 rows.
# Processed 38600000 rows.
# Processed 38700000 rows.
# Processed 38800000 rows.
# Processed 38900000 rows.
# Processed 39000000 rows.
# Processed 39100000 rows.
# Processed 39200000 rows.
# Processed 39300000 rows.
# Processed 39400000 rows.
# Processed 39500000 rows.
# Processed 39600000 rows.
# Processed 39700000 rows.
# Processed 39800000 rows.
# Processed 39900000 rows.
# Processed 40000000 rows.
# Processed 40100000 rows.
# Processed 40200000 rows.
# Processed 40300000 rows.
# Processed 40400000 rows.
# Processed 40500000 rows.
# Processed 40600000 rows.
# Processed 40700000 rows.
# Processed 40800000 rows.
# Processed 40900000 rows.
# Processed 41000000 rows.
# Processed 41100000 rows.
# Processed 41200000 rows.
# Processed 41300000 rows.
# Processed 41400000 rows.
# Processed 41500000 rows.
# Processed 41600000 rows.
# Processed 41700000 rows.
# Processed 41800000 rows.
# Processed 41900000 rows.
# Processed 42000000 rows.
# Processed 42100000 rows.
# Processed 42200000 rows.
# Processed 42300000 rows.
# Processed 42400000 rows.
# Processed 42500000 rows.
# Processed 42600000 rows.
# Processed 42700000 rows.
# Processed 42800000 rows.
# Processed 42900000 rows.
# Processed 43000000 rows.
# Processed 43100000 rows.
# Processed 43200000 rows.
# Processed 43300000 rows.
# Processed 43400000 rows.
# Processed 43500000 rows.
# Processed 43600000 rows.
# Processed 43700000 rows.
# Processed 43800000 rows.
# Processed 43900000 rows.
# Processed 44000000 rows.
# Processed 44100000 rows.
# Processed 44200000 rows.
# Processed 44300000 rows.
# Processed 44400000 rows.
# Processed 44500000 rows.
# Processed 44600000 rows.
# Processed 44700000 rows.
# Processed 44800000 rows.
# Processed 44900000 rows.
# Processed 45000000 rows.
# Processed 45100000 rows.
# Processed 45200000 rows.
# Processed 45300000 rows.
# Processed 45400000 rows.
# Processed 45500000 rows.
# Processed 45600000 rows.
# Processed 45700000 rows.
# Processed 45800000 rows.
# Processed 45900000 rows.
# Processed 46000000 rows.
# Processed 46100000 rows.
# Processed 46200000 rows.
# Processed 46300000 rows.
# Processed 46400000 rows.
# Processed 46500000 rows.
# Processed 46600000 rows.
# Processed 46700000 rows.
# Processed 46800000 rows.
# Processed 46900000 rows.
# Processed 47000000 rows.
# Processed 47100000 rows.
# Processed 47200000 rows.
# Processed 47300000 rows.
# Processed 47400000 rows.
# Processed 47500000 rows.
# Processed 47600000 rows.
# Processed 47700000 rows.
# Processed 47800000 rows.
# Processed 47900000 rows.
# Processed 48000000 rows.
# Processed 48100000 rows.
# Processed 48200000 rows.
# Processed 48300000 rows.
# Processed 48400000 rows.
# Processed 48500000 rows.
# Processed 48600000 rows.
# Processed 48700000 rows.
# Processed 48800000 rows.
# Processed 48900000 rows.
# Processed 49000000 rows.
# Processed 49100000 rows.
# Processed 49200000 rows.
# Processed 49300000 rows.
# Processed 49400000 rows.
# Processed 49500000 rows.
# Processed 49600000 rows.
# Processed 49700000 rows.
# Processed 49800000 rows.
# Processed 49900000 rows.
# Processed 50000000 rows.
# Processed 50100000 rows.
# Processed 50200000 rows.
# Processed 50300000 rows.
# Processed 50400000 rows.
# Processed 50500000 rows.
# Processed 50600000 rows.
# Processed 50700000 rows.
# Processed 50800000 rows.
# Processed 50900000 rows.
# Processed 51000000 rows.
# Processed 51100000 rows.
# Processed 51200000 rows.
# Processed 51300000 rows.
# Processed 51400000 rows.
# Processed 51500000 rows.
# Processed 51600000 rows.
# Processed 51700000 rows.
# Processed 51800000 rows.
# Processed 51900000 rows.
# Processed 52000000 rows.
# Processed 52100000 rows.
# Processed 52200000 rows.
# Processed 52300000 rows.
# Processed 52400000 rows.
# Processed 52500000 rows.
# Processed 52600000 rows.
# Processed 52700000 rows.
# Processed 52800000 rows.
# Processed 52900000 rows.
# Processed 53000000 rows.
# Processed 53100000 rows.
# Processed 53200000 rows.
# Processed 53300000 rows.
# Processed 53400000 rows.
# Processed 53500000 rows.
# Processed 53600000 rows.
# Processed 53700000 rows.
# Processed 53800000 rows.
# Processed 53900000 rows.
# Processed 54000000 rows.
# Processed 54100000 rows.
# Processed 54200000 rows.
# Processed 54300000 rows.
# Processed 54400000 rows.
# Processed 54500000 rows.
# Processed 54600000 rows.
# Processed 54700000 rows.
# Processed 54800000 rows.
# Processed 54900000 rows.
# Processed 55000000 rows.
# Processed 55100000 rows.
# Processed 55200000 rows.
# Processed 55300000 rows.
# Processed 55400000 rows.
# Processed 55500000 rows.
# Processed 55600000 rows.
# Processed 55700000 rows.
# Processed 55800000 rows.
# Processed 55900000 rows.
# Processed 56000000 rows.
# Processed 56100000 rows.
# Processed 56200000 rows.
# Processed 56300000 rows.
# Processed 56400000 rows.
# Processed 56500000 rows.
# Processed 56600000 rows.
# Processed 56700000 rows.
# Processed 56800000 rows.
# Processed 56900000 rows.
# Processed 57000000 rows.
# Processed 57100000 rows.
# Processed 57200000 rows.
# Processed 57300000 rows.
# Processed 57400000 rows.
# Processed 57500000 rows.
# Processed 57600000 rows.
# Processed 57700000 rows.
# Processed 57800000 rows.
# Processed 57900000 rows.
# Processed 58000000 rows.
# Processed 58100000 rows.
# Processed 58200000 rows.
# Processed 58300000 rows.
# Processed 58400000 rows.
# Processed 58500000 rows.
# Processed 58600000 rows.
# Processed 58700000 rows.
# Processed 58800000 rows.
# Processed 58900000 rows.
# Processed 59000000 rows.
# Processed 59100000 rows.
# Processed 59200000 rows.
# Processed 59300000 rows.
# Processed 59400000 rows.
# Processed 59500000 rows.
# Processed 59600000 rows.
# Processed 59700000 rows.
# Processed 59800000 rows.
# Processed 59900000 rows.
# Processed 60000000 rows.
# Processed 60100000 rows.
# Processed 60200000 rows.
# Processed 60300000 rows.
# Processed 60400000 rows.
# Processed 60500000 rows.
# Processed 60600000 rows.
# Processed 60700000 rows.
# Processed 60800000 rows.
# Processed 60900000 rows.
# Processed 61000000 rows.
# Processed 61100000 rows.
# Processed 61200000 rows.
# Processed 61300000 rows.
# Processed 61400000 rows.
# Processed 61500000 rows.
# Processed 61600000 rows.
# Processed 61700000 rows.
# Processed 61800000 rows.
# Processed 61900000 rows.
# Processed 62000000 rows.
# Processed 62100000 rows.
# Processed 62200000 rows.
# Processed 62300000 rows.
# Processed 62400000 rows.
# Processed 62500000 rows.
# Processed 62600000 rows.
# Processed 62700000 rows.
# Processed 62800000 rows.
# Processed 62900000 rows.
# Processed 63000000 rows.
# Processed 63100000 rows.
# Processed 63200000 rows.
# Processed 63300000 rows.
# Processed 63400000 rows.
# Processed 63500000 rows.
# Processed 63600000 rows.
# Processed 63700000 rows.
# Processed 63800000 rows.
# Processed 63900000 rows.
# Processed 64000000 rows.
# Processed 64100000 rows.
# Processed 64200000 rows.
# Processed 64300000 rows.
# Processed 64400000 rows.
# Processed 64500000 rows.
# Processed 64600000 rows.
# Processed 64700000 rows.
# Processed 64800000 rows.
# Processed 64900000 rows.
# Processed 65000000 rows.
# Processed 65100000 rows.
# Processed 65200000 rows.
# Processed 65300000 rows.
# Processed 65400000 rows.
# Processed 65500000 rows.
# Processed 65600000 rows.
# Processed 65700000 rows.
# Processed 65800000 rows.
# Processed 65900000 rows.
# Processed 66000000 rows.
# Processed 66100000 rows.
# Processed 66200000 rows.
# Processed 66300000 rows.
# Processed 66400000 rows.
# Processed 66500000 rows.
# Processed 66600000 rows.
# Processed 66700000 rows.
# Processed 66800000 rows.
# Processed 66900000 rows.
# Processed 67000000 rows.
# Processed 67100000 rows.
# Processed 67200000 rows.
# Processed 67300000 rows.
# Processed 67400000 rows.
# Processed 67500000 rows.
# Processed 67600000 rows.
# Processed 67700000 rows.
# Processed 67800000 rows.
# Processed 67900000 rows.
# Processed 68000000 rows.
# Processed 68100000 rows.
# Processed 68200000 rows.
# Processed 68300000 rows.
# Processed 68400000 rows.
# Processed 68500000 rows.
# Processed 68600000 rows.
# Processed 68700000 rows.
# Processed 68800000 rows.
# Processed 68900000 rows.
# Processed 69000000 rows.
# Processed 69100000 rows.
# Processed 69200000 rows.
# Processed 69300000 rows.
# Processed 69400000 rows.
# Processed 69500000 rows.
# Processed 69600000 rows.
# Processed 69700000 rows.
# Processed 69800000 rows.
# Processed 69900000 rows.
# Processed 70000000 rows.
# Processed 70100000 rows.
# Processed 70200000 rows.
# Processed 70300000 rows.
# Processed 70400000 rows.
# Processed 70500000 rows.
# Processed 70600000 rows.
# Processed 70700000 rows.
# Processed 70800000 rows.
# Processed 70900000 rows.
# Processed 71000000 rows.
# Processed 71100000 rows.
# Processed 71200000 rows.
# Processed 71300000 rows.
# Processed 71400000 rows.
# Processed 71500000 rows.
# Processed 71600000 rows.
# Processed 71700000 rows.
# Processed 71800000 rows.
# Processed 71900000 rows.
# Processed 72000000 rows.
# Processed 72100000 rows.
# Processed 72200000 rows.
# Processed 72300000 rows.
# Processed 72400000 rows.
# Processed 72500000 rows.
# Processed 72600000 rows.
# Processed 72700000 rows.
# Processed 72800000 rows.
# Processed 72900000 rows.
# Processed 73000000 rows.
# Processed 73100000 rows.
# Processed 73200000 rows.
# Processed 73300000 rows.
# Processed 73400000 rows.
# Processed 73500000 rows.
# Processed 73600000 rows.
# Processed 73700000 rows.
# Processed 73800000 rows.
# Processed 73900000 rows.
# Processed 74000000 rows.
# Processed 74100000 rows.
# Processed 74200000 rows.
# Processed 74300000 rows.
# Processed 74400000 rows.
# Processed 74500000 rows.
# Processed 74600000 rows.
# Processed 74700000 rows.
# Processed 74800000 rows.
# Processed 74900000 rows.
# Processed 75000000 rows.
# Processed 75100000 rows.
# Processed 75200000 rows.
# Processed 75300000 rows.
# Processed 75400000 rows.
# Processed 75500000 rows.
# Processed 75600000 rows.
# Processed 75700000 rows.
# Processed 75800000 rows.
# Processed 75900000 rows.
# Processed 76000000 rows.
# Processed 76100000 rows.
# Processed 76200000 rows.
# Processed 76300000 rows.
# Processed 76400000 rows.
# Processed 76500000 rows.
# Processed 76600000 rows.
# Processed 76700000 rows.
# Processed 76800000 rows.
# Processed 76900000 rows.
# Processed 77000000 rows.
# Processed 77100000 rows.
# Processed 77200000 rows.
# Processed 77300000 rows.
# Processed 77400000 rows.
# Processed 77500000 rows.
# Processed 77600000 rows.
# Processed 77700000 rows.
# Processed 77800000 rows.
# Processed 77900000 rows.
# Processed 78000000 rows.
# Processed 78100000 rows.
# Processed 78200000 rows.
# Processed 78300000 rows.
# Processed 78400000 rows.
# Processed 78500000 rows.
# Processed 78600000 rows.
# Processed 78700000 rows.
# Processed 78800000 rows.
# Processed 78900000 rows.
# Processed 79000000 rows.
# Processed 79100000 rows.
# Processed 79200000 rows.
# Processed 79300000 rows.
# Processed 79400000 rows.
# Processed 79500000 rows.
# Processed 79600000 rows.
# Processed 79700000 rows.
# Processed 79800000 rows.
# Processed 79900000 rows.
# Processed 80000000 rows.
# Processed 80100000 rows.
# Processed 80200000 rows.
# Processed 80300000 rows.
# Processed 80400000 rows.
# Processed 80500000 rows.
# Processed 80600000 rows.
# Processed 80700000 rows.
# Processed 80800000 rows.
# Processed 80900000 rows.
# Processed 81000000 rows.
# Processed 81100000 rows.
# Processed 81200000 rows.
# Processed 81300000 rows.
# Processed 81400000 rows.
# Processed 81500000 rows.
# Processed 81600000 rows.
# Processed 81700000 rows.
# Processed 81800000 rows.
# Processed 81900000 rows.
# Processed 82000000 rows.
# Processed 82100000 rows.
# Processed 82200000 rows.
# Processed 82300000 rows.
# Processed 82400000 rows.
# Processed 82500000 rows.
# Processed 82600000 rows.
# Processed 82700000 rows.
# Processed 82800000 rows.
# Processed 82900000 rows.
# Processed 83000000 rows.
# Processed 83100000 rows.
# Processed 83200000 rows.
# Processed 83300000 rows.
# Processed 83400000 rows.
# Processed 83500000 rows.
# Processed 83600000 rows.
# Processed 83700000 rows.
# Processed 83800000 rows.
# Processed 83900000 rows.
# Processed 84000000 rows.
# Processed 84100000 rows.
# Processed 84200000 rows.
# Processed 84300000 rows.
# Processed 84400000 rows.
# Processed 84500000 rows.
# Processed 84600000 rows.
# Processed 84700000 rows.
# Processed 84800000 rows.
# Processed 84900000 rows.
# Processed 85000000 rows.
# Processed 85100000 rows.
# Processed 85200000 rows.
# Processed 85300000 rows.
# Processed 85400000 rows.
# Processed 85500000 rows.
# Processed 85600000 rows.
# Processed 85700000 rows.
# Processed 85800000 rows.
# Processed 85900000 rows.
# Processed 86000000 rows.
# Processed 86100000 rows.
# Processed 86200000 rows.
# Processed 86300000 rows.
# Processed 86400000 rows.
# Processed 86500000 rows.
# Processed 86600000 rows.
# Processed 86700000 rows.
# Processed 86800000 rows.
# Processed 86900000 rows.
# Processed 87000000 rows.
# Processed 87100000 rows.
# Processed 87200000 rows.
# Processed 87300000 rows.
# Processed 87400000 rows.
# Processed 87500000 rows.
# Processed 87600000 rows.
# Processed 87700000 rows.
# Processed 87800000 rows.
# Processed 87900000 rows.
# Processed 88000000 rows.
# Processed 88100000 rows.
# Processed 88200000 rows.
# Processed 88300000 rows.
# Processed 88400000 rows.
# Processed 88500000 rows.
# Processed 88600000 rows.
# Processed 88700000 rows.
# Processed 88800000 rows.
# Processed 88900000 rows.
# Processed 89000000 rows.
# Processed 89100000 rows.
# Processed 89200000 rows.
# Processed 89300000 rows.
# Processed 89400000 rows.
# Processed 89500000 rows.
# Processed 89600000 rows.
# Processed 89700000 rows.
# Processed 89800000 rows.
# Processed 89900000 rows.
# Processed 90000000 rows.
# Processed 90100000 rows.
# Processed 90200000 rows.
# Processed 90300000 rows.
# Processed 90400000 rows.
# Processed 90500000 rows.
# Processed 90600000 rows.
# Processed 90700000 rows.
# Processed 90800000 rows.
# Processed 90900000 rows.
# Processed 91000000 rows.
# Processed 91100000 rows.
# Processed 91200000 rows.
# Processed 91300000 rows.
# Processed 91400000 rows.
# Processed 91500000 rows.
# Processed 91600000 rows.
# Processed 91700000 rows.
# Processed 91800000 rows.
# Processed 91900000 rows.
# Processed 92000000 rows.
# Processed 92100000 rows.
# Processed 92200000 rows.
# Processed 92300000 rows.
# Processed 92400000 rows.
# Processed 92500000 rows.
# Processed 92600000 rows.
# Processed 92700000 rows.
# Processed 92800000 rows.
# Processed 92900000 rows.
# Processed 93000000 rows.
# Processed 93100000 rows.
# Processed 93200000 rows.
# Processed 93300000 rows.
# Processed 93400000 rows.
# Processed 93500000 rows.
# Processed 93600000 rows.
# Processed 93700000 rows.
# Processed 93800000 rows.
# Processed 93900000 rows.
# Processed 94000000 rows.
# Processed 94100000 rows.
# Processed 94200000 rows.
# Processed 94300000 rows.
# Processed 94400000 rows.
# Processed 94500000 rows.
# Processed 94600000 rows.
# Processed 94700000 rows.
# Processed 94800000 rows.
# Processed 94900000 rows.
# Processed 95000000 rows.
# Processed 95100000 rows.
# Processed 95200000 rows.
# Processed 95300000 rows.
# Processed 95400000 rows.
# Processed 95500000 rows.
# Processed 95600000 rows.
# Processed 95700000 rows.
# Processed 95800000 rows.
# Processed 95900000 rows.
# Processed 96000000 rows.
# Processed 96100000 rows.
# Processed 96200000 rows.
# Processed 96300000 rows.
# Processed 96400000 rows.
# Processed 96500000 rows.
# Processed 96600000 rows.
# Processed 96700000 rows.
# Processed 96800000 rows.
# Processed 96900000 rows.
# Processed 97000000 rows.
# Processed 97100000 rows.
# Processed 97200000 rows.
# Processed 97300000 rows.
# Processed 97400000 rows.
# Processed 97500000 rows.
# Processed 97600000 rows.
# Processed 97700000 rows.
# Processed 97800000 rows.
# Processed 97900000 rows.
# Processed 98000000 rows.
# Processed 98100000 rows.
# Processed 98200000 rows.
# Processed 98300000 rows.
# Processed 98400000 rows.
# Processed 98500000 rows.
# Processed 98600000 rows.
# Processed 98700000 rows.
# Processed 98800000 rows.
# Processed 98900000 rows.
# Processed 99000000 rows.
# Processed 99100000 rows.
# Processed 99200000 rows.
# Processed 99300000 rows.
# Processed 99400000 rows.
# Processed 99500000 rows.
# Processed 99600000 rows.
# Processed 99700000 rows.
# Processed 99800000 rows.
# Processed 99900000 rows.
# Processed 100000000 rows.
# Processed 100100000 rows.
# Processed 100200000 rows.
# Processed 100300000 rows.
# Processed 100400000 rows.
# Processed 100500000 rows.
# Processed 100600000 rows.
# Processed 100700000 rows.
# Processed 100800000 rows.
# Processed 100900000 rows.
# Processed 101000000 rows.
# Processed 101100000 rows.
# Processed 101200000 rows.
# Processed 101300000 rows.
# Processed 101400000 rows.
# Processed 101500000 rows.
# Processed 101600000 rows.
# Processed 101700000 rows.
# Processed 101800000 rows.
# Processed 101900000 rows.
# Processed 102000000 rows.
# Processed 102100000 rows.
# Processed 102200000 rows.
# Processed 102300000 rows.
# Processed 102400000 rows.
# Processed 102500000 rows.
# Processed 102600000 rows.
# Processed 102700000 rows.
# Processed 102800000 rows.
# Processed 102900000 rows.
# Processed 103000000 rows.
# Processed 103100000 rows.
# Processed 103200000 rows.
# Processed 103300000 rows.
# Processed 103400000 rows.
# Processed 103500000 rows.
# Processed 103600000 rows.
# Processed 103700000 rows.
# Processed 103800000 rows.
# Processed 103900000 rows.
# Processed 104000000 rows.
# Processed 104100000 rows.
# Processed 104200000 rows.
# Processed 104300000 rows.
# Processed 104400000 rows.
# Processed 104500000 rows.
# Processed 104600000 rows.
# Processed 104700000 rows.
# Processed 104800000 rows.
# Processed 104900000 rows.
# Processed 105000000 rows.
# Processed 105100000 rows.
# Processed 105200000 rows.
# Processed 105300000 rows.
# Processed 105400000 rows.
# Processed 105500000 rows.
# Processed 105600000 rows.
# Processed 105700000 rows.
# Processed 105800000 rows.
# Processed 105900000 rows.
# Processed 106000000 rows.
# Processed 106100000 rows.
# Processed 106200000 rows.
# Processed 106300000 rows.
# Processed 106400000 rows.
# Processed 106500000 rows.
# Processed 106600000 rows.
# Processed 106700000 rows.
# Processed 106800000 rows.
# Processed 106900000 rows.
# Processed 107000000 rows.
# Processed 107100000 rows.
# Processed 107200000 rows.
# Processed 107300000 rows.
# Processed 107400000 rows.
# Processed 107500000 rows.
# Processed 107600000 rows.
# Processed 107700000 rows.
# Processed 107800000 rows.
# Processed 107900000 rows.
# Processed 108000000 rows.
# Processed 108100000 rows.
# Processed 108200000 rows.
# Processed 108300000 rows.
# Processed 108400000 rows.
# Processed 108500000 rows.
# Processed 108600000 rows.
# Processed 108700000 rows.
# Processed 108800000 rows.
# Processed 108900000 rows.
# Processed 109000000 rows.
# Processed 109100000 rows.
# Processed 109200000 rows.
# Processed 109300000 rows.
# Processed 109400000 rows.
# Processed 109500000 rows.
# Processed 109600000 rows.
# Processed 109700000 rows.
# Processed 109800000 rows.
# Processed 109900000 rows.
# Processed 110000000 rows.
# Processed 110100000 rows.
# Processed 110200000 rows.
# Processed 110300000 rows.
# Processed 110400000 rows.
# Processed 110500000 rows.
# Processed 110600000 rows.
# Processed 110700000 rows.
# Processed 110800000 rows.
# Processed 110900000 rows.
# Processed 111000000 rows.
# Processed 111100000 rows.
# Processed 111200000 rows.
# Processed 111300000 rows.
# Processed 111400000 rows.
# Processed 111500000 rows.
# Processed 111600000 rows.
# Processed 111700000 rows.
# Processed 111800000 rows.
# Processed 111900000 rows.
# Processed 112000000 rows.
# Processed 112100000 rows.
# Processed 112200000 rows.
# Processed 112300000 rows.
# Processed 112400000 rows.
# Processed 112500000 rows.
# Processed 112600000 rows.
# Processed 112700000 rows.
# Processed 112800000 rows.
# Processed 112900000 rows.
# Processed 113000000 rows.
# Processed 113100000 rows.
# Processed 113200000 rows.
# Processed 113300000 rows.
# Processed 113400000 rows.
# Processed 113500000 rows.
# Processed 113600000 rows.
# Processed 113700000 rows.
# Processed 113800000 rows.
# Processed 113900000 rows.
# Processed 114000000 rows.
# Processed 114100000 rows.
# Processed 114200000 rows.
# Processed 114300000 rows.
# Processed 114400000 rows.
# Processed 114500000 rows.
# Processed 114600000 rows.
# Processed 114700000 rows.
# Processed 114800000 rows.
# Processed 114900000 rows.
# Processed 115000000 rows.
# Processed 115100000 rows.
# Processed 115200000 rows.
# Processed 115300000 rows.
# Processed 115400000 rows.
# Processed 115500000 rows.
# Processed 115600000 rows.
# Processed 115700000 rows.
# Processed 115800000 rows.
# Processed 115900000 rows.
# Processed 116000000 rows.
# Processed 116100000 rows.
# Processed 116200000 rows.
# Processed 116300000 rows.
# Processed 116400000 rows.
# Processed 116500000 rows.
# Processed 116600000 rows.
# Processed 116700000 rows.
# Processed 116800000 rows.
# Processed 116900000 rows.
# Processed 117000000 rows.
# Processed 117100000 rows.
# Processed 117200000 rows.
# Processed 117300000 rows.
# Processed 117400000 rows.
# Processed 117500000 rows.
# Processed 117600000 rows.
# Processed 117700000 rows.
# Processed 117800000 rows.
# Processed 117900000 rows.
# Processed 118000000 rows.
# Processed 118100000 rows.
# Processed 118200000 rows.
# Processed 118300000 rows.
# Processed 118400000 rows.
# Processed 118500000 rows.
# Processed 118600000 rows.
# Processed 118700000 rows.
# Processed 118800000 rows.
# Processed 118900000 rows.
# Processed 119000000 rows.
# Processed 119100000 rows.
# Processed 119200000 rows.
# Processed 119300000 rows.
# Processed 119400000 rows.
# Processed 119500000 rows.
# Processed 119600000 rows.
# Processed 119700000 rows.
# Processed 119800000 rows.
# Processed 119900000 rows.
# Processed 120000000 rows.
# Processed 120100000 rows.
# Processed 120200000 rows.
# Processed 120300000 rows.
# Processed 120400000 rows.
# Processed 120500000 rows.
# Processed 120600000 rows.
# Processed 120700000 rows.
# Processed 120800000 rows.
# Processed 120900000 rows.
# Processed 121000000 rows.
# Processed 121100000 rows.
# Processed 121200000 rows.
# Processed 121300000 rows.
# Processed 121400000 rows.
# Processed 121500000 rows.
# Processed 121600000 rows.
# Processed 121700000 rows.
# Processed 121800000 rows.
# Processed 121900000 rows.
# Processed 122000000 rows.
# Processed 122100000 rows.
# Processed 122200000 rows.
# Processed 122300000 rows.
# Processed 122400000 rows.
# Processed 122500000 rows.
# Processed 122600000 rows.
# Processed 122700000 rows.
# Processed 122800000 rows.
# Processed 122900000 rows.
# Processed 123000000 rows.
# Processed 123100000 rows.
# Processed 123200000 rows.
# Processed 123300000 rows.
# Processed 123400000 rows.
# Processed 123500000 rows.
# Processed 123600000 rows.
# Processed 123700000 rows.
# Processed 123800000 rows.
# Processed 123900000 rows.
# Processed 124000000 rows.
# Processed 124100000 rows.
# Processed 124200000 rows.
# Processed 124300000 rows.
# Processed 124400000 rows.
# Processed 124500000 rows.
# Processed 124600000 rows.
# Processed 124700000 rows.
# Processed 124800000 rows.
# Processed 124900000 rows.
# Processed 125000000 rows.
# Processed 125100000 rows.
# Processed 125200000 rows.
# Processed 125300000 rows.
# Processed 125400000 rows.
# Processed 125500000 rows.
# Processed 125600000 rows.
# Processed 125700000 rows.
# Processed 125800000 rows.
# Processed 125900000 rows.
# Processed 126000000 rows.
# Processed 126100000 rows.
# Processed 126200000 rows.
# Processed 126300000 rows.
# Processed 126400000 rows.
# Processed 126500000 rows.
# Processed 126600000 rows.
# Processed 126700000 rows.
# Processed 126800000 rows.
# Processed 126900000 rows.
# Processed 127000000 rows.
# Processed 127100000 rows.
# Processed 127200000 rows.
# Processed 127300000 rows.
# Processed 127400000 rows.
# Processed 127500000 rows.
# Processed 127600000 rows.
# Processed 127700000 rows.
# Processed 127800000 rows.
# Processed 127900000 rows.
# Processed 128000000 rows.
# Processed 128100000 rows.
# Processed 128200000 rows.
# Processed 128300000 rows.
# Processed 128400000 rows.
# Processed 128500000 rows.
# Processed 128600000 rows.
# Processed 128700000 rows.
# Processed 128800000 rows.
# Processed 128900000 rows.
# Processed 129000000 rows.
# Processed 129100000 rows.
# Processed 129200000 rows.
# Processed 129300000 rows.
# Processed 129400000 rows.
# Processed 129500000 rows.
# Processed 129600000 rows.
# Processed 129700000 rows.
# Processed 129800000 rows.
# Processed 129900000 rows.
# Processed 130000000 rows.
# Processed 130100000 rows.
# Processed 130200000 rows.
# Processed 130300000 rows.
# Processed 130400000 rows.
# Processed 130500000 rows.
# Processed 130600000 rows.
# Processed 130700000 rows.
# Processed 130800000 rows.
# Processed 130900000 rows.
# Processed 131000000 rows.
# Processed 131100000 rows.
# Processed 131200000 rows.
# Processed 131300000 rows.
# Processed 131400000 rows.
# Processed 131500000 rows.
# Processed 131600000 rows.
# Processed 131700000 rows.
# Processed 131800000 rows.
# Processed 131900000 rows.
# Processed 132000000 rows.
# Processed 132100000 rows.
# Processed 132200000 rows.
# Processed 132300000 rows.
# Processed 132400000 rows.
# Processed 132500000 rows.
# Processed 132600000 rows.
# Processed 132700000 rows.
# Processed 132800000 rows.
# Processed 132900000 rows.
# Processed 133000000 rows.
# Processed 133100000 rows.
# Processed 133200000 rows.
# Processed 133300000 rows.
# Processed 133400000 rows.
# Processed 133500000 rows.
# Processed 133600000 rows.
# Processed 133700000 rows.
# Processed 133800000 rows.
# Processed 133900000 rows.
# Processed 134000000 rows.
# Processed 134100000 rows.
# Processed 134200000 rows.
# Processed 134300000 rows.
# Processed 134400000 rows.
# Processed 134500000 rows.
# Processed 134600000 rows.
# Processed 134700000 rows.
# Processed 134800000 rows.
# Processed 134900000 rows.
# Processed 135000000 rows.
# Processed 135100000 rows.
# Processed 135200000 rows.
# Processed 135300000 rows.
# Processed 135400000 rows.
# Processed 135500000 rows.
# Processed 135600000 rows.
# Processed 135700000 rows.
# Processed 135800000 rows.
# Processed 135900000 rows.
# Processed 136000000 rows.
# Processed 136100000 rows.
# Processed 136200000 rows.
# Processed 136300000 rows.
# Processed 136400000 rows.
# Processed 136500000 rows.
# Processed 136600000 rows.
# Processed 136700000 rows.
# Processed 136800000 rows.
# Processed 136900000 rows.
# Processed 137000000 rows.
# Processed 137100000 rows.
# Processed 137200000 rows.
# Processed 137300000 rows.
# Processed 137400000 rows.
# Processed 137500000 rows.
# Processed 137600000 rows.
# Processed 137700000 rows.
# Processed 137800000 rows.
# Processed 137900000 rows.
# Processed 138000000 rows.
# Processed 138100000 rows.
# Processed 138200000 rows.
# Processed 138300000 rows.
# Processed 138400000 rows.
# Processed 138500000 rows.
# Processed 138600000 rows.
# Processed 138700000 rows.
# Processed 138800000 rows.
# Processed 138900000 rows.
# Processed 139000000 rows.
# Processed 139100000 rows.
# Processed 139200000 rows.
# Processed 139300000 rows.
# Processed 139400000 rows.
# Processed 139500000 rows.
# Processed 139600000 rows.
# Processed 139700000 rows.
# Processed 139800000 rows.
# Processed 139900000 rows.
# Processed 140000000 rows.
# Processed 140100000 rows.
# Processed 140200000 rows.
# Processed 140300000 rows.
# Processed 140400000 rows.
# Processed 140500000 rows.
# Processed 140600000 rows.
# Processed 140700000 rows.
# Processed 140800000 rows.
# Processed 140900000 rows.
# Processed 141000000 rows.
# Processed 141100000 rows.
# Processed 141200000 rows.
# Processed 141300000 rows.
# Processed 141400000 rows.
# Processed 141500000 rows.
# Processed 141600000 rows.
# Processed 141700000 rows.
# Processed 141800000 rows.
# Processed 141900000 rows.
# Processed 142000000 rows.
# Processed 142100000 rows.
# Processed 142200000 rows.
# Processed 142300000 rows.
# Processed 142400000 rows.
# Processed 142500000 rows.
# Processed 142600000 rows.
# Processed 142700000 rows.
# Processed 142800000 rows.
# Processed 142900000 rows.
# Processed 143000000 rows.
# Processed 143100000 rows.
# Processed 143200000 rows.
# Processed 143300000 rows.
# Processed 143400000 rows.
# Processed 143500000 rows.
# Processed 143600000 rows.
# Processed 143700000 rows.
# Processed 143800000 rows.
# Processed 143900000 rows.
# Processed 144000000 rows.
# Processed 144100000 rows.
# Processed 144200000 rows.
# Processed 144300000 rows.
# Processed 144400000 rows.
# Processed 144500000 rows.
# Processed 144600000 rows.
# Processed 144700000 rows.
# Processed 144800000 rows.
# Processed 144900000 rows.
# Processed 145000000 rows.
# Processed 145100000 rows.
# Processed 145200000 rows.
# Processed 145300000 rows.
# Processed 145400000 rows.
# Processed 145500000 rows.
# Processed 145600000 rows.
# Processed 145700000 rows.
# Processed 145800000 rows.
# Processed 145900000 rows.
# Processed 146000000 rows.
# Processed 146100000 rows.
# Processed 146200000 rows.
# Processed 146300000 rows.
# Processed 146400000 rows.
# Processed 146500000 rows.
# Processed 146600000 rows.
# Processed 146700000 rows.
# Processed 146800000 rows.
# Processed 146900000 rows.
# Processed 147000000 rows.
# Processed 147100000 rows.
# Processed 147200000 rows.
# Processed 147300000 rows.
# Processed 147400000 rows.
# Processed 147500000 rows.
# Processed 147600000 rows.
# Processed 147700000 rows.
# Processed 147800000 rows.
# Processed 147900000 rows.
# Processed 148000000 rows.
# Processed 148100000 rows.
# Processed 148200000 rows.
# Processed 148300000 rows.
# Processed 148400000 rows.
# Processed 148500000 rows.
# Processed 148600000 rows.
# Processed 148700000 rows.
# Processed 148800000 rows.
# Processed 148900000 rows.
# Processed 149000000 rows.
# Processed 149100000 rows.
# Processed 149200000 rows.
# Processed 149300000 rows.
# Processed 149400000 rows.
# Processed 149500000 rows.
# Processed 149600000 rows.
# Processed 149700000 rows.
# Processed 149800000 rows.
# Processed 149900000 rows.
# Processed 150000000 rows.
# Processed 150100000 rows.
# Processed 150200000 rows.
# Processed 150300000 rows.
# Processed 150400000 rows.
# Processed 150500000 rows.
# Processed 150600000 rows.
# Processed 150700000 rows.
# Processed 150800000 rows.
# Processed 150900000 rows.
# Processed 151000000 rows.
# Processed 151100000 rows.
# Processed 151200000 rows.
# Processed 151300000 rows.
# Processed 151400000 rows.
# Processed 151500000 rows.
# Processed 151600000 rows.
# Processed 151700000 rows.
# Processed 151800000 rows.
# Processed 151900000 rows.
# Processed 152000000 rows.
# Processed 152100000 rows.
# Processed 152200000 rows.
# Processed 152300000 rows.
# Processed 152400000 rows.
# Processed 152500000 rows.
# Processed 152600000 rows.
# Processed 152700000 rows.
# Processed 152800000 rows.
# Processed 152900000 rows.
# Processed 153000000 rows.
# Processed 153100000 rows.
# Processed 153200000 rows.
# Processed 153300000 rows.
# Processed 153400000 rows.
# Processed 153500000 rows.
# Processed 153600000 rows.
# Processed 153700000 rows.
# Processed 153800000 rows.
# Processed 153900000 rows.
# Processed 154000000 rows.
# Processed 154100000 rows.
# Processed 154200000 rows.
# Processed 154300000 rows.
# Processed 154400000 rows.
# Processed 154500000 rows.
# Processed 154600000 rows.
# Processed 154700000 rows.
# Processed 154800000 rows.
# Processed 154900000 rows.
# Processed 155000000 rows.
# Processed 155100000 rows.
# Processed 155200000 rows.
# Processed 155300000 rows.
# Processed 155400000 rows.
# Processed 155500000 rows.
# Processed 155600000 rows.
# Processed 155700000 rows.
# Processed 155800000 rows.
# Processed 155900000 rows.
# Processed 156000000 rows.
# Processed 156100000 rows.
# Processed 156200000 rows.
# Processed 156300000 rows.
# Processed 156400000 rows.
# Processed 156500000 rows.
# Processed 156600000 rows.
# Processed 156700000 rows.
# Processed 156800000 rows.
# Processed 156900000 rows.
# Processed 157000000 rows.
# Processed 157100000 rows.
# Processed 157200000 rows.
# Processed 157300000 rows.
# Processed 157400000 rows.
# Processed 157500000 rows.
# Processed 157600000 rows.
# Processed 157700000 rows.
# Processed 157800000 rows.
# Processed 157900000 rows.
# Processed 158000000 rows.
# Processed 158100000 rows.
# Processed 158200000 rows.
# Processed 158300000 rows.
# Processed 158400000 rows.
# Processed 158500000 rows.
# Processed 158600000 rows.
# Processed 158700000 rows.
# Processed 158800000 rows.
# Processed 158900000 rows.
# Processed 159000000 rows.
# Processed 159100000 rows.
# Processed 159200000 rows.
# Processed 159300000 rows.
# Processed 159400000 rows.
# Processed 159500000 rows.
# Processed 159600000 rows.
# Processed 159700000 rows.
# Processed 159800000 rows.
# Processed 159900000 rows.
# Processed 160000000 rows.
# Processed 160100000 rows.
# Processed 160200000 rows.
# Processed 160300000 rows.
# Processed 160400000 rows.
# Processed 160500000 rows.
# Processed 160600000 rows.
# Processed 160700000 rows.
# Processed 160800000 rows.
# Processed 160900000 rows.
# Processed 161000000 rows.
# Processed 161100000 rows.
# Processed 161200000 rows.
# Processed 161300000 rows.
# Processed 161400000 rows.
# Processed 161500000 rows.
# Processed 161600000 rows.
# Processed 161700000 rows.
# Processed 161800000 rows.
# Processed 161900000 rows.
# Processed 162000000 rows.
# Processed 162100000 rows.
# Processed 162200000 rows.
# Processed 162300000 rows.
# Processed 162400000 rows.
# Processed 162500000 rows.
# Processed 162600000 rows.
# Processed 162700000 rows.
# Processed 162800000 rows.
# Processed 162900000 rows.
# Processed 163000000 rows.
# Processed 163100000 rows.
# Processed 163200000 rows.
# Processed 163300000 rows.
# Processed 163400000 rows.
# Processed 163500000 rows.
# Processed 163600000 rows.
# Processed 163700000 rows.
# Processed 163800000 rows.
# Processed 163900000 rows.
# Processed 164000000 rows.
# Processed 164100000 rows.
# Processed 164200000 rows.
# Processed 164300000 rows.
# Processed 164400000 rows.
# Processed 164500000 rows.
# Processed 164600000 rows.
# Processed 164700000 rows.
# Processed 164800000 rows.
# Processed 164900000 rows.
# Processed 165000000 rows.
# Processed 165100000 rows.
# Processed 165200000 rows.
# Processed 165300000 rows.
# Processed 165400000 rows.
# Processed 165500000 rows.
# Processed 165600000 rows.
# Processed 165700000 rows.
# Processed 165800000 rows.
# Processed 165900000 rows.
# Processed 166000000 rows.
# Processed 166100000 rows.
# Processed 166200000 rows.
# Processed 166300000 rows.
# Processed 166400000 rows.
# Processed 166500000 rows.
# Processed 166600000 rows.
# Processed 166700000 rows.
# Processed 166800000 rows.
# Processed 166900000 rows.
# Processed 167000000 rows.
# Processed 167100000 rows.
# Processed 167200000 rows.
# Processed 167300000 rows.
# Processed 167400000 rows.
# Processed 167500000 rows.
# Processed 167600000 rows.
# Processed 167700000 rows.
# Processed 167800000 rows.
# Processed 167900000 rows.
# Processed 168000000 rows.
# Processed 168100000 rows.
# Processed 168200000 rows.
# Processed 168300000 rows.
# Processed 168400000 rows.
# Processed 168500000 rows.
# Processed 168600000 rows.
# Processed 168700000 rows.
# Processed 168800000 rows.
# Processed 168900000 rows.
# Processed 169000000 rows.
# Processed 169100000 rows.
# Processed 169200000 rows.
# Processed 169300000 rows.
# Processed 169400000 rows.
# Processed 169500000 rows.
# Processed 169600000 rows.
# Processed 169700000 rows.
# Processed 169800000 rows.
# Processed 169900000 rows.
# Processed 170000000 rows.
# Processed 170100000 rows.
# Processed 170200000 rows.
# Processed 170300000 rows.
# Processed 170400000 rows.
# Processed 170500000 rows.
# Processed 170600000 rows.
# Processed 170700000 rows.
# Processed 170800000 rows.
# Processed 170900000 rows.
# Processed 171000000 rows.
# Processed 171100000 rows.
# Processed 171200000 rows.
# Processed 171300000 rows.
# Processed 171400000 rows.
# Processed 171500000 rows.
# Processed 171600000 rows.
# Processed 171700000 rows.
# Processed 171800000 rows.
# Processed 171900000 rows.
# Processed 172000000 rows.
# Processed 172100000 rows.
# Processed 172200000 rows.
# Processed 172300000 rows.
# Processed 172400000 rows.
# Processed 172500000 rows.
# Processed 172600000 rows.
# Processed 172700000 rows.
# Processed 172800000 rows.
# Processed 172900000 rows.
# Processed 173000000 rows.
# Processed 173100000 rows.
# Processed 173200000 rows.
# Processed 173300000 rows.
# Processed 173400000 rows.
# Processed 173500000 rows.
# Processed 173600000 rows.
# Processed 173700000 rows.
# Processed 173800000 rows.
# Processed 173900000 rows.
# Processed 174000000 rows.
# Processed 174100000 rows.
# Processed 174200000 rows.
# Processed 174300000 rows.
# Processed 174400000 rows.
# Processed 174500000 rows.
# Processed 174600000 rows.
# Processed 174700000 rows.
# Processed 174800000 rows.
# Processed 174900000 rows.
# Processed 175000000 rows.
# Processed 175100000 rows.
# Processed 175200000 rows.
# Processed 175300000 rows.
# Processed 175400000 rows.
# Processed 175500000 rows.
# Processed 175600000 rows.
# Processed 175700000 rows.
# Processed 175800000 rows.
# Processed 175900000 rows.
# Processed 176000000 rows.
# Processed 176100000 rows.
# Processed 176200000 rows.
# Processed 176300000 rows.
# Processed 176400000 rows.
# Processed 176500000 rows.
# Processed 176600000 rows.
# Processed 176700000 rows.
# Processed 176800000 rows.
# Processed 176900000 rows.
# Processed 177000000 rows.
# Processed 177100000 rows.
# Processed 177200000 rows.
# Processed 177300000 rows.
# Processed 177400000 rows.
# Processed 177500000 rows.
# Processed 177600000 rows.
# Processed 177700000 rows.
# Processed 177800000 rows.
# Processed 177900000 rows.
# Processed 178000000 rows.
# Processed 178100000 rows.
# Processed 178200000 rows.
# Processed 178300000 rows.
# Processed 178400000 rows.
# Processed 178500000 rows.
# Processed 178600000 rows.
# Processed 178700000 rows.
# Processed 178800000 rows.
# Processed 178900000 rows.
# Processed 179000000 rows.
# Processed 179100000 rows.
# Processed 179200000 rows.
# Processed 179300000 rows.
# Processed 179400000 rows.
# Processed 179500000 rows.
# Processed 179600000 rows.
# Processed 179700000 rows.
# Processed 179800000 rows.
# Processed 179900000 rows.
# Processed 180000000 rows.
# Processed 180100000 rows.
# Processed 180200000 rows.
# Processed 180300000 rows.
# Processed 180400000 rows.
# Processed 180500000 rows.
# Processed 180600000 rows.
# Processed 180700000 rows.
# Processed 180800000 rows.
# Processed 180900000 rows.
# Processed 181000000 rows.
# Processed 181100000 rows.
# Processed 181200000 rows.
# Processed 181300000 rows.
# Processed 181400000 rows.
# Processed 181500000 rows.
# Processed 181600000 rows.
# Processed 181700000 rows.
# Processed 181800000 rows.
# Processed 181900000 rows.
# Processed 182000000 rows.
# Processed 182100000 rows.
# Processed 182200000 rows.
# Processed 182300000 rows.
# Processed 182400000 rows.
# Processed 182500000 rows.
# Processed 182600000 rows.
# Processed 182700000 rows.
# Processed 182800000 rows.
# Processed 182900000 rows.
# Processed 183000000 rows.
# Processed 183100000 rows.
# Processed 183200000 rows.
# Processed 183300000 rows.
# Processed 183400000 rows.
# Processed 183500000 rows.
# Processed 183600000 rows.
# Processed 183700000 rows.
# Processed 183800000 rows.
# Processed 183900000 rows.
# Processed 184000000 rows.
# Processed 184100000 rows.
# Processed 184200000 rows.
# Processed 184300000 rows.
# Processed 184400000 rows.
# Processed 184500000 rows.
# Processed 184600000 rows.
# Processed 184700000 rows.
# Processed 184800000 rows.
# Processed 184900000 rows.
# Processed 185000000 rows.
# Processed 185100000 rows.
# Processed 185200000 rows.
# Processed 185300000 rows.
# Processed 185400000 rows.
# Processed 185500000 rows.
# Processed 185600000 rows.
# Processed 185700000 rows.
# Processed 185800000 rows.
# Processed 185900000 rows.
# Processed 186000000 rows.
# Processed 186100000 rows.
# Processed 186200000 rows.
# Processed 186300000 rows.
# Processed 186400000 rows.
# Processed 186500000 rows.
# Processed 186600000 rows.
# Processed 186700000 rows.
# Processed 186800000 rows.
# Processed 186900000 rows.
# Processed 187000000 rows.
# Processed 187100000 rows.
# Processed 187200000 rows.
# Processed 187300000 rows.
# Processed 187400000 rows.
# Processed 187500000 rows.
# Processed 187600000 rows.
# Processed 187700000 rows.
# Processed 187800000 rows.
# Processed 187900000 rows.
# Processed 188000000 rows.
# Processed 188100000 rows.
# Processed 188200000 rows.
# Processed 188300000 rows.
# Processed 188400000 rows.
# Processed 188500000 rows.
# Processed 188600000 rows.
# Processed 188700000 rows.
# Processed 188800000 rows.
# Processed 188900000 rows.
# Processed 189000000 rows.
# Processed 189100000 rows.
# Processed 189200000 rows.
# Processed 189300000 rows.
# Processed 189400000 rows.
# Processed 189500000 rows.
# Processed 189600000 rows.
# Processed 189700000 rows.
# Processed 189800000 rows.
# Processed 189900000 rows.
# Processed 190000000 rows.
# Processed 190100000 rows.
# Processed 190200000 rows.
# Processed 190300000 rows.
# Processed 190400000 rows.
# Processed 190500000 rows.
# Processed 190600000 rows.
# Processed 190700000 rows.
# Processed 190800000 rows.
# Processed 190900000 rows.
# Processed 191000000 rows.
# Processed 191100000 rows.
# Processed 191200000 rows.
# Processed 191300000 rows.
# Processed 191400000 rows.
# Processed 191500000 rows.
# Processed 191600000 rows.
# Processed 191700000 rows.
# Processed 191800000 rows.
# Processed 191900000 rows.
# Processed 192000000 rows.
# Processed 192100000 rows.
# Processed 192200000 rows.
# Processed 192300000 rows.
# Processed 192400000 rows.
# Processed 192500000 rows.
# Processed 192600000 rows.
# Processed 192700000 rows.
# Processed 192800000 rows.
# Processed 192900000 rows.
# Processed 193000000 rows.
# Processed 193100000 rows.
# Processed 193200000 rows.
# Processed 193300000 rows.
# Processed 193400000 rows.
# Processed 193500000 rows.
# Processed 193600000 rows.
# Processed 193700000 rows.
# Processed 193800000 rows.
# Processed 193900000 rows.
# Processed 194000000 rows.
# Processed 194100000 rows.
# Processed 194200000 rows.
# Processed 194300000 rows.
# Processed 194400000 rows.
# Processed 194500000 rows.
# Processed 194600000 rows.
# Processed 194700000 rows.
# Processed 194800000 rows.
# Processed 194900000 rows.
# Processed 195000000 rows.
# Processed 195100000 rows.
# Processed 195200000 rows.
# Processed 195300000 rows.
# Processed 195400000 rows.
# Processed 195500000 rows.
# Processed 195600000 rows.
# Processed 195700000 rows.
# Processed 195800000 rows.
# Processed 195900000 rows.
# Processed 196000000 rows.
# Processed 196100000 rows.
# Processed 196200000 rows.
# Processed 196300000 rows.
# Processed 196400000 rows.
# Processed 196500000 rows.
# Processed 196600000 rows.
# Processed 196700000 rows.
# Processed 196800000 rows.
# Processed 196900000 rows.
# Processed 197000000 rows.
# Processed 197100000 rows.
# Processed 197200000 rows.
# Processed 197300000 rows.
# Processed 197400000 rows.
# Processed 197500000 rows.
# Processed 197600000 rows.
# Processed 197700000 rows.
# Processed 197800000 rows.
# Processed 197900000 rows.
# Processed 198000000 rows.
# Processed 198100000 rows.
# Processed 198200000 rows.
# Processed 198300000 rows.
# Processed 198400000 rows.
# Processed 198500000 rows.
# Processed 198600000 rows.
# Processed 198700000 rows.
# Processed 198800000 rows.
# Processed 198900000 rows.
# Processed 199000000 rows.
# Processed 199100000 rows.
# Processed 199200000 rows.
# Processed 199300000 rows.
# Processed 199400000 rows.
# Processed 199500000 rows.
# Processed 199600000 rows.
# Processed 199700000 rows.
# Processed 199800000 rows.
# Processed 199900000 rows.
# Processed 200000000 rows.
# Processed 200100000 rows.
# Processed 200200000 rows.
# Processed 200300000 rows.
# Processed 200400000 rows.
# Processed 200500000 rows.
# Processed 200600000 rows.
# Processed 200700000 rows.
# Processed 200800000 rows.
# Processed 200900000 rows.
# Processed 201000000 rows.
# Processed 201100000 rows.
# Processed 201200000 rows.
# Processed 201300000 rows.
# Processed 201400000 rows.
# Processed 201500000 rows.
# Processed 201600000 rows.
# Processed 201700000 rows.
# Processed 201800000 rows.
# Processed 201900000 rows.
# Processed 202000000 rows.
# Processed 202100000 rows.
# Processed 202200000 rows.
# Processed 202300000 rows.
# Processed 202400000 rows.
# Processed 202500000 rows.
# Processed 202600000 rows.
# Processed 202700000 rows.
# Processed 202800000 rows.
# Processed 202900000 rows.
# Processed 203000000 rows.
# Processed 203100000 rows.
# Processed 203200000 rows.
# Processed 203300000 rows.
# Processed 203400000 rows.
# Processed 203500000 rows.
# Processed 203600000 rows.
# Processed 203700000 rows.
# Processed 203800000 rows.
# Processed 203900000 rows.
# Processed 204000000 rows.
# Processed 204100000 rows.
# Processed 204200000 rows.
# Processed 204300000 rows.
# Processed 204400000 rows.
# Processed 204500000 rows.
# Processed 204600000 rows.
# Processed 204700000 rows.
# Processed 204800000 rows.
# Processed 204900000 rows.
# Processed 205000000 rows.
# Processed 205100000 rows.
# Processed 205200000 rows.
# Processed 205300000 rows.
# Processed 205400000 rows.
# Processed 205500000 rows.
# Processed 205600000 rows.
# Processed 205700000 rows.
# Processed 205800000 rows.
# Processed 205900000 rows.
# Processed 206000000 rows.
# Processed 206100000 rows.
# Processed 206200000 rows.
# Processed 206300000 rows.
# Processed 206400000 rows.
# Processed 206500000 rows.
# Processed 206600000 rows.
# Processed 206700000 rows.
# Processed 206800000 rows.
# Processed 206900000 rows.
# Processed 207000000 rows.
# Processed 207100000 rows.
# Processed 207200000 rows.
# Processed 207300000 rows.
# Processed 207400000 rows.
# Processed 207500000 rows.
# Processed 207600000 rows.
# Processed 207700000 rows.
# Processed 207800000 rows.
# Processed 207900000 rows.
# Processed 208000000 rows.
# Processed 208100000 rows.
# Processed 208200000 rows.
# Processed 208300000 rows.
# Processed 208400000 rows.
# Processed 208500000 rows.
# Processed 208600000 rows.
# Processed 208700000 rows.
# Processed 208800000 rows.
# Processed 208900000 rows.
# Processed 209000000 rows.
# Processed 209100000 rows.
# Processed 209200000 rows.
# Processed 209300000 rows.
# Processed 209400000 rows.
# Processed 209500000 rows.
# Processed 209600000 rows.
# Processed 209700000 rows.
# Processed 209800000 rows.
# Processed 209900000 rows.
# Processed 210000000 rows.
# Processed 210100000 rows.
# Processed 210200000 rows.
# Processed 210300000 rows.
# Processed 210400000 rows.
# Processed 210500000 rows.
# Processed 210600000 rows.
# Processed 210700000 rows.
# Processed 210800000 rows.
# Processed 210900000 rows.
# Processed 211000000 rows.
# Processed 211100000 rows.
# Processed 211200000 rows.
# Processed 211300000 rows.
# Processed 211400000 rows.
# Processed 211500000 rows.
# Processed 211600000 rows.
# Processed 211700000 rows.
# Processed 211800000 rows.
# Processed 211900000 rows.
# Processed 212000000 rows.
# Processed 212100000 rows.
# Processed 212200000 rows.
# Processed 212300000 rows.
# Processed 212400000 rows.
# Processed 212500000 rows.
# Processed 212600000 rows.
# Processed 212700000 rows.
# Processed 212800000 rows.
# Processed 212900000 rows.
# Processed 213000000 rows.
# Processed 213100000 rows.
# Processed 213200000 rows.
# Processed 213300000 rows.
# Processed 213400000 rows.
# Processed 213500000 rows.
# Processed 213600000 rows.
# Processed 213700000 rows.
# Processed 213800000 rows.
# Processed 213900000 rows.
# Processed 214000000 rows.
# Processed 214100000 rows.
# Processed 214200000 rows.
# Processed 214300000 rows.
# Processed 214400000 rows.
# Processed 214500000 rows.
# Processed 214600000 rows.
# Processed 214700000 rows.
# Processed 214800000 rows.
# Processed 214900000 rows.
# Processed 215000000 rows.
# Processed 215100000 rows.
# Processed 215200000 rows.
# Processed 215300000 rows.
# Processed 215400000 rows.
# Processed 215500000 rows.
# Processed 215600000 rows.
# Processed 215700000 rows.
# Processed 215800000 rows.
# Processed 215900000 rows.
# Processed 216000000 rows.
# Processed 216100000 rows.
# Processed 216200000 rows.
# Processed 216300000 rows.
# Processed 216400000 rows.
# Processed 216500000 rows.
# Processed 216600000 rows.
# Processed 216700000 rows.
# Processed 216800000 rows.
# Processed 216900000 rows.
# Processed 217000000 rows.
# Processed 217100000 rows.
# Processed 217200000 rows.
# Processed 217300000 rows.
# Processed 217400000 rows.
# Processed 217500000 rows.
# Processed 217600000 rows.
# Processed 217700000 rows.
# Processed 217800000 rows.
# Processed 217900000 rows.
# Processed 218000000 rows.
# Processed 218100000 rows.
# Processed 218200000 rows.
# Processed 218300000 rows.
# Processed 218400000 rows.
# Processed 218500000 rows.
# Processed 218600000 rows.
# Processed 218700000 rows.
# Processed 218800000 rows.
# Processed 218900000 rows.
# Processed 219000000 rows.
# Processed 219100000 rows.
# Processed 219200000 rows.
# Processed 219300000 rows.
# Processed 219400000 rows.
# Processed 219500000 rows.
# Processed 219600000 rows.
# Processed 219700000 rows.
# Processed 219800000 rows.
# Processed 219900000 rows.
# Processed 220000000 rows.
# Processed 220100000 rows.
# Processed 220200000 rows.
# Processed 220300000 rows.
# Processed 220400000 rows.
# Processed 220500000 rows.
# Processed 220600000 rows.
# Processed 220700000 rows.
# Processed 220800000 rows.
# Processed 220900000 rows.
# Processed 221000000 rows.
# Processed 221100000 rows.
# Processed 221200000 rows.
# Processed 221300000 rows.
# Processed 221400000 rows.
# Processed 221500000 rows.
# Processed 221600000 rows.
# Processed 221700000 rows.
# Processed 221800000 rows.
# Processed 221900000 rows.
# Processed 222000000 rows.
# Processed 222100000 rows.
# Processed 222200000 rows.
# Processed 222300000 rows.
# Processed 222400000 rows.
# Processed 222500000 rows.
# Processed 222600000 rows.
# Processed 222700000 rows.
# Processed 222800000 rows.
# Processed 222900000 rows.
# Processed 223000000 rows.
# Processed 223100000 rows.
# Processed 223200000 rows.
# Processed 223300000 rows.
# Processed 223400000 rows.
# Processed 223500000 rows.
# Processed 223600000 rows.
# Processed 223700000 rows.
# Processed 223800000 rows.
# Processed 223900000 rows.
# Processed 224000000 rows.
# Processed 224100000 rows.
# Processed 224200000 rows.
# Processed 224300000 rows.
# Processed 224400000 rows.
# Processed 224500000 rows.
# Processed 224600000 rows.
# Processed 224700000 rows.
# Processed 224800000 rows.
# Processed 224900000 rows.
# Processed 225000000 rows.
# Processed 225100000 rows.
# Processed 225200000 rows.
# Processed 225300000 rows.
# Processed 225400000 rows.
# Processed 225500000 rows.
# Processed 225600000 rows.
# Processed 225700000 rows.
# Processed 225800000 rows.
# Processed 225900000 rows.
# Processed 226000000 rows.
# Processed 226100000 rows.
# Processed 226200000 rows.
# Processed 226300000 rows.
# Processed 226400000 rows.
# Processed 226500000 rows.
# Processed 226600000 rows.
# Processed 226700000 rows.
# Processed 226800000 rows.
# Processed 226900000 rows.
# Processed 227000000 rows.
# Processed 227100000 rows.
# Processed 227200000 rows.
# Processed 227300000 rows.
# Processed 227400000 rows.
# Processed 227500000 rows.
# Processed 227600000 rows.
# Processed 227700000 rows.
# Processed 227800000 rows.
# Processed 227900000 rows.
# Processed 228000000 rows.
# Processed 228100000 rows.
# Processed 228200000 rows.
# Processed 228300000 rows.
# Processed 228400000 rows.
# Processed 228500000 rows.
# Processed 228600000 rows.
# Processed 228700000 rows.
# Processed 228800000 rows.
# Processed 228900000 rows.
# Processed 229000000 rows.
# Processed 229100000 rows.
# Processed 229200000 rows.
# Processed 229300000 rows.
# Processed 229400000 rows.
# Processed 229500000 rows.
# Processed 229600000 rows.
# Processed 229700000 rows.
# Processed 229800000 rows.
# Processed 229900000 rows.
# Processed 230000000 rows.
# Processed 230100000 rows.
# Processed 230200000 rows.
# Processed 230300000 rows.
# Processed 230400000 rows.
# Processed 230500000 rows.
# Processed 230600000 rows.
# Processed 230700000 rows.
# Processed 230800000 rows.
# Processed 230900000 rows.
# Processed 231000000 rows.
# Processed 231100000 rows.
# Processed 231200000 rows.
# Processed 231300000 rows.
# Processed 231400000 rows.
# Processed 231500000 rows.
# Processed 231600000 rows.
# Processed 231700000 rows.
# Processed 231800000 rows.
# Processed 231900000 rows.
# Processed 232000000 rows.
# Processed 232100000 rows.
# Processed 232200000 rows.
# Processed 232300000 rows.
# Processed 232400000 rows.
# Processed 232500000 rows.
# Processed 232600000 rows.
# Processed 232700000 rows.
# Processed 232800000 rows.
# Processed 232900000 rows.
# Processed 233000000 rows.
# Processed 233100000 rows.
# Processed 233200000 rows.
# Processed 233300000 rows.
# Processed 233400000 rows.
# Processed 233500000 rows.
# Processed 233600000 rows.
# Processed 233700000 rows.
# Processed 233800000 rows.
# Processed 233900000 rows.
# Processed 234000000 rows.
# Processed 234100000 rows.
# Processed 234200000 rows.
# Processed 234300000 rows.
# Processed 234400000 rows.
# Processed 234500000 rows.
# Processed 234600000 rows.
# Processed 234700000 rows.
# Processed 234800000 rows.
# Processed 234900000 rows.
# Processed 235000000 rows.
# Processed 235100000 rows.
# Processed 235200000 rows.
# Processed 235300000 rows.
# Processed 235400000 rows.
# Processed 235500000 rows.
# Processed 235600000 rows.
# Processed 235700000 rows.
# Processed 235800000 rows.
# Processed 235900000 rows.
# Processed 236000000 rows.
# Processed 236100000 rows.
# Processed 236200000 rows.
# Processed 236300000 rows.
# Processed 236400000 rows.
# Processed 236500000 rows.
# Processed 236600000 rows.
# Processed 236700000 rows.
# Processed 236800000 rows.
# Processed 236900000 rows.
# Processed 237000000 rows.
# Processed 237100000 rows.
# Processed 237200000 rows.
# Processed 237300000 rows.
# Processed 237400000 rows.
# Processed 237500000 rows.
# Processed 237600000 rows.
# Processed 237700000 rows.
# Processed 237800000 rows.
# Processed 237900000 rows.
# Processed 238000000 rows.
# Processed 238100000 rows.
# Processed 238200000 rows.
# Processed 238300000 rows.
# Processed 238400000 rows.
# Processed 238500000 rows.
# Processed 238600000 rows.
# Processed 238700000 rows.
# Processed 238800000 rows.
# Processed 238900000 rows.
# Processed 239000000 rows.
# Processed 239100000 rows.
# Processed 239200000 rows.
# Processed 239300000 rows.
# Processed 239400000 rows.
# Processed 239500000 rows.
# Processed 239600000 rows.
# Processed 239700000 rows.
# Processed 239800000 rows.
# Processed 239900000 rows.
# Processed 240000000 rows.
# Processed 240100000 rows.
# Processed 240200000 rows.
# Processed 240300000 rows.
# Processed 240400000 rows.
# Processed 240500000 rows.
# Processed 240600000 rows.
# Processed 240700000 rows.
# Processed 240800000 rows.
# Processed 240900000 rows.
# Processed 241000000 rows.
# Processed 241100000 rows.
# Processed 241200000 rows.
# Processed 241300000 rows.
# Processed 241400000 rows.
# Processed 241500000 rows.
# Processed 241600000 rows.
# Processed 241700000 rows.
# Processed 241800000 rows.
# Processed 241900000 rows.
# Processed 242000000 rows.
# Processed 242100000 rows.
# Processed 242200000 rows.
# Processed 242300000 rows.
# Processed 242400000 rows.
# Processed 242500000 rows.
# Processed 242600000 rows.
# Processed 242700000 rows.
# Processed 242800000 rows.
# Processed 242900000 rows.
# Processed 243000000 rows.
# Processed 243100000 rows.
# Processed 243200000 rows.
# Processed 243300000 rows.
# Processed 243400000 rows.
# Processed 243500000 rows.
# Processed 243600000 rows.
# Processed 243700000 rows.
# Processed 243800000 rows.
# Processed 243900000 rows.
# Processed 244000000 rows.
# Processed 244100000 rows.
# Processed 244200000 rows.
# Processed 244300000 rows.
# Processed 244400000 rows.
# Processed 244500000 rows.
# Processed 244600000 rows.
# Processed 244700000 rows.
# Processed 244800000 rows.
# Processed 244900000 rows.
# Processed 245000000 rows.
# Processed 245100000 rows.
# Processed 245200000 rows.
# Processed 245300000 rows.
# Processed 245400000 rows.
# Processed 245500000 rows.
# Processed 245600000 rows.
# Processed 245700000 rows.
# Processed 245800000 rows.
# Processed 245900000 rows.
# Processed 246000000 rows.
# Processed 246100000 rows.
# Processed 246200000 rows.
# Processed 246300000 rows.
# Processed 246400000 rows.
# Processed 246500000 rows.
# Processed 246600000 rows.
# Processed 246700000 rows.
# Processed 246800000 rows.
# Processed 246900000 rows.
# Processed 247000000 rows.
# Processed 247100000 rows.
# Processed 247200000 rows.
# Processed 247300000 rows.
# Processed 247400000 rows.
# Processed 247500000 rows.
# Processed 247600000 rows.
# Processed 247700000 rows.
# Processed 247800000 rows.
# Processed 247900000 rows.
# Processed 248000000 rows.
# Processed 248100000 rows.
# Processed 248157124 rows.

# %%
example_result.head()
# Out:
#    subject_id           charttime    itemid  valuenum
# 0    17062372 2143-02-25 04:00:00  220292.0       5.0
# 1    17062372 2143-02-25 04:00:00  220293.0      20.0
# 2    17062372 2143-02-25 04:00:00  220339.0       5.0
# 3    17062372 2143-02-25 04:00:00  223835.0      40.0
# 4    17062372 2143-02-25 04:00:00  223848.0       1.0

# %% [markdown]
# Chunk 7 has results so it works for chunks other than chunk 8 and 9.
#
# Lets see if there are any sturctural differences between chunks 7, 8 and 9.

# %%
chunk_7_df = pd.read_parquet(chunk_7)
chunk_8_df = pd.read_parquet(chunk_8)
chunk_9_df = pd.read_parquet(chunk_9)

chunk_7_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 597 entries, 18404 to 20808
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   subject_id                     597 non-null    int64
#  1   hadm_id                        597 non-null    int64
#  2   stay_id                        597 non-null    int64
#  3   ventilation_starttime          597 non-null    datetime64[ns]
#  4   ventilation_endtime            597 non-null    datetime64[ns]
#  5   ventilation_itemid             597 non-null    int64
#  6   ventilation_ordercategoryname  597 non-null    object
#  7   extubation_starttime           597 non-null    datetime64[ns]
#  8   extubation_endtime             597 non-null    datetime64[ns]
#  9   extubation_itemid              597 non-null    int64
#  10  extubation_ordercategoryname   597 non-null    object
#  11  ventilation_duration           597 non-null    float64
#  12  anchor_age                     597 non-null    int64
#  13  extubation_failure             597 non-null    int64
# dtypes: datetime64[ns](4), float64(1), int64(7), object(2)
# memory usage: 70.0+ KB

# %%
# See if there are any structural differences between chunk 7 8 and 9
chunk_8_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 597 entries, 20810 to 23562
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   subject_id                     597 non-null    int64
#  1   hadm_id                        597 non-null    int64
#  2   stay_id                        597 non-null    int64
#  3   ventilation_starttime          597 non-null    datetime64[ns]
#  4   ventilation_endtime            597 non-null    datetime64[ns]
#  5   ventilation_itemid             597 non-null    int64
#  6   ventilation_ordercategoryname  597 non-null    object
#  7   extubation_starttime           597 non-null    datetime64[ns]
#  8   extubation_endtime             597 non-null    datetime64[ns]
#  9   extubation_itemid              597 non-null    int64
#  10  extubation_ordercategoryname   597 non-null    object
#  11  ventilation_duration           597 non-null    float64
#  12  anchor_age                     597 non-null    int64
#  13  extubation_failure             597 non-null    int64
# dtypes: datetime64[ns](4), float64(1), int64(7), object(2)
# memory usage: 70.0+ KB

# %%
chunk_9_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 597 entries, 23568 to 26133
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   subject_id                     597 non-null    int64
#  1   hadm_id                        597 non-null    int64
#  2   stay_id                        597 non-null    int64
#  3   ventilation_starttime          597 non-null    datetime64[ns]
#  4   ventilation_endtime            597 non-null    datetime64[ns]
#  5   ventilation_itemid             597 non-null    int64
#  6   ventilation_ordercategoryname  597 non-null    object
#  7   extubation_starttime           597 non-null    datetime64[ns]
#  8   extubation_endtime             597 non-null    datetime64[ns]
#  9   extubation_itemid              597 non-null    int64
#  10  extubation_ordercategoryname   597 non-null    object
#  11  ventilation_duration           597 non-null    float64
#  12  anchor_age                     597 non-null    int64
#  13  extubation_failure             597 non-null    int64
# dtypes: datetime64[ns](4), float64(1), int64(7), object(2)
# memory usage: 70.0+ KB

# %%
chunk_8_df.head()
# Out:
#        subject_id   hadm_id   stay_id ventilation_starttime  \
# 20810    18043820  25736266  37330264   2187-03-20 14:05:00
# 20812    18044289  23747254  32716668   2153-06-26 11:40:00
# 20813    18044722  23096487  33401395   2133-04-22 05:00:00
# 20822    18046344  22674038  30198295   2118-12-30 23:41:00
# 20824    18049351  28941140  37164191   2170-05-16 17:00:00
#
#       ventilation_endtime  ventilation_itemid ventilation_ordercategoryname  \
# 20810 2187-03-21 15:32:00              225792                   Ventilation
# 20812 2153-06-27 16:45:00              225792                   Ventilation
# 20813 2133-04-23 14:31:00              225792                   Ventilation
# 20822 2119-01-02 09:20:00              225792                   Ventilation
# 20824 2170-05-19 09:15:00              225792                   Ventilation
#
#       extubation_starttime  extubation_endtime  extubation_itemid  \
# 20810  2187-03-21 15:33:00 2187-03-21 15:34:00             227194
# 20812  2153-06-27 16:45:00 2153-06-27 16:46:00             227194
# 20813  2133-04-23 14:36:00 2133-04-23 14:37:00             227194
# 20822  2119-01-02 09:20:00 2119-01-02 09:21:00             227194
# 20824  2170-05-19 09:15:00 2170-05-19 09:16:00             227194
#
#       extubation_ordercategoryname  ventilation_duration  anchor_age  \
# 20810        Intubation/Extubation                1527.0          79
# 20812        Intubation/Extubation                1745.0          26
# 20813        Intubation/Extubation                2011.0          41
# 20822        Intubation/Extubation                3459.0          33
# 20824        Intubation/Extubation                3855.0          66
#
#        extubation_failure
# 20810                   0
# 20812                   0
# 20813                   0
# 20822                   0
# 20824                   0

# %%
chunk_9_df.head()
# Out:
#        subject_id   hadm_id   stay_id ventilation_starttime  \
# 23568    19041108  24980238  32226561   2123-03-05 23:55:00
# 23569    19042662  28440124  37249777   2184-04-04 19:37:00
# 23571    19045496  22343752  37979029   2148-08-09 11:40:00
# 23576    19046076  27649252  33240155   2116-04-05 00:00:00
# 23577    19046107  21398294  32733363   2138-04-14 12:08:00
#
#       ventilation_endtime  ventilation_itemid ventilation_ordercategoryname  \
# 23568 2123-03-11 11:15:00              225792                   Ventilation
# 23569 2184-04-13 09:40:00              225792                   Ventilation
# 23571 2148-08-13 15:40:00              225792                   Ventilation
# 23576 2116-04-06 08:58:00              225792                   Ventilation
# 23577 2138-04-16 12:39:00              225792                   Ventilation
#
#       extubation_starttime  extubation_endtime  extubation_itemid  \
# 23568  2123-03-11 11:15:00 2123-03-11 11:16:00             227194
# 23569  2184-04-13 09:40:00 2184-04-13 09:41:00             227194
# 23571  2148-08-13 15:40:00 2148-08-13 15:41:00             227194
# 23576  2116-04-06 09:02:00 2116-04-06 09:03:00             227194
# 23577  2138-04-16 12:40:00 2138-04-16 12:41:00             227194
#
#       extubation_ordercategoryname  ventilation_duration  anchor_age  \
# 23568        Intubation/Extubation                7880.0          54
# 23569        Intubation/Extubation               12363.0          62
# 23571        Intubation/Extubation                6000.0          80
# 23576        Intubation/Extubation                1978.0          74
# 23577        Intubation/Extubation                2911.0          62
#
#        extubation_failure
# 23568                   0
# 23569                   0
# 23571                   0
# 23576                   0
# 23577                   0

# %% [markdown]
# There seems to be no visible difference between the patient chunks.
#
# Let's try a variation of the function that does not rely on a dictionary - as it seems the issue may be centered around this.

# %%
# Equivalent function that does not rely on dictionaries
def process_all_chunk_3(chunk, patient_df, itemid_set, time_window):

    # Filter the columns to include only the relevant ones
    chunk = chunk[['subject_id', 'charttime', 'itemid', 'valuenum']].copy()

    # Drop rows where valuenum is null
    chunk = chunk.dropna(subset=['valuenum'])

    # Convert subject_id to nullable integer type if necessary
    chunk.loc[:, 'subject_id'] = chunk['subject_id'].astype('Int64')

    # Filter by subject_id
    chunk = chunk[chunk['subject_id'].isin(patient_df['subject_id'])]

    # Filter by itemid
    chunk = chunk[chunk['itemid'].isin(itemid_set)]

    # Use broadcasting to filter the chunk based on the extubation_starttime and time_window
    chunk = chunk.merge(patient_df[['subject_id', 'extubation_starttime', 'extubation_failure']], on='subject_id', how='left')
    chunk = chunk[(chunk['charttime'] >= chunk['extubation_starttime'] - time_window) &
                  (chunk['charttime'] <= chunk['extubation_starttime'])]

    return chunk

# %%
def extract_all_patient_data_3(patient_df, chartevents_file_path, itemids, time_window):
    # Initialize a list to hold the results
    results = []

    # Define the chunk size
    chunksize = 100000

    # Convert itemids to a set for faster lookup
    itemid_set = set(itemids)

    # Track the number of processed rows
    processed_rows = 0

    # Read and process the file in chunks
    for chunk in pd.read_csv(chartevents_file_path, parse_dates=['charttime'], chunksize=chunksize):
        # Process each chunk and filter the data
        filtered_df = process_all_chunk_3(chunk, patient_df, itemid_set, time_window)

        # Append the filtered data to the results list
        results.append(filtered_df)

        # Update the number of processed rows
        processed_rows += len(chunk)

        # Print progress
        print(f"Processed {processed_rows} rows.")

    # Concatenate all the results
    result_df = pd.concat(results, ignore_index=True)

    # Check if results_df is empty
    if result_df.empty:
        print("Warning: Results DataFrame is empty.")
        return None, None

    # Extract the data and labels
    data = result_df[['subject_id', 'charttime', 'itemid', 'valuenum']]
    labels = result_df[['subject_id', 'extubation_failure']]

    return data, labels

# %%
patient_chunk_files = [chunk_8, chunk_9]

chartevents_path = '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/mimic-iv-2.2-raw-data/icu/chartevents.csv'

output_dir = '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/05_time_series_data_preprocessing/feature_set_1_results'

# %%
time_window_hours = timedelta(hours=6)

# %%
feature_set_1_dynamic
# Out:
# [220210,
#  220277,
#  228640,
#  220235,
#  223830,
#  220224,
#  220228,
#  223835,
#  224685,
#  224686,
#  224695,
#  224687,
#  224696,
#  223849,
#  224419]

# %%
# Process patient chunk files 8 and 9 and save results to Google Drive
for i, patient_file in enumerate(patient_chunk_files, start=8):
    print(f"Processing patient chunk file: {patient_file}")

    # Read the patient chunk file
    patient_df = pd.read_parquet(patient_file)

    # Extract all data and labels
    data, labels = extract_all_patient_data_3(patient_df, chartevents_path, feature_set_1_dynamic, time_window_hours)

    # Save the results to Google Drive
    data_file_path = f'{output_dir}all_data_chunk_{i}.parquet'
    labels_file_path = f'{output_dir}all_labels_chunk_{i}.parquet'

    data.to_parquet(data_file_path)
    labels.to_parquet(labels_file_path)

    print(f"Saved all data and labels for chunk {i} to {output_dir}")
# Out:
# Processing patient chunk file: /content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/03_annotated_set/final_set_split_files/patient_chunk_8.parquet
# Processed 100000 rows.
# Processed 200000 rows.
# Processed 300000 rows.
# Processed 400000 rows.
# Processed 500000 rows.
# Processed 600000 rows.
# Processed 700000 rows.
# Processed 800000 rows.
# Processed 900000 rows.
# Processed 1000000 rows.
# Processed 1100000 rows.
# Processed 1200000 rows.
# Processed 1300000 rows.
# Processed 1400000 rows.
# Processed 1500000 rows.
# Processed 1600000 rows.
# Processed 1700000 rows.
# Processed 1800000 rows.
# Processed 1900000 rows.
# Processed 2000000 rows.
# Processed 2100000 rows.
# Processed 2200000 rows.
# Processed 2300000 rows.
# Processed 2400000 rows.
# Processed 2500000 rows.
# Processed 2600000 rows.
# Processed 2700000 rows.
# Processed 2800000 rows.
# Processed 2900000 rows.
# Processed 3000000 rows.
# Processed 3100000 rows.
# Processed 3200000 rows.
# Processed 3300000 rows.
# Processed 3400000 rows.
# Processed 3500000 rows.
# Processed 3600000 rows.
# Processed 3700000 rows.
# Processed 3800000 rows.
# Processed 3900000 rows.
# Processed 4000000 rows.
# Processed 4100000 rows.
# Processed 4200000 rows.
# Processed 4300000 rows.
# Processed 4400000 rows.
# Processed 4500000 rows.
# Processed 4600000 rows.
# Processed 4700000 rows.
# Processed 4800000 rows.
# Processed 4900000 rows.
# Processed 5000000 rows.
# Processed 5100000 rows.
# Processed 5200000 rows.
# Processed 5300000 rows.
# Processed 5400000 rows.
# Processed 5500000 rows.
# Processed 5600000 rows.
# Processed 5700000 rows.
# Processed 5800000 rows.
# Processed 5900000 rows.
# Processed 6000000 rows.
# Processed 6100000 rows.
# Processed 6200000 rows.
# Processed 6300000 rows.
# Processed 6400000 rows.
# Processed 6500000 rows.
# Processed 6600000 rows.
# Processed 6700000 rows.
# Processed 6800000 rows.
# Processed 6900000 rows.
# Processed 7000000 rows.
# Processed 7100000 rows.
# Processed 7200000 rows.
# Processed 7300000 rows.
# Processed 7400000 rows.
# Processed 7500000 rows.
# Processed 7600000 rows.
# Processed 7700000 rows.
# Processed 7800000 rows.
# Processed 7900000 rows.
# Processed 8000000 rows.
# Processed 8100000 rows.
# Processed 8200000 rows.
# Processed 8300000 rows.
# Processed 8400000 rows.
# Processed 8500000 rows.
# Processed 8600000 rows.
# Processed 8700000 rows.
# Processed 8800000 rows.
# Processed 8900000 rows.
# Processed 9000000 rows.
# Processed 9100000 rows.
# Processed 9200000 rows.
# Processed 9300000 rows.
# Processed 9400000 rows.
# Processed 9500000 rows.
# Processed 9600000 rows.
# Processed 9700000 rows.
# Processed 9800000 rows.
# Processed 9900000 rows.
# Processed 10000000 rows.
# Processed 10100000 rows.
# Processed 10200000 rows.
# Processed 10300000 rows.
# Processed 10400000 rows.
# Processed 10500000 rows.
# Processed 10600000 rows.
# Processed 10700000 rows.
# Processed 10800000 rows.
# Processed 10900000 rows.
# Processed 11000000 rows.
# Processed 11100000 rows.
# Processed 11200000 rows.
# Processed 11300000 rows.
# Processed 11400000 rows.
# Processed 11500000 rows.
# Processed 11600000 rows.
# Processed 11700000 rows.
# Processed 11800000 rows.
# Processed 11900000 rows.
# Processed 12000000 rows.
# Processed 12100000 rows.
# Processed 12200000 rows.
# Processed 12300000 rows.
# Processed 12400000 rows.
# Processed 12500000 rows.
# Processed 12600000 rows.
# Processed 12700000 rows.
# Processed 12800000 rows.
# Processed 12900000 rows.
# Processed 13000000 rows.
# Processed 13100000 rows.
# Processed 13200000 rows.
# Processed 13300000 rows.
# Processed 13400000 rows.
# Processed 13500000 rows.
# Processed 13600000 rows.
# Processed 13700000 rows.
# Processed 13800000 rows.
# Processed 13900000 rows.
# Processed 14000000 rows.
# Processed 14100000 rows.
# Processed 14200000 rows.
# Processed 14300000 rows.
# Processed 14400000 rows.
# Processed 14500000 rows.
# Processed 14600000 rows.
# Processed 14700000 rows.
# Processed 14800000 rows.
# Processed 14900000 rows.
# Processed 15000000 rows.
# Processed 15100000 rows.
# Processed 15200000 rows.
# Processed 15300000 rows.
# Processed 15400000 rows.
# Processed 15500000 rows.
# Processed 15600000 rows.
# Processed 15700000 rows.
# Processed 15800000 rows.
# Processed 15900000 rows.
# Processed 16000000 rows.
# Processed 16100000 rows.
# Processed 16200000 rows.
# Processed 16300000 rows.
# Processed 16400000 rows.
# Processed 16500000 rows.
# Processed 16600000 rows.
# Processed 16700000 rows.
# Processed 16800000 rows.
# Processed 16900000 rows.
# Processed 17000000 rows.
# Processed 17100000 rows.
# Processed 17200000 rows.
# Processed 17300000 rows.
# Processed 17400000 rows.
# Processed 17500000 rows.
# Processed 17600000 rows.
# Processed 17700000 rows.
# Processed 17800000 rows.
# Processed 17900000 rows.
# Processed 18000000 rows.
# Processed 18100000 rows.
# Processed 18200000 rows.
# Processed 18300000 rows.
# Processed 18400000 rows.
# Processed 18500000 rows.
# Processed 18600000 rows.
# Processed 18700000 rows.
# Processed 18800000 rows.
# Processed 18900000 rows.
# Processed 19000000 rows.
# Processed 19100000 rows.
# Processed 19200000 rows.
# Processed 19300000 rows.
# Processed 19400000 rows.
# Processed 19500000 rows.
# Processed 19600000 rows.
# Processed 19700000 rows.
# Processed 19800000 rows.
# Processed 19900000 rows.
# Processed 20000000 rows.
# Processed 20100000 rows.
# Processed 20200000 rows.
# Processed 20300000 rows.
# Processed 20400000 rows.
# Processed 20500000 rows.
# Processed 20600000 rows.
# Processed 20700000 rows.
# Processed 20800000 rows.
# Processed 20900000 rows.
# Processed 21000000 rows.
# Processed 21100000 rows.
# Processed 21200000 rows.
# Processed 21300000 rows.
# Processed 21400000 rows.
# Processed 21500000 rows.
# Processed 21600000 rows.
# Processed 21700000 rows.
# Processed 21800000 rows.
# Processed 21900000 rows.
# Processed 22000000 rows.
# Processed 22100000 rows.
# Processed 22200000 rows.
# Processed 22300000 rows.
# Processed 22400000 rows.
# Processed 22500000 rows.
# Processed 22600000 rows.
# Processed 22700000 rows.
# Processed 22800000 rows.
# Processed 22900000 rows.
# Processed 23000000 rows.
# Processed 23100000 rows.
# Processed 23200000 rows.
# Processed 23300000 rows.
# Processed 23400000 rows.
# Processed 23500000 rows.
# Processed 23600000 rows.
# Processed 23700000 rows.
# Processed 23800000 rows.
# Processed 23900000 rows.
# Processed 24000000 rows.
# Processed 24100000 rows.
# Processed 24200000 rows.
# Processed 24300000 rows.
# Processed 24400000 rows.
# Processed 24500000 rows.
# Processed 24600000 rows.
# Processed 24700000 rows.
# Processed 24800000 rows.
# Processed 24900000 rows.
# Processed 25000000 rows.
# Processed 25100000 rows.
# Processed 25200000 rows.
# Processed 25300000 rows.
# Processed 25400000 rows.
# Processed 25500000 rows.
# Processed 25600000 rows.
# Processed 25700000 rows.
# Processed 25800000 rows.
# Processed 25900000 rows.
# Processed 26000000 rows.
# Processed 26100000 rows.
# Processed 26200000 rows.
# Processed 26300000 rows.
# Processed 26400000 rows.
# Processed 26500000 rows.
# Processed 26600000 rows.
# Processed 26700000 rows.
# Processed 26800000 rows.
# Processed 26900000 rows.
# Processed 27000000 rows.
# Processed 27100000 rows.
# Processed 27200000 rows.
# Processed 27300000 rows.
# Processed 27400000 rows.
# Processed 27500000 rows.
# Processed 27600000 rows.
# Processed 27700000 rows.
# Processed 27800000 rows.
# Processed 27900000 rows.
# Processed 28000000 rows.
# Processed 28100000 rows.
# Processed 28200000 rows.
# Processed 28300000 rows.
# Processed 28400000 rows.
# Processed 28500000 rows.
# Processed 28600000 rows.
# Processed 28700000 rows.
# Processed 28800000 rows.
# Processed 28900000 rows.
# Processed 29000000 rows.
# Processed 29100000 rows.
# Processed 29200000 rows.
# Processed 29300000 rows.
# Processed 29400000 rows.
# Processed 29500000 rows.
# Processed 29600000 rows.
# Processed 29700000 rows.
# Processed 29800000 rows.
# Processed 29900000 rows.
# Processed 30000000 rows.
# Processed 30100000 rows.
# Processed 30200000 rows.
# Processed 30300000 rows.
# Processed 30400000 rows.
# Processed 30500000 rows.
# Processed 30600000 rows.
# Processed 30700000 rows.
# Processed 30800000 rows.
# Processed 30900000 rows.
# Processed 31000000 rows.
# Processed 31100000 rows.
# Processed 31200000 rows.
# Processed 31300000 rows.
# Processed 31400000 rows.
# Processed 31500000 rows.
# Processed 31600000 rows.
# Processed 31700000 rows.
# Processed 31800000 rows.
# Processed 31900000 rows.
# Processed 32000000 rows.
# Processed 32100000 rows.
# Processed 32200000 rows.
# Processed 32300000 rows.
# Processed 32400000 rows.
# Processed 32500000 rows.
# Processed 32600000 rows.
# Processed 32700000 rows.
# Processed 32800000 rows.
# Processed 32900000 rows.
# Processed 33000000 rows.
# Processed 33100000 rows.
# Processed 33200000 rows.
# Processed 33300000 rows.
# Processed 33400000 rows.
# Processed 33500000 rows.
# Processed 33600000 rows.
# Processed 33700000 rows.
# Processed 33800000 rows.
# Processed 33900000 rows.
# Processed 34000000 rows.
# Processed 34100000 rows.
# Processed 34200000 rows.
# Processed 34300000 rows.
# Processed 34400000 rows.
# Processed 34500000 rows.
# Processed 34600000 rows.
# Processed 34700000 rows.
# Processed 34800000 rows.
# Processed 34900000 rows.
# Processed 35000000 rows.
# Processed 35100000 rows.
# Processed 35200000 rows.
# Processed 35300000 rows.
# Processed 35400000 rows.
# Processed 35500000 rows.
# Processed 35600000 rows.
# Processed 35700000 rows.
# Processed 35800000 rows.
# Processed 35900000 rows.
# Processed 36000000 rows.
# Processed 36100000 rows.
# Processed 36200000 rows.
# Processed 36300000 rows.
# Processed 36400000 rows.
# Processed 36500000 rows.
# Processed 36600000 rows.
# Processed 36700000 rows.
# Processed 36800000 rows.
# Processed 36900000 rows.
# Processed 37000000 rows.
# Processed 37100000 rows.
# Processed 37200000 rows.
# Processed 37300000 rows.
# Processed 37400000 rows.
# Processed 37500000 rows.
# Processed 37600000 rows.
# Processed 37700000 rows.
# Processed 37800000 rows.
# Processed 37900000 rows.
# Processed 38000000 rows.
# Processed 38100000 rows.
# Processed 38200000 rows.
# Processed 38300000 rows.
# Processed 38400000 rows.
# Processed 38500000 rows.
# Processed 38600000 rows.
# Processed 38700000 rows.
# Processed 38800000 rows.
# Processed 38900000 rows.
# Processed 39000000 rows.
# Processed 39100000 rows.
# Processed 39200000 rows.
# Processed 39300000 rows.
# Processed 39400000 rows.
# Processed 39500000 rows.
# Processed 39600000 rows.
# Processed 39700000 rows.
# Processed 39800000 rows.
# Processed 39900000 rows.
# Processed 40000000 rows.
# Processed 40100000 rows.
# Processed 40200000 rows.
# Processed 40300000 rows.
# Processed 40400000 rows.
# Processed 40500000 rows.
# Processed 40600000 rows.
# Processed 40700000 rows.
# Processed 40800000 rows.
# Processed 40900000 rows.
# Processed 41000000 rows.
# Processed 41100000 rows.
# Processed 41200000 rows.
# Processed 41300000 rows.
# Processed 41400000 rows.
# Processed 41500000 rows.
# Processed 41600000 rows.
# Processed 41700000 rows.
# Processed 41800000 rows.
# Processed 41900000 rows.
# Processed 42000000 rows.
# Processed 42100000 rows.
# Processed 42200000 rows.
# Processed 42300000 rows.
# Processed 42400000 rows.
# Processed 42500000 rows.
# Processed 42600000 rows.
# Processed 42700000 rows.
# Processed 42800000 rows.
# Processed 42900000 rows.
# Processed 43000000 rows.
# Processed 43100000 rows.
# Processed 43200000 rows.
# Processed 43300000 rows.
# Processed 43400000 rows.
# Processed 43500000 rows.
# Processed 43600000 rows.
# Processed 43700000 rows.
# Processed 43800000 rows.
# Processed 43900000 rows.
# Processed 44000000 rows.
# Processed 44100000 rows.
# Processed 44200000 rows.
# Processed 44300000 rows.
# Processed 44400000 rows.
# Processed 44500000 rows.
# Processed 44600000 rows.
# Processed 44700000 rows.
# Processed 44800000 rows.
# Processed 44900000 rows.
# Processed 45000000 rows.
# Processed 45100000 rows.
# Processed 45200000 rows.
# Processed 45300000 rows.
# Processed 45400000 rows.
# Processed 45500000 rows.
# Processed 45600000 rows.
# Processed 45700000 rows.
# Processed 45800000 rows.
# Processed 45900000 rows.
# Processed 46000000 rows.
# Processed 46100000 rows.
# Processed 46200000 rows.
# Processed 46300000 rows.
# Processed 46400000 rows.
# Processed 46500000 rows.
# Processed 46600000 rows.
# Processed 46700000 rows.
# Processed 46800000 rows.
# Processed 46900000 rows.
# Processed 47000000 rows.
# Processed 47100000 rows.
# Processed 47200000 rows.
# Processed 47300000 rows.
# Processed 47400000 rows.
# Processed 47500000 rows.
# Processed 47600000 rows.
# Processed 47700000 rows.
# Processed 47800000 rows.
# Processed 47900000 rows.
# Processed 48000000 rows.
# Processed 48100000 rows.
# Processed 48200000 rows.
# Processed 48300000 rows.
# Processed 48400000 rows.
# Processed 48500000 rows.
# Processed 48600000 rows.
# Processed 48700000 rows.
# Processed 48800000 rows.
# Processed 48900000 rows.
# Processed 49000000 rows.
# Processed 49100000 rows.
# Processed 49200000 rows.
# Processed 49300000 rows.
# Processed 49400000 rows.
# Processed 49500000 rows.
# Processed 49600000 rows.
# Processed 49700000 rows.
# Processed 49800000 rows.
# Processed 49900000 rows.
# Processed 50000000 rows.
# Processed 50100000 rows.
# Processed 50200000 rows.
# Processed 50300000 rows.
# Processed 50400000 rows.
# Processed 50500000 rows.
# Processed 50600000 rows.
# Processed 50700000 rows.
# Processed 50800000 rows.
# Processed 50900000 rows.
# Processed 51000000 rows.
# Processed 51100000 rows.
# Processed 51200000 rows.
# Processed 51300000 rows.
# Processed 51400000 rows.
# Processed 51500000 rows.
# Processed 51600000 rows.
# Processed 51700000 rows.
# Processed 51800000 rows.
# Processed 51900000 rows.
# Processed 52000000 rows.
# Processed 52100000 rows.
# Processed 52200000 rows.
# Processed 52300000 rows.
# Processed 52400000 rows.
# Processed 52500000 rows.
# Processed 52600000 rows.
# Processed 52700000 rows.
# Processed 52800000 rows.
# Processed 52900000 rows.
# Processed 53000000 rows.
# Processed 53100000 rows.
# Processed 53200000 rows.
# Processed 53300000 rows.
# Processed 53400000 rows.
# Processed 53500000 rows.
# Processed 53600000 rows.
# Processed 53700000 rows.
# Processed 53800000 rows.
# Processed 53900000 rows.
# Processed 54000000 rows.
# Processed 54100000 rows.
# Processed 54200000 rows.
# Processed 54300000 rows.
# Processed 54400000 rows.
# Processed 54500000 rows.
# Processed 54600000 rows.
# Processed 54700000 rows.
# Processed 54800000 rows.
# Processed 54900000 rows.
# Processed 55000000 rows.
# Processed 55100000 rows.
# Processed 55200000 rows.
# Processed 55300000 rows.
# Processed 55400000 rows.
# Processed 55500000 rows.
# Processed 55600000 rows.
# Processed 55700000 rows.
# Processed 55800000 rows.
# Processed 55900000 rows.
# Processed 56000000 rows.
# Processed 56100000 rows.
# Processed 56200000 rows.
# Processed 56300000 rows.
# Processed 56400000 rows.
# Processed 56500000 rows.
# Processed 56600000 rows.
# Processed 56700000 rows.
# Processed 56800000 rows.
# Processed 56900000 rows.
# Processed 57000000 rows.
# Processed 57100000 rows.
# Processed 57200000 rows.
# Processed 57300000 rows.
# Processed 57400000 rows.
# Processed 57500000 rows.
# Processed 57600000 rows.
# Processed 57700000 rows.
# Processed 57800000 rows.
# Processed 57900000 rows.
# Processed 58000000 rows.
# Processed 58100000 rows.
# Processed 58200000 rows.
# Processed 58300000 rows.
# Processed 58400000 rows.
# Processed 58500000 rows.
# Processed 58600000 rows.
# Processed 58700000 rows.
# Processed 58800000 rows.
# Processed 58900000 rows.
# Processed 59000000 rows.
# Processed 59100000 rows.
# Processed 59200000 rows.
# Processed 59300000 rows.
# Processed 59400000 rows.
# Processed 59500000 rows.
# Processed 59600000 rows.
# Processed 59700000 rows.
# Processed 59800000 rows.
# Processed 59900000 rows.
# Processed 60000000 rows.
# Processed 60100000 rows.
# Processed 60200000 rows.
# Processed 60300000 rows.
# Processed 60400000 rows.
# Processed 60500000 rows.
# Processed 60600000 rows.
# Processed 60700000 rows.
# Processed 60800000 rows.
# Processed 60900000 rows.
# Processed 61000000 rows.
# Processed 61100000 rows.
# Processed 61200000 rows.
# Processed 61300000 rows.
# Processed 61400000 rows.
# Processed 61500000 rows.
# Processed 61600000 rows.
# Processed 61700000 rows.
# Processed 61800000 rows.
# Processed 61900000 rows.
# Processed 62000000 rows.
# Processed 62100000 rows.
# Processed 62200000 rows.
# Processed 62300000 rows.
# Processed 62400000 rows.
# Processed 62500000 rows.
# Processed 62600000 rows.
# Processed 62700000 rows.
# Processed 62800000 rows.
# Processed 62900000 rows.
# Processed 63000000 rows.
# Processed 63100000 rows.
# Processed 63200000 rows.
# Processed 63300000 rows.
# Processed 63400000 rows.
# Processed 63500000 rows.
# Processed 63600000 rows.
# Processed 63700000 rows.
# Processed 63800000 rows.
# Processed 63900000 rows.
# Processed 64000000 rows.
# Processed 64100000 rows.
# Processed 64200000 rows.
# Processed 64300000 rows.
# Processed 64400000 rows.
# Processed 64500000 rows.
# Processed 64600000 rows.
# Processed 64700000 rows.
# Processed 64800000 rows.
# Processed 64900000 rows.
# Processed 65000000 rows.
# Processed 65100000 rows.
# Processed 65200000 rows.
# Processed 65300000 rows.
# Processed 65400000 rows.
# Processed 65500000 rows.
# Processed 65600000 rows.
# Processed 65700000 rows.
# Processed 65800000 rows.
# Processed 65900000 rows.
# Processed 66000000 rows.
# Processed 66100000 rows.
# Processed 66200000 rows.
# Processed 66300000 rows.
# Processed 66400000 rows.
# Processed 66500000 rows.
# Processed 66600000 rows.
# Processed 66700000 rows.
# Processed 66800000 rows.
# Processed 66900000 rows.
# Processed 67000000 rows.
# Processed 67100000 rows.
# Processed 67200000 rows.
# Processed 67300000 rows.
# Processed 67400000 rows.
# Processed 67500000 rows.
# Processed 67600000 rows.
# Processed 67700000 rows.
# Processed 67800000 rows.
# Processed 67900000 rows.
# Processed 68000000 rows.
# Processed 68100000 rows.
# Processed 68200000 rows.
# Processed 68300000 rows.
# Processed 68400000 rows.
# Processed 68500000 rows.
# Processed 68600000 rows.
# Processed 68700000 rows.
# Processed 68800000 rows.
# Processed 68900000 rows.
# Processed 69000000 rows.
# Processed 69100000 rows.
# Processed 69200000 rows.
# Processed 69300000 rows.
# Processed 69400000 rows.
# Processed 69500000 rows.
# Processed 69600000 rows.
# Processed 69700000 rows.
# Processed 69800000 rows.
# Processed 69900000 rows.
# Processed 70000000 rows.
# Processed 70100000 rows.
# Processed 70200000 rows.
# Processed 70300000 rows.
# Processed 70400000 rows.
# Processed 70500000 rows.
# Processed 70600000 rows.
# Processed 70700000 rows.
# Processed 70800000 rows.
# Processed 70900000 rows.
# Processed 71000000 rows.
# Processed 71100000 rows.
# Processed 71200000 rows.
# Processed 71300000 rows.
# Processed 71400000 rows.
# Processed 71500000 rows.
# Processed 71600000 rows.
# Processed 71700000 rows.
# Processed 71800000 rows.
# Processed 71900000 rows.
# Processed 72000000 rows.
# Processed 72100000 rows.
# Processed 72200000 rows.
# Processed 72300000 rows.
# Processed 72400000 rows.
# Processed 72500000 rows.
# Processed 72600000 rows.
# Processed 72700000 rows.
# Processed 72800000 rows.
# Processed 72900000 rows.
# Processed 73000000 rows.
# Processed 73100000 rows.
# Processed 73200000 rows.
# Processed 73300000 rows.
# Processed 73400000 rows.
# Processed 73500000 rows.
# Processed 73600000 rows.
# Processed 73700000 rows.
# Processed 73800000 rows.
# Processed 73900000 rows.
# Processed 74000000 rows.
# Processed 74100000 rows.
# Processed 74200000 rows.
# Processed 74300000 rows.
# Processed 74400000 rows.
# Processed 74500000 rows.
# Processed 74600000 rows.
# Processed 74700000 rows.
# Processed 74800000 rows.
# Processed 74900000 rows.
# Processed 75000000 rows.
# Processed 75100000 rows.
# Processed 75200000 rows.
# Processed 75300000 rows.
# Processed 75400000 rows.
# Processed 75500000 rows.
# Processed 75600000 rows.
# Processed 75700000 rows.
# Processed 75800000 rows.
# Processed 75900000 rows.
# Processed 76000000 rows.
# Processed 76100000 rows.
# Processed 76200000 rows.
# Processed 76300000 rows.
# Processed 76400000 rows.
# Processed 76500000 rows.
# Processed 76600000 rows.
# Processed 76700000 rows.
# Processed 76800000 rows.
# Processed 76900000 rows.
# Processed 77000000 rows.
# Processed 77100000 rows.
# Processed 77200000 rows.
# Processed 77300000 rows.
# Processed 77400000 rows.
# Processed 77500000 rows.
# Processed 77600000 rows.
# Processed 77700000 rows.
# Processed 77800000 rows.
# Processed 77900000 rows.
# Processed 78000000 rows.
# Processed 78100000 rows.
# Processed 78200000 rows.
# Processed 78300000 rows.
# Processed 78400000 rows.
# Processed 78500000 rows.
# Processed 78600000 rows.
# Processed 78700000 rows.
# Processed 78800000 rows.
# Processed 78900000 rows.
# Processed 79000000 rows.
# Processed 79100000 rows.
# Processed 79200000 rows.
# Processed 79300000 rows.
# Processed 79400000 rows.
# Processed 79500000 rows.
# Processed 79600000 rows.
# Processed 79700000 rows.
# Processed 79800000 rows.
# Processed 79900000 rows.
# Processed 80000000 rows.
# Processed 80100000 rows.
# Processed 80200000 rows.
# Processed 80300000 rows.
# Processed 80400000 rows.
# Processed 80500000 rows.
# Processed 80600000 rows.
# Processed 80700000 rows.
# Processed 80800000 rows.
# Processed 80900000 rows.
# Processed 81000000 rows.
# Processed 81100000 rows.
# Processed 81200000 rows.
# Processed 81300000 rows.
# Processed 81400000 rows.
# Processed 81500000 rows.
# Processed 81600000 rows.
# Processed 81700000 rows.
# Processed 81800000 rows.
# Processed 81900000 rows.
# Processed 82000000 rows.
# Processed 82100000 rows.
# Processed 82200000 rows.
# Processed 82300000 rows.
# Processed 82400000 rows.
# Processed 82500000 rows.
# Processed 82600000 rows.
# Processed 82700000 rows.
# Processed 82800000 rows.
# Processed 82900000 rows.
# Processed 83000000 rows.
# Processed 83100000 rows.
# Processed 83200000 rows.
# Processed 83300000 rows.
# Processed 83400000 rows.
# Processed 83500000 rows.
# Processed 83600000 rows.
# Processed 83700000 rows.
# Processed 83800000 rows.
# Processed 83900000 rows.
# Processed 84000000 rows.
# Processed 84100000 rows.
# Processed 84200000 rows.
# Processed 84300000 rows.
# Processed 84400000 rows.
# Processed 84500000 rows.
# Processed 84600000 rows.
# Processed 84700000 rows.
# Processed 84800000 rows.
# Processed 84900000 rows.
# Processed 85000000 rows.
# Processed 85100000 rows.
# Processed 85200000 rows.
# Processed 85300000 rows.
# Processed 85400000 rows.
# Processed 85500000 rows.
# Processed 85600000 rows.
# Processed 85700000 rows.
# Processed 85800000 rows.
# Processed 85900000 rows.
# Processed 86000000 rows.
# Processed 86100000 rows.
# Processed 86200000 rows.
# Processed 86300000 rows.
# Processed 86400000 rows.
# Processed 86500000 rows.
# Processed 86600000 rows.
# Processed 86700000 rows.
# Processed 86800000 rows.
# Processed 86900000 rows.
# Processed 87000000 rows.
# Processed 87100000 rows.
# Processed 87200000 rows.
# Processed 87300000 rows.
# Processed 87400000 rows.
# Processed 87500000 rows.
# Processed 87600000 rows.
# Processed 87700000 rows.
# Processed 87800000 rows.
# Processed 87900000 rows.
# Processed 88000000 rows.
# Processed 88100000 rows.
# Processed 88200000 rows.
# Processed 88300000 rows.
# Processed 88400000 rows.
# Processed 88500000 rows.
# Processed 88600000 rows.
# Processed 88700000 rows.
# Processed 88800000 rows.
# Processed 88900000 rows.
# Processed 89000000 rows.
# Processed 89100000 rows.
# Processed 89200000 rows.
# Processed 89300000 rows.
# Processed 89400000 rows.
# Processed 89500000 rows.
# Processed 89600000 rows.
# Processed 89700000 rows.
# Processed 89800000 rows.
# Processed 89900000 rows.
# Processed 90000000 rows.
# Processed 90100000 rows.
# Processed 90200000 rows.
# Processed 90300000 rows.
# Processed 90400000 rows.
# Processed 90500000 rows.
# Processed 90600000 rows.
# Processed 90700000 rows.
# Processed 90800000 rows.
# Processed 90900000 rows.
# Processed 91000000 rows.
# Processed 91100000 rows.
# Processed 91200000 rows.
# Processed 91300000 rows.
# Processed 91400000 rows.
# Processed 91500000 rows.
# Processed 91600000 rows.
# Processed 91700000 rows.
# Processed 91800000 rows.
# Processed 91900000 rows.
# Processed 92000000 rows.
# Processed 92100000 rows.
# Processed 92200000 rows.
# Processed 92300000 rows.
# Processed 92400000 rows.
# Processed 92500000 rows.
# Processed 92600000 rows.
# Processed 92700000 rows.
# Processed 92800000 rows.
# Processed 92900000 rows.
# Processed 93000000 rows.
# Processed 93100000 rows.
# Processed 93200000 rows.
# Processed 93300000 rows.
# Processed 93400000 rows.
# Processed 93500000 rows.
# Processed 93600000 rows.
# Processed 93700000 rows.
# Processed 93800000 rows.
# Processed 93900000 rows.
# Processed 94000000 rows.
# Processed 94100000 rows.
# Processed 94200000 rows.
# Processed 94300000 rows.
# Processed 94400000 rows.
# Processed 94500000 rows.
# Processed 94600000 rows.
# Processed 94700000 rows.
# Processed 94800000 rows.
# Processed 94900000 rows.
# Processed 95000000 rows.
# Processed 95100000 rows.
# Processed 95200000 rows.
# Processed 95300000 rows.
# Processed 95400000 rows.
# Processed 95500000 rows.
# Processed 95600000 rows.
# Processed 95700000 rows.
# Processed 95800000 rows.
# Processed 95900000 rows.
# Processed 96000000 rows.
# Processed 96100000 rows.
# Processed 96200000 rows.
# Processed 96300000 rows.
# Processed 96400000 rows.
# Processed 96500000 rows.
# Processed 96600000 rows.
# Processed 96700000 rows.
# Processed 96800000 rows.
# Processed 96900000 rows.
# Processed 97000000 rows.
# Processed 97100000 rows.
# Processed 97200000 rows.
# Processed 97300000 rows.
# Processed 97400000 rows.
# Processed 97500000 rows.
# Processed 97600000 rows.
# Processed 97700000 rows.
# Processed 97800000 rows.
# Processed 97900000 rows.
# Processed 98000000 rows.
# Processed 98100000 rows.
# Processed 98200000 rows.
# Processed 98300000 rows.
# Processed 98400000 rows.
# Processed 98500000 rows.
# Processed 98600000 rows.
# Processed 98700000 rows.
# Processed 98800000 rows.
# Processed 98900000 rows.
# Processed 99000000 rows.
# Processed 99100000 rows.
# Processed 99200000 rows.
# Processed 99300000 rows.
# Processed 99400000 rows.
# Processed 99500000 rows.
# Processed 99600000 rows.
# Processed 99700000 rows.
# Processed 99800000 rows.
# Processed 99900000 rows.
# Processed 100000000 rows.
# Processed 100100000 rows.
# Processed 100200000 rows.
# Processed 100300000 rows.
# Processed 100400000 rows.
# Processed 100500000 rows.
# Processed 100600000 rows.
# Processed 100700000 rows.
# Processed 100800000 rows.
# Processed 100900000 rows.
# Processed 101000000 rows.
# Processed 101100000 rows.
# Processed 101200000 rows.
# Processed 101300000 rows.
# Processed 101400000 rows.
# Processed 101500000 rows.
# Processed 101600000 rows.
# Processed 101700000 rows.
# Processed 101800000 rows.
# Processed 101900000 rows.
# Processed 102000000 rows.
# Processed 102100000 rows.
# Processed 102200000 rows.
# Processed 102300000 rows.
# Processed 102400000 rows.
# Processed 102500000 rows.
# Processed 102600000 rows.
# Processed 102700000 rows.
# Processed 102800000 rows.
# Processed 102900000 rows.
# Processed 103000000 rows.
# Processed 103100000 rows.
# Processed 103200000 rows.
# Processed 103300000 rows.
# Processed 103400000 rows.
# Processed 103500000 rows.
# Processed 103600000 rows.
# Processed 103700000 rows.
# Processed 103800000 rows.
# Processed 103900000 rows.
# Processed 104000000 rows.
# Processed 104100000 rows.
# Processed 104200000 rows.
# Processed 104300000 rows.
# Processed 104400000 rows.
# Processed 104500000 rows.
# Processed 104600000 rows.
# Processed 104700000 rows.
# Processed 104800000 rows.
# Processed 104900000 rows.
# Processed 105000000 rows.
# Processed 105100000 rows.
# Processed 105200000 rows.
# Processed 105300000 rows.
# Processed 105400000 rows.
# Processed 105500000 rows.
# Processed 105600000 rows.
# Processed 105700000 rows.
# Processed 105800000 rows.
# Processed 105900000 rows.
# Processed 106000000 rows.
# Processed 106100000 rows.
# Processed 106200000 rows.
# Processed 106300000 rows.
# Processed 106400000 rows.
# Processed 106500000 rows.
# Processed 106600000 rows.
# Processed 106700000 rows.
# Processed 106800000 rows.
# Processed 106900000 rows.
# Processed 107000000 rows.
# Processed 107100000 rows.
# Processed 107200000 rows.
# Processed 107300000 rows.
# Processed 107400000 rows.
# Processed 107500000 rows.
# Processed 107600000 rows.
# Processed 107700000 rows.
# Processed 107800000 rows.
# Processed 107900000 rows.
# Processed 108000000 rows.
# Processed 108100000 rows.
# Processed 108200000 rows.
# Processed 108300000 rows.
# Processed 108400000 rows.
# Processed 108500000 rows.
# Processed 108600000 rows.
# Processed 108700000 rows.
# Processed 108800000 rows.
# Processed 108900000 rows.
# Processed 109000000 rows.
# Processed 109100000 rows.
# Processed 109200000 rows.
# Processed 109300000 rows.
# Processed 109400000 rows.
# Processed 109500000 rows.
# Processed 109600000 rows.
# Processed 109700000 rows.
# Processed 109800000 rows.
# Processed 109900000 rows.
# Processed 110000000 rows.
# Processed 110100000 rows.
# Processed 110200000 rows.
# Processed 110300000 rows.
# Processed 110400000 rows.
# Processed 110500000 rows.
# Processed 110600000 rows.
# Processed 110700000 rows.
# Processed 110800000 rows.
# Processed 110900000 rows.
# Processed 111000000 rows.
# Processed 111100000 rows.
# Processed 111200000 rows.
# Processed 111300000 rows.
# Processed 111400000 rows.
# Processed 111500000 rows.
# Processed 111600000 rows.
# Processed 111700000 rows.
# Processed 111800000 rows.
# Processed 111900000 rows.
# Processed 112000000 rows.
# Processed 112100000 rows.
# Processed 112200000 rows.
# Processed 112300000 rows.
# Processed 112400000 rows.
# Processed 112500000 rows.
# Processed 112600000 rows.
# Processed 112700000 rows.
# Processed 112800000 rows.
# Processed 112900000 rows.
# Processed 113000000 rows.
# Processed 113100000 rows.
# Processed 113200000 rows.
# Processed 113300000 rows.
# Processed 113400000 rows.
# Processed 113500000 rows.
# Processed 113600000 rows.
# Processed 113700000 rows.
# Processed 113800000 rows.
# Processed 113900000 rows.
# Processed 114000000 rows.
# Processed 114100000 rows.
# Processed 114200000 rows.
# Processed 114300000 rows.
# Processed 114400000 rows.
# Processed 114500000 rows.
# Processed 114600000 rows.
# Processed 114700000 rows.
# Processed 114800000 rows.
# Processed 114900000 rows.
# Processed 115000000 rows.
# Processed 115100000 rows.
# Processed 115200000 rows.
# Processed 115300000 rows.
# Processed 115400000 rows.
# Processed 115500000 rows.
# Processed 115600000 rows.
# Processed 115700000 rows.
# Processed 115800000 rows.
# Processed 115900000 rows.
# Processed 116000000 rows.
# Processed 116100000 rows.
# Processed 116200000 rows.
# Processed 116300000 rows.
# Processed 116400000 rows.
# Processed 116500000 rows.
# Processed 116600000 rows.
# Processed 116700000 rows.
# Processed 116800000 rows.
# Processed 116900000 rows.
# Processed 117000000 rows.
# Processed 117100000 rows.
# Processed 117200000 rows.
# Processed 117300000 rows.
# Processed 117400000 rows.
# Processed 117500000 rows.
# Processed 117600000 rows.
# Processed 117700000 rows.
# Processed 117800000 rows.
# Processed 117900000 rows.
# Processed 118000000 rows.
# Processed 118100000 rows.
# Processed 118200000 rows.
# Processed 118300000 rows.
# Processed 118400000 rows.
# Processed 118500000 rows.
# Processed 118600000 rows.
# Processed 118700000 rows.
# Processed 118800000 rows.
# Processed 118900000 rows.
# Processed 119000000 rows.
# Processed 119100000 rows.
# Processed 119200000 rows.
# Processed 119300000 rows.
# Processed 119400000 rows.
# Processed 119500000 rows.
# Processed 119600000 rows.
# Processed 119700000 rows.
# Processed 119800000 rows.
# Processed 119900000 rows.
# Processed 120000000 rows.
# Processed 120100000 rows.
# Processed 120200000 rows.
# Processed 120300000 rows.
# Processed 120400000 rows.
# Processed 120500000 rows.
# Processed 120600000 rows.
# Processed 120700000 rows.
# Processed 120800000 rows.
# Processed 120900000 rows.
# Processed 121000000 rows.
# Processed 121100000 rows.
# Processed 121200000 rows.
# Processed 121300000 rows.
# Processed 121400000 rows.
# Processed 121500000 rows.
# Processed 121600000 rows.
# Processed 121700000 rows.
# Processed 121800000 rows.
# Processed 121900000 rows.
# Processed 122000000 rows.
# Processed 122100000 rows.
# Processed 122200000 rows.
# Processed 122300000 rows.
# Processed 122400000 rows.
# Processed 122500000 rows.
# Processed 122600000 rows.
# Processed 122700000 rows.
# Processed 122800000 rows.
# Processed 122900000 rows.
# Processed 123000000 rows.
# Processed 123100000 rows.
# Processed 123200000 rows.
# Processed 123300000 rows.
# Processed 123400000 rows.
# Processed 123500000 rows.
# Processed 123600000 rows.
# Processed 123700000 rows.
# Processed 123800000 rows.
# Processed 123900000 rows.
# Processed 124000000 rows.
# Processed 124100000 rows.
# Processed 124200000 rows.
# Processed 124300000 rows.
# Processed 124400000 rows.
# Processed 124500000 rows.
# Processed 124600000 rows.
# Processed 124700000 rows.
# Processed 124800000 rows.
# Processed 124900000 rows.
# Processed 125000000 rows.
# Processed 125100000 rows.
# Processed 125200000 rows.
# Processed 125300000 rows.
# Processed 125400000 rows.
# Processed 125500000 rows.
# Processed 125600000 rows.
# Processed 125700000 rows.
# Processed 125800000 rows.
# Processed 125900000 rows.
# Processed 126000000 rows.
# Processed 126100000 rows.
# Processed 126200000 rows.
# Processed 126300000 rows.
# Processed 126400000 rows.
# Processed 126500000 rows.
# Processed 126600000 rows.
# Processed 126700000 rows.
# Processed 126800000 rows.
# Processed 126900000 rows.
# Processed 127000000 rows.
# Processed 127100000 rows.
# Processed 127200000 rows.
# Processed 127300000 rows.
# Processed 127400000 rows.
# Processed 127500000 rows.
# Processed 127600000 rows.
# Processed 127700000 rows.
# Processed 127800000 rows.
# Processed 127900000 rows.
# Processed 128000000 rows.
# Processed 128100000 rows.
# Processed 128200000 rows.
# Processed 128300000 rows.
# Processed 128400000 rows.
# Processed 128500000 rows.
# Processed 128600000 rows.
# Processed 128700000 rows.
# Processed 128800000 rows.
# Processed 128900000 rows.
# Processed 129000000 rows.
# Processed 129100000 rows.
# Processed 129200000 rows.
# Processed 129300000 rows.
# Processed 129400000 rows.
# Processed 129500000 rows.
# Processed 129600000 rows.
# Processed 129700000 rows.
# Processed 129800000 rows.
# Processed 129900000 rows.
# Processed 130000000 rows.
# Processed 130100000 rows.
# Processed 130200000 rows.
# Processed 130300000 rows.
# Processed 130400000 rows.
# Processed 130500000 rows.
# Processed 130600000 rows.
# Processed 130700000 rows.
# Processed 130800000 rows.
# Processed 130900000 rows.
# Processed 131000000 rows.
# Processed 131100000 rows.
# Processed 131200000 rows.
# Processed 131300000 rows.
# Processed 131400000 rows.
# Processed 131500000 rows.
# Processed 131600000 rows.
# Processed 131700000 rows.
# Processed 131800000 rows.
# Processed 131900000 rows.
# Processed 132000000 rows.
# Processed 132100000 rows.
# Processed 132200000 rows.
# Processed 132300000 rows.
# Processed 132400000 rows.
# Processed 132500000 rows.
# Processed 132600000 rows.
# Processed 132700000 rows.
# Processed 132800000 rows.
# Processed 132900000 rows.
# Processed 133000000 rows.
# Processed 133100000 rows.
# Processed 133200000 rows.
# Processed 133300000 rows.
# Processed 133400000 rows.
# Processed 133500000 rows.
# Processed 133600000 rows.
# Processed 133700000 rows.
# Processed 133800000 rows.
# Processed 133900000 rows.
# Processed 134000000 rows.
# Processed 134100000 rows.
# Processed 134200000 rows.
# Processed 134300000 rows.
# Processed 134400000 rows.
# Processed 134500000 rows.
# Processed 134600000 rows.
# Processed 134700000 rows.
# Processed 134800000 rows.
# Processed 134900000 rows.
# Processed 135000000 rows.
# Processed 135100000 rows.
# Processed 135200000 rows.
# Processed 135300000 rows.
# Processed 135400000 rows.
# Processed 135500000 rows.
# Processed 135600000 rows.
# Processed 135700000 rows.
# Processed 135800000 rows.
# Processed 135900000 rows.
# Processed 136000000 rows.
# Processed 136100000 rows.
# Processed 136200000 rows.
# Processed 136300000 rows.
# Processed 136400000 rows.
# Processed 136500000 rows.
# Processed 136600000 rows.
# Processed 136700000 rows.
# Processed 136800000 rows.
# Processed 136900000 rows.
# Processed 137000000 rows.
# Processed 137100000 rows.
# Processed 137200000 rows.
# Processed 137300000 rows.
# Processed 137400000 rows.
# Processed 137500000 rows.
# Processed 137600000 rows.
# Processed 137700000 rows.
# Processed 137800000 rows.
# Processed 137900000 rows.
# Processed 138000000 rows.
# Processed 138100000 rows.
# Processed 138200000 rows.
# Processed 138300000 rows.
# Processed 138400000 rows.
# Processed 138500000 rows.
# Processed 138600000 rows.
# Processed 138700000 rows.
# Processed 138800000 rows.
# Processed 138900000 rows.
# Processed 139000000 rows.
# Processed 139100000 rows.
# Processed 139200000 rows.
# Processed 139300000 rows.
# Processed 139400000 rows.
# Processed 139500000 rows.
# Processed 139600000 rows.
# Processed 139700000 rows.
# Processed 139800000 rows.
# Processed 139900000 rows.
# Processed 140000000 rows.
# Processed 140100000 rows.
# Processed 140200000 rows.
# Processed 140300000 rows.
# Processed 140400000 rows.
# Processed 140500000 rows.
# Processed 140600000 rows.
# Processed 140700000 rows.
# Processed 140800000 rows.
# Processed 140900000 rows.
# Processed 141000000 rows.
# Processed 141100000 rows.
# Processed 141200000 rows.
# Processed 141300000 rows.
# Processed 141400000 rows.
# Processed 141500000 rows.
# Processed 141600000 rows.
# Processed 141700000 rows.
# Processed 141800000 rows.
# Processed 141900000 rows.
# Processed 142000000 rows.
# Processed 142100000 rows.
# Processed 142200000 rows.
# Processed 142300000 rows.
# Processed 142400000 rows.
# Processed 142500000 rows.
# Processed 142600000 rows.
# Processed 142700000 rows.
# Processed 142800000 rows.
# Processed 142900000 rows.
# Processed 143000000 rows.
# Processed 143100000 rows.
# Processed 143200000 rows.
# Processed 143300000 rows.
# Processed 143400000 rows.
# Processed 143500000 rows.
# Processed 143600000 rows.
# Processed 143700000 rows.
# Processed 143800000 rows.
# Processed 143900000 rows.
# Processed 144000000 rows.
# Processed 144100000 rows.
# Processed 144200000 rows.
# Processed 144300000 rows.
# Processed 144400000 rows.
# Processed 144500000 rows.
# Processed 144600000 rows.
# Processed 144700000 rows.
# Processed 144800000 rows.
# Processed 144900000 rows.
# Processed 145000000 rows.
# Processed 145100000 rows.
# Processed 145200000 rows.
# Processed 145300000 rows.
# Processed 145400000 rows.
# Processed 145500000 rows.
# Processed 145600000 rows.
# Processed 145700000 rows.
# Processed 145800000 rows.
# Processed 145900000 rows.
# Processed 146000000 rows.
# Processed 146100000 rows.
# Processed 146200000 rows.
# Processed 146300000 rows.
# Processed 146400000 rows.
# Processed 146500000 rows.
# Processed 146600000 rows.
# Processed 146700000 rows.
# Processed 146800000 rows.
# Processed 146900000 rows.
# Processed 147000000 rows.
# Processed 147100000 rows.
# Processed 147200000 rows.
# Processed 147300000 rows.
# Processed 147400000 rows.
# Processed 147500000 rows.
# Processed 147600000 rows.
# Processed 147700000 rows.
# Processed 147800000 rows.
# Processed 147900000 rows.
# Processed 148000000 rows.
# Processed 148100000 rows.
# Processed 148200000 rows.
# Processed 148300000 rows.
# Processed 148400000 rows.
# Processed 148500000 rows.
# Processed 148600000 rows.
# Processed 148700000 rows.
# Processed 148800000 rows.
# Processed 148900000 rows.
# Processed 149000000 rows.
# Processed 149100000 rows.
# Processed 149200000 rows.
# Processed 149300000 rows.
# Processed 149400000 rows.
# Processed 149500000 rows.
# Processed 149600000 rows.
# Processed 149700000 rows.
# Processed 149800000 rows.
# Processed 149900000 rows.
# Processed 150000000 rows.
# Processed 150100000 rows.
# Processed 150200000 rows.
# Processed 150300000 rows.
# Processed 150400000 rows.
# Processed 150500000 rows.
# Processed 150600000 rows.
# Processed 150700000 rows.
# Processed 150800000 rows.
# Processed 150900000 rows.
# Processed 151000000 rows.
# Processed 151100000 rows.
# Processed 151200000 rows.
# Processed 151300000 rows.
# Processed 151400000 rows.
# Processed 151500000 rows.
# Processed 151600000 rows.
# Processed 151700000 rows.
# Processed 151800000 rows.
# Processed 151900000 rows.
# Processed 152000000 rows.
# Processed 152100000 rows.
# Processed 152200000 rows.
# Processed 152300000 rows.
# Processed 152400000 rows.
# Processed 152500000 rows.
# Processed 152600000 rows.
# Processed 152700000 rows.
# Processed 152800000 rows.
# Processed 152900000 rows.
# Processed 153000000 rows.
# Processed 153100000 rows.
# Processed 153200000 rows.
# Processed 153300000 rows.
# Processed 153400000 rows.
# Processed 153500000 rows.
# Processed 153600000 rows.
# Processed 153700000 rows.
# Processed 153800000 rows.
# Processed 153900000 rows.
# Processed 154000000 rows.
# Processed 154100000 rows.
# Processed 154200000 rows.
# Processed 154300000 rows.
# Processed 154400000 rows.
# Processed 154500000 rows.
# Processed 154600000 rows.
# Processed 154700000 rows.
# Processed 154800000 rows.
# Processed 154900000 rows.
# Processed 155000000 rows.
# Processed 155100000 rows.
# Processed 155200000 rows.
# Processed 155300000 rows.
# Processed 155400000 rows.
# Processed 155500000 rows.
# Processed 155600000 rows.
# Processed 155700000 rows.
# Processed 155800000 rows.
# Processed 155900000 rows.
# Processed 156000000 rows.
# Processed 156100000 rows.
# Processed 156200000 rows.
# Processed 156300000 rows.
# Processed 156400000 rows.
# Processed 156500000 rows.
# Processed 156600000 rows.
# Processed 156700000 rows.
# Processed 156800000 rows.
# Processed 156900000 rows.
# Processed 157000000 rows.
# Processed 157100000 rows.
# Processed 157200000 rows.
# Processed 157300000 rows.
# Processed 157400000 rows.
# Processed 157500000 rows.
# Processed 157600000 rows.
# Processed 157700000 rows.
# Processed 157800000 rows.
# Processed 157900000 rows.
# Processed 158000000 rows.
# Processed 158100000 rows.
# Processed 158200000 rows.
# Processed 158300000 rows.
# Processed 158400000 rows.
# Processed 158500000 rows.
# Processed 158600000 rows.
# Processed 158700000 rows.
# Processed 158800000 rows.
# Processed 158900000 rows.
# Processed 159000000 rows.
# Processed 159100000 rows.
# Processed 159200000 rows.
# Processed 159300000 rows.
# Processed 159400000 rows.
# Processed 159500000 rows.
# Processed 159600000 rows.
# Processed 159700000 rows.
# Processed 159800000 rows.
# Processed 159900000 rows.
# Processed 160000000 rows.
# Processed 160100000 rows.
# Processed 160200000 rows.
# Processed 160300000 rows.
# Processed 160400000 rows.
# Processed 160500000 rows.
# Processed 160600000 rows.
# Processed 160700000 rows.
# Processed 160800000 rows.
# Processed 160900000 rows.
# Processed 161000000 rows.
# Processed 161100000 rows.
# Processed 161200000 rows.
# Processed 161300000 rows.
# Processed 161400000 rows.
# Processed 161500000 rows.
# Processed 161600000 rows.
# Processed 161700000 rows.
# Processed 161800000 rows.
# Processed 161900000 rows.
# Processed 162000000 rows.
# Processed 162100000 rows.
# Processed 162200000 rows.
# Processed 162300000 rows.
# Processed 162400000 rows.
# Processed 162500000 rows.
# Processed 162600000 rows.
# Processed 162700000 rows.
# Processed 162800000 rows.
# Processed 162900000 rows.
# Processed 163000000 rows.
# Processed 163100000 rows.
# Processed 163200000 rows.
# Processed 163300000 rows.
# Processed 163400000 rows.
# Processed 163500000 rows.
# Processed 163600000 rows.
# Processed 163700000 rows.
# Processed 163800000 rows.
# Processed 163900000 rows.
# Processed 164000000 rows.
# Processed 164100000 rows.
# Processed 164200000 rows.
# Processed 164300000 rows.
# Processed 164400000 rows.
# Processed 164500000 rows.
# Processed 164600000 rows.
# Processed 164700000 rows.
# Processed 164800000 rows.
# Processed 164900000 rows.
# Processed 165000000 rows.
# Processed 165100000 rows.
# Processed 165200000 rows.
# Processed 165300000 rows.
# Processed 165400000 rows.
# Processed 165500000 rows.
# Processed 165600000 rows.
# Processed 165700000 rows.
# Processed 165800000 rows.
# Processed 165900000 rows.
# Processed 166000000 rows.
# Processed 166100000 rows.
# Processed 166200000 rows.
# Processed 166300000 rows.
# Processed 166400000 rows.
# Processed 166500000 rows.
# Processed 166600000 rows.
# Processed 166700000 rows.
# Processed 166800000 rows.
# Processed 166900000 rows.
# Processed 167000000 rows.
# Processed 167100000 rows.
# Processed 167200000 rows.
# Processed 167300000 rows.
# Processed 167400000 rows.
# Processed 167500000 rows.
# Processed 167600000 rows.
# Processed 167700000 rows.
# Processed 167800000 rows.
# Processed 167900000 rows.
# Processed 168000000 rows.
# Processed 168100000 rows.
# Processed 168200000 rows.
# Processed 168300000 rows.
# Processed 168400000 rows.
# Processed 168500000 rows.
# Processed 168600000 rows.
# Processed 168700000 rows.
# Processed 168800000 rows.
# Processed 168900000 rows.
# Processed 169000000 rows.
# Processed 169100000 rows.
# Processed 169200000 rows.
# Processed 169300000 rows.
# Processed 169400000 rows.
# Processed 169500000 rows.
# Processed 169600000 rows.
# Processed 169700000 rows.
# Processed 169800000 rows.
# Processed 169900000 rows.
# Processed 170000000 rows.
# Processed 170100000 rows.
# Processed 170200000 rows.
# Processed 170300000 rows.
# Processed 170400000 rows.
# Processed 170500000 rows.
# Processed 170600000 rows.
# Processed 170700000 rows.
# Processed 170800000 rows.
# Processed 170900000 rows.
# Processed 171000000 rows.
# Processed 171100000 rows.
# Processed 171200000 rows.
# Processed 171300000 rows.
# Processed 171400000 rows.
# Processed 171500000 rows.
# Processed 171600000 rows.
# Processed 171700000 rows.
# Processed 171800000 rows.
# Processed 171900000 rows.
# Processed 172000000 rows.
# Processed 172100000 rows.
# Processed 172200000 rows.
# Processed 172300000 rows.
# Processed 172400000 rows.
# Processed 172500000 rows.
# Processed 172600000 rows.
# Processed 172700000 rows.
# Processed 172800000 rows.
# Processed 172900000 rows.
# Processed 173000000 rows.
# Processed 173100000 rows.
# Processed 173200000 rows.
# Processed 173300000 rows.
# Processed 173400000 rows.
# Processed 173500000 rows.
# Processed 173600000 rows.
# Processed 173700000 rows.
# Processed 173800000 rows.
# Processed 173900000 rows.
# Processed 174000000 rows.
# Processed 174100000 rows.
# Processed 174200000 rows.
# Processed 174300000 rows.
# Processed 174400000 rows.
# Processed 174500000 rows.
# Processed 174600000 rows.
# Processed 174700000 rows.
# Processed 174800000 rows.
# Processed 174900000 rows.
# Processed 175000000 rows.
# Processed 175100000 rows.
# Processed 175200000 rows.
# Processed 175300000 rows.
# Processed 175400000 rows.
# Processed 175500000 rows.
# Processed 175600000 rows.
# Processed 175700000 rows.
# Processed 175800000 rows.
# Processed 175900000 rows.
# Processed 176000000 rows.
# Processed 176100000 rows.
# Processed 176200000 rows.
# Processed 176300000 rows.
# Processed 176400000 rows.
# Processed 176500000 rows.
# Processed 176600000 rows.
# Processed 176700000 rows.
# Processed 176800000 rows.
# Processed 176900000 rows.
# Processed 177000000 rows.
# Processed 177100000 rows.
# Processed 177200000 rows.
# Processed 177300000 rows.
# Processed 177400000 rows.
# Processed 177500000 rows.
# Processed 177600000 rows.
# Processed 177700000 rows.
# Processed 177800000 rows.
# Processed 177900000 rows.
# Processed 178000000 rows.
# Processed 178100000 rows.
# Processed 178200000 rows.
# Processed 178300000 rows.
# Processed 178400000 rows.
# Processed 178500000 rows.
# Processed 178600000 rows.
# Processed 178700000 rows.
# Processed 178800000 rows.
# Processed 178900000 rows.
# Processed 179000000 rows.
# Processed 179100000 rows.
# Processed 179200000 rows.
# Processed 179300000 rows.
# Processed 179400000 rows.
# Processed 179500000 rows.
# Processed 179600000 rows.
# Processed 179700000 rows.
# Processed 179800000 rows.
# Processed 179900000 rows.
# Processed 180000000 rows.
# Processed 180100000 rows.
# Processed 180200000 rows.
# Processed 180300000 rows.
# Processed 180400000 rows.
# Processed 180500000 rows.
# Processed 180600000 rows.
# Processed 180700000 rows.
# Processed 180800000 rows.
# Processed 180900000 rows.
# Processed 181000000 rows.
# Processed 181100000 rows.
# Processed 181200000 rows.
# Processed 181300000 rows.
# Processed 181400000 rows.
# Processed 181500000 rows.
# Processed 181600000 rows.
# Processed 181700000 rows.
# Processed 181800000 rows.
# Processed 181900000 rows.
# Processed 182000000 rows.
# Processed 182100000 rows.
# Processed 182200000 rows.
# Processed 182300000 rows.
# Processed 182400000 rows.
# Processed 182500000 rows.
# Processed 182600000 rows.
# Processed 182700000 rows.
# Processed 182800000 rows.
# Processed 182900000 rows.
# Processed 183000000 rows.
# Processed 183100000 rows.
# Processed 183200000 rows.
# Processed 183300000 rows.
# Processed 183400000 rows.
# Processed 183500000 rows.
# Processed 183600000 rows.
# Processed 183700000 rows.
# Processed 183800000 rows.
# Processed 183900000 rows.
# Processed 184000000 rows.
# Processed 184100000 rows.
# Processed 184200000 rows.
# Processed 184300000 rows.
# Processed 184400000 rows.
# Processed 184500000 rows.
# Processed 184600000 rows.
# Processed 184700000 rows.
# Processed 184800000 rows.
# Processed 184900000 rows.
# Processed 185000000 rows.
# Processed 185100000 rows.
# Processed 185200000 rows.
# Processed 185300000 rows.
# Processed 185400000 rows.
# Processed 185500000 rows.
# Processed 185600000 rows.
# Processed 185700000 rows.
# Processed 185800000 rows.
# Processed 185900000 rows.
# Processed 186000000 rows.
# Processed 186100000 rows.
# Processed 186200000 rows.
# Processed 186300000 rows.
# Processed 186400000 rows.
# Processed 186500000 rows.
# Processed 186600000 rows.
# Processed 186700000 rows.
# Processed 186800000 rows.
# Processed 186900000 rows.
# Processed 187000000 rows.
# Processed 187100000 rows.
# Processed 187200000 rows.
# Processed 187300000 rows.
# Processed 187400000 rows.
# Processed 187500000 rows.
# Processed 187600000 rows.
# Processed 187700000 rows.
# Processed 187800000 rows.
# Processed 187900000 rows.
# Processed 188000000 rows.
# Processed 188100000 rows.
# ...
# Processed 188700000 rows.
# Processed 188800000 rows.
# Processed 188900000 rows.
# Processed 189000000 rows.
# Processed 189100000 rows.
# Processed 189200000 rows.
# Processed 189300000 rows.
# Processed 189400000 rows.
# Processed 189500000 rows.
# Processed 189600000 rows.
# Processed 189700000 rows.
# Processed 189800000 rows.
# Processed 189900000 rows.
# Processed 190000000 rows.
# Processed 190100000 rows.
# Processed 190200000 rows.
# Processed 190300000 rows.
# Processed 190400000 rows.
# Processed 190500000 rows.
# Processed 190600000 rows.
# Processed 190700000 rows.
# Processed 190800000 rows.
# Processed 190900000 rows.
# Processed 191000000 rows.
# Processed 191100000 rows.
# Processed 191200000 rows.
# Processed 191300000 rows.
# Processed 191400000 rows.
# Processed 191500000 rows.
# Processed 191600000 rows.
# Processed 191700000 rows.
# Processed 191800000 rows.
# Processed 191900000 rows.
# Processed 192000000 rows.
# Processed 192100000 rows.
# Processed 192200000 rows.
# Processed 192300000 rows.
# Processed 192400000 rows.
# Processed 192500000 rows.
# Processed 192600000 rows.
# Processed 192700000 rows.
# Processed 192800000 rows.
# Processed 192900000 rows.
# Processed 193000000 rows.
# Processed 193100000 rows.
# Processed 193200000 rows.
# Processed 193300000 rows.
# Processed 193400000 rows.
# Processed 193500000 rows.
# Processed 193600000 rows.
# Processed 193700000 rows.
# Processed 193800000 rows.
# Processed 193900000 rows.
# Processed 194000000 rows.
# Processed 194100000 rows.
# Processed 194200000 rows.
# Processed 194300000 rows.
# Processed 194400000 rows.
# Processed 194500000 rows.
# Processed 194600000 rows.
# Processed 194700000 rows.
# Processed 194800000 rows.
# Processed 194900000 rows.
# Processed 195000000 rows.
# Processed 195100000 rows.
# Processed 195200000 rows.
# Processed 195300000 rows.
# Processed 195400000 rows.
# Processed 195500000 rows.
# Processed 195600000 rows.
# Processed 195700000 rows.
# Processed 195800000 rows.
# Processed 195900000 rows.
# Processed 196000000 rows.
# Processed 196100000 rows.
# Processed 196200000 rows.
# Processed 196300000 rows.
# Processed 196400000 rows.
# Processed 196500000 rows.
# Processed 196600000 rows.
# Processed 196700000 rows.
# Processed 196800000 rows.
# Processed 196900000 rows.
# Processed 197000000 rows.
# Processed 197100000 rows.
# Processed 197200000 rows.
# Processed 197300000 rows.
# Processed 197400000 rows.
# Processed 197500000 rows.
# Processed 197600000 rows.
# Processed 197700000 rows.
# Processed 197800000 rows.
# Processed 197900000 rows.
# Processed 198000000 rows.
# Processed 198100000 rows.
# Processed 198200000 rows.
# Processed 198300000 rows.
# Processed 198400000 rows.
# Processed 198500000 rows.
# Processed 198600000 rows.
# Processed 198700000 rows.
# Processed 198800000 rows.
# Processed 198900000 rows.
# Processed 199000000 rows.
# Processed 199100000 rows.
# Processed 199200000 rows.
# Processed 199300000 rows.
# Processed 199400000 rows.
# Processed 199500000 rows.
# Processed 199600000 rows.
# Processed 199700000 rows.
# Processed 199800000 rows.
# Processed 199900000 rows.
# Processed 200000000 rows.
# Processed 200100000 rows.
# Processed 200200000 rows.
# Processed 200300000 rows.
# Processed 200400000 rows.
# Processed 200500000 rows.
# Processed 200600000 rows.
# Processed 200700000 rows.
# Processed 200800000 rows.
# Processed 200900000 rows.
# Processed 201000000 rows.
# Processed 201100000 rows.
# Processed 201200000 rows.
# Processed 201300000 rows.
# Processed 201400000 rows.
# Processed 201500000 rows.
# Processed 201600000 rows.
# Processed 201700000 rows.
# Processed 201800000 rows.
# Processed 201900000 rows.
# Processed 202000000 rows.
# Processed 202100000 rows.
# Processed 202200000 rows.
# Processed 202300000 rows.
# Processed 202400000 rows.
# Processed 202500000 rows.
# Processed 202600000 rows.
# Processed 202700000 rows.
# Processed 202800000 rows.
# Processed 202900000 rows.
# Processed 203000000 rows.
# Processed 203100000 rows.
# Processed 203200000 rows.
# Processed 203300000 rows.
# Processed 203400000 rows.
# Processed 203500000 rows.
# Processed 203600000 rows.
# Processed 203700000 rows.
# Processed 203800000 rows.
# Processed 203900000 rows.
# Processed 204000000 rows.
# Processed 204100000 rows.
# Processed 204200000 rows.
# Processed 204300000 rows.
# Processed 204400000 rows.
# Processed 204500000 rows.
# Processed 204600000 rows.
# Processed 204700000 rows.
# Processed 204800000 rows.
# Processed 204900000 rows.
# Processed 205000000 rows.
# Processed 205100000 rows.
# Processed 205200000 rows.
# Processed 205300000 rows.
# Processed 205400000 rows.
# Processed 205500000 rows.
# Processed 205600000 rows.
# Processed 205700000 rows.
# Processed 205800000 rows.
# Processed 205900000 rows.
# Processed 206000000 rows.
# Processed 206100000 rows.
# Processed 206200000 rows.
# Processed 206300000 rows.
# Processed 206400000 rows.
# Processed 206500000 rows.
# Processed 206600000 rows.
# Processed 206700000 rows.
# Processed 206800000 rows.
# Processed 206900000 rows.
# Processed 207000000 rows.
# Processed 207100000 rows.
# Processed 207200000 rows.
# Processed 207300000 rows.
# Processed 207400000 rows.
# Processed 207500000 rows.
# Processed 207600000 rows.
# Processed 207700000 rows.
# Processed 207800000 rows.
# Processed 207900000 rows.
# Processed 208000000 rows.
# Processed 208100000 rows.
# Processed 208200000 rows.
# Processed 208300000 rows.
# Processed 208400000 rows.
# Processed 208500000 rows.
# Processed 208600000 rows.
# Processed 208700000 rows.
# Processed 208800000 rows.
# Processed 208900000 rows.
# Processed 209000000 rows.
# Processed 209100000 rows.
# Processed 209200000 rows.
# Processed 209300000 rows.
# Processed 209400000 rows.
# Processed 209500000 rows.
# Processed 209600000 rows.
# Processed 209700000 rows.
# Processed 209800000 rows.
# Processed 209900000 rows.
# Processed 210000000 rows.
# Processed 210100000 rows.
# Processed 210200000 rows.
# Processed 210300000 rows.
# Processed 210400000 rows.
# Processed 210500000 rows.
# Processed 210600000 rows.
# Processed 210700000 rows.
# Processed 210800000 rows.
# Processed 210900000 rows.
# Processed 211000000 rows.
# Processed 211100000 rows.
# Processed 211200000 rows.
# Processed 211300000 rows.
# Processed 211400000 rows.
# Processed 211500000 rows.
# Processed 211600000 rows.
# Processed 211700000 rows.
# Processed 211800000 rows.
# Processed 211900000 rows.
# Processed 212000000 rows.
# Processed 212100000 rows.
# Processed 212200000 rows.
# Processed 212300000 rows.
# Processed 212400000 rows.
# Processed 212500000 rows.
# Processed 212600000 rows.
# Processed 212700000 rows.
# Processed 212800000 rows.
# Processed 212900000 rows.
# Processed 213000000 rows.
# Processed 213100000 rows.
# Processed 213200000 rows.
# Processed 213300000 rows.
# Processed 213400000 rows.
# Processed 213500000 rows.
# Processed 213600000 rows.
# Processed 213700000 rows.
# Processed 213800000 rows.
# Processed 213900000 rows.
# Processed 214000000 rows.
# Processed 214100000 rows.
# Processed 214200000 rows.
# Processed 214300000 rows.
# Processed 214400000 rows.
# Processed 214500000 rows.
# Processed 214600000 rows.
# Processed 214700000 rows.
# Processed 214800000 rows.
# Processed 214900000 rows.
# Processed 215000000 rows.
# Processed 215100000 rows.
# Processed 215200000 rows.
# Processed 215300000 rows.
# Processed 215400000 rows.
# Processed 215500000 rows.
# Processed 215600000 rows.
# Processed 215700000 rows.
# Processed 215800000 rows.
# Processed 215900000 rows.
# Processed 216000000 rows.
# Processed 216100000 rows.
# Processed 216200000 rows.
# Processed 216300000 rows.
# Processed 216400000 rows.
# Processed 216500000 rows.
# Processed 216600000 rows.
# Processed 216700000 rows.
# Processed 216800000 rows.
# Processed 216900000 rows.
# Processed 217000000 rows.
# Processed 217100000 rows.
# Processed 217200000 rows.
# Processed 217300000 rows.
# Processed 217400000 rows.
# Processed 217500000 rows.
# Processed 217600000 rows.
# Processed 217700000 rows.
# Processed 217800000 rows.
# Processed 217900000 rows.
# Processed 218000000 rows.
# Processed 218100000 rows.
# Processed 218200000 rows.
# Processed 218300000 rows.
# Processed 218400000 rows.
# Processed 218500000 rows.
# Processed 218600000 rows.
# Processed 218700000 rows.
# Processed 218800000 rows.
# Processed 218900000 rows.
# Processed 219000000 rows.
# Processed 219100000 rows.
# Processed 219200000 rows.
# Processed 219300000 rows.
# Processed 219400000 rows.
# Processed 219500000 rows.
# Processed 219600000 rows.
# Processed 219700000 rows.
# Processed 219800000 rows.
# Processed 219900000 rows.
# Processed 220000000 rows.
# Processed 220100000 rows.
# Processed 220200000 rows.
# Processed 220300000 rows.
# Processed 220400000 rows.
# Processed 220500000 rows.
# Processed 220600000 rows.
# Processed 220700000 rows.
# Processed 220800000 rows.
# Processed 220900000 rows.
# Processed 221000000 rows.
# Processed 221100000 rows.
# Processed 221200000 rows.
# Processed 221300000 rows.
# Processed 221400000 rows.
# Processed 221500000 rows.
# Processed 221600000 rows.
# Processed 221700000 rows.
# Processed 221800000 rows.
# Processed 221900000 rows.
# Processed 222000000 rows.
# Processed 222100000 rows.
# Processed 222200000 rows.
# Processed 222300000 rows.
# Processed 222400000 rows.
# Processed 222500000 rows.
# Processed 222600000 rows.
# Processed 222700000 rows.
# Processed 222800000 rows.
# Processed 222900000 rows.
# Processed 223000000 rows.
# Processed 223100000 rows.
# Processed 223200000 rows.
# Processed 223300000 rows.
# Processed 223400000 rows.
# Processed 223500000 rows.
# Processed 223600000 rows.
# Processed 223700000 rows.
# Processed 223800000 rows.
# Processed 223900000 rows.
# Processed 224000000 rows.
# Processed 224100000 rows.
# Processed 224200000 rows.
# Processed 224300000 rows.
# Processed 224400000 rows.
# Processed 224500000 rows.
# Processed 224600000 rows.
# Processed 224700000 rows.
# Processed 224800000 rows.
# Processed 224900000 rows.
# Processed 225000000 rows.
# Processed 225100000 rows.
# Processed 225200000 rows.
# Processed 225300000 rows.
# Processed 225400000 rows.
# Processed 225500000 rows.
# Processed 225600000 rows.
# Processed 225700000 rows.
# Processed 225800000 rows.
# Processed 225900000 rows.
# Processed 226000000 rows.
# Processed 226100000 rows.
# Processed 226200000 rows.
# Processed 226300000 rows.
# Processed 226400000 rows.
# Processed 226500000 rows.
# Processed 226600000 rows.
# Processed 226700000 rows.
# Processed 226800000 rows.
# Processed 226900000 rows.
# Processed 227000000 rows.
# Processed 227100000 rows.
# Processed 227200000 rows.
# Processed 227300000 rows.
# Processed 227400000 rows.
# Processed 227500000 rows.
# Processed 227600000 rows.
# Processed 227700000 rows.
# Processed 227800000 rows.
# Processed 227900000 rows.
# Processed 228000000 rows.
# Processed 228100000 rows.
# Processed 228200000 rows.
# Processed 228300000 rows.
# Processed 228400000 rows.
# Processed 228500000 rows.
# Processed 228600000 rows.
# Processed 228700000 rows.
# Processed 228800000 rows.
# Processed 228900000 rows.
# Processed 229000000 rows.
# Processed 229100000 rows.
# Processed 229200000 rows.
# Processed 229300000 rows.
# Processed 229400000 rows.
# Processed 229500000 rows.
# Processed 229600000 rows.
# Processed 229700000 rows.
# Processed 229800000 rows.
# Processed 229900000 rows.
# Processed 230000000 rows.
# Processed 230100000 rows.
# Processed 230200000 rows.
# Processed 230300000 rows.
# Processed 230400000 rows.
# Processed 230500000 rows.
# Processed 230600000 rows.
# Processed 230700000 rows.
# Processed 230800000 rows.
# Processed 230900000 rows.
# Processed 231000000 rows.
# Processed 231100000 rows.
# Processed 231200000 rows.
# Processed 231300000 rows.
# Processed 231400000 rows.
# Processed 231500000 rows.
# Processed 231600000 rows.
# Processed 231700000 rows.
# Processed 231800000 rows.
# Processed 231900000 rows.
# Processed 232000000 rows.
# Processed 232100000 rows.
# Processed 232200000 rows.
# Processed 232300000 rows.
# Processed 232400000 rows.
# Processed 232500000 rows.
# Processed 232600000 rows.
# Processed 232700000 rows.
# Processed 232800000 rows.
# Processed 232900000 rows.
# Processed 233000000 rows.
# Processed 233100000 rows.
# Processed 233200000 rows.
# Processed 233300000 rows.
# Processed 233400000 rows.
# Processed 233500000 rows.
# Processed 233600000 rows.
# Processed 233700000 rows.
# Processed 233800000 rows.
# Processed 233900000 rows.
# Processed 234000000 rows.
# Processed 234100000 rows.
# Processed 234200000 rows.
# Processed 234300000 rows.
# Processed 234400000 rows.
# Processed 234500000 rows.
# Processed 234600000 rows.
# Processed 234700000 rows.
# Processed 234800000 rows.
# Processed 234900000 rows.
# Processed 235000000 rows.
# Processed 235100000 rows.
# Processed 235200000 rows.
# Processed 235300000 rows.
# Processed 235400000 rows.
# Processed 235500000 rows.
# Processed 235600000 rows.
# Processed 235700000 rows.
# Processed 235800000 rows.
# Processed 235900000 rows.
# Processed 236000000 rows.
# Processed 236100000 rows.
# Processed 236200000 rows.
# Processed 236300000 rows.
# Processed 236400000 rows.
# Processed 236500000 rows.
# Processed 236600000 rows.
# Processed 236700000 rows.
# Processed 236800000 rows.
# Processed 236900000 rows.
# Processed 237000000 rows.
# Processed 237100000 rows.
# Processed 237200000 rows.
# Processed 237300000 rows.
# Processed 237400000 rows.
# Processed 237500000 rows.
# Processed 237600000 rows.
# Processed 237700000 rows.
# Processed 237800000 rows.
# Processed 237900000 rows.
# Processed 238000000 rows.
# Processed 238100000 rows.
# Processed 238200000 rows.
# Processed 238300000 rows.
# Processed 238400000 rows.
# Processed 238500000 rows.
# Processed 238600000 rows.
# Processed 238700000 rows.
# Processed 238800000 rows.
# Processed 238900000 rows.
# Processed 239000000 rows.
# Processed 239100000 rows.
# Processed 239200000 rows.
# Processed 239300000 rows.
# Processed 239400000 rows.
# Processed 239500000 rows.
# Processed 239600000 rows.
# Processed 239700000 rows.
# Processed 239800000 rows.
# Processed 239900000 rows.
# Processed 240000000 rows.
# Processed 240100000 rows.
# Processed 240200000 rows.
# Processed 240300000 rows.
# Processed 240400000 rows.
# Processed 240500000 rows.
# Processed 240600000 rows.
# Processed 240700000 rows.
# Processed 240800000 rows.
# Processed 240900000 rows.
# Processed 241000000 rows.
# Processed 241100000 rows.
# Processed 241200000 rows.
# Processed 241300000 rows.
# Processed 241400000 rows.
# Processed 241500000 rows.
# Processed 241600000 rows.
# Processed 241700000 rows.
# Processed 241800000 rows.
# Processed 241900000 rows.
# Processed 242000000 rows.
# Processed 242100000 rows.
# Processed 242200000 rows.
# Processed 242300000 rows.
# Processed 242400000 rows.
# Processed 242500000 rows.
# Processed 242600000 rows.
# Processed 242700000 rows.
# Processed 242800000 rows.
# Processed 242900000 rows.
# Processed 243000000 rows.
# Processed 243100000 rows.
# Processed 243200000 rows.
# Processed 243300000 rows.
# Processed 243400000 rows.
# Processed 243500000 rows.
# Processed 243600000 rows.
# Processed 243700000 rows.
# Processed 243800000 rows.
# Processed 243900000 rows.
# Processed 244000000 rows.
# Processed 244100000 rows.
# Processed 244200000 rows.
# Processed 244300000 rows.
# Processed 244400000 rows.
# Processed 244500000 rows.
# Processed 244600000 rows.
# Processed 244700000 rows.
# Processed 244800000 rows.
# Processed 244900000 rows.
# Processed 245000000 rows.
# Processed 245100000 rows.
# Processed 245200000 rows.
# Processed 245300000 rows.
# Processed 245400000 rows.
# Processed 245500000 rows.
# Processed 245600000 rows.
# Processed 245700000 rows.
# Processed 245800000 rows.
# Processed 245900000 rows.
# Processed 246000000 rows.
# Processed 246100000 rows.
# Processed 246200000 rows.
# Processed 246300000 rows.
# Processed 246400000 rows.
# Processed 246500000 rows.
# Processed 246600000 rows.
# Processed 246700000 rows.
# Processed 246800000 rows.
# Processed 246900000 rows.
# Processed 247000000 rows.
# Processed 247100000 rows.
# Processed 247200000 rows.
# Processed 247300000 rows.
# Processed 247400000 rows.
# Processed 247500000 rows.
# Processed 247600000 rows.
# Processed 247700000 rows.
# Processed 247800000 rows.
# Processed 247900000 rows.
# Processed 248000000 rows.
# Processed 248100000 rows.
# Processed 248157124 rows.
# Warning: Results DataFrame is empty.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-984a7bf20186> in <cell line: 2>()
#      13     labels_file_path = f'{output_dir}all_labels_chunk_{i}.parquet'
#      14
# ---> 15     data.to_parquet(data_file_path)
#      16     labels.to_parquet(labels_file_path)
#      17
#
# AttributeError: 'NoneType' object has no attribute 'to_parquet'

# %% [markdown]
# Yet again, there seems to be no data for either of the chunks.
#
# As a final try, we will run the whole patient dataset and extract the timeseries data without splitting into chunks.

# %%
# Load all patients
patient_file = '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/03_annotated_set/annotation_v03.parquet'

patient_df = pd.read_parquet(patient_file)
patient_df.shape[0]
# Out:
# 5970

# %%
chartevents_path
# Out:
# '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/mimic-iv-2.2-raw-data/icu/chartevents.csv'

# %%
feature_set_1_dynamic
# Out:
# [220210,
#  220277,
#  228640,
#  220235,
#  223830,
#  220224,
#  220228,
#  223835,
#  224685,
#  224686,
#  224695,
#  224687,
#  224696,
#  223849,
#  224419]

# %%
time_window_hours = timedelta(hours=6)

# %%
output_dir
# Out:
# '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/05_time_series_data_preprocessing/feature_set_1_results'

# %%
# Run the original function on the entire dataset and save the results
full_data, full_labels = extract_patient_data_2(patient_df, chartevents_path, feature_set_1_dynamic, time_window_hours)
full_data.to_parquet(f'{output_dir}/full_data.parquet')
full_labels.to_parquet(f'{output_dir}/full_labels.parquet')

print(f"Saved all data and labels to {output_dir}")
# Out:
# Processed 10000000 rows
# Processed 20000000 rows
# Processed 30000000 rows
# Processed 40000000 rows
# Processed 50000000 rows
# Processed 60000000 rows
# Processed 70000000 rows
# Processed 80000000 rows
# Processed 90000000 rows
# Processed 100000000 rows
# Processed 110000000 rows
# Processed 120000000 rows
# Processed 130000000 rows
# Processed 140000000 rows
# Processed 150000000 rows
# Processed 160000000 rows
# Processed 170000000 rows
# Processed 180000000 rows
# Processed 190000000 rows
# Processed 200000000 rows
# Processed 210000000 rows
# Processed 220000000 rows
# Processed 230000000 rows
# Processed 240000000 rows
# Saved all data and labels to /content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/05_time_series_data_preprocessing/feature_set_1_results

# %%
# Analyse full_data
full_data.head()
# Out:
#    subject_id           charttime    itemid  valuenum
# 0    10001884 2131-01-12 15:00:00  223835.0      40.0
# 1    10001884 2131-01-12 15:00:00  224685.0     284.0
# 2    10001884 2131-01-12 15:00:00  224686.0     284.0
# 3    10001884 2131-01-12 15:00:00  224687.0       6.1
# 4    10001884 2131-01-12 15:00:00  224695.0      17.0

# %%
full_data.shape[0]
# Out:
# 116639

# %%
# Count the number of unique subject_ids in the full data
unique_subject_ids = full_data['subject_id'].unique()
print("Number of unique subject_ids in the full data: ", len(unique_subject_ids))
# Out:
# Number of unique subject_ids in the full data:  4701

# %%
# Count the number of patients in the original patient set
num_patients = patient_df.shape[0]
print("Number of patients in the original patient set: ", num_patients)
# Out:
# Number of patients in the original patient set:  5970

# %% [markdown]
# When extracting the full patient data, it seems there is only data present for 4701 patients out of the full 5970 which corroborates the possibility that both patient chunks 8 and 9 had no relevant data as this is approximately 20% of the orginal patient size.

# %% [markdown]
# For a final validation, we can look at how many unique patients there were in the 8 patient chunks.

# %%
# Load the first 8 patient chunks
successful_patient_chunk_results_files = [f'/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/05_time_series_data_preprocessing/feature_set_1_results/data_chunk_{i}.parquet' for i in range(8)]
successful_patient_chunk_results_files
# Out:
# ['/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/05_time_series_data_preprocessing/feature_set_1_results/data_chunk_0.parquet',
#  '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/05_time_series_data_preprocessing/feature_set_1_results/data_chunk_1.parquet',
#  '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/05_time_series_data_preprocessing/feature_set_1_results/data_chunk_2.parquet',
#  '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/05_time_series_data_preprocessing/feature_set_1_results/data_chunk_3.parquet',
#  '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/05_time_series_data_preprocessing/feature_set_1_results/data_chunk_4.parquet',
#  '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/05_time_series_data_preprocessing/feature_set_1_results/data_chunk_5.parquet',
#  '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/05_time_series_data_preprocessing/feature_set_1_results/data_chunk_6.parquet',
#  '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/05_time_series_data_preprocessing/feature_set_1_results/data_chunk_7.parquet']

# %%
# Load and count the total number of unique subject_ids across all 8 patient chunk results
total_unique_subject_ids = 0
for file in successful_patient_chunk_results_files:
    patient_chunk = pd.read_parquet(file)
    unique_subject_ids = patient_chunk['subject_id'].unique()

    total_unique_subject_ids += len(unique_subject_ids)

print("Total number of unique subject_ids across all 8 patient chunks: ", total_unique_subject_ids)
# Out:
# Total number of unique subject_ids across all 8 patient chunks:  4701

# %% [markdown]
# As this is the same for the chunks and the full dataset we can conclude that patients in chunks 8 and 9 do not have any data for the 15 itemids in the last 6 hours before extubation.
#
# As such we can treat the full dataset as the final dataset to carry forward for further preprocessing.

# %%
# Count the number of unique itemids in the full dataset
unique_itemids = full_data['itemid'].unique()
print("Number of unique itemids in the full dataset: ", len(unique_itemids))
# Out:
# Number of unique itemids in the full dataset:  15

# %%
# Count the number of itemids initally input to be extracted
num_itemids = len(feature_set_1_dynamic)
print("Number of itemids initially input to be extracted: ", num_itemids)
# Out:
# Number of itemids initially input to be extracted:  15

# %% [markdown]
# All itemids have a record but we will need to see how consistently these were measured for when we format the data for our LSTM model.
#
# This will be carried out in the next file.

# %% [markdown]
# **Addendum: Extracting data inclusive of missing valuenum**
#
# We can also extract the full data including missing values that we can impute later.
#
# To do this we need to amend the functions slightly.

# %%
def process_chunk_2_incl_null(chunk, patient_dict, itemid_set, time_window):
    # Filter the columns
    chunk = chunk[['subject_id', 'charttime', 'itemid', 'valuenum']].copy()

    # Drop rows where only itemid is null and NOT valuenum
    chunk = chunk.dropna(subset=['itemid'])

    # Convert subject_id to nullable integer type if necessary
    chunk.loc[:, 'subject_id'] = chunk['subject_id'].astype('Int64')

    # Filter by subject_id
    chunk = chunk[chunk['subject_id'].isin(patient_dict.keys())]

    # Filter by itemid
    chunk = chunk[chunk['itemid'].isin(itemid_set)]

    # Apply the time window filter using the patient_dict
    filtered_rows = []
    for idx, row in chunk.iterrows():
        extubation_time = patient_dict[row['subject_id']]['extubation_starttime']
        if (row['charttime'] >= extubation_time - time_window) and (row['charttime'] <= extubation_time):
            filtered_rows.append(row)

    filtered_df = pd.DataFrame(filtered_rows)
    if not filtered_df.empty:
        filtered_df['extubation_starttime'] = filtered_df['subject_id'].map(lambda x: patient_dict[x]['extubation_starttime'])
        filtered_df['extubation_failure'] = filtered_df['subject_id'].map(lambda x: patient_dict[x]['extubation_failure'])

    return filtered_df

# %%
def extract_patient_data_2_incl_null(patient_df, chartevents_file_path, itemids, time_window):
    # Initialize a list to hold the results
    results = []

    # Define the chunk size
    chunksize = 100000

    # Convert itemids to a set for faster lookup
    itemid_set = set(itemids)

    # Convert patient_df to a dictionary for fast lookups
    patient_dict = patient_df.set_index('subject_id').to_dict('index')

    # # Get the total number of rows in the file
    # total_rows = sum(1 for row in open(chartevents_file_path)) - 1  # Subtract 1 for the header row


    # Track the number of processed rows
    processed_rows = 0

    # Read and process the file in chunks
    for chunk in pd.read_csv(chartevents_file_path, parse_dates=['charttime'], chunksize=chunksize):

      # Process each chunk and filter the data
      filtered_df = process_chunk_2_incl_null(chunk, patient_dict, itemid_set, time_window)

      # Append the filtered data to the results list
      results.append(filtered_df)

      # Update the processed rows count
      processed_rows += len(chunk)

      # Print the progress every 100,000 rows
      if processed_rows % 10000000 == 0:
          print(f"Processed {processed_rows} rows")


    # Concatenate all the results
    result_df = pd.concat(results, ignore_index=True)

    # Check if result_df is empty and handle it accordingly
    if result_df.empty:
        print("Warning: No data found for the given criteria.")
        return pd.DataFrame(), pd.DataFrame() # Return empty DataFrames


    # Extract the data and labels
    data = result_df[['subject_id', 'charttime', 'itemid', 'valuenum']]
    labels = result_df[['subject_id','extubation_failure']]

    return data, labels

# %%
# Run the original function on the entire dataset and save the results
full_data_incl_null, full_labels_incl_null = extract_patient_data_2_incl_null(patient_df, chartevents_path, feature_set_1_dynamic, time_window_hours)
full_data.to_parquet(f'{output_dir}/full_data_incl_null.parquet')
full_labels.to_parquet(f'{output_dir}/full_labels_incl_null.parquet')

print(f"Saved all data and labels to {output_dir}")
# Out:
# Processed 10000000 rows
# Processed 20000000 rows
# Processed 30000000 rows
# Processed 40000000 rows
# Processed 50000000 rows
# Processed 60000000 rows
# Processed 70000000 rows
# Processed 80000000 rows
# Processed 90000000 rows
# Processed 100000000 rows
# Processed 110000000 rows
# Processed 120000000 rows
# Processed 130000000 rows
# Processed 140000000 rows
# Processed 150000000 rows
# Processed 160000000 rows
# Processed 170000000 rows
# Processed 180000000 rows
# Processed 190000000 rows
# Processed 200000000 rows
# Processed 210000000 rows
# Processed 220000000 rows
# Processed 230000000 rows
# Processed 240000000 rows
# Saved all data and labels to /content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/05_time_series_data_preprocessing/feature_set_1_results

# %%
# Count the number of patients in this full dataset without nas
unique_subject_ids = full_data_incl_null['subject_id'].unique()
print("Number of unique subject_ids in the full data including nulls: ", len(unique_subject_ids))
# Out:
# Number of unique subject_ids in the full data including nulls:  4701

# %% [markdown]
# The same number of patients are present in this dataset as expected.

# %%
# Count the number of rows in this dataset to see how much timeseries data we have
num_rows = full_data_incl_null.shape[0]
print("Number of rows in the full data including nulls: ", num_rows)
# Out:
# Number of rows in the full data including nulls:  117438

# %%
# Calculate the difference between the number of rows with and without nulls
diff = num_rows - full_data.shape[0]
print("Difference between the number of rows with and without nulls: ", diff)
# Out:
# Difference between the number of rows with and without nulls:  799

# %% [markdown]
# Let's see which itemids are contributing to these null values

# %%
# For each itemid count the number of null values
null_counts = full_data_incl_null.groupby('itemid')['valuenum'].apply(lambda x: x.isnull().sum()).reset_index()
null_counts.columns = ['itemid', 'null_count']
null_counts
# Out:
#       itemid  null_count
# 0   220210.0           0
# 1   220224.0           0
# 2   220228.0           0
# 3   220235.0           0
# 4   220277.0           0
# 5   223830.0           0
# 6   223835.0           0
# 7   223849.0         799
# 8   224419.0           0
# 9   224685.0           0
# 10  224686.0           0
# 11  224687.0           0
# 12  224695.0           0
# 13  224696.0           0
# 14  228640.0           0

# %% [markdown]
# It seems to be just one item id (223849) that is contributing to the null values.
#
# Let's identify this item ID so we can consider this in future preprocessing.

# %%
# Load the d_items data frame
d_items_file = '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/mimic-iv-2.2-raw-data/icu/d_items.csv'
d_items_df = pd.read_csv(d_items_file)
d_items_df.head()
# Out:
#    itemid                    label        abbreviation         linksto  \
# 0  220001             Problem List        Problem List     chartevents
# 1  220003       ICU Admission date  ICU Admission date  datetimeevents
# 2  220045               Heart Rate                  HR     chartevents
# 3  220046  Heart rate Alarm - High     HR Alarm - High     chartevents
# 4  220047   Heart Rate Alarm - Low      HR Alarm - Low     chartevents
#
#               category unitname     param_type  lownormalvalue  \
# 0              General      NaN           Text             NaN
# 1                  ADT      NaN  Date and time             NaN
# 2  Routine Vital Signs      bpm        Numeric             NaN
# 3               Alarms      bpm        Numeric             NaN
# 4               Alarms      bpm        Numeric             NaN
#
#    highnormalvalue
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
# Match the itemid 223849 to the corresponding label in d_items and return the label to identify
itemid_223849 = d_items_df[d_items_df['itemid'] == 223849]['label']
print(itemid_223849)
# Out:
# 391    Ventilator Mode
# Name: label, dtype: object

# %% [markdown]
# Ventilator mode has a significant number of null values which will need to be handled in later preprocessing.

# %% [markdown]
# As a final check, we can ensure that the item_ids in the full_data have no null values.

# %%
# Check that the itemids in full_data have no null values
null_counts = full_data.groupby('itemid')['valuenum'].apply(lambda x: x.isnull().sum()).reset_index()
null_counts.columns = ['itemid', 'null_count']
null_counts
# Out:
#       itemid  null_count
# 0   220210.0           0
# 1   220224.0           0
# 2   220228.0           0
# 3   220235.0           0
# 4   220277.0           0
# 5   223830.0           0
# 6   223835.0           0
# 7   223849.0           0
# 8   224419.0           0
# 9   224685.0           0
# 10  224686.0           0
# 11  224687.0           0
# 12  224695.0           0
# 13  224696.0           0
# 14  228640.0           0

# %% [markdown]
# We can now proceed with pre-processing the data for feature set 1 for model input.

# %% [markdown]
# **Analyse the class split in the data**

# %%
import pandas as pd

# %%
data_path = '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/05_time_series_data_extraction/feature_set_1_results/full_data_feature_set_1/full_data_incl_null.parquet'

data = pd.read_parquet(data_path)
data.head()
# Out:
#    subject_id           charttime    itemid  valuenum
# 0    10001884 2131-01-12 15:00:00  223835.0      40.0
# 1    10001884 2131-01-12 15:00:00  224685.0     284.0
# 2    10001884 2131-01-12 15:00:00  224686.0     284.0
# 3    10001884 2131-01-12 15:00:00  224687.0       6.1
# 4    10001884 2131-01-12 15:00:00  224695.0      17.0

# %%
data['subject_id'].nunique()
# Out:
# 4701

# %%
labels_path = '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/05_time_series_data_extraction/feature_set_1_results/full_data_feature_set_1/full_labels_incl_null.parquet'

labels = pd.read_parquet(labels_path)
labels.head()
# Out:
#    subject_id  extubation_failure
# 0    10001884                   1
# 1    10001884                   1
# 2    10001884                   1
# 3    10001884                   1
# 4    10001884                   1

# %%
# Drop duplicates of subject ifd
labels = labels.drop_duplicates(subset=['subject_id'])
labels.head()
# Out:
#      subject_id  extubation_failure
# 0      10001884                   1
# 30     10002428                   0
# 66     10004235                   1
# 91     10004720                   1
# 115    10004733                   0

# %%
labels['subject_id'].nunique()
# Out:
# 4701

# %%
# Give the % of 1 in extubation failure
labels['extubation_failure'].value_counts(normalize=True) * 100
# Out:
# extubation_failure
# 0    67.155924
# 1    32.844076
# Name: proportion, dtype: float64
