# %% [markdown]
# # **LSTM Fused Decision**
#
# We will create a Fused Decision machine learning architecture to try and best process our data.
#
# Previously, the LSTM model had quite poor performance despite all techniques being employed to prevent overfitting, data imbalance and full hyperparameter tuning and creoss-validation. The data was even re-processed to ensure that there was no data leakage and the train and test set had comparable levels of synthetic data.
#
# Now we will try a slightly different technique whereby we adapt more to the data we have available. We noticed that the sampling frequency of features differ in the 6 hour time window with some features sampled much less than others. Previously, we would resample all data to the same 30 min interval but for features that were rarely observed, this would require a lot of data to be synthesised, meaning the model was likely learning from synthetic patterns which can lead to overfitting.
#
# Now, the data has been processed such that features have been split into subsets based on similar sampling frequencies and each subset has been resampled to a bespoke rate that is better representative of the original data i.e. features that have fewer observations in the original data will be resampeled at a lower rate. This still required a balance between data synthesis and data density as the models require sufficient data to be trained on.
#
# As such, we will create a fused decision system whereby each subset is passed through a separate LSTM model that will be trained to learn from that data and the outputs of each combined to create a fused binary classficaition decision.
#
# In order to limit the model learning from synthetic patterns, where there was no original data for a patient for a specific feature, the value for that has been set to NaN. We will then create a mask around these features that prevents the model learning from this missing data.
#
# The inherent architecture will be eseentially the same as the LSTM employed previously but now with a few extra layers.
#
# It should be noted that not all patients are represented in each subset as some patients had no data for those features and to limit data synthesis we chose not to create data from scratch. It does mean that the lower frequency models will not be learning from as many patients but this is done to avoid creating sythetic data patterns.
#
# **Hyperparameter tuning**
#
# A decision needed to be made regarding whether to have local hyperparameters for each layer or to have a global set of hyperparameters. While having individual hyperparameters for each model would likley help produce the best possible performance, it would require significant computational resources which are not available in this project. As such, we will use a global set of hyperparameters and tune them using Bayesian Optimisation as done previously, noting that future work would likely benefit from more detailed hyperparameter options.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.model_selection import train_test_split
import itertools
import pickle
import json

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-3.6.1-py3-none-any.whl.metadata (17 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.2-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.32)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.5)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.5-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)
# Downloading optuna-3.6.1-py3-none-any.whl (380 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.1/380.1 kB 8.1 MB/s eta 0:00:00
# Downloading alembic-1.13.2-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.0/233.0 kB 25.3 MB/s eta 0:00:00
# Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.5-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 8.1 MB/s eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.5 alembic-1.13.2 colorlog-6.8.2 optuna-3.6.1

# %%
import optuna

# %% [markdown]
# ### **Functions to prepare the dataset**

# %% [markdown]
# # **Load the data**

# %%
# Load the sequences and labels
low_train_seq_path = '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/08_model_input_data/02_feature_set_2/01_lstm_data/dynamic_data/low_frequency_train_sequences_v1.npy'
medium_train_seq_path = '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/08_model_input_data/02_feature_set_2/01_lstm_data/dynamic_data/medium_frequency_train_sequences_v1.npy'
high_train_seq_path = '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/08_model_input_data/02_feature_set_2/01_lstm_data/dynamic_data/high_frequency_train_sequences_v1.npy'
labels_train_path = '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/08_model_input_data/02_feature_set_2/01_lstm_data/dynamic_data/low_frequency_train_labels_v1.npy'

low_freq_train_sequences = np.load(low_train_seq_path, allow_pickle=True).astype(np.float32)
medium_freq_train_sequences = np.load(medium_train_seq_path, allow_pickle=True).astype(np.float32)
high_freq_train_sequences = np.load(high_train_seq_path, allow_pickle=True).astype(np.float32)
labels_train = np.load(labels_train_path, allow_pickle=True).astype(np.float32)

print("Low frequency sequences shape:", low_freq_train_sequences.shape)
print("Medium frequency sequences shape:", medium_freq_train_sequences.shape)
print("High frequency sequences shape:", high_freq_train_sequences.shape)
print("Labels shape:", labels_train.shape)
# Out:
# Low frequency sequences shape: (3760, 4, 3)
# Medium frequency sequences shape: (3760, 7, 10)
# High frequency sequences shape: (3760, 13, 6)
# Labels shape: (3760,)

# %% [markdown]
# # **Experiment 1**
#
# We can now commence hyperparameter tuning using Bayesian Optimisation.

# %%
class MultiInputTimeSeriesDataset(Dataset):
    """
    A custom PyTorch Dataset class for time series data with multiple input sequences.

    Args:
        low_sequences (numpy.ndarray): Low-frequency sequences.
        medium_sequences (numpy.ndarray): Medium-frequency sequences.
        high_sequences (numpy.ndarray): High-frequency sequences.
        labels (numpy.ndarray): Corresponding labels for the sequences.

    Methods:
        __len__(): Returns the number of samples in the dataset.
        __getitem__(idx): Returns a dictionary containing the sequences and label for the given index.
    """
    def __init__(self, low_sequences, medium_sequences, high_sequences, labels):
        self.low_sequences = low_sequences
        self.medium_sequences = medium_sequences
        self.high_sequences = high_sequences
        self.labels = labels

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return {
            'low_freq_sequence': torch.tensor(self.low_sequences[idx], dtype=torch.float32),
            'medium_freq_sequence': torch.tensor(self.medium_sequences[idx], dtype=torch.float32),
            'high_freq_sequence': torch.tensor(self.high_sequences[idx], dtype=torch.float32),
            'label': torch.tensor(self.labels[idx], dtype=torch.float32)
        }

# %%
def create_multi_input_data_loaders(low_freq_train_sequences,
                                    medium_freq_train_sequences,
                                    high_freq_train_sequences,
                                    train_labels,
                                    low_freq_val_sequences,
                                    medium_freq_val_sequences,
                                    high_freq_val_sequences,
                                    val_labels,
                                    low_freq_test_sequences,
                                    medium_freq_test_sequences,
                                    high_freq_test_sequences,
                                    test_labels,
                                    batch_size):
    """
    Creates PyTorch DataLoader objects for training, validation, and test sets with multiple inputs.

    Args:
        low_freq_train_sequences, medium_freq_train_sequences, high_freq_train_sequences: Training sequences.
        train_labels: Training labels for all sequences.
        low_freq_val_sequences, medium_freq_val_sequences, high_freq_val_sequences: Validation sequences.
        val_labels: Validation labels for all sequences.
        low_freq_test_sequences, medium_freq_test_sequences, high_freq_test_sequences: Test sequences.
        test_labels: Test labels for all sequences.
        batch_size: Batch size for the DataLoaders.

    Returns:
        tuple: A tuple containing the train, validation, and test DataLoaders.
    """
    train_dataset = MultiInputTimeSeriesDataset(low_freq_train_sequences, medium_freq_train_sequences, high_freq_train_sequences, train_labels)
    val_dataset = MultiInputTimeSeriesDataset(low_freq_val_sequences, medium_freq_val_sequences, high_freq_val_sequences, val_labels)
    test_dataset = MultiInputTimeSeriesDataset(low_freq_test_sequences, medium_freq_test_sequences, high_freq_test_sequences, test_labels)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    return train_loader, val_loader, test_loader

# %% [markdown]
# **SMOTE and RandomUnderSampler do not seem to be able to handle NaNs we will handle under and oversampling manually.**

# %%
import numpy as np
from sklearn.utils import resample

def undersample_data(low_sequences, labels, medium_sequences, high_sequences):
    """
    Undersamples the data by randomly reducing the majority class samples.

    Args:
        low_sequences (np.ndarray): Low frequency sequences.
        labels (np.ndarray): Corresponding labels for sequences.
        medium_sequences (np.ndarray): Medium frequency sequences.
        high_sequences (np.ndarray): High frequency sequences.

    Returns:
        tuple: Undersampled sequences and labels for low, medium, and high frequency data.
    """
    # Identify the minority and majority classes
    minority_class = min(set(labels), key=list(labels).count)
    majority_class = max(set(labels), key=list(labels).count)

    # Split the data into minority and majority classes
    minority_indices = np.where(labels == minority_class)[0]
    majority_indices = np.where(labels == majority_class)[0]

    # Randomly undersample the majority class
    undersampled_majority_indices = resample(majority_indices, replace=False, n_samples=len(minority_indices), random_state=42)

    # Combine minority and undersampled majority indices
    undersampled_indices = np.concatenate([minority_indices, undersampled_majority_indices])

    # Get the undersampled sequences and labels
    low_sequences_resampled = low_sequences[undersampled_indices]
    labels_resampled = labels[undersampled_indices]
    medium_sequences_resampled = medium_sequences[undersampled_indices]
    high_sequences_resampled = high_sequences[undersampled_indices]

    return low_sequences_resampled, labels_resampled, medium_sequences_resampled, high_sequences_resampled

def oversample_data(low_sequences, labels, medium_sequences, high_sequences):
    """
    Oversamples the data by duplicating the minority class samples.

    Args:
        low_sequences (np.ndarray): Low frequency sequences.
        labels (np.ndarray): Corresponding labels for sequences.
        medium_sequences (np.ndarray): Medium frequency sequences.
        high_sequences (np.ndarray): High frequency sequences.

    Returns:
        tuple: Oversampled sequences and labels for low, medium, and high frequency data.
    """
    # Identify the minority and majority classes
    minority_class = min(set(labels), key=list(labels).count)
    majority_class = max(set(labels), key=list(labels).count)

    # Split the data into minority and majority classes
    minority_indices = np.where(labels == minority_class)[0]
    majority_indices = np.where(labels == majority_class)[0]

    # Randomly oversample the minority class
    oversampled_minority_indices = resample(minority_indices, replace=True, n_samples=len(majority_indices), random_state=42)

    # Combine majority and oversampled minority indices
    oversampled_indices = np.concatenate([majority_indices, oversampled_minority_indices])

    # Get the oversampled sequences and labels
    low_sequences_resampled = low_sequences[oversampled_indices]
    labels_resampled = labels[oversampled_indices]
    medium_sequences_resampled = medium_sequences[oversampled_indices]
    high_sequences_resampled = high_sequences[oversampled_indices]

    return low_sequences_resampled, labels_resampled, medium_sequences_resampled, high_sequences_resampled

# %%
class FusedLSTMModel(nn.Module):
    """
    A fused LSTM model for sequence classification and handles masking.

    """
    def __init__(self, low_input_dim, medium_input_dim, high_input_dim, hidden_dim, layer_dim, output_dim, dropout_prob):
      super(FusedLSTMModel, self).__init__()
      self.hidden_dim = hidden_dim
      self.layer_dim = layer_dim

      if layer_dim == 1:
        dropout_prob = 0.0

      # Define the LSTM layers
      self.low_lstm = nn.LSTM(low_input_dim, hidden_dim, layer_dim, batch_first=True, dropout=dropout_prob)
      self.medium_lstm = nn.LSTM(medium_input_dim, hidden_dim, layer_dim, batch_first=True, dropout=dropout_prob)
      self.high_lstm = nn.LSTM(high_input_dim, hidden_dim, layer_dim, batch_first=True, dropout=dropout_prob)

      # Define the fully connected layer to fuse outputs
      self.fc = nn.Linear(hidden_dim * 3, output_dim)

      # Define sigmoid for binary classification
      self.sigmoid = nn.Sigmoid()

    def forward(self, low_x, medium_x, high_x):
      # Create masks and handle NaNs
      low_mask = ~low_x.isnan()
      medium_mask = ~medium_x.isnan()
      high_mask = ~high_x.isnan()

      # Set NaNs to zeroes to be passed through model
      low_x = torch.where(low_mask, low_x, torch.zeros_like(low_x))
      medium_x = torch.where(medium_mask, medium_x, torch.zeros_like(medium_x))
      high_x = torch.where(high_mask, high_x, torch.zeros_like(high_x))

      # Initial hidden and cell states
      h0_low = torch.zeros(self.layer_dim, low_x.size(0), self.hidden_dim).to(low_x.device)
      c0_low = torch.zeros(self.layer_dim, low_x.size(0), self.hidden_dim).to(low_x.device)

      h0_medium = torch.zeros(self.layer_dim, medium_x.size(0), self.hidden_dim).to(medium_x.device)
      c0_medium = torch.zeros(self.layer_dim, medium_x.size(0), self.hidden_dim).to(medium_x.device)

      h0_high = torch.zeros(self.layer_dim, high_x.size(0), self.hidden_dim).to(high_x.device)
      c0_high = torch.zeros(self.layer_dim, high_x.size(0), self.hidden_dim).to(high_x.device)

      # Forward pass through LSTM layers
      low_out, _ = self.low_lstm(low_x, (h0_low, c0_low))
      medium_out, _ = self.medium_lstm(medium_x, (h0_medium, c0_medium))
      high_out, _ = self.high_lstm(high_x, (h0_high, c0_high))

      # Ensure masks are the same shape as the LSTM outputs
      low_mask = low_mask[:, :, 0].unsqueeze(-1).expand(-1, -1, low_out.shape[-1])
      medium_mask = medium_mask[:, :, 0].unsqueeze(-1).expand(-1, -1, medium_out.shape[-1])
      high_mask = high_mask[:, :, 0].unsqueeze(-1).expand(-1, -1, high_out.shape[-1])

      # Apply masks to the LSTM outputs by zeroing out invalid positions
      low_out = low_out * low_mask.float()
      medium_out = medium_out * medium_mask.float()
      high_out = high_out * high_mask.float()

      # Get the last valid output for each sequence
      def get_last_valid_output(output, mask):
        last_valid_index = mask.sum(dim=1) - 1
        last_valid_index = torch.clamp(last_valid_index, min=0)  # Ensure no negative indices
        last_valid_index = last_valid_index.unsqueeze(1).unsqueeze(2).expand(-1, 1, output.size(-1))
        return output.gather(1, last_valid_index).squeeze(1)

      low_out_last = get_last_valid_output(low_out, low_mask[:, :, 0])
      medium_out_last = get_last_valid_output(medium_out, medium_mask[:, :, 0])
      high_out_last = get_last_valid_output(high_out, high_mask[:, :, 0])

      # Concatenate the outputs
      out = torch.cat((low_out_last, medium_out_last, high_out_last), dim=1)

      # Apply the fully connected layer to fuse outputs
      out = self.fc(out)

      # Apply sigmoid for binary classification
      out = self.sigmoid(out)

      return out

# %%
def train_fused_model_with_early_stopping_logging(model, train_loader, val_loader, criterion, optimizer, num_epochs, device, patience, output_path):
    """
    Train the fused LSTM model with early stopping and logging.

    Parameters:
    model (nn.Module): The fused LSTM model to be trained.
    train_loader (DataLoader): DataLoader for the training data.
    val_loader (DataLoader): DataLoader for the validation data.
    criterion (nn.Module): Loss function.
    optimizer (torch.optim.Optimizer): Optimizer.
    num_epochs (int): Number of epochs to train the model.
    device (torch.device): Device to run the model on (CPU or GPU).
    patience (int): Number of epochs to wait for improvement before stopping early.
    output_path (str): Path to save the best model checkpoint.

    Returns:
    model (nn.Module): The trained LSTM model.
    train_losses (list): List of training losses per epoch.
    val_losses (list): List of validation losses per epoch.
    val_aucs (list): List of validation AUC scores per epoch.
    """
    model.to(device)
    best_model_wts = model.state_dict()
    best_auc = 0.0

    early_stopping = EarlyStopping(output_path, patience=patience, min_delta=0)

    train_losses = []
    val_losses = []
    val_aucs = []

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for data in train_loader:
            low_freq_sequences = data['low_freq_sequence'].to(device)
            medium_freq_sequences = data['medium_freq_sequence'].to(device)
            high_freq_sequences = data['high_freq_sequence'].to(device)
            labels = data['label'].to(device).view(-1, 1)

            optimizer.zero_grad()
            outputs = model(low_freq_sequences, medium_freq_sequences, high_freq_sequences)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * low_freq_sequences.size(0)

        epoch_loss = running_loss / len(train_loader.dataset)
        train_losses.append(epoch_loss)

        model.eval()
        val_running_loss = 0.0
        val_outputs = []
        val_labels = []

        with torch.no_grad():
            for data in val_loader:
                low_freq_sequences = data['low_freq_sequence'].to(device)
                medium_freq_sequences = data['medium_freq_sequence'].to(device)
                high_freq_sequences = data['high_freq_sequence'].to(device)
                labels = data['label'].to(device).view(-1, 1)

                outputs = model(low_freq_sequences, medium_freq_sequences, high_freq_sequences)

                loss = criterion(outputs, labels)
                val_running_loss += loss.item() * low_freq_sequences.size(0)

                val_outputs.extend(outputs.cpu().numpy())
                val_labels.extend(labels.cpu().numpy())

        val_loss = val_running_loss / len(val_loader.dataset)
        val_losses.append(val_loss)

        val_auc = roc_auc_score(val_labels, val_outputs)
        val_aucs.append(val_auc)

        early_stopping(val_auc, model)

        if val_auc > best_auc:
            best_auc = val_auc
            best_model_wts = model.state_dict()

        print(f'Epoch {epoch}/{num_epochs - 1}, Loss: {epoch_loss:.4f}, Val Loss: {val_loss:.4f}, Val AUC: {val_auc:.4f}')

        if early_stopping.early_stop:
            print("Early stopping")
            break

    model.load_state_dict(best_model_wts)
    return model, train_losses, val_losses, val_aucs

# %%
class EarlyStopping:
    """
    Early stops the training if validation loss doesn't improve after a given patience.

    Args:
        output_path (str): Path to save the best model checkpoint.
        patience (int, optional): How long to wait after last time validation loss improved. Defaults to 5.
        min_delta (float, optional): Minimum change in the monitored quantity to qualify as an improvement. Defaults to 0.
    """
    def __init__(self, output_path, patience=5, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.output_path = output_path

    def __call__(self, val_auc, model):
        """
        Checks the validation AUC and decides whether to stop training.

        Args:
            val_auc (float): Validation AUC score.
            model (torch.nn.Module): The model being trained.
        """
        if self.best_score is None:
            self.best_score = val_auc
            self.save_checkpoint(model)
        elif val_auc < self.best_score + self.min_delta:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = val_auc
            self.save_checkpoint(model)
            self.counter = 0

    def save_checkpoint(self, model):
        """
        Saves the model checkpoint.

        Args:
            model (torch.nn.Module): The model to save.
        """
        torch.save(model.state_dict(), self.output_path)

# %%
def shuffle_data(sequences, labels):
    assert len(sequences) == len(labels)
    p = np.random.permutation(len(sequences))
    return sequences[p], labels[p]

def split_data_into_folds(sequences, labels, num_folds):
    fold_size = len(sequences) // num_folds
    sequences_folds = []
    labels_folds = []
    for i in range(num_folds):
        start_idx = i * fold_size
        if i == num_folds - 1:  # Make sure the last fold includes any remaining data points
            end_idx = len(sequences)
        else:
            end_idx = start_idx + fold_size
        sequences_folds.append(sequences[start_idx:end_idx])
        labels_folds.append(labels[start_idx:end_idx])
    return sequences_folds, labels_folds

# %%
def reset_model(model):
    """
    Reset the parameters of the model to their initial values.

    Parameters:
    model (nn.Module): The model whose parameters need to be reset.
    """
    def reset_parameters(layer):
        if hasattr(layer, 'reset_parameters'):
            layer.reset_parameters()

    # Iterate over each module in the model and reset parameters if possible
    for layer in model.children():
        if isinstance(layer, nn.Module):
            reset_parameters(layer)
            # Recursively reset parameters for any sub-modules
            for sub_layer in layer.children():
                reset_parameters(sub_layer)

# %%
def manual_cross_validation(low_sequences, medium_sequences, high_sequences, labels, hyperparameters, num_folds=5, patience=5, output_path=None):
    """
    Perform manual cross-validation for the fused LSTM model.

    Parameters:
    low_sequences (np.array): Low frequency sequences.
    medium_sequences (np.array): Medium frequency sequences.
    high_sequences (np.array): High frequency sequences.
    labels (np.array): Labels for sequences.
    hyperparameters (list): List of hyperparameter dictionaries to evaluate.
    num_folds (int): Number of folds for cross-validation. Default is 5.
    patience (int): Number of epochs to wait for improvement before stopping early. Default is 5.
    output_path (str): Path to save the best model checkpoint.

    Returns:
    tuple: Best model, best hyperparameters, best AUC score.
    """
    def shuffle_data(sequences, labels):
        assert len(sequences) == len(labels)
        p = np.random.permutation(len(sequences))
        return sequences[p], labels[p]

    def split_data_into_folds(sequences, labels, num_folds):
        fold_size = len(sequences) // num_folds
        sequences_folds = []
        labels_folds = []
        for i in range(num_folds):
            start_idx = i * fold_size
            if i == num_folds - 1:  # Make sure the last fold includes any remaining data points
                end_idx = len(sequences)
            else:
                end_idx = start_idx + fold_size
            sequences_folds.append(sequences[start_idx:end_idx])
            labels_folds.append(labels[start_idx:end_idx])
        return sequences_folds, labels_folds

    # Shuffle and split the data into folds
    low_sequences, labels = shuffle_data(low_sequences, labels)
    medium_sequences, _ = shuffle_data(medium_sequences, labels)
    high_sequences, _ = shuffle_data(high_sequences, labels)

    low_sequences_folds, labels_folds = split_data_into_folds(low_sequences, labels, num_folds)
    medium_sequences_folds, _ = split_data_into_folds(medium_sequences, labels, num_folds)
    high_sequences_folds, _ = split_data_into_folds(high_sequences, labels, num_folds)

    best_auc = 0.0
    best_model = None
    best_hyperparams = None

    best_train_losses = None
    best_val_losses = None
    best_val_aucs = None

    for i in range(num_folds):
        # Separate into train and validation sets
        val_low_sequences = low_sequences_folds[i]
        val_labels = labels_folds[i]
        train_low_sequences = np.concatenate([low_sequences_folds[j] for j in range(num_folds) if j != i])
        train_labels = np.concatenate([labels_folds[j] for j in range(num_folds) if j != i])

        val_medium_sequences = medium_sequences_folds[i]
        train_medium_sequences = np.concatenate([medium_sequences_folds[j] for j in range(num_folds) if j != i])

        val_high_sequences = high_sequences_folds[i]
        train_high_sequences = np.concatenate([high_sequences_folds[j] for j in range(num_folds) if j != i])

        for params in hyperparameters:
            # Handle sampling methods
            if params['sampling_method'] == 'undersample':
                train_low_sequences_resampled, train_labels_resampled, train_medium_sequences_resampled, train_high_sequences_resampled = undersample_data(
                    train_low_sequences, train_labels, train_medium_sequences, train_high_sequences
                )
            elif params['sampling_method'] == 'oversample':
                train_low_sequences_resampled, train_labels_resampled, train_medium_sequences_resampled, train_high_sequences_resampled = oversample_data(
                    train_low_sequences, train_labels, train_medium_sequences, train_high_sequences
                )
            else:
                train_low_sequences_resampled, train_labels_resampled = train_low_sequences, train_labels
                train_medium_sequences_resampled, train_high_sequences_resampled = train_medium_sequences, train_high_sequences

            # Create data loaders for each subset using the provided function
            train_loader, val_loader, _ = create_multi_input_data_loaders(
                train_low_sequences_resampled,
                train_medium_sequences_resampled,
                train_high_sequences_resampled,
                train_labels_resampled,
                val_low_sequences,
                val_medium_sequences,
                val_high_sequences,
                val_labels,
                val_low_sequences, # Placeholder
                val_medium_sequences, # Placeholder
                val_high_sequences, # Placeholder
                val_labels, # Placeholder
                batch_size=params['batch_size']
            )

            # Determine the input_dim for each subset
            low_input_dim = train_low_sequences.shape[2]
            medium_input_dim = train_medium_sequences.shape[2]
            high_input_dim = train_high_sequences.shape[2]

            # Initialize the model
            model = FusedLSTMModel(
                low_input_dim=low_input_dim,
                medium_input_dim=medium_input_dim,
                high_input_dim=high_input_dim,
                hidden_dim=params['hidden_dim'],
                layer_dim=params['layer_dim'],
                output_dim=1,
                dropout_prob=params['dropout_prob']
            ).to(device)

            # Reset the model parameters
            reset_model(model)

            # Define the loss function
            criterion = nn.BCELoss()

            # Apply weighted loss function if indicated and where sampling is not over or undersampling
            if params['loss'] == 'weighted' and params['sampling_method'] == 'normal':
                pos_weight = torch.tensor([len(train_labels_resampled) / (2.0 * sum(train_labels_resampled))]).to(device)
                criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)  # Create weighted loss

            # Define the optimizer with learning rate and L2 weight decay
            optimizer = optim.Adam(model.parameters(), lr=params['learning_rate'], weight_decay=params['weight_decay'])

            # Train the model with early stopping and logging
            model, train_losses, val_losses, val_aucs = train_fused_model_with_early_stopping_logging(
                model, train_loader, val_loader, criterion, optimizer,
                params['num_epochs'], device, patience, output_path
            )

            # Evaluate the model
            val_outputs = []
            val_labels_list = []
            model.eval()
            with torch.no_grad():
                for data in val_loader:
                    low_freq_sequences = data['low_freq_sequence'].to(device)
                    medium_freq_sequences = data['medium_freq_sequence'].to(device)
                    high_freq_sequences = data['high_freq_sequence'].to(device)
                    labels_batch = data['label'].to(device).view(-1, 1)
                    outputs = model(low_freq_sequences, medium_freq_sequences, high_freq_sequences)

                    val_outputs.extend(outputs.cpu().numpy().flatten())
                    val_labels_list.extend(labels_batch.cpu().numpy().flatten())

            val_auc = roc_auc_score(val_labels_list, val_outputs)
            if val_auc > best_auc:
                best_auc = val_auc
                best_model = model
                best_hyperparams = params
                best_train_losses = train_losses
                best_val_losses = val_losses
                best_val_aucs = val_aucs

            print(f"Params: {params}, Val AUC: {val_auc:.4f}")

    # Plot training and validation loss and AUC for the best model
    if best_train_losses and best_val_losses and best_val_aucs:
        epochs = range(1, len(best_train_losses) + 1)
        plt.figure(figsize=(16, 6))

        # Plot training and validation loss
        plt.subplot(1, 2, 1)
        plt.plot(epochs, best_train_losses, 'b-', label='Training loss')
        plt.plot(epochs, best_val_losses, 'r-', label='Validation loss')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.legend()

        # Plot validation AUC
        plt.subplot(1, 2, 2)
        plt.plot(epochs, best_val_aucs, 'g-', label='Validation AUC')
        plt.xlabel('Epochs')
        plt.ylabel('AUC')
        plt.legend()

        plt.tight_layout()
        plt.show()

    return best_model, best_hyperparams, best_auc

# %% [markdown]
# **Load the data**

# %% [markdown]
# **Define parameter grid and objective function**

# %%
param_grid = {
    'hidden_dim': [32, 64, 128, 256, 512],
    'layer_dim': [1, 2, 3, 4], # In line with Zeng et al.
    'dropout_prob': [0.0, 0.25, 0.5, 0.75], # In line with Zeng et al.
    'learning_rate': [0.01, 0.001, 0.0001, 0.00001],
    'batch_size': [16, 32, 64, 128],
    'num_epochs': [10, 20, 30, 40, 50],
    'sampling_method': ['normal', 'undersample', 'oversample'],
    'loss': ['normal', 'weighted'],
    'weight_decay': [0.00001, 0.0001, 0.001, 0.01]
}

param_combinations = list(itertools.product(*param_grid.values()))

param_combinations = [
    dict(zip(param_grid.keys(), combination))
    for combination in param_combinations
]

print(f"Number of parameter combinations: {len(param_combinations)}")
# Out:
# Number of parameter combinations: 153600

# %%
def objective_wrapper(low_train_sequences, medium_train_sequences, high_train_sequences, train_labels, hyperparameter_grid):
    """
    Wrapper function for the Optuna objective.

    Parameters:
    low_train_sequences (np.array): Low frequency training sequences.
    medium_train_sequences (np.array): Medium frequency training sequences.
    high_train_sequences (np.array): High frequency training sequences.
    train_labels (np.array): Labels for training sequences.
    hyperparameter_grid (dict): Dictionary containing hyperparameters and their possible values.

    Returns:
    function: Optuna objective function.
    """
    def objective(trial):
        hidden_dim = trial.suggest_categorical('hidden_dim', hyperparameter_grid['hidden_dim'])
        layer_dim = trial.suggest_categorical('layer_dim', hyperparameter_grid['layer_dim'])
        dropout_prob = trial.suggest_categorical('dropout_prob', hyperparameter_grid['dropout_prob'])
        learning_rate = trial.suggest_categorical('learning_rate', hyperparameter_grid['learning_rate'])
        batch_size = trial.suggest_categorical('batch_size', hyperparameter_grid['batch_size'])
        num_epochs = trial.suggest_categorical('num_epochs', hyperparameter_grid['num_epochs'])
        sampling_method = trial.suggest_categorical('sampling_method', hyperparameter_grid['sampling_method'])
        loss = trial.suggest_categorical('loss', hyperparameter_grid['loss'])
        weight_decay = trial.suggest_categorical('weight_decay', hyperparameter_grid['weight_decay'])

        # Check if weighted loss is used with undersampling or oversampling and skip if so
        if loss == 'weighted' and sampling_method != 'normal':
            raise optuna.TrialPruned()

        hyperparameters = {
            'hidden_dim': hidden_dim,
            'layer_dim': layer_dim,
            'dropout_prob': dropout_prob,
            'learning_rate': learning_rate,
            'batch_size': batch_size,
            'num_epochs': num_epochs,
            'sampling_method': sampling_method,
            'loss': loss,
            'weight_decay': weight_decay
        }

        # Run cross-validation
        best_model, best_hyperparams, best_auc = manual_cross_validation(
            low_train_sequences,
            medium_train_sequences,
            high_train_sequences,
            train_labels,
            [hyperparameters],
            num_folds=5,
            patience=5,
            output_path="None"
        )

        # Optuna minimizes the objective, so return the negative AUC
        return -best_auc

    return objective

# %% [markdown]
# ### **Run Bayesian Optimisation**

# %%
study_exp_1 = optuna.create_study(direction='minimize')
study_exp_1.optimize(objective_wrapper(low_freq_train_sequences, medium_freq_train_sequences, high_freq_train_sequences, labels_train, param_grid), n_trials=100)

best_params = study_exp_1.best_params
print("Best hyperparameters:", best_params)

best_score = study_exp_1.best_value
print("Best score:", best_score)

# Save the best hyperparameters
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
best_params = {'hidden_dim': 512, 'layer_dim': 2, 'dropout_prob': 0.25, 'learning_rate': 0.0001, 'batch_size': 16, 'num_epochs': 50, 'sampling_method': 'oversample', 'loss': 'normal', 'weight_decay': 1e-05}

# %% [markdown]
# ### **Train the final model**

# %%
# Load the test sequences
low_test_seq_path = '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/08_model_input_data/02_feature_set_2/01_lstm_data/dynamic_data/low_frequency_test_sequences_v1.npy'
medium_test_seq_path = '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/08_model_input_data/02_feature_set_2/01_lstm_data/dynamic_data/medium_frequency_test_sequences_v1.npy'
high_test_seq_path = '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/08_model_input_data/02_feature_set_2/01_lstm_data/dynamic_data/high_frequency_test_sequences_v1.npy'

# Load the test labels
test_labels_path = '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/08_model_input_data/02_feature_set_2/01_lstm_data/dynamic_data/low_frequency_test_labels_v1.npy'

low_freq_test_sequences = np.load(low_test_seq_path, allow_pickle=True).astype(np.float32)
medium_freq_test_sequences = np.load(medium_test_seq_path, allow_pickle=True).astype(np.float32)
high_freq_test_sequences = np.load(high_test_seq_path, allow_pickle=True).astype(np.float32)

labels_test = np.load(test_labels_path, allow_pickle=True).astype(np.float32)

print(f'Low frequency test sequences shape: {low_freq_test_sequences.shape}')
print(f'Medium frequency test sequences shape: {medium_freq_test_sequences.shape}')
print(f'High frequency test sequences shape: {high_freq_test_sequences.shape}')
print(f'Test labels shape: {labels_test.shape}')
# Out:
# Low frequency test sequences shape: (941, 4, 3)
# Medium frequency test sequences shape: (941, 7, 10)
# High frequency test sequences shape: (941, 13, 6)
# Test labels shape: (941,)

# %%
final_model = FusedLSTMModel(
    low_input_dim=low_freq_train_sequences.shape[2],
    medium_input_dim=medium_freq_train_sequences.shape[2],
    high_input_dim=high_freq_train_sequences.shape[2],
    hidden_dim=best_params['hidden_dim'],
    layer_dim=best_params['layer_dim'],
    output_dim=1,
    dropout_prob=best_params['dropout_prob']
).to(device)

final_model
# Out:
# FusedLSTMModel(
#   (low_lstm): LSTM(3, 512, num_layers=2, batch_first=True, dropout=0.25)
#   (medium_lstm): LSTM(10, 512, num_layers=2, batch_first=True, dropout=0.25)
#   (high_lstm): LSTM(6, 512, num_layers=2, batch_first=True, dropout=0.25)
#   (fc): Linear(in_features=1536, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )

# %%
# Handle sampling methods
if best_params['sampling_method'] == 'oversample':
  train_low_sequences_resampled, train_labels_resampled, train_medium_sequences_resampled, train_high_sequences_resampled = oversample_data(
      low_freq_train_sequences, labels_train,
      medium_freq_train_sequences, high_freq_train_sequences)
elif best_params['sampling_method'] == 'undersample':
  train_low_sequences_resampled, train_labels_resampled, train_medium_sequences_resampled, train_high_sequences_resampled = undersample_data(
      low_freq_train_sequences, labels_train,
      medium_freq_train_sequences, high_freq_train_sequences)
else:
  train_low_sequences_resampled, train_labels_resampled = low_freq_train_sequences, labels_train
  train_medium_sequences_resampled, train_high_sequences_resampled = medium_freq_train_sequences, high_freq_train_sequences

# Define the loss function
if best_params['loss'] == 'weighted':
  pos_weight = torch.tensor([len(train_labels_resampled) / (2.0 * sum(train_labels_resampled))]).to(device)
  criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)
else:
  criterion = nn.BCELoss()

# Define the optimizer with learning rate and L2 weight decay
optimizer = optim.Adam(
    final_model.parameters(),
    lr=best_params['learning_rate'],
    weight_decay=best_params['weight_decay']
)

# Define the device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Move the model to the device
final_model = final_model.to(device)

# Create data loaders
train_loader, _ , test_loader = create_multi_input_data_loaders(
    train_low_sequences_resampled,
    train_medium_sequences_resampled,
    train_high_sequences_resampled,
    train_labels_resampled,
    _,
    _,
    _,
    _,
    low_freq_test_sequences,
    medium_freq_test_sequences,
    high_freq_test_sequences,
    labels_test,
    batch_size=best_params['batch_size']
)

# %% [markdown]
# **Train the final model**

# %%
# Train the final model on the whole training set
def train_final_model(model, train_loader, criterion, optimizer, num_epochs, device):
    """
    Train the model with the given parameters.

    Parameters:
    model (nn.Module): The neural network model to be trained.
    train_loader (DataLoader): The DataLoader for the training dataset.
    criterion (nn.Module): The loss function.
    optimizer (torch.optim.Optimizer): The optimizer.
    num_epochs (int): The number of epochs to train the model.
    device (torch.device): The device to train the model on.

    Returns:
    nn.Module: The trained model.
    list: The list of training losses over epochs.
    """
    model.to(device)
    model.train()

    train_losses = []

    for epoch in range(num_epochs):
        running_loss = 0.0

        for data in train_loader:
            # Get the input sequences and labels
            low_freq_sequences = data['low_freq_sequence'].to(device)
            medium_freq_sequences = data['medium_freq_sequence'].to(device)
            high_freq_sequences = data['high_freq_sequence'].to(device)
            labels = data['label'].to(device).view(-1, 1)

            optimizer.zero_grad()
            outputs = model(low_freq_sequences, medium_freq_sequences, high_freq_sequences)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * low_freq_sequences.size(0)

        epoch_loss = running_loss / len(train_loader.dataset)
        train_losses.append(epoch_loss)
        print(f'Epoch {epoch + 1}/{num_epochs}, Loss: {epoch_loss:.4f}')

    return model, train_losses

# %%
reset_model(final_model)

# %%
final_model, train_losses = train_final_model(
    final_model,
    train_loader,
    criterion,
    optimizer,
    num_epochs=best_params['num_epochs'],
    device=device
)
# Out:
# Epoch 1/50, Loss: 0.6879
# Epoch 2/50, Loss: 0.6765
# Epoch 3/50, Loss: 0.6731
# Epoch 4/50, Loss: 0.6691
# Epoch 5/50, Loss: 0.6693
# Epoch 6/50, Loss: 0.6665
# Epoch 7/50, Loss: 0.6651
# Epoch 8/50, Loss: 0.6623
# Epoch 9/50, Loss: 0.6598
# Epoch 10/50, Loss: 0.6590
# Epoch 11/50, Loss: 0.6597
# Epoch 12/50, Loss: 0.6596
# Epoch 13/50, Loss: 0.6576
# Epoch 14/50, Loss: 0.6567
# Epoch 15/50, Loss: 0.6569
# Epoch 16/50, Loss: 0.6540
# Epoch 17/50, Loss: 0.6555
# Epoch 18/50, Loss: 0.6541
# Epoch 19/50, Loss: 0.6535
# Epoch 20/50, Loss: 0.6529
# Epoch 21/50, Loss: 0.6517
# Epoch 22/50, Loss: 0.6546
# Epoch 23/50, Loss: 0.6523
# Epoch 24/50, Loss: 0.6513
# Epoch 25/50, Loss: 0.6516
# Epoch 26/50, Loss: 0.6513
# Epoch 27/50, Loss: 0.6507
# Epoch 28/50, Loss: 0.6501
# Epoch 29/50, Loss: 0.6522
# Epoch 30/50, Loss: 0.6491
# Epoch 31/50, Loss: 0.6500
# Epoch 32/50, Loss: 0.6469
# Epoch 33/50, Loss: 0.6468
# Epoch 34/50, Loss: 0.6473
# Epoch 35/50, Loss: 0.6470
# Epoch 36/50, Loss: 0.6465
# Epoch 37/50, Loss: 0.6459
# Epoch 38/50, Loss: 0.6462
# Epoch 39/50, Loss: 0.6450
# Epoch 40/50, Loss: 0.6458
# Epoch 41/50, Loss: 0.6460
# Epoch 42/50, Loss: 0.6452
# Epoch 43/50, Loss: 0.6456
# Epoch 44/50, Loss: 0.6452
# Epoch 45/50, Loss: 0.6449
# Epoch 46/50, Loss: 0.6435
# Epoch 47/50, Loss: 0.6438
# Epoch 48/50, Loss: 0.6433
# Epoch 49/50, Loss: 0.6408
# Epoch 50/50, Loss: 0.6423

# %%
# Save final model
output_dir = '/content/drive/MyDrive/MSc_Final_Project/03_model_development/02_feature_set_2/01_lstm_fused_decision/dynamic_data/best_models/final_model_v2.pkl'

with open(output_dir, 'wb') as f:
    pickle.dump(final_model, f)

# Save best params
params_path = '/content/drive/MyDrive/MSc_Final_Project/03_model_development/02_feature_set_2/01_lstm_fused_decision/dynamic_data/best_models/best_params_v2.json'

with open(params_path, 'w') as f:
    json.dump(best_params, f)

# %% [markdown]
# ### **Evaluate the final model**

# %%
def evaluate_model(model, test_loader, device):
    """
    Evaluate the model on the test dataset and calculate evaluation metrics.

    Parameters:
    model (nn.Module): The neural network model to be evaluated.
    test_loader (DataLoader): The DataLoader for the test dataset.
    device (torch.device): The device to evaluate the model on.

    Returns:
    tuple: A tuple containing the evaluation metrics (accuracy, precision, recall, f1, roc_auc, specificity).
    """
    model.to(device)
    model.eval()
    test_outputs = []
    test_labels = []

    with torch.no_grad():
        for data in test_loader:
            # Get the input sequences and labels
            low_freq_sequences = data['low_freq_sequence'].to(device)
            medium_freq_sequences = data['medium_freq_sequence'].to(device)
            high_freq_sequences = data['high_freq_sequence'].to(device)
            labels = data['label'].to(device).view(-1, 1)  # Ensure labels have shape [batch_size, 1]

            outputs = model(low_freq_sequences, medium_freq_sequences, high_freq_sequences)
            test_outputs.extend(outputs.cpu().numpy().flatten())
            test_labels.extend(labels.cpu().numpy().flatten())

    test_outputs = np.array(test_outputs)
    test_labels = np.array(test_labels)

    # Calculate various metrics
    accuracy = accuracy_score(test_labels, test_outputs.round())
    precision = precision_score(test_labels, test_outputs.round())
    recall = recall_score(test_labels, test_outputs.round())
    f1 = f1_score(test_labels, test_outputs.round())
    roc_auc = roc_auc_score(test_labels, test_outputs)
    tn, fp, fn, tp = confusion_matrix(test_labels, test_outputs.round()).ravel()
    specificity = tn / (tn + fp)
    sensitivity = recall

    print(f'Accuracy: {accuracy:.4f}')
    print(f'Precision: {precision:.4f}')
    print(f'Recall (Sensitivity): {recall:.4f}')
    print(f'F1 Score: {f1:.4f}')
    print(f'ROC AUC: {roc_auc:.4f}')
    print(f'Specificity: {specificity:.4f}')

    return (accuracy, precision, recall, f1, roc_auc, specificity), test_outputs

# %%
_, outputs = evaluate_model(final_model, test_loader, device)
# Out:
# Accuracy: 0.6259
# Precision: 0.4362
# Recall (Sensitivity): 0.4757
# F1 Score: 0.4551
# ROC AUC: 0.6441
# Specificity: 0.6994

# %%
# Evaluate the final model
_, outputs = evaluate_model(final_model, test_loader, device)
# Out:
# Accuracy: 0.6259
# Precision: 0.4362
# Recall (Sensitivity): 0.4757
# F1 Score: 0.4551
# ROC AUC: 0.6441
# Specificity: 0.6994

# %%
# Load the final model
output_dir = '/content/drive/MyDrive/MSc_Final_Project/03_model_development/02_feature_set_2/01_lstm_fused_decision/dynamic_data/best_models/final_model.pkl'

with open(output_dir, 'rb') as f:
    final_model = pickle.load(f)

# %%
# Save predictions for ensemble method
np.save('/content/drive/MyDrive/MSc_Final_Project/03_model_development/02_feature_set_2/01_lstm_fused_decision/dynamic_data/best_models/predictions_v2.npy', outputs)

# %% [markdown]
# ## **NOTE**
#
# The performance is poor, and resenbles when we did not use feature subsets for feature set 1. It is likely that with more features, the methodology used to split the features into subsets is likely not transferable to feature set 2. A more bespoke feature engineering is required given the greater number of features present.
#
# However, further feature engineering is beyond the scope of this project. The focus was on the most relevant features which was feature set 1 and then replicating the same methodology (engineering and processing) for further feature sets. It seems further work would require more targeted breakdown of features but we have shown in this study an avenue forward towards imporving model performance.

# %%
# Load the trained model
output_dir = '/content/drive/MyDrive/MSc_Final_Project/03_model_development/02_feature_set_2/01_lstm_fused_decision/dynamic_data/best_models/final_model_v2.pkl'

with open(output_dir, 'rb') as f:
    final_model = pickle.load(f)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/storage.py:414: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(io.BytesIO(b))

# %%
final_model
# Out:
# FusedLSTMModel(
#   (low_lstm): LSTM(3, 512, num_layers=2, batch_first=True, dropout=0.25)
#   (medium_lstm): LSTM(10, 512, num_layers=2, batch_first=True, dropout=0.25)
#   (high_lstm): LSTM(6, 512, num_layers=2, batch_first=True, dropout=0.25)
#   (fc): Linear(in_features=1536, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )

# %% [markdown]
# **Calculate the F1 on the minority class**

# %%
def calculate_f1_minority(model, test_loader, device):
    """
    Calculate the F1 score for the minority class.

    Parameters:
    model (nn.Module): Trained LSTM model.
    test_loader (DataLoader): DataLoader for the test data.
    device (torch.device): Device to run the model on (CPU or GPU).

    Returns:
    float: F1 score for the minority class.
    """
    model.to(device)
    model.eval()

    all_labels = []
    all_predictions = []

    with torch.no_grad():
        for data in test_loader:
            low_freq_sequences = data['low_freq_sequence'].to(device)
            medium_freq_sequences = data['medium_freq_sequence'].to(device)
            high_freq_sequences = data['high_freq_sequence'].to(device)
            labels = data['label'].to(device)

            outputs = model(low_freq_sequences, medium_freq_sequences, high_freq_sequences)
            predictions = (outputs >= 0.5).cpu().numpy().astype(int)

            all_labels.extend(labels.cpu().numpy())
            all_predictions.extend(predictions)

    # Calculate F1 score for the minority class (class 1)
    f1_minority = f1_score(all_labels, all_predictions, average='binary', pos_label=1)
    return f1_minority

# %%
calculate_f1_minority(final_model, test_loader, device)
# Out:
# 0.4551083591331269

# %% [markdown]
# The F1 on the extubation failure class is much lower than the simpler LSTM model.
#
# This suggests that the model complexity could lead to over or underfitting. This might be the case as the lower frequency layers had significantly less data to learn from.
#
# Hyperparameter Tuning: The fused model might require different hyperparameters compared to the simpler LSTM. Parameters such as learning rate, batch size, number of layers, dropout rate, and hidden dimensions might need to be adjusted specifically for the fused architecture.
#
# Integration of Multi-Frequency Data: The way different frequency sequences are fused might not be optimal. The model might struggle to effectively combine information from different frequency sequences if they are not properly aligned or if the fusion strategy is not appropriate.

# %% [markdown]
# **Confusion Matrix**
#
# We can see what the confusion matrix looks like for this model.

# %%
def get_model_predictions(model, test_loader, device):
    """
    Get model predictions and true labels from the test data.

    Parameters:
    model (nn.Module): Trained model.
    test_loader (DataLoader): DataLoader for the test data.
    device (torch.device): Device to run the model on (CPU or GPU).

    Returns:
    tuple: A tuple containing true labels, predicted labels, and output scores.
    """
    model.to(device)
    model.eval()

    # Ensure the LSTM weights are compacted
    if hasattr(model, 'lstm'):
        model.lstm.flatten_parameters()

    y_true = []
    y_pred = []
    y_scores = []

    with torch.no_grad():
        for data in test_loader:
            low_freq_test_sequences = data['low_freq_sequence'].to(device)
            medium_freq_test_sequences = data['medium_freq_sequence'].to(device)
            high_freq_test_sequences = data['high_freq_sequence'].to(device)
            labels = data['label'].to(device).view(-1, 1)  # Ensure labels have shape [batch_size, 1]

            outputs = model(low_freq_test_sequences, medium_freq_test_sequences, high_freq_test_sequences)

            preds = (outputs >= 0.5).float()
            y_true.extend(labels.cpu().numpy())
            y_pred.extend(preds.cpu().numpy())
            y_scores.extend(outputs.cpu().numpy())

    return np.array(y_true), np.array(y_pred), np.array(y_scores)

# %%
def plot_confusion_matrix(cm, class_names):
    """
    Plot the confusion matrix using seaborn heatmap.

    Parameters:
    cm (array-like): Confusion matrix.
    class_names (list): List of class names.
    """
    fig, ax = plt.subplots(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix')
    plt.show()

# Define class names
class_names = ['extubation_success', 'extubation_failure']  # Replace with your actual class names if different

# %%
y_true, y_pred, y_scores = get_model_predictions(final_model, test_loader, device)

cm = confusion_matrix(y_true, y_pred)
plot_confusion_matrix(cm, class_names)

# %% [markdown]
# The model predicts all failure classes - highlighting the sensitivity to feature engineering.

# %% [markdown]
# **Classification threshold**
#
# We can see whether there is a better classification threshold than 0.5 which is the standard currently used.

# %%
import numpy as np
import torch
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

def find_best_threshold_and_evaluate(model, test_loader, device):
    """
    Find the best threshold for binary classification based on ROC AUC and calculate evaluation metrics.

    Parameters:
    model (nn.Module): The trained model.
    test_loader (DataLoader): DataLoader for the test data.
    device (torch.device): Device to run the model on (CPU or GPU).

    Returns:
    dict: A dictionary containing the best threshold, ROC AUC, and other evaluation metrics.
    """
    model.eval()  # Set the model to evaluation mode

    all_probs = []
    all_labels = []

    with torch.no_grad():
        for data in test_loader:
            low_freq_sequences = data['low_freq_sequence'].to(device)
            medium_freq_sequences = data['medium_freq_sequence'].to(device)
            high_freq_sequences = data['high_freq_sequence'].to(device)
            labels = data['label'].to(device).view(-1, 1)

            # Get model output (predicted probabilities)
            output = model(low_freq_sequences, medium_freq_sequences, high_freq_sequences)

            # Append predicted probabilities and true labels
            all_probs.extend(output.cpu().numpy().flatten())
            all_labels.extend(labels.cpu().numpy().flatten())

    # Convert lists to numpy arrays
    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels)

    best_threshold = 0.5
    best_metric_value = 0.0

    thresholds = np.arange(0.0, 1.0, 0.01)  # You can change the step size if needed

    for threshold in thresholds:
        preds = (all_probs >= threshold).astype(int)
        metric_value = f1_score(all_labels, preds)

        if metric_value > best_metric_value:
            best_metric_value = metric_value
            best_threshold = threshold

    # Apply the best threshold to get the final predictions
    final_preds = (all_probs >= best_threshold).astype(int)

    # Calculate the final evaluation metrics
    accuracy = accuracy_score(all_labels, final_preds)
    precision = precision_score(all_labels, final_preds)
    recall = recall_score(all_labels, final_preds)
    f1 = f1_score(all_labels, final_preds)
    roc_auc = roc_auc_score(all_labels, all_probs)  # Use probabilities for ROC AUC
    specificity = recall_score(all_labels, final_preds, pos_label=0)

    metrics = {
        'best_threshold': best_threshold,
        'best_metric_value': best_metric_value,
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1,
        'roc_auc': roc_auc,
        'specificity': specificity
    }

    print(f"Best Threshold: {best_threshold}")
    print(f"Best Metric Value: {best_metric_value}")
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1:.4f}")
    print(f"ROC AUC: {roc_auc:.4f}")
    print(f"Specificity: {specificity:.4f}")

    return metrics

# %%
find_best_threshold_and_evaluate(final_model, test_loader, device)
# Out:
# Best Threshold: 0.32
# Best Metric Value: 0.5226039783001808
# Accuracy: 0.4389
# Precision: 0.3626
# Recall: 0.9353
# F1 Score: 0.5226
# ROC AUC: 0.6441
# Specificity: 0.1962
# {'best_threshold': 0.32,
#  'best_metric_value': 0.5226039783001808,
#  'accuracy': 0.43889479277364507,
#  'precision': 0.36260978670012545,
#  'recall': 0.9352750809061489,
#  'f1_score': 0.5226039783001808,
#  'roc_auc': 0.6440923149399861,
#  'specificity': 0.1962025316455696}

# %% [markdown]
# **Plot ROC curve**

# %%
import matplotlib.pyplot as plt
import torch
import numpy as np
from sklearn.metrics import roc_curve

def plot_roc_curve(model, test_loader, device):
    """
    Generates and plots the ROC curve for the given model and test data.

    Parameters:
    model (torch.nn.Module): The trained model.
    test_loader (DataLoader): DataLoader for the test data.
    device (torch.device): The device to run the model on (CPU or GPU).

    Returns:
    None
    """
    model.to(device)
    model.eval()

    all_probs = []
    all_labels = []

    with torch.no_grad():
        for data in test_loader:
            low_freq_sequences = data['low_freq_sequence'].to(device)
            medium_freq_sequences = data['medium_freq_sequence'].to(device)
            high_freq_sequences = data['high_freq_sequence'].to(device)
            labels = data['label'].to(device).view(-1, 1)

            # Get model output (predicted probabilities)
            output = model(low_freq_sequences, medium_freq_sequences, high_freq_sequences)

            # Append predicted probabilities and true labels
            all_probs.extend(output.cpu().numpy().flatten())
            all_labels.extend(labels.cpu().numpy().flatten())

    # Convert lists to numpy arrays
    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels)

    # Compute ROC curve
    fpr, tpr, thresholds = roc_curve(all_labels, all_probs)

    # Plot ROC curve
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, label='ROC curve (area = {:.2f})'.format(roc_auc_score(all_labels, all_probs)))
    plt.plot([0, 1], [0, 1], 'k--', label='Random chance')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.legend(loc='lower right')
    plt.grid(True)
    plt.show()

# %%
plot_roc_curve(final_model, test_loader, device)

# %% [markdown]
# The curve is better than the straight line shown for the simpler architecture.

# %% [markdown]
# ### **Model Interpretability**
#
# We can now implement feature ablation.

# %%
# Load the feature names
low_feature_names = '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/08_model_input_data/02_feature_set_2/01_lstm_data/dynamic_data/low_freq_feature_names_v1.npy'
medium_feature_names = '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/08_model_input_data/02_feature_set_2/01_lstm_data/dynamic_data/medium_freq_feature_names_v1.npy'
high_feature_names = '/content/drive/MyDrive/MSc_Final_Project/02_data_analysis/mimic/data_analysis/datasets/08_model_input_data/02_feature_set_2/01_lstm_data/dynamic_data/high_freq_feature_names_v1.npy'

low_freq_feature_names = np.load(low_feature_names, allow_pickle=True)
medium_freq_feature_names = np.load(medium_feature_names, allow_pickle=True)
high_freq_feature_names = np.load(high_feature_names, allow_pickle=True)

print(low_freq_feature_names)
print(medium_freq_feature_names)
print(high_freq_feature_names)
# Out:
# ['PH (Arterial)' 'Arterial O2 pressure' 'Arterial CO2 Pressure']
# ['Inspired O2 Fraction' 'GCS - Eye Opening' 'GCS - Motor Response'
#  'Tidal Volume (observed)' 'Minute Volume' 'Mean Airway Pressure'
#  'Peak Insp. Pressure' 'Temperature Fahrenheit'
#  'Tidal Volume (spontaneous)' 'Richmond-RAS Scale']
# ['Heart Rate' 'O2 saturation pulseoxymetry' 'Respiratory Rate'
#  'Arterial Blood Pressure mean' 'Arterial Blood Pressure diastolic'
#  'Arterial Blood Pressure systolic']

# %%
import matplotlib.pyplot as plt
import pandas as pd
import torch
from torch.utils.data import DataLoader
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

def evaluate_model_ablation(model, data_loader, criterion, device):
    model.eval()
    all_labels = []
    all_outputs = []
    total_loss = 0.0

    with torch.no_grad():
        for data in data_loader:
            low_freq_sequences = data['low_freq_sequence'].to(device)
            medium_freq_sequences = data['medium_freq_sequence'].to(device)
            high_freq_sequences = data['high_freq_sequence'].to(device)
            labels = data['label'].to(device).view(-1, 1)

            outputs = model(low_freq_sequences, medium_freq_sequences, high_freq_sequences)
            loss = criterion(outputs, labels)
            total_loss += loss.item() * labels.size(0)

            all_outputs.extend(outputs.cpu().numpy().flatten())
            all_labels.extend(labels.cpu().numpy().flatten())

    avg_loss = total_loss / len(data_loader.dataset)
    accuracy = accuracy_score(all_labels, (np.array(all_outputs) > 0.5).astype(int))
    precision = precision_score(all_labels, (np.array(all_outputs) > 0.5).astype(int))
    recall = recall_score(all_labels, (np.array(all_outputs) > 0.5).astype(int))
    f1 = f1_score(all_labels, (np.array(all_outputs) > 0.5).astype(int))
    roc_auc = roc_auc_score(all_labels, all_outputs)
    specificity = recall_score(all_labels, (np.array(all_outputs) <= 0.5).astype(int))

    return avg_loss, accuracy, precision, recall, f1, roc_auc, specificity

# %%
def feature_ablation_with_names(low_train_sequences, medium_train_sequences, high_train_sequences, train_labels,
                                low_test_sequences, medium_test_sequences, high_test_sequences, test_labels,
                                model, best_hyperparams, device, low_feature_names, medium_feature_names, high_feature_names):
    """
    Perform feature ablation by retraining the model without each feature.

    Parameters:
    low_train_sequences (np.array): The low frequency training sequences.
    medium_train_sequences (np.array): The medium frequency training sequences.
    high_train_sequences (np.array): The high frequency training sequences.
    train_labels (np.array): The training labels.
    low_test_sequences (np.array): The low frequency test sequences.
    medium_test_sequences (np.array): The medium frequency test sequences.
    high_test_sequences (np.array): The high frequency test sequences.
    test_labels (np.array): The test labels.
    model (nn.Module): The trained fused LSTM model.
    best_hyperparams (dict): The best hyperparameters.
    device (torch.device): The device to run the model on.
    low_feature_names (list): List of low frequency feature names.
    medium_feature_names (list): List of medium frequency feature names.
    high_feature_names (list): List of high frequency feature names.

    Returns:
    feature_importances (pd.DataFrame): DataFrame containing the importance of each feature.
    """
    feature_importances = {}

    criterion = nn.BCELoss()
    test_loader = create_multi_input_data_loaders(
        low_test_sequences, medium_test_sequences, high_test_sequences, test_labels,
        low_test_sequences, medium_test_sequences, high_test_sequences, test_labels,
        low_test_sequences, medium_test_sequences, high_test_sequences, test_labels,
        best_hyperparams['batch_size']
    )[2]  # Only get the test loader

    _, base_accuracy, base_precision, base_recall, base_f1, base_roc_auc, base_specificity = evaluate_model_ablation(
        model, test_loader, criterion, device
    )

    def ablate_and_evaluate(train_sequences, test_sequences, feature_names, subset):
        for feature_idx in range(train_sequences.shape[2]):
            feature_name = feature_names[feature_idx]
            print(f"Ablating feature {feature_name} ({feature_idx + 1}/{train_sequences.shape[2]})")

            # Remove the feature from the sequences
            train_sequences_ablation = np.delete(train_sequences, feature_idx, axis=2)
            test_sequences_ablation = np.delete(test_sequences, feature_idx, axis=2)

            if subset == 0:
                train_loader, val_loader, test_loader = create_multi_input_data_loaders(
                    train_sequences_ablation, medium_train_sequences, high_train_sequences, train_labels,
                    train_sequences_ablation, medium_train_sequences, high_train_sequences, train_labels,
                    test_sequences_ablation, medium_test_sequences, high_test_sequences, test_labels,
                    best_hyperparams['batch_size']
                )
            elif subset == 1:
                train_loader, val_loader, test_loader = create_multi_input_data_loaders(
                    low_train_sequences, train_sequences_ablation, high_train_sequences, train_labels,
                    low_train_sequences, train_sequences_ablation, high_train_sequences, train_labels,
                    low_test_sequences, test_sequences_ablation, high_test_sequences, test_labels,
                    best_hyperparams['batch_size']
                )
            else:
                train_loader, val_loader, test_loader = create_multi_input_data_loaders(
                    low_train_sequences, medium_train_sequences, train_sequences_ablation, train_labels,
                    low_train_sequences, medium_train_sequences, train_sequences_ablation, train_labels,
                    low_test_sequences, medium_test_sequences, test_sequences_ablation, test_labels,
                    best_hyperparams['batch_size']
                )

            # Initialize a new model for this ablation
            ablation_model = FusedLSTMModel(
                low_input_dim=low_train_sequences.shape[2] - (1 if subset == 0 else 0),
                medium_input_dim=medium_train_sequences.shape[2] - (1 if subset == 1 else 0),
                high_input_dim=high_train_sequences.shape[2] - (1 if subset == 2 else 0),
                hidden_dim=best_hyperparams['hidden_dim'],
                layer_dim=best_hyperparams['layer_dim'],
                output_dim=1,
                dropout_prob=best_hyperparams['dropout_prob']
            ).to(device)

            optimizer = torch.optim.Adam(ablation_model.parameters(), lr=best_hyperparams['learning_rate'])

            # Train the model
            ablation_model, _, _, _ = train_fused_model_with_early_stopping_logging(
                ablation_model, train_loader, val_loader, criterion, optimizer,
                best_hyperparams['num_epochs'], device, patience=5, output_path='checkpoint.pth'
            )

            # Evaluate the model
            _, accuracy, precision, recall, f1, roc_auc, specificity = evaluate_model_ablation(ablation_model, test_loader, criterion, device)

            feature_importances[feature_name] = {
                'accuracy': base_accuracy - accuracy,
                'precision': base_precision - precision,
                'recall': base_recall - recall,
                'f1': base_f1 - f1,
                'roc_auc': base_roc_auc - roc_auc,
                'specificity': base_specificity - specificity
            }

    ablate_and_evaluate(low_train_sequences, low_test_sequences, low_feature_names, 0)
    ablate_and_evaluate(medium_train_sequences, medium_test_sequences, medium_feature_names, 1)
    ablate_and_evaluate(high_train_sequences, high_test_sequences, high_feature_names, 2)

    # Convert feature importances to a DataFrame for better readability
    feature_importances_df = pd.DataFrame.from_dict(feature_importances, orient='index')
    feature_importances_df = feature_importances_df.sort_values(by='roc_auc', ascending=False)

    # Plot feature importance
    plt.figure(figsize=(12, 8))
    plt.barh(feature_importances_df.index, feature_importances_df['roc_auc'], align='center', alpha=0.7)
    plt.xlabel('Change in ROC_AUC')
    plt.title('Feature Importance based on change in ROC_AUC')
    plt.gca().invert_yaxis()
    plt.show()

    return feature_importances_df

# %%
# Execute feature ablation
feature_importances_df = feature_ablation_with_names(
    train_low_sequences_resampled,
    train_medium_sequences_resampled,
    train_high_sequences_resampled,
    train_labels_resampled,
    low_freq_test_sequences,
    medium_freq_test_sequences,
    high_freq_test_sequences,
    labels_test,
    final_model,
    best_params,
    device,
    low_freq_feature_names,
    medium_freq_feature_names,
    high_freq_feature_names
)
# Out:
# Ablating feature PH (Arterial) (1/3)
# Epoch 0/49, Loss: 0.6881, Val Loss: 0.6814, Val AUC: 0.6067
# Epoch 1/49, Loss: 0.6762, Val Loss: 0.6719, Val AUC: 0.6197
# Epoch 2/49, Loss: 0.6726, Val Loss: 0.6721, Val AUC: 0.6249
# Epoch 3/49, Loss: 0.6681, Val Loss: 0.6807, Val AUC: 0.6337
# Epoch 4/49, Loss: 0.6663, Val Loss: 0.6614, Val AUC: 0.6417
# Epoch 5/49, Loss: 0.6650, Val Loss: 0.6614, Val AUC: 0.6458
# Epoch 6/49, Loss: 0.6635, Val Loss: 0.6592, Val AUC: 0.6514
# Epoch 7/49, Loss: 0.6609, Val Loss: 0.6607, Val AUC: 0.6549
# Epoch 8/49, Loss: 0.6593, Val Loss: 0.6603, Val AUC: 0.6556
# Epoch 9/49, Loss: 0.6579, Val Loss: 0.6568, Val AUC: 0.6612
# Epoch 10/49, Loss: 0.6570, Val Loss: 0.6584, Val AUC: 0.6536
# Epoch 11/49, Loss: 0.6561, Val Loss: 0.6514, Val AUC: 0.6612
# Epoch 12/49, Loss: 0.6554, Val Loss: 0.6500, Val AUC: 0.6659
# Epoch 13/49, Loss: 0.6529, Val Loss: 0.6487, Val AUC: 0.6619
# Epoch 14/49, Loss: 0.6522, Val Loss: 0.6509, Val AUC: 0.6694
# Epoch 15/49, Loss: 0.6513, Val Loss: 0.6566, Val AUC: 0.6615
# Epoch 16/49, Loss: 0.6506, Val Loss: 0.6500, Val AUC: 0.6652
# Epoch 17/49, Loss: 0.6515, Val Loss: 0.6477, Val AUC: 0.6681
# Epoch 18/49, Loss: 0.6500, Val Loss: 0.6478, Val AUC: 0.6701
# Epoch 19/49, Loss: 0.6494, Val Loss: 0.6438, Val AUC: 0.6742
# Epoch 20/49, Loss: 0.6490, Val Loss: 0.6475, Val AUC: 0.6743
# Epoch 21/49, Loss: 0.6493, Val Loss: 0.6459, Val AUC: 0.6734
# Epoch 22/49, Loss: 0.6484, Val Loss: 0.6453, Val AUC: 0.6764
# Epoch 23/49, Loss: 0.6467, Val Loss: 0.6447, Val AUC: 0.6754
# Epoch 24/49, Loss: 0.6493, Val Loss: 0.6444, Val AUC: 0.6792
# Epoch 25/49, Loss: 0.6448, Val Loss: 0.6512, Val AUC: 0.6724
# Epoch 26/49, Loss: 0.6456, Val Loss: 0.6407, Val AUC: 0.6783
# Epoch 27/49, Loss: 0.6443, Val Loss: 0.6410, Val AUC: 0.6759
# Epoch 28/49, Loss: 0.6449, Val Loss: 0.6442, Val AUC: 0.6770
# Epoch 29/49, Loss: 0.6448, Val Loss: 0.6396, Val AUC: 0.6820
# Epoch 30/49, Loss: 0.6433, Val Loss: 0.6400, Val AUC: 0.6806
# Epoch 31/49, Loss: 0.6433, Val Loss: 0.6390, Val AUC: 0.6814
# Epoch 32/49, Loss: 0.6425, Val Loss: 0.6446, Val AUC: 0.6784
# Epoch 33/49, Loss: 0.6409, Val Loss: 0.6394, Val AUC: 0.6835
# Epoch 34/49, Loss: 0.6405, Val Loss: 0.6355, Val AUC: 0.6855
# Epoch 35/49, Loss: 0.6403, Val Loss: 0.6376, Val AUC: 0.6853
# Epoch 36/49, Loss: 0.6402, Val Loss: 0.6340, Val AUC: 0.6868
# Epoch 37/49, Loss: 0.6391, Val Loss: 0.6360, Val AUC: 0.6851
# Epoch 38/49, Loss: 0.6398, Val Loss: 0.6387, Val AUC: 0.6806
# Epoch 39/49, Loss: 0.6389, Val Loss: 0.6337, Val AUC: 0.6885
# Epoch 40/49, Loss: 0.6394, Val Loss: 0.6398, Val AUC: 0.6905
# Epoch 41/49, Loss: 0.6372, Val Loss: 0.6423, Val AUC: 0.6914
# Epoch 42/49, Loss: 0.6377, Val Loss: 0.6354, Val AUC: 0.6852
# Epoch 43/49, Loss: 0.6382, Val Loss: 0.6341, Val AUC: 0.6942
# Epoch 44/49, Loss: 0.6364, Val Loss: 0.6303, Val AUC: 0.6938
# Epoch 45/49, Loss: 0.6343, Val Loss: 0.6342, Val AUC: 0.6892
# Epoch 46/49, Loss: 0.6343, Val Loss: 0.6272, Val AUC: 0.6975
# Epoch 47/49, Loss: 0.6344, Val Loss: 0.6324, Val AUC: 0.6919
# Epoch 48/49, Loss: 0.6344, Val Loss: 0.6317, Val AUC: 0.6964
# Epoch 49/49, Loss: 0.6343, Val Loss: 0.6269, Val AUC: 0.6999
# Ablating feature Arterial O2 pressure (2/3)
# Epoch 0/49, Loss: 0.6883, Val Loss: 0.6793, Val AUC: 0.6061
# Epoch 1/49, Loss: 0.6743, Val Loss: 0.6711, Val AUC: 0.6185
# Epoch 2/49, Loss: 0.6723, Val Loss: 0.6757, Val AUC: 0.6249
# Epoch 3/49, Loss: 0.6687, Val Loss: 0.6635, Val AUC: 0.6361
# Epoch 4/49, Loss: 0.6671, Val Loss: 0.6656, Val AUC: 0.6359
# Epoch 5/49, Loss: 0.6668, Val Loss: 0.6631, Val AUC: 0.6392
# Epoch 6/49, Loss: 0.6656, Val Loss: 0.6673, Val AUC: 0.6441
# Epoch 7/49, Loss: 0.6646, Val Loss: 0.6577, Val AUC: 0.6446
# Epoch 8/49, Loss: 0.6626, Val Loss: 0.6582, Val AUC: 0.6465
# Epoch 9/49, Loss: 0.6599, Val Loss: 0.6598, Val AUC: 0.6499
# Epoch 10/49, Loss: 0.6596, Val Loss: 0.6596, Val AUC: 0.6502
# Epoch 11/49, Loss: 0.6584, Val Loss: 0.6638, Val AUC: 0.6554
# Epoch 12/49, Loss: 0.6574, Val Loss: 0.6581, Val AUC: 0.6496
# Epoch 13/49, Loss: 0.6564, Val Loss: 0.6528, Val AUC: 0.6574
# Epoch 14/49, Loss: 0.6549, Val Loss: 0.6491, Val AUC: 0.6614
# Epoch 15/49, Loss: 0.6576, Val Loss: 0.6580, Val AUC: 0.6541
# Epoch 16/49, Loss: 0.6530, Val Loss: 0.6483, Val AUC: 0.6655
# Epoch 17/49, Loss: 0.6534, Val Loss: 0.6500, Val AUC: 0.6678
# Epoch 18/49, Loss: 0.6524, Val Loss: 0.6510, Val AUC: 0.6640
# Epoch 19/49, Loss: 0.6532, Val Loss: 0.6468, Val AUC: 0.6684
# Epoch 20/49, Loss: 0.6518, Val Loss: 0.6465, Val AUC: 0.6717
# Epoch 21/49, Loss: 0.6503, Val Loss: 0.6438, Val AUC: 0.6722
# Epoch 22/49, Loss: 0.6508, Val Loss: 0.6498, Val AUC: 0.6655
# Epoch 23/49, Loss: 0.6483, Val Loss: 0.6536, Val AUC: 0.6707
# Epoch 24/49, Loss: 0.6492, Val Loss: 0.6595, Val AUC: 0.6744
# Epoch 25/49, Loss: 0.6501, Val Loss: 0.6425, Val AUC: 0.6741
# Epoch 26/49, Loss: 0.6480, Val Loss: 0.6423, Val AUC: 0.6783
# Epoch 27/49, Loss: 0.6484, Val Loss: 0.6438, Val AUC: 0.6767
# Epoch 28/49, Loss: 0.6488, Val Loss: 0.6425, Val AUC: 0.6780
# Epoch 29/49, Loss: 0.6475, Val Loss: 0.6419, Val AUC: 0.6757
# Epoch 30/49, Loss: 0.6458, Val Loss: 0.6409, Val AUC: 0.6768
# Epoch 31/49, Loss: 0.6445, Val Loss: 0.6420, Val AUC: 0.6771
# Early stopping
# Ablating feature Arterial CO2 Pressure (3/3)
# Epoch 0/49, Loss: 0.6871, Val Loss: 0.6807, Val AUC: 0.6100
# Epoch 1/49, Loss: 0.6774, Val Loss: 0.6735, Val AUC: 0.6169
# Epoch 2/49, Loss: 0.6718, Val Loss: 0.6650, Val AUC: 0.6277
# Epoch 3/49, Loss: 0.6700, Val Loss: 0.6653, Val AUC: 0.6373
# Epoch 4/49, Loss: 0.6656, Val Loss: 0.6643, Val AUC: 0.6400
# Epoch 5/49, Loss: 0.6664, Val Loss: 0.6610, Val AUC: 0.6395
# Epoch 6/49, Loss: 0.6641, Val Loss: 0.6583, Val AUC: 0.6484
# Epoch 7/49, Loss: 0.6613, Val Loss: 0.6550, Val AUC: 0.6502
# Epoch 8/49, Loss: 0.6615, Val Loss: 0.6593, Val AUC: 0.6545
# Epoch 9/49, Loss: 0.6588, Val Loss: 0.6661, Val AUC: 0.6482
# Epoch 10/49, Loss: 0.6581, Val Loss: 0.6591, Val AUC: 0.6545
# Epoch 11/49, Loss: 0.6558, Val Loss: 0.6584, Val AUC: 0.6571
# Epoch 12/49, Loss: 0.6564, Val Loss: 0.6541, Val AUC: 0.6571
# Epoch 13/49, Loss: 0.6532, Val Loss: 0.6582, Val AUC: 0.6578
# Epoch 14/49, Loss: 0.6567, Val Loss: 0.6500, Val AUC: 0.6648
# Epoch 15/49, Loss: 0.6546, Val Loss: 0.6481, Val AUC: 0.6633
# Epoch 16/49, Loss: 0.6533, Val Loss: 0.6522, Val AUC: 0.6601
# Epoch 17/49, Loss: 0.6521, Val Loss: 0.6503, Val AUC: 0.6669
# Epoch 18/49, Loss: 0.6512, Val Loss: 0.6490, Val AUC: 0.6671
# Epoch 19/49, Loss: 0.6500, Val Loss: 0.6511, Val AUC: 0.6708
# Epoch 20/49, Loss: 0.6512, Val Loss: 0.6462, Val AUC: 0.6708
# Epoch 21/49, Loss: 0.6493, Val Loss: 0.6459, Val AUC: 0.6741
# Epoch 22/49, Loss: 0.6479, Val Loss: 0.6417, Val AUC: 0.6742
# Epoch 23/49, Loss: 0.6488, Val Loss: 0.6442, Val AUC: 0.6758
# Epoch 24/49, Loss: 0.6488, Val Loss: 0.6425, Val AUC: 0.6759
# Epoch 25/49, Loss: 0.6481, Val Loss: 0.6437, Val AUC: 0.6749
# Epoch 26/49, Loss: 0.6468, Val Loss: 0.6470, Val AUC: 0.6733
# Epoch 27/49, Loss: 0.6477, Val Loss: 0.6468, Val AUC: 0.6785
# Epoch 28/49, Loss: 0.6442, Val Loss: 0.6438, Val AUC: 0.6728
# Epoch 29/49, Loss: 0.6449, Val Loss: 0.6457, Val AUC: 0.6754
# Epoch 30/49, Loss: 0.6446, Val Loss: 0.6410, Val AUC: 0.6785
# Epoch 31/49, Loss: 0.6446, Val Loss: 0.6415, Val AUC: 0.6768
# Epoch 32/49, Loss: 0.6457, Val Loss: 0.6403, Val AUC: 0.6809
# Epoch 33/49, Loss: 0.6429, Val Loss: 0.6404, Val AUC: 0.6788
# Epoch 34/49, Loss: 0.6424, Val Loss: 0.6369, Val AUC: 0.6847
# Epoch 35/49, Loss: 0.6410, Val Loss: 0.6380, Val AUC: 0.6852
# Epoch 36/49, Loss: 0.6419, Val Loss: 0.6363, Val AUC: 0.6845
# Epoch 37/49, Loss: 0.6407, Val Loss: 0.6396, Val AUC: 0.6785
# Epoch 38/49, Loss: 0.6393, Val Loss: 0.6399, Val AUC: 0.6781
# Epoch 39/49, Loss: 0.6385, Val Loss: 0.6361, Val AUC: 0.6834
# Epoch 40/49, Loss: 0.6405, Val Loss: 0.6347, Val AUC: 0.6884
# Epoch 41/49, Loss: 0.6392, Val Loss: 0.6352, Val AUC: 0.6863
# Epoch 42/49, Loss: 0.6396, Val Loss: 0.6341, Val AUC: 0.6869
# Epoch 43/49, Loss: 0.6378, Val Loss: 0.6331, Val AUC: 0.6902
# Epoch 44/49, Loss: 0.6371, Val Loss: 0.6333, Val AUC: 0.6906
# Epoch 45/49, Loss: 0.6368, Val Loss: 0.6299, Val AUC: 0.6937
# Epoch 46/49, Loss: 0.6373, Val Loss: 0.6357, Val AUC: 0.6843
# Epoch 47/49, Loss: 0.6369, Val Loss: 0.6315, Val AUC: 0.6928
# Epoch 48/49, Loss: 0.6376, Val Loss: 0.6292, Val AUC: 0.6931
# Epoch 49/49, Loss: 0.6350, Val Loss: 0.6347, Val AUC: 0.6910
# Ablating feature Inspired O2 Fraction (1/10)
# Epoch 0/49, Loss: 0.6901, Val Loss: 0.6838, Val AUC: 0.6011
# Epoch 1/49, Loss: 0.6796, Val Loss: 0.6882, Val AUC: 0.6067
# Epoch 2/49, Loss: 0.6741, Val Loss: 0.6689, Val AUC: 0.6284
# Epoch 3/49, Loss: 0.6702, Val Loss: 0.6738, Val AUC: 0.6311
# Epoch 4/49, Loss: 0.6673, Val Loss: 0.6712, Val AUC: 0.6294
# Epoch 5/49, Loss: 0.6669, Val Loss: 0.6625, Val AUC: 0.6419
# Epoch 6/49, Loss: 0.6654, Val Loss: 0.6610, Val AUC: 0.6435
# Epoch 7/49, Loss: 0.6613, Val Loss: 0.6586, Val AUC: 0.6390
# Epoch 8/49, Loss: 0.6626, Val Loss: 0.6568, Val AUC: 0.6442
# Epoch 9/49, Loss: 0.6609, Val Loss: 0.6586, Val AUC: 0.6515
# Epoch 10/49, Loss: 0.6592, Val Loss: 0.6539, Val AUC: 0.6511
# Epoch 11/49, Loss: 0.6592, Val Loss: 0.6553, Val AUC: 0.6492
# Epoch 12/49, Loss: 0.6594, Val Loss: 0.6533, Val AUC: 0.6541
# Epoch 13/49, Loss: 0.6594, Val Loss: 0.6551, Val AUC: 0.6548
# Epoch 14/49, Loss: 0.6569, Val Loss: 0.6547, Val AUC: 0.6532
# Epoch 15/49, Loss: 0.6587, Val Loss: 0.6571, Val AUC: 0.6527
# Epoch 16/49, Loss: 0.6573, Val Loss: 0.6532, Val AUC: 0.6526
# Epoch 17/49, Loss: 0.6561, Val Loss: 0.6516, Val AUC: 0.6555
# Epoch 18/49, Loss: 0.6561, Val Loss: 0.6524, Val AUC: 0.6548
# Epoch 19/49, Loss: 0.6549, Val Loss: 0.6505, Val AUC: 0.6575
# Epoch 20/49, Loss: 0.6551, Val Loss: 0.6527, Val AUC: 0.6574
# Epoch 21/49, Loss: 0.6561, Val Loss: 0.6580, Val AUC: 0.6538
# Epoch 22/49, Loss: 0.6545, Val Loss: 0.6549, Val AUC: 0.6599
# Epoch 23/49, Loss: 0.6528, Val Loss: 0.6505, Val AUC: 0.6611
# Epoch 24/49, Loss: 0.6527, Val Loss: 0.6479, Val AUC: 0.6638
# Epoch 25/49, Loss: 0.6527, Val Loss: 0.6482, Val AUC: 0.6620
# Epoch 26/49, Loss: 0.6522, Val Loss: 0.6489, Val AUC: 0.6654
# Epoch 27/49, Loss: 0.6515, Val Loss: 0.6458, Val AUC: 0.6661
# Epoch 28/49, Loss: 0.6512, Val Loss: 0.6484, Val AUC: 0.6618
# Epoch 29/49, Loss: 0.6493, Val Loss: 0.6432, Val AUC: 0.6701
# Epoch 30/49, Loss: 0.6493, Val Loss: 0.6476, Val AUC: 0.6706
# Epoch 31/49, Loss: 0.6488, Val Loss: 0.6434, Val AUC: 0.6719
# Epoch 32/49, Loss: 0.6472, Val Loss: 0.6420, Val AUC: 0.6728
# Epoch 33/49, Loss: 0.6474, Val Loss: 0.6417, Val AUC: 0.6729
# Epoch 34/49, Loss: 0.6468, Val Loss: 0.6472, Val AUC: 0.6654
# Epoch 35/49, Loss: 0.6476, Val Loss: 0.6434, Val AUC: 0.6749
# Epoch 36/49, Loss: 0.6466, Val Loss: 0.6453, Val AUC: 0.6748
# Epoch 37/49, Loss: 0.6451, Val Loss: 0.6400, Val AUC: 0.6765
# Epoch 38/49, Loss: 0.6463, Val Loss: 0.6424, Val AUC: 0.6743
# Epoch 39/49, Loss: 0.6466, Val Loss: 0.6376, Val AUC: 0.6771
# Epoch 40/49, Loss: 0.6440, Val Loss: 0.6386, Val AUC: 0.6773
# Epoch 41/49, Loss: 0.6436, Val Loss: 0.6379, Val AUC: 0.6802
# Epoch 42/49, Loss: 0.6427, Val Loss: 0.6432, Val AUC: 0.6751
# Epoch 43/49, Loss: 0.6441, Val Loss: 0.6361, Val AUC: 0.6793
# Epoch 44/49, Loss: 0.6419, Val Loss: 0.6470, Val AUC: 0.6717
# Epoch 45/49, Loss: 0.6427, Val Loss: 0.6375, Val AUC: 0.6800
# Epoch 46/49, Loss: 0.6427, Val Loss: 0.6400, Val AUC: 0.6817
# Epoch 47/49, Loss: 0.6416, Val Loss: 0.6369, Val AUC: 0.6849
# Epoch 48/49, Loss: 0.6408, Val Loss: 0.6339, Val AUC: 0.6844
# Epoch 49/49, Loss: 0.6394, Val Loss: 0.6332, Val AUC: 0.6874
# Ablating feature GCS - Eye Opening (2/10)
# Epoch 0/49, Loss: 0.6881, Val Loss: 0.6773, Val AUC: 0.6048
# Epoch 1/49, Loss: 0.6763, Val Loss: 0.6697, Val AUC: 0.6222
# Epoch 2/49, Loss: 0.6737, Val Loss: 0.6710, Val AUC: 0.6262
# Epoch 3/49, Loss: 0.6687, Val Loss: 0.6644, Val AUC: 0.6322
# Epoch 4/49, Loss: 0.6682, Val Loss: 0.6695, Val AUC: 0.6376
# Epoch 5/49, Loss: 0.6677, Val Loss: 0.6646, Val AUC: 0.6427
# Epoch 6/49, Loss: 0.6636, Val Loss: 0.6619, Val AUC: 0.6450
# Epoch 7/49, Loss: 0.6631, Val Loss: 0.6579, Val AUC: 0.6485
# Epoch 8/49, Loss: 0.6615, Val Loss: 0.6592, Val AUC: 0.6536
# Epoch 9/49, Loss: 0.6606, Val Loss: 0.6588, Val AUC: 0.6558
# Epoch 10/49, Loss: 0.6603, Val Loss: 0.6546, Val AUC: 0.6517
# Epoch 11/49, Loss: 0.6574, Val Loss: 0.6541, Val AUC: 0.6525
# Epoch 12/49, Loss: 0.6574, Val Loss: 0.6520, Val AUC: 0.6614
# Epoch 13/49, Loss: 0.6561, Val Loss: 0.6537, Val AUC: 0.6576
# Epoch 14/49, Loss: 0.6545, Val Loss: 0.6504, Val AUC: 0.6654
# Epoch 15/49, Loss: 0.6531, Val Loss: 0.6500, Val AUC: 0.6666
# Epoch 16/49, Loss: 0.6534, Val Loss: 0.6512, Val AUC: 0.6670
# Epoch 17/49, Loss: 0.6518, Val Loss: 0.6570, Val AUC: 0.6703
# Epoch 18/49, Loss: 0.6523, Val Loss: 0.6687, Val AUC: 0.6703
# Epoch 19/49, Loss: 0.6507, Val Loss: 0.6531, Val AUC: 0.6675
# Epoch 20/49, Loss: 0.6506, Val Loss: 0.6514, Val AUC: 0.6668
# Epoch 21/49, Loss: 0.6496, Val Loss: 0.6480, Val AUC: 0.6651
# Epoch 22/49, Loss: 0.6483, Val Loss: 0.6455, Val AUC: 0.6706
# Epoch 23/49, Loss: 0.6495, Val Loss: 0.6434, Val AUC: 0.6706
# Epoch 24/49, Loss: 0.6492, Val Loss: 0.6455, Val AUC: 0.6754
# Epoch 25/49, Loss: 0.6496, Val Loss: 0.6443, Val AUC: 0.6754
# Epoch 26/49, Loss: 0.6487, Val Loss: 0.6445, Val AUC: 0.6755
# Epoch 27/49, Loss: 0.6456, Val Loss: 0.6481, Val AUC: 0.6688
# Epoch 28/49, Loss: 0.6461, Val Loss: 0.6403, Val AUC: 0.6780
# Epoch 29/49, Loss: 0.6439, Val Loss: 0.6405, Val AUC: 0.6785
# Epoch 30/49, Loss: 0.6465, Val Loss: 0.6538, Val AUC: 0.6766
# Epoch 31/49, Loss: 0.6451, Val Loss: 0.6406, Val AUC: 0.6818
# Epoch 32/49, Loss: 0.6443, Val Loss: 0.6455, Val AUC: 0.6838
# Epoch 33/49, Loss: 0.6429, Val Loss: 0.6378, Val AUC: 0.6845
# Epoch 34/49, Loss: 0.6432, Val Loss: 0.6362, Val AUC: 0.6859
# Epoch 35/49, Loss: 0.6417, Val Loss: 0.6413, Val AUC: 0.6792
# Epoch 36/49, Loss: 0.6415, Val Loss: 0.6383, Val AUC: 0.6783
# Epoch 37/49, Loss: 0.6440, Val Loss: 0.6379, Val AUC: 0.6833
# Epoch 38/49, Loss: 0.6419, Val Loss: 0.6368, Val AUC: 0.6804
# Epoch 39/49, Loss: 0.6420, Val Loss: 0.6384, Val AUC: 0.6804
# Early stopping
# Ablating feature GCS - Motor Response (3/10)
# Epoch 0/49, Loss: 0.6899, Val Loss: 0.6810, Val AUC: 0.6014
# Epoch 1/49, Loss: 0.6775, Val Loss: 0.6706, Val AUC: 0.6126
# Epoch 2/49, Loss: 0.6741, Val Loss: 0.6691, Val AUC: 0.6260
# Epoch 3/49, Loss: 0.6717, Val Loss: 0.6692, Val AUC: 0.6271
# Epoch 4/49, Loss: 0.6685, Val Loss: 0.6622, Val AUC: 0.6333
# Epoch 5/49, Loss: 0.6647, Val Loss: 0.6597, Val AUC: 0.6388
# Epoch 6/49, Loss: 0.6635, Val Loss: 0.6630, Val AUC: 0.6455
# Epoch 7/49, Loss: 0.6627, Val Loss: 0.6654, Val AUC: 0.6495
# Epoch 8/49, Loss: 0.6603, Val Loss: 0.6553, Val AUC: 0.6541
# Epoch 9/49, Loss: 0.6587, Val Loss: 0.6579, Val AUC: 0.6490
# Epoch 10/49, Loss: 0.6560, Val Loss: 0.6535, Val AUC: 0.6564
# Epoch 11/49, Loss: 0.6569, Val Loss: 0.6594, Val AUC: 0.6532
# Epoch 12/49, Loss: 0.6571, Val Loss: 0.6504, Val AUC: 0.6608
# Epoch 13/49, Loss: 0.6551, Val Loss: 0.6501, Val AUC: 0.6588
# Epoch 14/49, Loss: 0.6562, Val Loss: 0.6559, Val AUC: 0.6651
# Epoch 15/49, Loss: 0.6529, Val Loss: 0.6578, Val AUC: 0.6549
# Epoch 16/49, Loss: 0.6522, Val Loss: 0.6498, Val AUC: 0.6683
# Epoch 17/49, Loss: 0.6512, Val Loss: 0.6484, Val AUC: 0.6685
# Epoch 18/49, Loss: 0.6510, Val Loss: 0.6534, Val AUC: 0.6709
# Epoch 19/49, Loss: 0.6507, Val Loss: 0.6473, Val AUC: 0.6668
# Epoch 20/49, Loss: 0.6491, Val Loss: 0.6450, Val AUC: 0.6723
# Epoch 21/49, Loss: 0.6500, Val Loss: 0.6468, Val AUC: 0.6742
# Epoch 22/49, Loss: 0.6497, Val Loss: 0.6433, Val AUC: 0.6744
# Epoch 23/49, Loss: 0.6479, Val Loss: 0.6476, Val AUC: 0.6742
# Epoch 24/49, Loss: 0.6485, Val Loss: 0.6444, Val AUC: 0.6756
# Epoch 25/49, Loss: 0.6472, Val Loss: 0.6427, Val AUC: 0.6779
# Epoch 26/49, Loss: 0.6466, Val Loss: 0.6450, Val AUC: 0.6768
# Epoch 27/49, Loss: 0.6464, Val Loss: 0.6437, Val AUC: 0.6755
# Epoch 28/49, Loss: 0.6463, Val Loss: 0.6488, Val AUC: 0.6790
# Epoch 29/49, Loss: 0.6463, Val Loss: 0.6412, Val AUC: 0.6801
# Epoch 30/49, Loss: 0.6463, Val Loss: 0.6411, Val AUC: 0.6772
# Epoch 31/49, Loss: 0.6465, Val Loss: 0.6403, Val AUC: 0.6812
# Epoch 32/49, Loss: 0.6439, Val Loss: 0.6434, Val AUC: 0.6791
# Epoch 33/49, Loss: 0.6440, Val Loss: 0.6391, Val AUC: 0.6821
# Epoch 34/49, Loss: 0.6432, Val Loss: 0.6391, Val AUC: 0.6850
# Epoch 35/49, Loss: 0.6429, Val Loss: 0.6387, Val AUC: 0.6844
# Epoch 36/49, Loss: 0.6433, Val Loss: 0.6371, Val AUC: 0.6861
# Epoch 37/49, Loss: 0.6417, Val Loss: 0.6489, Val AUC: 0.6672
# Epoch 38/49, Loss: 0.6435, Val Loss: 0.6405, Val AUC: 0.6823
# Epoch 39/49, Loss: 0.6409, Val Loss: 0.6395, Val AUC: 0.6818
# Epoch 40/49, Loss: 0.6407, Val Loss: 0.6330, Val AUC: 0.6900
# Epoch 41/49, Loss: 0.6393, Val Loss: 0.6400, Val AUC: 0.6803
# Epoch 42/49, Loss: 0.6411, Val Loss: 0.6373, Val AUC: 0.6872
# Epoch 43/49, Loss: 0.6403, Val Loss: 0.6385, Val AUC: 0.6863
# Epoch 44/49, Loss: 0.6391, Val Loss: 0.6350, Val AUC: 0.6894
# Epoch 45/49, Loss: 0.6385, Val Loss: 0.6367, Val AUC: 0.6913
# Epoch 46/49, Loss: 0.6381, Val Loss: 0.6342, Val AUC: 0.6866
# Epoch 47/49, Loss: 0.6372, Val Loss: 0.6327, Val AUC: 0.6928
# Epoch 48/49, Loss: 0.6383, Val Loss: 0.6301, Val AUC: 0.6941
# Epoch 49/49, Loss: 0.6357, Val Loss: 0.6296, Val AUC: 0.6940
# Ablating feature Tidal Volume (observed) (4/10)
# Epoch 0/49, Loss: 0.6877, Val Loss: 0.6770, Val AUC: 0.6055
# Epoch 1/49, Loss: 0.6754, Val Loss: 0.6853, Val AUC: 0.6167
# Epoch 2/49, Loss: 0.6708, Val Loss: 0.6762, Val AUC: 0.6232
# Epoch 3/49, Loss: 0.6709, Val Loss: 0.6641, Val AUC: 0.6350
# Epoch 4/49, Loss: 0.6674, Val Loss: 0.6623, Val AUC: 0.6378
# Epoch 5/49, Loss: 0.6640, Val Loss: 0.6620, Val AUC: 0.6401
# Epoch 6/49, Loss: 0.6615, Val Loss: 0.6673, Val AUC: 0.6428
# Epoch 7/49, Loss: 0.6616, Val Loss: 0.6552, Val AUC: 0.6532
# Epoch 8/49, Loss: 0.6621, Val Loss: 0.6540, Val AUC: 0.6525
# Epoch 9/49, Loss: 0.6585, Val Loss: 0.6548, Val AUC: 0.6538
# Epoch 10/49, Loss: 0.6589, Val Loss: 0.6577, Val AUC: 0.6473
# Epoch 11/49, Loss: 0.6571, Val Loss: 0.6601, Val AUC: 0.6521
# Epoch 12/49, Loss: 0.6576, Val Loss: 0.6551, Val AUC: 0.6594
# Epoch 13/49, Loss: 0.6562, Val Loss: 0.6507, Val AUC: 0.6585
# Epoch 14/49, Loss: 0.6533, Val Loss: 0.6501, Val AUC: 0.6647
# Epoch 15/49, Loss: 0.6533, Val Loss: 0.6486, Val AUC: 0.6653
# Epoch 16/49, Loss: 0.6545, Val Loss: 0.6476, Val AUC: 0.6670
# Epoch 17/49, Loss: 0.6539, Val Loss: 0.6470, Val AUC: 0.6682
# Epoch 18/49, Loss: 0.6513, Val Loss: 0.6453, Val AUC: 0.6700
# Epoch 19/49, Loss: 0.6508, Val Loss: 0.6467, Val AUC: 0.6668
# Epoch 20/49, Loss: 0.6515, Val Loss: 0.6441, Val AUC: 0.6718
# Epoch 21/49, Loss: 0.6495, Val Loss: 0.6460, Val AUC: 0.6706
# Epoch 22/49, Loss: 0.6484, Val Loss: 0.6612, Val AUC: 0.6706
# Epoch 23/49, Loss: 0.6494, Val Loss: 0.6477, Val AUC: 0.6719
# Epoch 24/49, Loss: 0.6482, Val Loss: 0.6446, Val AUC: 0.6773
# Epoch 25/49, Loss: 0.6477, Val Loss: 0.6448, Val AUC: 0.6772
# Epoch 26/49, Loss: 0.6450, Val Loss: 0.6469, Val AUC: 0.6772
# Epoch 27/49, Loss: 0.6471, Val Loss: 0.6452, Val AUC: 0.6768
# Epoch 28/49, Loss: 0.6456, Val Loss: 0.6395, Val AUC: 0.6790
# Epoch 29/49, Loss: 0.6432, Val Loss: 0.6447, Val AUC: 0.6795
# Epoch 30/49, Loss: 0.6458, Val Loss: 0.6434, Val AUC: 0.6739
# Epoch 31/49, Loss: 0.6441, Val Loss: 0.6403, Val AUC: 0.6781
# Epoch 32/49, Loss: 0.6447, Val Loss: 0.6378, Val AUC: 0.6823
# Epoch 33/49, Loss: 0.6450, Val Loss: 0.6380, Val AUC: 0.6831
# Epoch 34/49, Loss: 0.6430, Val Loss: 0.6423, Val AUC: 0.6848
# Epoch 35/49, Loss: 0.6432, Val Loss: 0.6403, Val AUC: 0.6822
# Epoch 36/49, Loss: 0.6433, Val Loss: 0.6434, Val AUC: 0.6768
# Epoch 37/49, Loss: 0.6426, Val Loss: 0.6431, Val AUC: 0.6823
# Epoch 38/49, Loss: 0.6405, Val Loss: 0.6371, Val AUC: 0.6828
# Epoch 39/49, Loss: 0.6410, Val Loss: 0.6362, Val AUC: 0.6862
# Epoch 40/49, Loss: 0.6393, Val Loss: 0.6418, Val AUC: 0.6832
# Epoch 41/49, Loss: 0.6392, Val Loss: 0.6335, Val AUC: 0.6891
# Epoch 42/49, Loss: 0.6386, Val Loss: 0.6422, Val AUC: 0.6869
# Epoch 43/49, Loss: 0.6417, Val Loss: 0.6329, Val AUC: 0.6874
# Epoch 44/49, Loss: 0.6391, Val Loss: 0.6312, Val AUC: 0.6907
# Epoch 45/49, Loss: 0.6386, Val Loss: 0.6306, Val AUC: 0.6907
# Epoch 46/49, Loss: 0.6382, Val Loss: 0.6306, Val AUC: 0.6949
# Epoch 47/49, Loss: 0.6356, Val Loss: 0.6306, Val AUC: 0.6902
# Epoch 48/49, Loss: 0.6343, Val Loss: 0.6288, Val AUC: 0.6965
# Epoch 49/49, Loss: 0.6371, Val Loss: 0.6290, Val AUC: 0.6922
# Ablating feature Minute Volume (5/10)
# Epoch 0/49, Loss: 0.6879, Val Loss: 0.6801, Val AUC: 0.6039
# Epoch 1/49, Loss: 0.6763, Val Loss: 0.6733, Val AUC: 0.6135
# Epoch 2/49, Loss: 0.6712, Val Loss: 0.6745, Val AUC: 0.6269
# Epoch 3/49, Loss: 0.6687, Val Loss: 0.6665, Val AUC: 0.6339
# Epoch 4/49, Loss: 0.6662, Val Loss: 0.6595, Val AUC: 0.6399
# Epoch 5/49, Loss: 0.6645, Val Loss: 0.6608, Val AUC: 0.6437
# Epoch 6/49, Loss: 0.6643, Val Loss: 0.6586, Val AUC: 0.6461
# Epoch 7/49, Loss: 0.6616, Val Loss: 0.6598, Val AUC: 0.6477
# Epoch 8/49, Loss: 0.6609, Val Loss: 0.6558, Val AUC: 0.6518
# Epoch 9/49, Loss: 0.6602, Val Loss: 0.6564, Val AUC: 0.6551
# Epoch 10/49, Loss: 0.6574, Val Loss: 0.6721, Val AUC: 0.6531
# Epoch 11/49, Loss: 0.6570, Val Loss: 0.6531, Val AUC: 0.6569
# Epoch 12/49, Loss: 0.6547, Val Loss: 0.6600, Val AUC: 0.6480
# Epoch 13/49, Loss: 0.6570, Val Loss: 0.6536, Val AUC: 0.6637
# Epoch 14/49, Loss: 0.6532, Val Loss: 0.6533, Val AUC: 0.6585
# Epoch 15/49, Loss: 0.6533, Val Loss: 0.6538, Val AUC: 0.6612
# Epoch 16/49, Loss: 0.6523, Val Loss: 0.6469, Val AUC: 0.6646
# Epoch 17/49, Loss: 0.6534, Val Loss: 0.6529, Val AUC: 0.6675
# Epoch 18/49, Loss: 0.6513, Val Loss: 0.6536, Val AUC: 0.6616
# Epoch 19/49, Loss: 0.6508, Val Loss: 0.6477, Val AUC: 0.6707
# Epoch 20/49, Loss: 0.6507, Val Loss: 0.6484, Val AUC: 0.6656
# Epoch 21/49, Loss: 0.6501, Val Loss: 0.6472, Val AUC: 0.6698
# Epoch 22/49, Loss: 0.6500, Val Loss: 0.6482, Val AUC: 0.6695
# Epoch 23/49, Loss: 0.6486, Val Loss: 0.6468, Val AUC: 0.6724
# Epoch 24/49, Loss: 0.6481, Val Loss: 0.6441, Val AUC: 0.6731
# Epoch 25/49, Loss: 0.6465, Val Loss: 0.6496, Val AUC: 0.6721
# Epoch 26/49, Loss: 0.6466, Val Loss: 0.6487, Val AUC: 0.6773
# Epoch 27/49, Loss: 0.6463, Val Loss: 0.6414, Val AUC: 0.6761
# Epoch 28/49, Loss: 0.6467, Val Loss: 0.6420, Val AUC: 0.6760
# Epoch 29/49, Loss: 0.6462, Val Loss: 0.6423, Val AUC: 0.6729
# Epoch 30/49, Loss: 0.6459, Val Loss: 0.6430, Val AUC: 0.6752
# Epoch 31/49, Loss: 0.6448, Val Loss: 0.6408, Val AUC: 0.6801
# Epoch 32/49, Loss: 0.6452, Val Loss: 0.6390, Val AUC: 0.6819
# Epoch 33/49, Loss: 0.6441, Val Loss: 0.6398, Val AUC: 0.6786
# Epoch 34/49, Loss: 0.6441, Val Loss: 0.6422, Val AUC: 0.6802
# Epoch 35/49, Loss: 0.6420, Val Loss: 0.6389, Val AUC: 0.6804
# Epoch 36/49, Loss: 0.6419, Val Loss: 0.6376, Val AUC: 0.6816
# Epoch 37/49, Loss: 0.6394, Val Loss: 0.6430, Val AUC: 0.6796
# Early stopping
# Ablating feature Mean Airway Pressure (6/10)
# Epoch 0/49, Loss: 0.6886, Val Loss: 0.6770, Val AUC: 0.6071
# Epoch 1/49, Loss: 0.6766, Val Loss: 0.6754, Val AUC: 0.6108
# Epoch 2/49, Loss: 0.6738, Val Loss: 0.6681, Val AUC: 0.6297
# Epoch 3/49, Loss: 0.6679, Val Loss: 0.6674, Val AUC: 0.6189
# Epoch 4/49, Loss: 0.6664, Val Loss: 0.6664, Val AUC: 0.6373
# Epoch 5/49, Loss: 0.6652, Val Loss: 0.6621, Val AUC: 0.6424
# Epoch 6/49, Loss: 0.6653, Val Loss: 0.6635, Val AUC: 0.6255
# Epoch 7/49, Loss: 0.6623, Val Loss: 0.6558, Val AUC: 0.6469
# Epoch 8/49, Loss: 0.6597, Val Loss: 0.6591, Val AUC: 0.6510
# Epoch 9/49, Loss: 0.6588, Val Loss: 0.6572, Val AUC: 0.6538
# Epoch 10/49, Loss: 0.6578, Val Loss: 0.6553, Val AUC: 0.6526
# Epoch 11/49, Loss: 0.6580, Val Loss: 0.6532, Val AUC: 0.6605
# Epoch 12/49, Loss: 0.6560, Val Loss: 0.6522, Val AUC: 0.6583
# Epoch 13/49, Loss: 0.6567, Val Loss: 0.6541, Val AUC: 0.6592
# Epoch 14/49, Loss: 0.6549, Val Loss: 0.6603, Val AUC: 0.6630
# Epoch 15/49, Loss: 0.6537, Val Loss: 0.6498, Val AUC: 0.6648
# Epoch 16/49, Loss: 0.6522, Val Loss: 0.6487, Val AUC: 0.6671
# Epoch 17/49, Loss: 0.6523, Val Loss: 0.6484, Val AUC: 0.6635
# Epoch 18/49, Loss: 0.6515, Val Loss: 0.6489, Val AUC: 0.6718
# Epoch 19/49, Loss: 0.6491, Val Loss: 0.6648, Val AUC: 0.6663
# Epoch 20/49, Loss: 0.6502, Val Loss: 0.6474, Val AUC: 0.6726
# Epoch 21/49, Loss: 0.6502, Val Loss: 0.6472, Val AUC: 0.6710
# Epoch 22/49, Loss: 0.6498, Val Loss: 0.6438, Val AUC: 0.6742
# Epoch 23/49, Loss: 0.6480, Val Loss: 0.6457, Val AUC: 0.6704
# Epoch 24/49, Loss: 0.6487, Val Loss: 0.6443, Val AUC: 0.6758
# Epoch 25/49, Loss: 0.6471, Val Loss: 0.6422, Val AUC: 0.6760
# Epoch 26/49, Loss: 0.6471, Val Loss: 0.6430, Val AUC: 0.6733
# Epoch 27/49, Loss: 0.6459, Val Loss: 0.6439, Val AUC: 0.6761
# Epoch 28/49, Loss: 0.6460, Val Loss: 0.6428, Val AUC: 0.6778
# Epoch 29/49, Loss: 0.6448, Val Loss: 0.6468, Val AUC: 0.6728
# Epoch 30/49, Loss: 0.6454, Val Loss: 0.6399, Val AUC: 0.6780
# Epoch 31/49, Loss: 0.6446, Val Loss: 0.6405, Val AUC: 0.6808
# Epoch 32/49, Loss: 0.6451, Val Loss: 0.6470, Val AUC: 0.6769
# Epoch 33/49, Loss: 0.6441, Val Loss: 0.6421, Val AUC: 0.6779
# Epoch 34/49, Loss: 0.6436, Val Loss: 0.6377, Val AUC: 0.6828
# Epoch 35/49, Loss: 0.6432, Val Loss: 0.6397, Val AUC: 0.6809
# Epoch 36/49, Loss: 0.6424, Val Loss: 0.6387, Val AUC: 0.6842
# Epoch 37/49, Loss: 0.6443, Val Loss: 0.6364, Val AUC: 0.6843
# Epoch 38/49, Loss: 0.6417, Val Loss: 0.6364, Val AUC: 0.6875
# Epoch 39/49, Loss: 0.6420, Val Loss: 0.6350, Val AUC: 0.6871
# Epoch 40/49, Loss: 0.6409, Val Loss: 0.6482, Val AUC: 0.6819
# Epoch 41/49, Loss: 0.6408, Val Loss: 0.6367, Val AUC: 0.6877
# Epoch 42/49, Loss: 0.6414, Val Loss: 0.6358, Val AUC: 0.6866
# Epoch 43/49, Loss: 0.6437, Val Loss: 0.6386, Val AUC: 0.6870
# Epoch 44/49, Loss: 0.6387, Val Loss: 0.6388, Val AUC: 0.6878
# Epoch 45/49, Loss: 0.6388, Val Loss: 0.6366, Val AUC: 0.6843
# Epoch 46/49, Loss: 0.6395, Val Loss: 0.6333, Val AUC: 0.6880
# Epoch 47/49, Loss: 0.6380, Val Loss: 0.6336, Val AUC: 0.6910
# Epoch 48/49, Loss: 0.6376, Val Loss: 0.6304, Val AUC: 0.6922
# Epoch 49/49, Loss: 0.6371, Val Loss: 0.6301, Val AUC: 0.6933
# Ablating feature Peak Insp. Pressure (7/10)
# Epoch 0/49, Loss: 0.6891, Val Loss: 0.6802, Val AUC: 0.6021
# Epoch 1/49, Loss: 0.6784, Val Loss: 0.6821, Val AUC: 0.6113
# Epoch 2/49, Loss: 0.6752, Val Loss: 0.6711, Val AUC: 0.6269
# Epoch 3/49, Loss: 0.6709, Val Loss: 0.6661, Val AUC: 0.6246
# Epoch 4/49, Loss: 0.6688, Val Loss: 0.6643, Val AUC: 0.6370
# Epoch 5/49, Loss: 0.6667, Val Loss: 0.6680, Val AUC: 0.6439
# Epoch 6/49, Loss: 0.6640, Val Loss: 0.6588, Val AUC: 0.6470
# Epoch 7/49, Loss: 0.6624, Val Loss: 0.6560, Val AUC: 0.6527
# Epoch 8/49, Loss: 0.6605, Val Loss: 0.6598, Val AUC: 0.6478
# Epoch 9/49, Loss: 0.6598, Val Loss: 0.6561, Val AUC: 0.6586
# Epoch 10/49, Loss: 0.6583, Val Loss: 0.6586, Val AUC: 0.6615
# Epoch 11/49, Loss: 0.6559, Val Loss: 0.6525, Val AUC: 0.6563
# Epoch 12/49, Loss: 0.6555, Val Loss: 0.6493, Val AUC: 0.6649
# Epoch 13/49, Loss: 0.6539, Val Loss: 0.6619, Val AUC: 0.6567
# Epoch 14/49, Loss: 0.6550, Val Loss: 0.6502, Val AUC: 0.6661
# Epoch 15/49, Loss: 0.6518, Val Loss: 0.6540, Val AUC: 0.6670
# Epoch 16/49, Loss: 0.6528, Val Loss: 0.6464, Val AUC: 0.6681
# Epoch 17/49, Loss: 0.6530, Val Loss: 0.6467, Val AUC: 0.6683
# Epoch 18/49, Loss: 0.6512, Val Loss: 0.6443, Val AUC: 0.6713
# Epoch 19/49, Loss: 0.6502, Val Loss: 0.6475, Val AUC: 0.6693
# Epoch 20/49, Loss: 0.6490, Val Loss: 0.6672, Val AUC: 0.6688
# Epoch 21/49, Loss: 0.6487, Val Loss: 0.6531, Val AUC: 0.6660
# Epoch 22/49, Loss: 0.6490, Val Loss: 0.6484, Val AUC: 0.6693
# Epoch 23/49, Loss: 0.6499, Val Loss: 0.6439, Val AUC: 0.6756
# Epoch 24/49, Loss: 0.6494, Val Loss: 0.6451, Val AUC: 0.6727
# Epoch 25/49, Loss: 0.6466, Val Loss: 0.6417, Val AUC: 0.6771
# Epoch 26/49, Loss: 0.6469, Val Loss: 0.6412, Val AUC: 0.6770
# Epoch 27/49, Loss: 0.6461, Val Loss: 0.6405, Val AUC: 0.6793
# Epoch 28/49, Loss: 0.6455, Val Loss: 0.6399, Val AUC: 0.6784
# Epoch 29/49, Loss: 0.6463, Val Loss: 0.6396, Val AUC: 0.6795
# Epoch 30/49, Loss: 0.6444, Val Loss: 0.6407, Val AUC: 0.6801
# Epoch 31/49, Loss: 0.6448, Val Loss: 0.6409, Val AUC: 0.6788
# Epoch 32/49, Loss: 0.6437, Val Loss: 0.6383, Val AUC: 0.6830
# Epoch 33/49, Loss: 0.6429, Val Loss: 0.6396, Val AUC: 0.6799
# Epoch 34/49, Loss: 0.6445, Val Loss: 0.6392, Val AUC: 0.6786
# Epoch 35/49, Loss: 0.6439, Val Loss: 0.6377, Val AUC: 0.6839
# Epoch 36/49, Loss: 0.6412, Val Loss: 0.6381, Val AUC: 0.6816
# Epoch 37/49, Loss: 0.6417, Val Loss: 0.6370, Val AUC: 0.6841
# Epoch 38/49, Loss: 0.6413, Val Loss: 0.6363, Val AUC: 0.6859
# Epoch 39/49, Loss: 0.6391, Val Loss: 0.6376, Val AUC: 0.6852
# Epoch 40/49, Loss: 0.6414, Val Loss: 0.6384, Val AUC: 0.6861
# Epoch 41/49, Loss: 0.6436, Val Loss: 0.6380, Val AUC: 0.6826
# Epoch 42/49, Loss: 0.6402, Val Loss: 0.6359, Val AUC: 0.6881
# Epoch 43/49, Loss: 0.6405, Val Loss: 0.6331, Val AUC: 0.6903
# Epoch 44/49, Loss: 0.6393, Val Loss: 0.6318, Val AUC: 0.6898
# Epoch 45/49, Loss: 0.6395, Val Loss: 0.6324, Val AUC: 0.6887
# Epoch 46/49, Loss: 0.6384, Val Loss: 0.6316, Val AUC: 0.6907
# Epoch 47/49, Loss: 0.6354, Val Loss: 0.6295, Val AUC: 0.6935
# Epoch 48/49, Loss: 0.6366, Val Loss: 0.6392, Val AUC: 0.6818
# Epoch 49/49, Loss: 0.6384, Val Loss: 0.6323, Val AUC: 0.6918
# Ablating feature Temperature Fahrenheit (8/10)
# Epoch 0/49, Loss: 0.6884, Val Loss: 0.6790, Val AUC: 0.6102
# Epoch 1/49, Loss: 0.6773, Val Loss: 0.6745, Val AUC: 0.6177
# Epoch 2/49, Loss: 0.6727, Val Loss: 0.6725, Val AUC: 0.6292
# Epoch 3/49, Loss: 0.6697, Val Loss: 0.6707, Val AUC: 0.6388
# Epoch 4/49, Loss: 0.6663, Val Loss: 0.6634, Val AUC: 0.6343
# Epoch 5/49, Loss: 0.6660, Val Loss: 0.6673, Val AUC: 0.6455
# Epoch 6/49, Loss: 0.6650, Val Loss: 0.6577, Val AUC: 0.6497
# Epoch 7/49, Loss: 0.6628, Val Loss: 0.6606, Val AUC: 0.6505
# Epoch 8/49, Loss: 0.6609, Val Loss: 0.6567, Val AUC: 0.6552
# Epoch 9/49, Loss: 0.6591, Val Loss: 0.6587, Val AUC: 0.6528
# Epoch 10/49, Loss: 0.6601, Val Loss: 0.6610, Val AUC: 0.6578
# Epoch 11/49, Loss: 0.6576, Val Loss: 0.6519, Val AUC: 0.6615
# Epoch 12/49, Loss: 0.6577, Val Loss: 0.6537, Val AUC: 0.6627
# Epoch 13/49, Loss: 0.6551, Val Loss: 0.6577, Val AUC: 0.6640
# Epoch 14/49, Loss: 0.6574, Val Loss: 0.6527, Val AUC: 0.6619
# Epoch 15/49, Loss: 0.6548, Val Loss: 0.6494, Val AUC: 0.6654
# Epoch 16/49, Loss: 0.6537, Val Loss: 0.6556, Val AUC: 0.6645
# Epoch 17/49, Loss: 0.6526, Val Loss: 0.6542, Val AUC: 0.6664
# Epoch 18/49, Loss: 0.6528, Val Loss: 0.6481, Val AUC: 0.6688
# Epoch 19/49, Loss: 0.6521, Val Loss: 0.6474, Val AUC: 0.6725
# Epoch 20/49, Loss: 0.6527, Val Loss: 0.6485, Val AUC: 0.6691
# Epoch 21/49, Loss: 0.6497, Val Loss: 0.6492, Val AUC: 0.6692
# Epoch 22/49, Loss: 0.6494, Val Loss: 0.6433, Val AUC: 0.6748
# Epoch 23/49, Loss: 0.6503, Val Loss: 0.6437, Val AUC: 0.6765
# Epoch 24/49, Loss: 0.6477, Val Loss: 0.6494, Val AUC: 0.6723
# Epoch 25/49, Loss: 0.6485, Val Loss: 0.6493, Val AUC: 0.6729
# Epoch 26/49, Loss: 0.6476, Val Loss: 0.6430, Val AUC: 0.6744
# Epoch 27/49, Loss: 0.6474, Val Loss: 0.6416, Val AUC: 0.6782
# Epoch 28/49, Loss: 0.6457, Val Loss: 0.6417, Val AUC: 0.6791
# Epoch 29/49, Loss: 0.6471, Val Loss: 0.6459, Val AUC: 0.6721
# Epoch 30/49, Loss: 0.6446, Val Loss: 0.6465, Val AUC: 0.6762
# Epoch 31/49, Loss: 0.6430, Val Loss: 0.6411, Val AUC: 0.6759
# Epoch 32/49, Loss: 0.6450, Val Loss: 0.6399, Val AUC: 0.6813
# Epoch 33/49, Loss: 0.6449, Val Loss: 0.6376, Val AUC: 0.6822
# Epoch 34/49, Loss: 0.6436, Val Loss: 0.6380, Val AUC: 0.6811
# Epoch 35/49, Loss: 0.6435, Val Loss: 0.6416, Val AUC: 0.6836
# Epoch 36/49, Loss: 0.6419, Val Loss: 0.6392, Val AUC: 0.6789
# Epoch 37/49, Loss: 0.6427, Val Loss: 0.6400, Val AUC: 0.6804
# Epoch 38/49, Loss: 0.6414, Val Loss: 0.6365, Val AUC: 0.6837
# Epoch 39/49, Loss: 0.6406, Val Loss: 0.6360, Val AUC: 0.6856
# Epoch 40/49, Loss: 0.6407, Val Loss: 0.6404, Val AUC: 0.6851
# Epoch 41/49, Loss: 0.6416, Val Loss: 0.6330, Val AUC: 0.6888
# Epoch 42/49, Loss: 0.6399, Val Loss: 0.6424, Val AUC: 0.6777
# Epoch 43/49, Loss: 0.6385, Val Loss: 0.6341, Val AUC: 0.6877
# Epoch 44/49, Loss: 0.6380, Val Loss: 0.6331, Val AUC: 0.6906
# Epoch 45/49, Loss: 0.6349, Val Loss: 0.6383, Val AUC: 0.6840
# Epoch 46/49, Loss: 0.6360, Val Loss: 0.6310, Val AUC: 0.6924
# Epoch 47/49, Loss: 0.6359, Val Loss: 0.6289, Val AUC: 0.6952
# Epoch 48/49, Loss: 0.6365, Val Loss: 0.6354, Val AUC: 0.6925
# Epoch 49/49, Loss: 0.6362, Val Loss: 0.6286, Val AUC: 0.6952
# Ablating feature Tidal Volume (spontaneous) (9/10)
# Epoch 0/49, Loss: 0.6895, Val Loss: 0.6816, Val AUC: 0.6060
# Epoch 1/49, Loss: 0.6803, Val Loss: 0.6751, Val AUC: 0.6199
# Epoch 2/49, Loss: 0.6746, Val Loss: 0.6763, Val AUC: 0.6262
# Epoch 3/49, Loss: 0.6723, Val Loss: 0.6653, Val AUC: 0.6336
# Epoch 4/49, Loss: 0.6692, Val Loss: 0.6615, Val AUC: 0.6431
# Epoch 5/49, Loss: 0.6671, Val Loss: 0.6608, Val AUC: 0.6454
# Epoch 6/49, Loss: 0.6626, Val Loss: 0.6597, Val AUC: 0.6476
# Epoch 7/49, Loss: 0.6617, Val Loss: 0.6600, Val AUC: 0.6524
# Epoch 8/49, Loss: 0.6611, Val Loss: 0.6562, Val AUC: 0.6577
# Epoch 9/49, Loss: 0.6582, Val Loss: 0.6605, Val AUC: 0.6528
# Epoch 10/49, Loss: 0.6583, Val Loss: 0.6518, Val AUC: 0.6603
# Epoch 11/49, Loss: 0.6568, Val Loss: 0.6521, Val AUC: 0.6585
# Epoch 12/49, Loss: 0.6575, Val Loss: 0.6584, Val AUC: 0.6535
# Epoch 13/49, Loss: 0.6562, Val Loss: 0.6538, Val AUC: 0.6580
# Epoch 14/49, Loss: 0.6562, Val Loss: 0.6521, Val AUC: 0.6641
# Epoch 15/49, Loss: 0.6546, Val Loss: 0.6511, Val AUC: 0.6626
# Epoch 16/49, Loss: 0.6537, Val Loss: 0.6486, Val AUC: 0.6674
# Epoch 17/49, Loss: 0.6538, Val Loss: 0.6478, Val AUC: 0.6662
# Epoch 18/49, Loss: 0.6530, Val Loss: 0.6479, Val AUC: 0.6668
# Epoch 19/49, Loss: 0.6535, Val Loss: 0.6479, Val AUC: 0.6691
# Epoch 20/49, Loss: 0.6509, Val Loss: 0.6480, Val AUC: 0.6693
# Epoch 21/49, Loss: 0.6523, Val Loss: 0.6470, Val AUC: 0.6711
# Epoch 22/49, Loss: 0.6516, Val Loss: 0.6482, Val AUC: 0.6706
# Epoch 23/49, Loss: 0.6501, Val Loss: 0.6445, Val AUC: 0.6712
# Epoch 24/49, Loss: 0.6508, Val Loss: 0.6502, Val AUC: 0.6666
# Epoch 25/49, Loss: 0.6515, Val Loss: 0.6456, Val AUC: 0.6742
# Epoch 26/49, Loss: 0.6489, Val Loss: 0.6453, Val AUC: 0.6709
# Epoch 27/49, Loss: 0.6492, Val Loss: 0.6471, Val AUC: 0.6687
# Epoch 28/49, Loss: 0.6477, Val Loss: 0.6448, Val AUC: 0.6748
# Epoch 29/49, Loss: 0.6487, Val Loss: 0.6420, Val AUC: 0.6746
# Epoch 30/49, Loss: 0.6467, Val Loss: 0.6429, Val AUC: 0.6741
# Epoch 31/49, Loss: 0.6489, Val Loss: 0.6453, Val AUC: 0.6779
# Epoch 32/49, Loss: 0.6460, Val Loss: 0.6447, Val AUC: 0.6724
# Epoch 33/49, Loss: 0.6457, Val Loss: 0.6415, Val AUC: 0.6786
# Epoch 34/49, Loss: 0.6442, Val Loss: 0.6434, Val AUC: 0.6752
# Epoch 35/49, Loss: 0.6447, Val Loss: 0.6413, Val AUC: 0.6829
# Epoch 36/49, Loss: 0.6443, Val Loss: 0.6405, Val AUC: 0.6796
# Epoch 37/49, Loss: 0.6446, Val Loss: 0.6442, Val AUC: 0.6781
# Epoch 38/49, Loss: 0.6439, Val Loss: 0.6400, Val AUC: 0.6823
# Epoch 39/49, Loss: 0.6454, Val Loss: 0.6409, Val AUC: 0.6830
# Epoch 40/49, Loss: 0.6424, Val Loss: 0.6416, Val AUC: 0.6840
# Epoch 41/49, Loss: 0.6422, Val Loss: 0.6367, Val AUC: 0.6837
# Epoch 42/49, Loss: 0.6421, Val Loss: 0.6423, Val AUC: 0.6815
# Epoch 43/49, Loss: 0.6418, Val Loss: 0.6367, Val AUC: 0.6856
# Epoch 44/49, Loss: 0.6393, Val Loss: 0.6348, Val AUC: 0.6876
# Epoch 45/49, Loss: 0.6412, Val Loss: 0.6353, Val AUC: 0.6865
# Epoch 46/49, Loss: 0.6407, Val Loss: 0.6376, Val AUC: 0.6891
# Epoch 47/49, Loss: 0.6393, Val Loss: 0.6372, Val AUC: 0.6862
# Epoch 48/49, Loss: 0.6387, Val Loss: 0.6363, Val AUC: 0.6857
# Epoch 49/49, Loss: 0.6392, Val Loss: 0.6332, Val AUC: 0.6927
# Ablating feature Richmond-RAS Scale (10/10)
# Epoch 0/49, Loss: 0.6886, Val Loss: 0.6767, Val AUC: 0.6031
# Epoch 1/49, Loss: 0.6764, Val Loss: 0.6706, Val AUC: 0.6209
# Epoch 2/49, Loss: 0.6710, Val Loss: 0.6680, Val AUC: 0.6224
# Epoch 3/49, Loss: 0.6693, Val Loss: 0.6639, Val AUC: 0.6305
# Epoch 4/49, Loss: 0.6669, Val Loss: 0.6605, Val AUC: 0.6390
# Epoch 5/49, Loss: 0.6652, Val Loss: 0.6616, Val AUC: 0.6415
# Epoch 6/49, Loss: 0.6631, Val Loss: 0.6577, Val AUC: 0.6402
# Epoch 7/49, Loss: 0.6626, Val Loss: 0.6612, Val AUC: 0.6443
# Epoch 8/49, Loss: 0.6611, Val Loss: 0.6553, Val AUC: 0.6527
# Epoch 9/49, Loss: 0.6565, Val Loss: 0.6540, Val AUC: 0.6537
# Epoch 10/49, Loss: 0.6588, Val Loss: 0.6562, Val AUC: 0.6589
# Epoch 11/49, Loss: 0.6577, Val Loss: 0.6537, Val AUC: 0.6609
# Epoch 12/49, Loss: 0.6550, Val Loss: 0.6547, Val AUC: 0.6585
# Epoch 13/49, Loss: 0.6542, Val Loss: 0.6491, Val AUC: 0.6623
# Epoch 14/49, Loss: 0.6549, Val Loss: 0.6562, Val AUC: 0.6663
# Epoch 15/49, Loss: 0.6542, Val Loss: 0.6489, Val AUC: 0.6667
# Epoch 16/49, Loss: 0.6521, Val Loss: 0.6500, Val AUC: 0.6661
# Epoch 17/49, Loss: 0.6511, Val Loss: 0.6571, Val AUC: 0.6697
# Epoch 18/49, Loss: 0.6508, Val Loss: 0.6450, Val AUC: 0.6723
# Epoch 19/49, Loss: 0.6502, Val Loss: 0.6476, Val AUC: 0.6715
# Epoch 20/49, Loss: 0.6492, Val Loss: 0.6433, Val AUC: 0.6721
# Epoch 21/49, Loss: 0.6495, Val Loss: 0.6462, Val AUC: 0.6702
# Epoch 22/49, Loss: 0.6485, Val Loss: 0.6455, Val AUC: 0.6690
# Epoch 23/49, Loss: 0.6490, Val Loss: 0.6453, Val AUC: 0.6715
# Early stopping
# Ablating feature Heart Rate (1/6)
# Epoch 0/49, Loss: 0.6875, Val Loss: 0.6778, Val AUC: 0.6053
# Epoch 1/49, Loss: 0.6771, Val Loss: 0.6726, Val AUC: 0.6114
# Epoch 2/49, Loss: 0.6760, Val Loss: 0.6702, Val AUC: 0.6180
# Epoch 3/49, Loss: 0.6705, Val Loss: 0.6677, Val AUC: 0.6294
# Epoch 4/49, Loss: 0.6658, Val Loss: 0.6632, Val AUC: 0.6383
# Epoch 5/49, Loss: 0.6650, Val Loss: 0.6618, Val AUC: 0.6400
# Epoch 6/49, Loss: 0.6638, Val Loss: 0.6567, Val AUC: 0.6438
# Epoch 7/49, Loss: 0.6620, Val Loss: 0.6653, Val AUC: 0.6385
# Epoch 8/49, Loss: 0.6599, Val Loss: 0.6556, Val AUC: 0.6460
# Epoch 9/49, Loss: 0.6606, Val Loss: 0.6545, Val AUC: 0.6505
# Epoch 10/49, Loss: 0.6584, Val Loss: 0.6573, Val AUC: 0.6551
# Epoch 11/49, Loss: 0.6563, Val Loss: 0.6531, Val AUC: 0.6581
# Epoch 12/49, Loss: 0.6557, Val Loss: 0.6525, Val AUC: 0.6531
# Epoch 13/49, Loss: 0.6557, Val Loss: 0.6513, Val AUC: 0.6585
# Epoch 14/49, Loss: 0.6548, Val Loss: 0.6506, Val AUC: 0.6625
# Epoch 15/49, Loss: 0.6551, Val Loss: 0.6484, Val AUC: 0.6643
# Epoch 16/49, Loss: 0.6543, Val Loss: 0.6504, Val AUC: 0.6667
# Epoch 17/49, Loss: 0.6530, Val Loss: 0.6466, Val AUC: 0.6683
# Epoch 18/49, Loss: 0.6513, Val Loss: 0.6523, Val AUC: 0.6606
# Epoch 19/49, Loss: 0.6516, Val Loss: 0.6558, Val AUC: 0.6657
# Epoch 20/49, Loss: 0.6517, Val Loss: 0.6470, Val AUC: 0.6703
# Epoch 21/49, Loss: 0.6485, Val Loss: 0.6450, Val AUC: 0.6710
# Epoch 22/49, Loss: 0.6476, Val Loss: 0.6525, Val AUC: 0.6732
# Epoch 23/49, Loss: 0.6490, Val Loss: 0.6469, Val AUC: 0.6735
# Epoch 24/49, Loss: 0.6497, Val Loss: 0.6491, Val AUC: 0.6724
# Epoch 25/49, Loss: 0.6489, Val Loss: 0.6463, Val AUC: 0.6685
# Epoch 26/49, Loss: 0.6476, Val Loss: 0.6471, Val AUC: 0.6753
# Epoch 27/49, Loss: 0.6484, Val Loss: 0.6424, Val AUC: 0.6725
# Epoch 28/49, Loss: 0.6487, Val Loss: 0.6443, Val AUC: 0.6749
# Epoch 29/49, Loss: 0.6470, Val Loss: 0.6435, Val AUC: 0.6766
# Epoch 30/49, Loss: 0.6464, Val Loss: 0.6394, Val AUC: 0.6780
# Epoch 31/49, Loss: 0.6457, Val Loss: 0.6450, Val AUC: 0.6780
# Epoch 32/49, Loss: 0.6458, Val Loss: 0.6449, Val AUC: 0.6723
# Epoch 33/49, Loss: 0.6447, Val Loss: 0.6387, Val AUC: 0.6785
# Epoch 34/49, Loss: 0.6445, Val Loss: 0.6378, Val AUC: 0.6799
# Epoch 35/49, Loss: 0.6446, Val Loss: 0.6391, Val AUC: 0.6789
# Epoch 36/49, Loss: 0.6438, Val Loss: 0.6404, Val AUC: 0.6807
# Epoch 37/49, Loss: 0.6420, Val Loss: 0.6396, Val AUC: 0.6807
# Epoch 38/49, Loss: 0.6406, Val Loss: 0.6381, Val AUC: 0.6835
# Epoch 39/49, Loss: 0.6416, Val Loss: 0.6364, Val AUC: 0.6862
# Epoch 40/49, Loss: 0.6401, Val Loss: 0.6363, Val AUC: 0.6815
# Epoch 41/49, Loss: 0.6392, Val Loss: 0.6373, Val AUC: 0.6839
# Epoch 42/49, Loss: 0.6410, Val Loss: 0.6339, Val AUC: 0.6882
# Epoch 43/49, Loss: 0.6381, Val Loss: 0.6357, Val AUC: 0.6824
# Epoch 44/49, Loss: 0.6376, Val Loss: 0.6346, Val AUC: 0.6909
# Epoch 45/49, Loss: 0.6382, Val Loss: 0.6327, Val AUC: 0.6876
# Epoch 46/49, Loss: 0.6376, Val Loss: 0.6320, Val AUC: 0.6873
# Epoch 47/49, Loss: 0.6366, Val Loss: 0.6292, Val AUC: 0.6912
# Epoch 48/49, Loss: 0.6374, Val Loss: 0.6347, Val AUC: 0.6907
# Epoch 49/49, Loss: 0.6351, Val Loss: 0.6348, Val AUC: 0.6852
# Ablating feature O2 saturation pulseoxymetry (2/6)
# Epoch 0/49, Loss: 0.6870, Val Loss: 0.6763, Val AUC: 0.6062
# Epoch 1/49, Loss: 0.6783, Val Loss: 0.6733, Val AUC: 0.6127
# Epoch 2/49, Loss: 0.6730, Val Loss: 0.6677, Val AUC: 0.6264
# Epoch 3/49, Loss: 0.6695, Val Loss: 0.6647, Val AUC: 0.6295
# Epoch 4/49, Loss: 0.6662, Val Loss: 0.6708, Val AUC: 0.6313
# Epoch 5/49, Loss: 0.6671, Val Loss: 0.6705, Val AUC: 0.6386
# Epoch 6/49, Loss: 0.6641, Val Loss: 0.6587, Val AUC: 0.6453
# Epoch 7/49, Loss: 0.6631, Val Loss: 0.6567, Val AUC: 0.6491
# Epoch 8/49, Loss: 0.6594, Val Loss: 0.6580, Val AUC: 0.6500
# Epoch 9/49, Loss: 0.6605, Val Loss: 0.6532, Val AUC: 0.6547
# Epoch 10/49, Loss: 0.6581, Val Loss: 0.6525, Val AUC: 0.6587
# Epoch 11/49, Loss: 0.6563, Val Loss: 0.6566, Val AUC: 0.6557
# Epoch 12/49, Loss: 0.6552, Val Loss: 0.6588, Val AUC: 0.6605
# Epoch 13/49, Loss: 0.6541, Val Loss: 0.6491, Val AUC: 0.6635
# Epoch 14/49, Loss: 0.6535, Val Loss: 0.6509, Val AUC: 0.6656
# Epoch 15/49, Loss: 0.6533, Val Loss: 0.6563, Val AUC: 0.6625
# Epoch 16/49, Loss: 0.6538, Val Loss: 0.6511, Val AUC: 0.6577
# Epoch 17/49, Loss: 0.6506, Val Loss: 0.6466, Val AUC: 0.6655
# Epoch 18/49, Loss: 0.6509, Val Loss: 0.6475, Val AUC: 0.6697
# Epoch 19/49, Loss: 0.6519, Val Loss: 0.6527, Val AUC: 0.6701
# Epoch 20/49, Loss: 0.6514, Val Loss: 0.6442, Val AUC: 0.6698
# Epoch 21/49, Loss: 0.6486, Val Loss: 0.6441, Val AUC: 0.6720
# Epoch 22/49, Loss: 0.6497, Val Loss: 0.6454, Val AUC: 0.6693
# Epoch 23/49, Loss: 0.6492, Val Loss: 0.6509, Val AUC: 0.6694
# Epoch 24/49, Loss: 0.6478, Val Loss: 0.6432, Val AUC: 0.6737
# Epoch 25/49, Loss: 0.6481, Val Loss: 0.6459, Val AUC: 0.6731
# Epoch 26/49, Loss: 0.6483, Val Loss: 0.6430, Val AUC: 0.6752
# Epoch 27/49, Loss: 0.6476, Val Loss: 0.6408, Val AUC: 0.6759
# Epoch 28/49, Loss: 0.6468, Val Loss: 0.6424, Val AUC: 0.6787
# Epoch 29/49, Loss: 0.6470, Val Loss: 0.6414, Val AUC: 0.6757
# Epoch 30/49, Loss: 0.6488, Val Loss: 0.6423, Val AUC: 0.6782
# Epoch 31/49, Loss: 0.6452, Val Loss: 0.6425, Val AUC: 0.6768
# Epoch 32/49, Loss: 0.6442, Val Loss: 0.6424, Val AUC: 0.6808
# Epoch 33/49, Loss: 0.6440, Val Loss: 0.6417, Val AUC: 0.6780
# Epoch 34/49, Loss: 0.6444, Val Loss: 0.6404, Val AUC: 0.6762
# Epoch 35/49, Loss: 0.6440, Val Loss: 0.6393, Val AUC: 0.6827
# Epoch 36/49, Loss: 0.6432, Val Loss: 0.6393, Val AUC: 0.6778
# Epoch 37/49, Loss: 0.6439, Val Loss: 0.6390, Val AUC: 0.6819
# Epoch 38/49, Loss: 0.6424, Val Loss: 0.6441, Val AUC: 0.6740
# Epoch 39/49, Loss: 0.6431, Val Loss: 0.6381, Val AUC: 0.6845
# Epoch 40/49, Loss: 0.6404, Val Loss: 0.6368, Val AUC: 0.6852
# Epoch 41/49, Loss: 0.6431, Val Loss: 0.6357, Val AUC: 0.6886
# Epoch 42/49, Loss: 0.6395, Val Loss: 0.6355, Val AUC: 0.6872
# Epoch 43/49, Loss: 0.6406, Val Loss: 0.6331, Val AUC: 0.6872
# Epoch 44/49, Loss: 0.6412, Val Loss: 0.6340, Val AUC: 0.6892
# Epoch 45/49, Loss: 0.6386, Val Loss: 0.6338, Val AUC: 0.6884
# Epoch 46/49, Loss: 0.6391, Val Loss: 0.6315, Val AUC: 0.6902
# Epoch 47/49, Loss: 0.6384, Val Loss: 0.6363, Val AUC: 0.6877
# Epoch 48/49, Loss: 0.6382, Val Loss: 0.6316, Val AUC: 0.6920
# Epoch 49/49, Loss: 0.6366, Val Loss: 0.6365, Val AUC: 0.6851
# Ablating feature Respiratory Rate (3/6)
# Epoch 0/49, Loss: 0.6899, Val Loss: 0.6790, Val AUC: 0.6027
# Epoch 1/49, Loss: 0.6781, Val Loss: 0.6730, Val AUC: 0.6121
# Epoch 2/49, Loss: 0.6742, Val Loss: 0.6709, Val AUC: 0.6130
# Epoch 3/49, Loss: 0.6727, Val Loss: 0.6694, Val AUC: 0.6216
# Epoch 4/49, Loss: 0.6714, Val Loss: 0.6696, Val AUC: 0.6216
# Epoch 5/49, Loss: 0.6702, Val Loss: 0.6748, Val AUC: 0.6208
# Epoch 6/49, Loss: 0.6701, Val Loss: 0.6718, Val AUC: 0.6340
# Epoch 7/49, Loss: 0.6673, Val Loss: 0.6648, Val AUC: 0.6314
# Epoch 8/49, Loss: 0.6653, Val Loss: 0.6601, Val AUC: 0.6433
# Epoch 9/49, Loss: 0.6641, Val Loss: 0.6602, Val AUC: 0.6450
# Epoch 10/49, Loss: 0.6619, Val Loss: 0.6572, Val AUC: 0.6534
# Epoch 11/49, Loss: 0.6610, Val Loss: 0.6618, Val AUC: 0.6482
# Epoch 12/49, Loss: 0.6621, Val Loss: 0.6556, Val AUC: 0.6536
# Epoch 13/49, Loss: 0.6574, Val Loss: 0.6561, Val AUC: 0.6512
# Epoch 14/49, Loss: 0.6576, Val Loss: 0.6540, Val AUC: 0.6592
# Epoch 15/49, Loss: 0.6551, Val Loss: 0.6529, Val AUC: 0.6604
# Epoch 16/49, Loss: 0.6549, Val Loss: 0.6537, Val AUC: 0.6604
# Epoch 17/49, Loss: 0.6543, Val Loss: 0.6515, Val AUC: 0.6624
# Epoch 18/49, Loss: 0.6534, Val Loss: 0.6498, Val AUC: 0.6650
# Epoch 19/49, Loss: 0.6537, Val Loss: 0.6499, Val AUC: 0.6646
# Epoch 20/49, Loss: 0.6529, Val Loss: 0.6541, Val AUC: 0.6573
# Epoch 21/49, Loss: 0.6519, Val Loss: 0.6500, Val AUC: 0.6677
# Epoch 22/49, Loss: 0.6506, Val Loss: 0.6497, Val AUC: 0.6610
# Epoch 23/49, Loss: 0.6524, Val Loss: 0.6461, Val AUC: 0.6682
# Epoch 24/49, Loss: 0.6511, Val Loss: 0.6477, Val AUC: 0.6694
# Epoch 25/49, Loss: 0.6505, Val Loss: 0.6455, Val AUC: 0.6667
# Epoch 26/49, Loss: 0.6505, Val Loss: 0.6444, Val AUC: 0.6725
# Epoch 27/49, Loss: 0.6486, Val Loss: 0.6436, Val AUC: 0.6715
# Epoch 28/49, Loss: 0.6469, Val Loss: 0.6457, Val AUC: 0.6678
# Epoch 29/49, Loss: 0.6478, Val Loss: 0.6522, Val AUC: 0.6722
# Epoch 30/49, Loss: 0.6492, Val Loss: 0.6516, Val AUC: 0.6714
# Epoch 31/49, Loss: 0.6482, Val Loss: 0.6423, Val AUC: 0.6706
# Early stopping
# Ablating feature Arterial Blood Pressure mean (4/6)
# Epoch 0/49, Loss: 0.6878, Val Loss: 0.6775, Val AUC: 0.6085
# Epoch 1/49, Loss: 0.6765, Val Loss: 0.6721, Val AUC: 0.6215
# Epoch 2/49, Loss: 0.6727, Val Loss: 0.6699, Val AUC: 0.6294
# Epoch 3/49, Loss: 0.6694, Val Loss: 0.6629, Val AUC: 0.6355
# Epoch 4/49, Loss: 0.6681, Val Loss: 0.6631, Val AUC: 0.6363
# Epoch 5/49, Loss: 0.6646, Val Loss: 0.6602, Val AUC: 0.6421
# Epoch 6/49, Loss: 0.6630, Val Loss: 0.6570, Val AUC: 0.6488
# Epoch 7/49, Loss: 0.6615, Val Loss: 0.6597, Val AUC: 0.6454
# Epoch 8/49, Loss: 0.6606, Val Loss: 0.6586, Val AUC: 0.6582
# Epoch 9/49, Loss: 0.6590, Val Loss: 0.6539, Val AUC: 0.6548
# Epoch 10/49, Loss: 0.6578, Val Loss: 0.6521, Val AUC: 0.6586
# Epoch 11/49, Loss: 0.6559, Val Loss: 0.6502, Val AUC: 0.6612
# Epoch 12/49, Loss: 0.6562, Val Loss: 0.6525, Val AUC: 0.6635
# Epoch 13/49, Loss: 0.6562, Val Loss: 0.6495, Val AUC: 0.6646
# Epoch 14/49, Loss: 0.6550, Val Loss: 0.6493, Val AUC: 0.6641
# Epoch 15/49, Loss: 0.6539, Val Loss: 0.6498, Val AUC: 0.6674
# Epoch 16/49, Loss: 0.6526, Val Loss: 0.6505, Val AUC: 0.6598
# Epoch 17/49, Loss: 0.6527, Val Loss: 0.6479, Val AUC: 0.6690
# Epoch 18/49, Loss: 0.6515, Val Loss: 0.6451, Val AUC: 0.6701
# Epoch 19/49, Loss: 0.6498, Val Loss: 0.6530, Val AUC: 0.6667
# Epoch 20/49, Loss: 0.6530, Val Loss: 0.6459, Val AUC: 0.6714
# Epoch 21/49, Loss: 0.6505, Val Loss: 0.6533, Val AUC: 0.6734
# Epoch 22/49, Loss: 0.6490, Val Loss: 0.6431, Val AUC: 0.6724
# Epoch 23/49, Loss: 0.6465, Val Loss: 0.6421, Val AUC: 0.6743
# Epoch 24/49, Loss: 0.6479, Val Loss: 0.6453, Val AUC: 0.6776
# Epoch 25/49, Loss: 0.6463, Val Loss: 0.6451, Val AUC: 0.6732
# Epoch 26/49, Loss: 0.6461, Val Loss: 0.6412, Val AUC: 0.6805
# Epoch 27/49, Loss: 0.6461, Val Loss: 0.6416, Val AUC: 0.6770
# Epoch 28/49, Loss: 0.6459, Val Loss: 0.6401, Val AUC: 0.6808
# Epoch 29/49, Loss: 0.6442, Val Loss: 0.6385, Val AUC: 0.6833
# Epoch 30/49, Loss: 0.6450, Val Loss: 0.6423, Val AUC: 0.6774
# Epoch 31/49, Loss: 0.6438, Val Loss: 0.6374, Val AUC: 0.6814
# Epoch 32/49, Loss: 0.6432, Val Loss: 0.6383, Val AUC: 0.6837
# Epoch 33/49, Loss: 0.6421, Val Loss: 0.6426, Val AUC: 0.6827
# Epoch 34/49, Loss: 0.6427, Val Loss: 0.6410, Val AUC: 0.6826
# Epoch 35/49, Loss: 0.6412, Val Loss: 0.6441, Val AUC: 0.6771
# Epoch 36/49, Loss: 0.6426, Val Loss: 0.6362, Val AUC: 0.6858
# Epoch 37/49, Loss: 0.6439, Val Loss: 0.6350, Val AUC: 0.6864
# Epoch 38/49, Loss: 0.6416, Val Loss: 0.6347, Val AUC: 0.6853
# Epoch 39/49, Loss: 0.6407, Val Loss: 0.6388, Val AUC: 0.6836
# Epoch 40/49, Loss: 0.6396, Val Loss: 0.6413, Val AUC: 0.6838
# Epoch 41/49, Loss: 0.6404, Val Loss: 0.6377, Val AUC: 0.6898
# Epoch 42/49, Loss: 0.6400, Val Loss: 0.6334, Val AUC: 0.6895
# Epoch 43/49, Loss: 0.6384, Val Loss: 0.6301, Val AUC: 0.6923
# Epoch 44/49, Loss: 0.6396, Val Loss: 0.6368, Val AUC: 0.6883
# Epoch 45/49, Loss: 0.6356, Val Loss: 0.6331, Val AUC: 0.6863
# Epoch 46/49, Loss: 0.6396, Val Loss: 0.6319, Val AUC: 0.6926
# Epoch 47/49, Loss: 0.6372, Val Loss: 0.6322, Val AUC: 0.6900
# Epoch 48/49, Loss: 0.6360, Val Loss: 0.6285, Val AUC: 0.6944
# Epoch 49/49, Loss: 0.6362, Val Loss: 0.6321, Val AUC: 0.6911
# Ablating feature Arterial Blood Pressure diastolic (5/6)
# Epoch 0/49, Loss: 0.6887, Val Loss: 0.6771, Val AUC: 0.6103
# Epoch 1/49, Loss: 0.6746, Val Loss: 0.6784, Val AUC: 0.6213
# Epoch 2/49, Loss: 0.6729, Val Loss: 0.6718, Val AUC: 0.6254
# Epoch 3/49, Loss: 0.6715, Val Loss: 0.6681, Val AUC: 0.6204
# Epoch 4/49, Loss: 0.6693, Val Loss: 0.6671, Val AUC: 0.6351
# Epoch 5/49, Loss: 0.6672, Val Loss: 0.6636, Val AUC: 0.6400
# Epoch 6/49, Loss: 0.6659, Val Loss: 0.6607, Val AUC: 0.6388
# Epoch 7/49, Loss: 0.6639, Val Loss: 0.6583, Val AUC: 0.6481
# Epoch 8/49, Loss: 0.6624, Val Loss: 0.6596, Val AUC: 0.6439
# Epoch 9/49, Loss: 0.6602, Val Loss: 0.6544, Val AUC: 0.6547
# Epoch 10/49, Loss: 0.6593, Val Loss: 0.6581, Val AUC: 0.6503
# Epoch 11/49, Loss: 0.6595, Val Loss: 0.6519, Val AUC: 0.6566
# Epoch 12/49, Loss: 0.6563, Val Loss: 0.6518, Val AUC: 0.6547
# Epoch 13/49, Loss: 0.6562, Val Loss: 0.6533, Val AUC: 0.6584
# Epoch 14/49, Loss: 0.6535, Val Loss: 0.6515, Val AUC: 0.6581
# Epoch 15/49, Loss: 0.6534, Val Loss: 0.6489, Val AUC: 0.6627
# Epoch 16/49, Loss: 0.6530, Val Loss: 0.6543, Val AUC: 0.6654
# Epoch 17/49, Loss: 0.6530, Val Loss: 0.6497, Val AUC: 0.6611
# Epoch 18/49, Loss: 0.6518, Val Loss: 0.6530, Val AUC: 0.6671
# Epoch 19/49, Loss: 0.6524, Val Loss: 0.6477, Val AUC: 0.6662
# Epoch 20/49, Loss: 0.6506, Val Loss: 0.6521, Val AUC: 0.6650
# Epoch 21/49, Loss: 0.6500, Val Loss: 0.6453, Val AUC: 0.6695
# Epoch 22/49, Loss: 0.6498, Val Loss: 0.6446, Val AUC: 0.6718
# Epoch 23/49, Loss: 0.6493, Val Loss: 0.6459, Val AUC: 0.6679
# Epoch 24/49, Loss: 0.6502, Val Loss: 0.6466, Val AUC: 0.6714
# Epoch 25/49, Loss: 0.6496, Val Loss: 0.6502, Val AUC: 0.6736
# Epoch 26/49, Loss: 0.6488, Val Loss: 0.6524, Val AUC: 0.6725
# Epoch 27/49, Loss: 0.6498, Val Loss: 0.6447, Val AUC: 0.6704
# Epoch 28/49, Loss: 0.6481, Val Loss: 0.6408, Val AUC: 0.6771
# Epoch 29/49, Loss: 0.6488, Val Loss: 0.6438, Val AUC: 0.6727
# Epoch 30/49, Loss: 0.6464, Val Loss: 0.6409, Val AUC: 0.6757
# Epoch 31/49, Loss: 0.6464, Val Loss: 0.6412, Val AUC: 0.6773
# Epoch 32/49, Loss: 0.6461, Val Loss: 0.6428, Val AUC: 0.6805
# Epoch 33/49, Loss: 0.6439, Val Loss: 0.6408, Val AUC: 0.6777
# Epoch 34/49, Loss: 0.6442, Val Loss: 0.6448, Val AUC: 0.6763
# Epoch 35/49, Loss: 0.6451, Val Loss: 0.6369, Val AUC: 0.6820
# Epoch 36/49, Loss: 0.6448, Val Loss: 0.6372, Val AUC: 0.6810
# Epoch 37/49, Loss: 0.6416, Val Loss: 0.6365, Val AUC: 0.6833
# Epoch 38/49, Loss: 0.6403, Val Loss: 0.6397, Val AUC: 0.6832
# Epoch 39/49, Loss: 0.6407, Val Loss: 0.6351, Val AUC: 0.6895
# Epoch 40/49, Loss: 0.6408, Val Loss: 0.6348, Val AUC: 0.6850
# Epoch 41/49, Loss: 0.6427, Val Loss: 0.6374, Val AUC: 0.6831
# Epoch 42/49, Loss: 0.6397, Val Loss: 0.6368, Val AUC: 0.6848
# Epoch 43/49, Loss: 0.6372, Val Loss: 0.6361, Val AUC: 0.6814
# Epoch 44/49, Loss: 0.6398, Val Loss: 0.6330, Val AUC: 0.6878
# Early stopping
# Ablating feature Arterial Blood Pressure systolic (6/6)
# Epoch 0/49, Loss: 0.6878, Val Loss: 0.6801, Val AUC: 0.6051
# Epoch 1/49, Loss: 0.6752, Val Loss: 0.6708, Val AUC: 0.6168
# Epoch 2/49, Loss: 0.6698, Val Loss: 0.6660, Val AUC: 0.6340
# Epoch 3/49, Loss: 0.6670, Val Loss: 0.6924, Val AUC: 0.6349
# Epoch 4/49, Loss: 0.6679, Val Loss: 0.6647, Val AUC: 0.6412
# Epoch 5/49, Loss: 0.6648, Val Loss: 0.6617, Val AUC: 0.6472
# Epoch 6/49, Loss: 0.6627, Val Loss: 0.6580, Val AUC: 0.6470
# Epoch 7/49, Loss: 0.6623, Val Loss: 0.6555, Val AUC: 0.6537
# Epoch 8/49, Loss: 0.6595, Val Loss: 0.6541, Val AUC: 0.6502
# Epoch 9/49, Loss: 0.6584, Val Loss: 0.6573, Val AUC: 0.6551
# Epoch 10/49, Loss: 0.6573, Val Loss: 0.6508, Val AUC: 0.6581
# Epoch 11/49, Loss: 0.6547, Val Loss: 0.6516, Val AUC: 0.6606
# Epoch 12/49, Loss: 0.6534, Val Loss: 0.6530, Val AUC: 0.6571
# Epoch 13/49, Loss: 0.6554, Val Loss: 0.6539, Val AUC: 0.6611
# Epoch 14/49, Loss: 0.6550, Val Loss: 0.6560, Val AUC: 0.6652
# Epoch 15/49, Loss: 0.6541, Val Loss: 0.6579, Val AUC: 0.6655
# Epoch 16/49, Loss: 0.6564, Val Loss: 0.6478, Val AUC: 0.6691
# Epoch 17/49, Loss: 0.6515, Val Loss: 0.6485, Val AUC: 0.6666
# Epoch 18/49, Loss: 0.6528, Val Loss: 0.6516, Val AUC: 0.6684
# Epoch 19/49, Loss: 0.6514, Val Loss: 0.6456, Val AUC: 0.6702
# Epoch 20/49, Loss: 0.6502, Val Loss: 0.6446, Val AUC: 0.6720
# Epoch 21/49, Loss: 0.6507, Val Loss: 0.6506, Val AUC: 0.6703
# Epoch 22/49, Loss: 0.6489, Val Loss: 0.6469, Val AUC: 0.6695
# Epoch 23/49, Loss: 0.6476, Val Loss: 0.6449, Val AUC: 0.6704
# Epoch 24/49, Loss: 0.6483, Val Loss: 0.6437, Val AUC: 0.6726
# Epoch 25/49, Loss: 0.6467, Val Loss: 0.6410, Val AUC: 0.6775
# Epoch 26/49, Loss: 0.6460, Val Loss: 0.6451, Val AUC: 0.6806
# Epoch 27/49, Loss: 0.6453, Val Loss: 0.6421, Val AUC: 0.6792
# Epoch 28/49, Loss: 0.6443, Val Loss: 0.6429, Val AUC: 0.6804
# Epoch 29/49, Loss: 0.6445, Val Loss: 0.6456, Val AUC: 0.6677
# Epoch 30/49, Loss: 0.6508, Val Loss: 0.6492, Val AUC: 0.6651
# Epoch 31/49, Loss: 0.6451, Val Loss: 0.6392, Val AUC: 0.6813
# Epoch 32/49, Loss: 0.6437, Val Loss: 0.6422, Val AUC: 0.6833
# Epoch 33/49, Loss: 0.6418, Val Loss: 0.6388, Val AUC: 0.6817
# Epoch 34/49, Loss: 0.6444, Val Loss: 0.6499, Val AUC: 0.6781
# Epoch 35/49, Loss: 0.6421, Val Loss: 0.6364, Val AUC: 0.6847
# Epoch 36/49, Loss: 0.6416, Val Loss: 0.6361, Val AUC: 0.6869
# Epoch 37/49, Loss: 0.6406, Val Loss: 0.6383, Val AUC: 0.6844
# Epoch 38/49, Loss: 0.6405, Val Loss: 0.6369, Val AUC: 0.6863
# Epoch 39/49, Loss: 0.6403, Val Loss: 0.6342, Val AUC: 0.6898
# Epoch 40/49, Loss: 0.6396, Val Loss: 0.6360, Val AUC: 0.6878
# Epoch 41/49, Loss: 0.6402, Val Loss: 0.6335, Val AUC: 0.6868
# Epoch 42/49, Loss: 0.6386, Val Loss: 0.6363, Val AUC: 0.6850
# Epoch 43/49, Loss: 0.6394, Val Loss: 0.6326, Val AUC: 0.6902
# Epoch 44/49, Loss: 0.6384, Val Loss: 0.6328, Val AUC: 0.6877
# Epoch 45/49, Loss: 0.6369, Val Loss: 0.6343, Val AUC: 0.6915
# Epoch 46/49, Loss: 0.6371, Val Loss: 0.6323, Val AUC: 0.6931
# Epoch 47/49, Loss: 0.6368, Val Loss: 0.6406, Val AUC: 0.6814
# Epoch 48/49, Loss: 0.6355, Val Loss: 0.6318, Val AUC: 0.6939
# Epoch 49/49, Loss: 0.6359, Val Loss: 0.6334, Val AUC: 0.6939

# %% [markdown]
# ![image.png](data:image/png;base64,...)
